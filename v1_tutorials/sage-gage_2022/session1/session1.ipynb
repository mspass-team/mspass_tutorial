# %% [markdown]
# # MsPASS Short Course:  SAGE-GAGE 2022
# ## Session 1:   Overview
# The purpose of this notebook is to provide a overview of the main features of MsPASS.  It should
# also reinforce key concepts we addressed in the preceding lecture.
# The notebook will lead you through the following steps:
#
# 1.  We will assemble a small, working data set.  It will be built from miniseed data we previously
#     downloaded with the obspy FDSN waveform web service.   Each of you will download your own copy
#     of source and receiver metadata and see how we load these into the database and produce
#     cross-references to the waveform data.
# 2.  We will run a set of common, simple processing steps.  These are a mix of database operations to
#     associate the right source and receiver metadata with each waveform and some lightweight waveform
#     manipulation to window data around a theoretical P time and bundle the data into three-component
#     data objects.
# 3.  We illustrate how easy it is to translate a serial workflow to a parallel workflow.  That will
#     provide the background for the following section that is focused completely on parallel processing.
#
# This notebook can be run after the workshop on a local machine with the package called docker installed.
# For the workshop we will be running this notebook on stampede2 at TACC where we will use singularity
# instead of docker.
#
# ## Preprocessing:  assembling a working data set for this session
# ### Source selection
# We are going to be working with the reflection seismology equivalent of a shot gather.
# For this session we will be working with a single magnitude 7.0 aftershock of the 2012
# Tohoku earthquake recorded by the USArray.
#
# The first step is to pull the detailed source information and save it our database.

# %%
from obspy import UTCDateTime
from obspy.clients.fdsn import Client
client=Client("IRIS")
t0=UTCDateTime('2011-04-07T14:32:44.100000Z')
starttime=t0-3600.0
endtime=t0+3600.0
lat0=38.3
lon0=142.5
minlat=lat0-3.0
maxlat=lat0+3.0
minlon=lon0-3.0
maxlon=lon0+3.0
minmag=6.5

cat=client.get_events(starttime=starttime,endtime=endtime,
        minlatitude=minlat,minlongitude=minlon,
        maxlatitude=maxlat,maxlongitude=maxlon,
        minmagnitude=minmag)
print(cat)
# Out:
# 1 Event(s) in Catalog:
# 2011-04-07T14:32:44.100000Z | +38.251, +141.730 | 7.1 MW

# %% [markdown]
# Note the above is a pure obspy python script.   They define a *Catalog* object they use to store event information.  A *Catalog* is more or less an image of the quakeml format data delivered by FDSN web service calls that the IRIS DMC just responded to when you ran that box.  The next box makes the first use of a MsPASS.  This short script saves the *Catalog* we just created into the MsPASS database system (based on MongoDB):

# %%
#from mspasspy.db.client import DBClient
#from mspasspy.db.database import Database
#dbclient = DBClient()
#db = Database(dbclient,"sagegage_2022")
# new form does not work
from mspasspy.client import Client
mp_client = Client()
db = mp_client.get_database('sagegage_2022')

# %%
n=db.save_catalog(cat)
print('number of event entries saved in source collection=',n)
# Out:
# number of event entries saved in source collection= 1

# %% [markdown]
# #### Select stations and download station metadata
# We now need to do parallel procedure to retrieve any relevant station information.  For this exercise we are going to use only data from the USArray "TA" stations, which have the SEED net code "TA".   As with sources we use obspy's web service client, but in this case we retrieve station data:

# %%
inv=client.get_stations(network='TA',starttime=starttime,endtime=endtime,
                        format='xml',channel='BH?',level='response')
net=inv.networks
x=net[0]
sta=x.stations
print("Number of stations retrieved=",len(sta))
#print(inv)
# Out:
# Number of stations retrieved= 433

# %% [markdown]
# Similar to the source data, obspy's web service client creates an image of the returned stationxml data that they call an *Inventory*.   We next use a parallel, simple database method to save this python object to our working database:

# %%
ret=db.save_inventory(inv)
# Out:
# Database.save_inventory processing summary:
# Number of site records processed= 434
# number of site records saved= 434
# number of channel records processed= 1308
# number of channel records saved= 1302

# %% [markdown]
# In this case, this function produced only a summary of what it wrote.  There is a verbose mode we turned off that would have told us that the reason the last two lines have a different number is that web services returned 6 duplicates.   As those of you who have worked with a lot of IRIS data probably know there are a lot of station metadata inconsistencies in what you get from web services.   Anyone who has had to deal with experimental data totally understand why, but it is a truth and a never ending job people at DMC and other data centers face.   The point for this session is that save_inventory always checks for duplicates and will silently skip them unless the verbose option is turned on.  If running verbose the duplicates will still be skipped, but you will get an error message.  Although we skipped it here, in general we recommend running save_inventory in verbose mode to make sure you are aware of any warts in the station metadata.

# %% [markdown]
# ### Load waveform data
# Normally obtaining waveform data that define your "dataset" can be a time consuming process.
# The waveform data you will be using today was originally downloaded with obspy using a python
# script similar to this:
#
#     #####################################################################
#     import os   # need this for directory handling
#     from obspy import UTCDateTime
#     db=Database(dbclient,'shortcourse')
#     dbsource=db.source
#     doc=dbsource.find_one()
#     origin_time=doc['time']
#     # We need the ObjectId of the source to provide a cross reference to link our
#     # waveform data to the right source.  Better to do this now than later as association
#     # can be a big challenge
#     id=doc['_id']
#     print('Starting to download data for event with origin time=',UTCDateTime(origin_time))
#     start_offset=763.0-4*60.0   # 763 is an approximate P wave travel time to TA center
#     end_offset=1400.0+10*60.0
#     stime=origin_time+start_offset
#     etime=origin_time+end_offset
#     t0=time.time()
#     strm=client.get_waveforms(
#             starttime=UTCDateTime(stime),
#             endtime=UTCDateTime(etime),
#             network='TA',
#             station='*',
#             channel='BH?',
#             location='*'
#         )
#     # The output of get_waveforms is an obspy Stream object. Stream objects are iterable
#     # so we work through the group saving each waveform to a separate file
#     # That is a terrible approach, but one we will use for pedagotic reasons in session 2
#     i=0   # used as a counter for creating unique mseed file names in this script
#     filebase='shortcourse'
#     dir='./wf'
#     if not os.path.exists(dir):
#         os.makedirs(dir)
#     for d in strm:
#         # We use obspy's writer here to save these data as miniseed.  We will be using that version
#         # of the data set in a later session.  There writer by default uses the SAC model of one
#         # file per Trace so we have to create a large number of files.
#         filename = "{base}_{count}.mseed".format(base=filebase,count=i)
#         d.write(dir+"/"+filename,format='MSEED')
#         i += 1
#         path=dir+"/"+filename
#         db.index_mseed_file(path)
#     #####################################################################
#
# If you pulled this tutorial from github the above script should allow you to recreate the set of
# miniseed files we will use in the workshop.  Some file name hacking will likely be required if you are in
# that situation.
#
# Students in the workshop need only run the following code box:

# %%
import os
wfdir = "/tmp/wf"   # change this directory as needed
with os.scandir(wfdir) as entries:
    count=0
    for entry in entries:
        if entry.is_file():
            filename= wfdir +'/'+entry.name
            print("Processing file=",filename)
            db.index_mseed_file(entry.name, dir=wfdir)
            count += 1
print('Number of files processed=',count)
# Out:
# Processing file= /tmp/wf/shortcourse_26.mseed
# Processing file= /tmp/wf/shortcourse_528.mseed
# Processing file= /tmp/wf/shortcourse_272.mseed
# Processing file= /tmp/wf/shortcourse_488.mseed
# Processing file= /tmp/wf/shortcourse_716.mseed
# Processing file= /tmp/wf/shortcourse_993.mseed
# Processing file= /tmp/wf/shortcourse_1164.mseed
# Processing file= /tmp/wf/shortcourse_733.mseed
# Processing file= /tmp/wf/shortcourse_910.mseed
# Processing file= /tmp/wf/shortcourse_340.mseed
# Processing file= /tmp/wf/shortcourse_657.mseed
# Processing file= /tmp/wf/shortcourse_511.mseed
# Processing file= /tmp/wf/shortcourse_1066.mseed
# Processing file= /tmp/wf/shortcourse_520.mseed
# Processing file= /tmp/wf/shortcourse_169.mseed
# Processing file= /tmp/wf/shortcourse_688.mseed
# Processing file= /tmp/wf/shortcourse_543.mseed
# Processing file= /tmp/wf/shortcourse_31.mseed
# Processing file= /tmp/wf/shortcourse_837.mseed
# Processing file= /tmp/wf/shortcourse_573.mseed
# Processing file= /tmp/wf/shortcourse_33.mseed
# Processing file= /tmp/wf/shortcourse_670.mseed
# Processing file= /tmp/wf/shortcourse_931.mseed
# Processing file= /tmp/wf/shortcourse_974.mseed
# Processing file= /tmp/wf/shortcourse_1132.mseed
# Processing file= /tmp/wf/shortcourse_205.mseed
# Processing file= /tmp/wf/shortcourse_925.mseed
# Processing file= /tmp/wf/shortcourse_287.mseed
# Processing file= /tmp/wf/shortcourse_783.mseed
# Processing file= /tmp/wf/shortcourse_1263.mseed
# Processing file= /tmp/wf/shortcourse_427.mseed
# Processing file= /tmp/wf/shortcourse_1044.mseed
# Processing file= /tmp/wf/shortcourse_1082.mseed
# Processing file= /tmp/wf/shortcourse_306.mseed
# Processing file= /tmp/wf/shortcourse_1118.mseed
# Processing file= /tmp/wf/shortcourse_809.mseed
# Processing file= /tmp/wf/shortcourse_710.mseed
# Processing file= /tmp/wf/shortcourse_602.mseed
# Processing file= /tmp/wf/shortcourse_456.mseed
# Processing file= /tmp/wf/shortcourse_693.mseed
# Processing file= /tmp/wf/shortcourse_80.mseed
# Processing file= /tmp/wf/shortcourse_1207.mseed
# Processing file= /tmp/wf/shortcourse_542.mseed
# Processing file= /tmp/wf/shortcourse_1104.mseed
# Processing file= /tmp/wf/shortcourse_1091.mseed
# Processing file= /tmp/wf/shortcourse_74.mseed
# Processing file= /tmp/wf/shortcourse_792.mseed
# Processing file= /tmp/wf/shortcourse_1081.mseed
# Processing file= /tmp/wf/shortcourse_19.mseed
# Processing file= /tmp/wf/shortcourse_55.mseed
# Processing file= /tmp/wf/shortcourse_970.mseed
# Processing file= /tmp/wf/shortcourse_282.mseed
# Processing file= /tmp/wf/shortcourse_580.mseed
# Processing file= /tmp/wf/shortcourse_293.mseed
# Processing file= /tmp/wf/shortcourse_424.mseed
# Processing file= /tmp/wf/shortcourse_128.mseed
# Processing file= /tmp/wf/shortcourse_789.mseed
# Processing file= /tmp/wf/shortcourse_433.mseed
# Processing file= /tmp/wf/shortcourse_683.mseed
# Processing file= /tmp/wf/shortcourse_991.mseed
# Processing file= /tmp/wf/shortcourse_469.mseed
# Processing file= /tmp/wf/shortcourse_137.mseed
# Processing file= /tmp/wf/shortcourse_755.mseed
# Processing file= /tmp/wf/shortcourse_828.mseed
# Processing file= /tmp/wf/shortcourse_372.mseed
# Processing file= /tmp/wf/shortcourse_1009.mseed
# Processing file= /tmp/wf/shortcourse_77.mseed
# Processing file= /tmp/wf/shortcourse_599.mseed
# Processing file= /tmp/wf/shortcourse_738.mseed
# Processing file= /tmp/wf/shortcourse_44.mseed
# Processing file= /tmp/wf/shortcourse_803.mseed
# Processing file= /tmp/wf/shortcourse_1029.mseed
# Processing file= /tmp/wf/shortcourse_706.mseed
# Processing file= /tmp/wf/shortcourse_1239.mseed
# Processing file= /tmp/wf/shortcourse_1234.mseed
# Processing file= /tmp/wf/shortcourse_392.mseed
# Processing file= /tmp/wf/shortcourse_1222.mseed
# Processing file= /tmp/wf/shortcourse_211.mseed
# Processing file= /tmp/wf/shortcourse_147.mseed
# Processing file= /tmp/wf/shortcourse_234.mseed
# Processing file= /tmp/wf/shortcourse_501.mseed
# Processing file= /tmp/wf/shortcourse_369.mseed
# Processing file= /tmp/wf/shortcourse_350.mseed
# Processing file= /tmp/wf/shortcourse_888.mseed
# Processing file= /tmp/wf/shortcourse_1031.mseed
# Processing file= /tmp/wf/shortcourse_90.mseed
# Processing file= /tmp/wf/shortcourse_196.mseed
# Processing file= /tmp/wf/shortcourse_1116.mseed
# Processing file= /tmp/wf/shortcourse_946.mseed
# Processing file= /tmp/wf/shortcourse_415.mseed
# Processing file= /tmp/wf/shortcourse_577.mseed
# Processing file= /tmp/wf/shortcourse_214.mseed
# Processing file= /tmp/wf/shortcourse_684.mseed
# Processing file= /tmp/wf/shortcourse_289.mseed
# Processing file= /tmp/wf/shortcourse_1148.mseed
# Processing file= /tmp/wf/shortcourse_402.mseed
# Processing file= /tmp/wf/shortcourse_587.mseed
# Processing file= /tmp/wf/shortcourse_391.mseed
# Processing file= /tmp/wf/shortcourse_585.mseed
# Processing file= /tmp/wf/shortcourse_401.mseed
# Processing file= /tmp/wf/shortcourse_1050.mseed
# Processing file= /tmp/wf/shortcourse_601.mseed
# Processing file= /tmp/wf/shortcourse_308.mseed
# Processing file= /tmp/wf/shortcourse_568.mseed
# Processing file= /tmp/wf/shortcourse_772.mseed
# Processing file= /tmp/wf/shortcourse_1235.mseed
# Processing file= /tmp/wf/shortcourse_1160.mseed
# Processing file= /tmp/wf/shortcourse_531.mseed
# Processing file= /tmp/wf/shortcourse_342.mseed
# Processing file= /tmp/wf/shortcourse_1210.mseed
# Processing file= /tmp/wf/shortcourse_246.mseed
# Processing file= /tmp/wf/shortcourse_83.mseed
# Processing file= /tmp/wf/shortcourse_938.mseed
# Processing file= /tmp/wf/shortcourse_1134.mseed
# Processing file= /tmp/wf/shortcourse_1285.mseed
# Processing file= /tmp/wf/shortcourse_355.mseed
# Processing file= /tmp/wf/shortcourse_1078.mseed
# Processing file= /tmp/wf/shortcourse_1248.mseed
# Processing file= /tmp/wf/shortcourse_1237.mseed
# Processing file= /tmp/wf/shortcourse_152.mseed
# Processing file= /tmp/wf/shortcourse_1108.mseed
# Processing file= /tmp/wf/shortcourse_518.mseed
# Processing file= /tmp/wf/shortcourse_1107.mseed
# Processing file= /tmp/wf/shortcourse_723.mseed
# Processing file= /tmp/wf/shortcourse_88.mseed
# Processing file= /tmp/wf/shortcourse_14.mseed
# Processing file= /tmp/wf/shortcourse_643.mseed
# Processing file= /tmp/wf/shortcourse_1016.mseed
# Processing file= /tmp/wf/shortcourse_545.mseed
# Processing file= /tmp/wf/shortcourse_482.mseed
# Processing file= /tmp/wf/shortcourse_1274.mseed
# Processing file= /tmp/wf/shortcourse_32.mseed
# Processing file= /tmp/wf/shortcourse_852.mseed
# Processing file= /tmp/wf/shortcourse_986.mseed
# Processing file= /tmp/wf/shortcourse_781.mseed
# Processing file= /tmp/wf/shortcourse_1241.mseed
# Processing file= /tmp/wf/shortcourse_144.mseed
# Processing file= /tmp/wf/shortcourse_248.mseed
# Processing file= /tmp/wf/shortcourse_730.mseed
# Processing file= /tmp/wf/shortcourse_973.mseed
# Processing file= /tmp/wf/shortcourse_907.mseed
# Processing file= /tmp/wf/shortcourse_215.mseed
# Processing file= /tmp/wf/shortcourse_318.mseed
# Processing file= /tmp/wf/shortcourse_641.mseed
# Processing file= /tmp/wf/shortcourse_145.mseed
# Processing file= /tmp/wf/shortcourse_1229.mseed
# Processing file= /tmp/wf/shortcourse_581.mseed
# Processing file= /tmp/wf/shortcourse_917.mseed
# Processing file= /tmp/wf/shortcourse_483.mseed
# Processing file= /tmp/wf/shortcourse_1147.mseed
# Processing file= /tmp/wf/shortcourse_1161.mseed
# Processing file= /tmp/wf/shortcourse_108.mseed
# Processing file= /tmp/wf/shortcourse_744.mseed
# Processing file= /tmp/wf/shortcourse_359.mseed
# Processing file= /tmp/wf/shortcourse_555.mseed
# Processing file= /tmp/wf/shortcourse_892.mseed
# Processing file= /tmp/wf/shortcourse_1273.mseed
# Processing file= /tmp/wf/shortcourse_398.mseed
# Processing file= /tmp/wf/shortcourse_1267.mseed
# Processing file= /tmp/wf/shortcourse_978.mseed
# Processing file= /tmp/wf/shortcourse_681.mseed
# Processing file= /tmp/wf/shortcourse_439.mseed
# Processing file= /tmp/wf/shortcourse_659.mseed
# Processing file= /tmp/wf/shortcourse_49.mseed
# Processing file= /tmp/wf/shortcourse_902.mseed
# Processing file= /tmp/wf/shortcourse_1163.mseed
# Processing file= /tmp/wf/shortcourse_935.mseed
# Processing file= /tmp/wf/shortcourse_149.mseed
# Processing file= /tmp/wf/shortcourse_440.mseed
# Processing file= /tmp/wf/shortcourse_1253.mseed
# Processing file= /tmp/wf/shortcourse_446.mseed
# Processing file= /tmp/wf/shortcourse_390.mseed
# Processing file= /tmp/wf/shortcourse_1208.mseed
# Processing file= /tmp/wf/shortcourse_475.mseed
# Processing file= /tmp/wf/shortcourse_709.mseed
# Processing file= /tmp/wf/shortcourse_578.mseed
# Processing file= /tmp/wf/shortcourse_444.mseed
# Processing file= /tmp/wf/shortcourse_630.mseed
# Processing file= /tmp/wf/shortcourse_877.mseed
# Processing file= /tmp/wf/shortcourse_816.mseed
# Processing file= /tmp/wf/shortcourse_1211.mseed
# Processing file= /tmp/wf/shortcourse_652.mseed
# Processing file= /tmp/wf/shortcourse_294.mseed
# Processing file= /tmp/wf/shortcourse_623.mseed
# Processing file= /tmp/wf/shortcourse_133.mseed
# Processing file= /tmp/wf/shortcourse_756.mseed
# Processing file= /tmp/wf/shortcourse_296.mseed
# Processing file= /tmp/wf/shortcourse_265.mseed
# Processing file= /tmp/wf/shortcourse_418.mseed
# Processing file= /tmp/wf/shortcourse_1152.mseed
# Processing file= /tmp/wf/shortcourse_148.mseed
# Processing file= /tmp/wf/shortcourse_159.mseed
# Processing file= /tmp/wf/shortcourse_813.mseed
# Processing file= /tmp/wf/shortcourse_1067.mseed
# Processing file= /tmp/wf/shortcourse_393.mseed
# Processing file= /tmp/wf/shortcourse_228.mseed
# Processing file= /tmp/wf/shortcourse_914.mseed
# Processing file= /tmp/wf/shortcourse_753.mseed
# Processing file= /tmp/wf/shortcourse_241.mseed
# Processing file= /tmp/wf/shortcourse_96.mseed
# Processing file= /tmp/wf/shortcourse_143.mseed
# Processing file= /tmp/wf/shortcourse_1275.mseed
# Processing file= /tmp/wf/shortcourse_16.mseed
# Processing file= /tmp/wf/shortcourse_1196.mseed
# Processing file= /tmp/wf/shortcourse_962.mseed
# Processing file= /tmp/wf/shortcourse_564.mseed
# Processing file= /tmp/wf/shortcourse_245.mseed
# Processing file= /tmp/wf/shortcourse_866.mseed
# Processing file= /tmp/wf/shortcourse_403.mseed
# Processing file= /tmp/wf/shortcourse_920.mseed
# Processing file= /tmp/wf/shortcourse_703.mseed
# Processing file= /tmp/wf/shortcourse_903.mseed
# Processing file= /tmp/wf/shortcourse_544.mseed
# Processing file= /tmp/wf/shortcourse_655.mseed
# Processing file= /tmp/wf/shortcourse_1280.mseed
# Processing file= /tmp/wf/shortcourse_751.mseed
# Processing file= /tmp/wf/shortcourse_59.mseed
# Processing file= /tmp/wf/shortcourse_173.mseed
# Processing file= /tmp/wf/shortcourse_588.mseed
# Processing file= /tmp/wf/shortcourse_121.mseed
# Processing file= /tmp/wf/shortcourse_1238.mseed
# Processing file= /tmp/wf/shortcourse_436.mseed
# Processing file= /tmp/wf/shortcourse_773.mseed
# Processing file= /tmp/wf/shortcourse_1149.mseed
# Processing file= /tmp/wf/shortcourse_742.mseed
# Processing file= /tmp/wf/shortcourse_1183.mseed
# Processing file= /tmp/wf/shortcourse_124.mseed
# Processing file= /tmp/wf/shortcourse_502.mseed
# Processing file= /tmp/wf/shortcourse_162.mseed
# Processing file= /tmp/wf/shortcourse_200.mseed
# Processing file= /tmp/wf/shortcourse_57.mseed
# Processing file= /tmp/wf/shortcourse_529.mseed
# Processing file= /tmp/wf/shortcourse_251.mseed
# Processing file= /tmp/wf/shortcourse_466.mseed
# Processing file= /tmp/wf/shortcourse_1231.mseed
# Processing file= /tmp/wf/shortcourse_268.mseed
# Processing file= /tmp/wf/shortcourse_743.mseed
# Processing file= /tmp/wf/shortcourse_273.mseed
# Processing file= /tmp/wf/shortcourse_464.mseed
# Processing file= /tmp/wf/shortcourse_936.mseed
# Processing file= /tmp/wf/shortcourse_1206.mseed
# Processing file= /tmp/wf/shortcourse_1185.mseed
# Processing file= /tmp/wf/shortcourse_52.mseed
# Processing file= /tmp/wf/shortcourse_924.mseed
# Processing file= /tmp/wf/shortcourse_279.mseed
# Processing file= /tmp/wf/shortcourse_799.mseed
# Processing file= /tmp/wf/shortcourse_192.mseed
# Processing file= /tmp/wf/shortcourse_1218.mseed
# Processing file= /tmp/wf/shortcourse_230.mseed
# Processing file= /tmp/wf/shortcourse_63.mseed
# Processing file= /tmp/wf/shortcourse_219.mseed
# Processing file= /tmp/wf/shortcourse_890.mseed
# Processing file= /tmp/wf/shortcourse_333.mseed
# Processing file= /tmp/wf/shortcourse_912.mseed
# Processing file= /tmp/wf/shortcourse_795.mseed
# Processing file= /tmp/wf/shortcourse_822.mseed
# Processing file= /tmp/wf/shortcourse_671.mseed
# Processing file= /tmp/wf/shortcourse_194.mseed
# Processing file= /tmp/wf/shortcourse_500.mseed
# Processing file= /tmp/wf/shortcourse_172.mseed
# Processing file= /tmp/wf/shortcourse_1247.mseed
# Processing file= /tmp/wf/shortcourse_1069.mseed
# Processing file= /tmp/wf/shortcourse_622.mseed
# Processing file= /tmp/wf/shortcourse_1252.mseed
# Processing file= /tmp/wf/shortcourse_478.mseed
# Processing file= /tmp/wf/shortcourse_6.mseed
# Processing file= /tmp/wf/shortcourse_284.mseed
# Processing file= /tmp/wf/shortcourse_428.mseed
# Processing file= /tmp/wf/shortcourse_1049.mseed
# Processing file= /tmp/wf/shortcourse_591.mseed
# Processing file= /tmp/wf/shortcourse_351.mseed
# Processing file= /tmp/wf/shortcourse_649.mseed
# Processing file= /tmp/wf/shortcourse_663.mseed
# Processing file= /tmp/wf/shortcourse_224.mseed
# Processing file= /tmp/wf/shortcourse_387.mseed
# Processing file= /tmp/wf/shortcourse_965.mseed
# Processing file= /tmp/wf/shortcourse_448.mseed
# Processing file= /tmp/wf/shortcourse_27.mseed
# Processing file= /tmp/wf/shortcourse_198.mseed
# Processing file= /tmp/wf/shortcourse_801.mseed
# Processing file= /tmp/wf/shortcourse_419.mseed
# Processing file= /tmp/wf/shortcourse_749.mseed
# Processing file= /tmp/wf/shortcourse_539.mseed
# Processing file= /tmp/wf/shortcourse_139.mseed
# Processing file= /tmp/wf/shortcourse_325.mseed
# Processing file= /tmp/wf/shortcourse_975.mseed
# Processing file= /tmp/wf/shortcourse_1276.mseed
# Processing file= /tmp/wf/shortcourse_353.mseed
# Processing file= /tmp/wf/shortcourse_375.mseed
# Processing file= /tmp/wf/shortcourse_913.mseed
# Processing file= /tmp/wf/shortcourse_860.mseed
# Processing file= /tmp/wf/shortcourse_947.mseed
# Processing file= /tmp/wf/shortcourse_1228.mseed
# Processing file= /tmp/wf/shortcourse_326.mseed
# Processing file= /tmp/wf/shortcourse_840.mseed
# Processing file= /tmp/wf/shortcourse_99.mseed
# Processing file= /tmp/wf/shortcourse_413.mseed
# Processing file= /tmp/wf/shortcourse_1221.mseed
# Processing file= /tmp/wf/shortcourse_1063.mseed
# Processing file= /tmp/wf/shortcourse_104.mseed
# Processing file= /tmp/wf/shortcourse_1202.mseed
# Processing file= /tmp/wf/shortcourse_102.mseed
# Processing file= /tmp/wf/shortcourse_1018.mseed
# Processing file= /tmp/wf/shortcourse_597.mseed
# Processing file= /tmp/wf/shortcourse_576.mseed
# Processing file= /tmp/wf/shortcourse_871.mseed
# Processing file= /tmp/wf/shortcourse_1036.mseed
# Processing file= /tmp/wf/shortcourse_1189.mseed
# Processing file= /tmp/wf/shortcourse_463.mseed
# Processing file= /tmp/wf/shortcourse_595.mseed
# Processing file= /tmp/wf/shortcourse_1224.mseed
# Processing file= /tmp/wf/shortcourse_820.mseed
# Processing file= /tmp/wf/shortcourse_856.mseed
# Processing file= /tmp/wf/shortcourse_437.mseed
# Processing file= /tmp/wf/shortcourse_158.mseed
# Processing file= /tmp/wf/shortcourse_1144.mseed
# Processing file= /tmp/wf/shortcourse_698.mseed
# Processing file= /tmp/wf/shortcourse_1203.mseed
# Processing file= /tmp/wf/shortcourse_1219.mseed
# Processing file= /tmp/wf/shortcourse_75.mseed
# Processing file= /tmp/wf/shortcourse_629.mseed
# Processing file= /tmp/wf/shortcourse_352.mseed
# Processing file= /tmp/wf/shortcourse_416.mseed
# Processing file= /tmp/wf/shortcourse_610.mseed
# Processing file= /tmp/wf/shortcourse_1061.mseed
# Processing file= /tmp/wf/shortcourse_713.mseed
# Processing file= /tmp/wf/shortcourse_239.mseed
# Processing file= /tmp/wf/shortcourse_726.mseed
# Processing file= /tmp/wf/shortcourse_70.mseed
# Processing file= /tmp/wf/shortcourse_472.mseed
# Processing file= /tmp/wf/shortcourse_598.mseed
# Processing file= /tmp/wf/shortcourse_462.mseed
# Processing file= /tmp/wf/shortcourse_503.mseed
# Processing file= /tmp/wf/shortcourse_848.mseed
# Processing file= /tmp/wf/shortcourse_957.mseed
# Processing file= /tmp/wf/shortcourse_530.mseed
# Processing file= /tmp/wf/shortcourse_1028.mseed
# Processing file= /tmp/wf/shortcourse_1030.mseed
# Processing file= /tmp/wf/shortcourse_741.mseed
# Processing file= /tmp/wf/shortcourse_365.mseed
# Processing file= /tmp/wf/shortcourse_636.mseed
# Processing file= /tmp/wf/shortcourse_676.mseed
# Processing file= /tmp/wf/shortcourse_642.mseed
# Processing file= /tmp/wf/shortcourse_204.mseed
# Processing file= /tmp/wf/shortcourse_452.mseed
# Processing file= /tmp/wf/shortcourse_36.mseed
# Processing file= /tmp/wf/shortcourse_549.mseed
# Processing file= /tmp/wf/shortcourse_596.mseed
# Processing file= /tmp/wf/shortcourse_565.mseed
# Processing file= /tmp/wf/shortcourse_514.mseed
# Processing file= /tmp/wf/shortcourse_421.mseed
# Processing file= /tmp/wf/shortcourse_286.mseed
# Processing file= /tmp/wf/shortcourse_407.mseed
# Processing file= /tmp/wf/shortcourse_1096.mseed
# Processing file= /tmp/wf/shortcourse_373.mseed
# Processing file= /tmp/wf/shortcourse_109.mseed
# Processing file= /tmp/wf/shortcourse_1201.mseed
# Processing file= /tmp/wf/shortcourse_315.mseed
# Processing file= /tmp/wf/shortcourse_442.mseed
# Processing file= /tmp/wf/shortcourse_774.mseed
# Processing file= /tmp/wf/shortcourse_269.mseed
# Processing file= /tmp/wf/shortcourse_404.mseed
# Processing file= /tmp/wf/shortcourse_1217.mseed
# Processing file= /tmp/wf/shortcourse_1272.mseed
# Processing file= /tmp/wf/shortcourse_1123.mseed
# Processing file= /tmp/wf/shortcourse_757.mseed
# Processing file= /tmp/wf/shortcourse_264.mseed
# Processing file= /tmp/wf/shortcourse_707.mseed
# Processing file= /tmp/wf/shortcourse_958.mseed
# Processing file= /tmp/wf/shortcourse_735.mseed
# Processing file= /tmp/wf/shortcourse_939.mseed
# Processing file= /tmp/wf/shortcourse_999.mseed
# Processing file= /tmp/wf/shortcourse_788.mseed
# Processing file= /tmp/wf/shortcourse_1000.mseed
# Processing file= /tmp/wf/shortcourse_252.mseed
# Processing file= /tmp/wf/shortcourse_1005.mseed
# Processing file= /tmp/wf/shortcourse_764.mseed
# Processing file= /tmp/wf/shortcourse_79.mseed
# Processing file= /tmp/wf/shortcourse_714.mseed
# Processing file= /tmp/wf/shortcourse_656.mseed
# Processing file= /tmp/wf/shortcourse_1259.mseed
# Processing file= /tmp/wf/shortcourse_673.mseed
# Processing file= /tmp/wf/shortcourse_129.mseed
# Processing file= /tmp/wf/shortcourse_976.mseed
# Processing file= /tmp/wf/shortcourse_288.mseed
# Processing file= /tmp/wf/shortcourse_276.mseed
# Processing file= /tmp/wf/shortcourse_87.mseed
# Processing file= /tmp/wf/shortcourse_984.mseed
# Processing file= /tmp/wf/shortcourse_1138.mseed
# Processing file= /tmp/wf/shortcourse_831.mseed
# Processing file= /tmp/wf/shortcourse_563.mseed
# Processing file= /tmp/wf/shortcourse_176.mseed
# Processing file= /tmp/wf/shortcourse_1020.mseed
# Processing file= /tmp/wf/shortcourse_885.mseed
# Processing file= /tmp/wf/shortcourse_1073.mseed
# Processing file= /tmp/wf/shortcourse_332.mseed
# Processing file= /tmp/wf/shortcourse_883.mseed
# Processing file= /tmp/wf/shortcourse_513.mseed
# Processing file= /tmp/wf/shortcourse_1064.mseed
# Processing file= /tmp/wf/shortcourse_400.mseed
# Processing file= /tmp/wf/shortcourse_348.mseed
# Processing file= /tmp/wf/shortcourse_1034.mseed
# Processing file= /tmp/wf/shortcourse_592.mseed
# Processing file= /tmp/wf/shortcourse_37.mseed
# Processing file= /tmp/wf/shortcourse_821.mseed
# Processing file= /tmp/wf/shortcourse_42.mseed
# Processing file= /tmp/wf/shortcourse_523.mseed
# Processing file= /tmp/wf/shortcourse_654.mseed
# Processing file= /tmp/wf/shortcourse_868.mseed
# Processing file= /tmp/wf/shortcourse_611.mseed
# Processing file= /tmp/wf/shortcourse_1004.mseed
# Processing file= /tmp/wf/shortcourse_811.mseed
# Processing file= /tmp/wf/shortcourse_638.mseed
# Processing file= /tmp/wf/shortcourse_1173.mseed
# Processing file= /tmp/wf/shortcourse_624.mseed
# Processing file= /tmp/wf/shortcourse_1214.mseed
# Processing file= /tmp/wf/shortcourse_833.mseed
# Processing file= /tmp/wf/shortcourse_185.mseed
# Processing file= /tmp/wf/shortcourse_111.mseed
# Processing file= /tmp/wf/shortcourse_696.mseed
# Processing file= /tmp/wf/shortcourse_310.mseed
# Processing file= /tmp/wf/shortcourse_1056.mseed
# Processing file= /tmp/wf/shortcourse_1146.mseed
# Processing file= /tmp/wf/shortcourse_231.mseed
# Processing file= /tmp/wf/shortcourse_56.mseed
# Processing file= /tmp/wf/shortcourse_569.mseed
# Processing file= /tmp/wf/shortcourse_346.mseed
# Processing file= /tmp/wf/shortcourse_356.mseed
# Processing file= /tmp/wf/shortcourse_15.mseed
# Processing file= /tmp/wf/shortcourse_943.mseed
# Processing file= /tmp/wf/shortcourse_915.mseed
# Processing file= /tmp/wf/shortcourse_1076.mseed
# Processing file= /tmp/wf/shortcourse_869.mseed
# Processing file= /tmp/wf/shortcourse_525.mseed
# Processing file= /tmp/wf/shortcourse_846.mseed
# Processing file= /tmp/wf/shortcourse_278.mseed
# Processing file= /tmp/wf/shortcourse_835.mseed
# Processing file= /tmp/wf/shortcourse_1085.mseed
# Processing file= /tmp/wf/shortcourse_886.mseed
# Processing file= /tmp/wf/shortcourse_1143.mseed
# Processing file= /tmp/wf/shortcourse_85.mseed
# Processing file= /tmp/wf/shortcourse_950.mseed
# Processing file= /tmp/wf/shortcourse_724.mseed
# Processing file= /tmp/wf/shortcourse_896.mseed
# Processing file= /tmp/wf/shortcourse_776.mseed
# Processing file= /tmp/wf/shortcourse_1047.mseed
# Processing file= /tmp/wf/shortcourse_668.mseed
# Processing file= /tmp/wf/shortcourse_557.mseed
# Processing file= /tmp/wf/shortcourse_1112.mseed
# Processing file= /tmp/wf/shortcourse_266.mseed
# Processing file= /tmp/wf/shortcourse_1048.mseed
# Processing file= /tmp/wf/shortcourse_357.mseed
# Processing file= /tmp/wf/shortcourse_485.mseed
# Processing file= /tmp/wf/shortcourse_100.mseed
# Processing file= /tmp/wf/shortcourse_313.mseed
# Processing file= /tmp/wf/shortcourse_499.mseed
# Processing file= /tmp/wf/shortcourse_1243.mseed
# Processing file= /tmp/wf/shortcourse_78.mseed
# Processing file= /tmp/wf/shortcourse_793.mseed
# Processing file= /tmp/wf/shortcourse_1142.mseed
# Processing file= /tmp/wf/shortcourse_434.mseed
# Processing file= /tmp/wf/shortcourse_18.mseed
# Processing file= /tmp/wf/shortcourse_1027.mseed
# Processing file= /tmp/wf/shortcourse_116.mseed
# Processing file= /tmp/wf/shortcourse_303.mseed
# Processing file= /tmp/wf/shortcourse_584.mseed
# Processing file= /tmp/wf/shortcourse_807.mseed
# Processing file= /tmp/wf/shortcourse_1197.mseed
# Processing file= /tmp/wf/shortcourse_830.mseed
# Processing file= /tmp/wf/shortcourse_367.mseed
# Processing file= /tmp/wf/shortcourse_281.mseed
# Processing file= /tmp/wf/shortcourse_1097.mseed
# Processing file= /tmp/wf/shortcourse_362.mseed
# Processing file= /tmp/wf/shortcourse_1090.mseed
# Processing file= /tmp/wf/shortcourse_1117.mseed
# Processing file= /tmp/wf/shortcourse_22.mseed
# Processing file= /tmp/wf/shortcourse_534.mseed
# Processing file= /tmp/wf/shortcourse_364.mseed
# Processing file= /tmp/wf/shortcourse_1158.mseed
# Processing file= /tmp/wf/shortcourse_916.mseed
# Processing file= /tmp/wf/shortcourse_226.mseed
# Processing file= /tmp/wf/shortcourse_349.mseed
# Processing file= /tmp/wf/shortcourse_93.mseed
# Processing file= /tmp/wf/shortcourse_876.mseed
# Processing file= /tmp/wf/shortcourse_430.mseed
# Processing file= /tmp/wf/shortcourse_54.mseed
# Processing file= /tmp/wf/shortcourse_509.mseed
# Processing file= /tmp/wf/shortcourse_855.mseed
# Processing file= /tmp/wf/shortcourse_763.mseed
# Processing file= /tmp/wf/shortcourse_167.mseed
# Processing file= /tmp/wf/shortcourse_963.mseed
# Processing file= /tmp/wf/shortcourse_944.mseed
# Processing file= /tmp/wf/shortcourse_700.mseed
# Processing file= /tmp/wf/shortcourse_411.mseed
# Processing file= /tmp/wf/shortcourse_28.mseed
# Processing file= /tmp/wf/shortcourse_662.mseed
# Processing file= /tmp/wf/shortcourse_232.mseed
# Processing file= /tmp/wf/shortcourse_23.mseed
# Processing file= /tmp/wf/shortcourse_396.mseed
# Processing file= /tmp/wf/shortcourse_1166.mseed
# Processing file= /tmp/wf/shortcourse_1120.mseed
# Processing file= /tmp/wf/shortcourse_217.mseed
# Processing file= /tmp/wf/shortcourse_1051.mseed
# Processing file= /tmp/wf/shortcourse_341.mseed
# Processing file= /tmp/wf/shortcourse_1281.mseed
# Processing file= /tmp/wf/shortcourse_512.mseed
# Processing file= /tmp/wf/shortcourse_195.mseed
# Processing file= /tmp/wf/shortcourse_1119.mseed
# Processing file= /tmp/wf/shortcourse_519.mseed
# Processing file= /tmp/wf/shortcourse_996.mseed
# Processing file= /tmp/wf/shortcourse_41.mseed
# Processing file= /tmp/wf/shortcourse_1165.mseed
# Processing file= /tmp/wf/shortcourse_157.mseed
# Processing file= /tmp/wf/shortcourse_553.mseed
# Processing file= /tmp/wf/shortcourse_1086.mseed
# Processing file= /tmp/wf/shortcourse_1077.mseed
# Processing file= /tmp/wf/shortcourse_48.mseed
# Processing file= /tmp/wf/shortcourse_113.mseed
# Processing file= /tmp/wf/shortcourse_836.mseed
# Processing file= /tmp/wf/shortcourse_153.mseed
# Processing file= /tmp/wf/shortcourse_321.mseed
# Processing file= /tmp/wf/shortcourse_81.mseed
# Processing file= /tmp/wf/shortcourse_720.mseed
# Processing file= /tmp/wf/shortcourse_842.mseed
# Processing file= /tmp/wf/shortcourse_660.mseed
# Processing file= /tmp/wf/shortcourse_1150.mseed
# Processing file= /tmp/wf/shortcourse_981.mseed
# Processing file= /tmp/wf/shortcourse_257.mseed
# Processing file= /tmp/wf/shortcourse_1101.mseed
# Processing file= /tmp/wf/shortcourse_1193.mseed
# Processing file= /tmp/wf/shortcourse_255.mseed
# Processing file= /tmp/wf/shortcourse_838.mseed
# Processing file= /tmp/wf/shortcourse_759.mseed
# Processing file= /tmp/wf/shortcourse_138.mseed
# Processing file= /tmp/wf/shortcourse_784.mseed
# Processing file= /tmp/wf/shortcourse_397.mseed
# Processing file= /tmp/wf/shortcourse_1139.mseed
# Processing file= /tmp/wf/shortcourse_1035.mseed
# Processing file= /tmp/wf/shortcourse_537.mseed
# Processing file= /tmp/wf/shortcourse_844.mseed
# Processing file= /tmp/wf/shortcourse_570.mseed
# Processing file= /tmp/wf/shortcourse_550.mseed
# Processing file= /tmp/wf/shortcourse_1270.mseed
# Processing file= /tmp/wf/shortcourse_1070.mseed
# Processing file= /tmp/wf/shortcourse_804.mseed
# Processing file= /tmp/wf/shortcourse_328.mseed
# Processing file= /tmp/wf/shortcourse_893.mseed
# Processing file= /tmp/wf/shortcourse_926.mseed
# Processing file= /tmp/wf/shortcourse_384.mseed
# Processing file= /tmp/wf/shortcourse_156.mseed
# Processing file= /tmp/wf/shortcourse_593.mseed
# Processing file= /tmp/wf/shortcourse_762.mseed
# Processing file= /tmp/wf/shortcourse_609.mseed
# Processing file= /tmp/wf/shortcourse_207.mseed
# Processing file= /tmp/wf/shortcourse_1137.mseed
# Processing file= /tmp/wf/shortcourse_658.mseed
# Processing file= /tmp/wf/shortcourse_834.mseed
# Processing file= /tmp/wf/shortcourse_460.mseed
# Processing file= /tmp/wf/shortcourse_238.mseed
# Processing file= /tmp/wf/shortcourse_115.mseed
# Processing file= /tmp/wf/shortcourse_959.mseed
# Processing file= /tmp/wf/shortcourse_929.mseed
# Processing file= /tmp/wf/shortcourse_731.mseed
# Processing file= /tmp/wf/shortcourse_107.mseed
# Processing file= /tmp/wf/shortcourse_750.mseed
# Processing file= /tmp/wf/shortcourse_615.mseed
# Processing file= /tmp/wf/shortcourse_38.mseed
# Processing file= /tmp/wf/shortcourse_171.mseed
# Processing file= /tmp/wf/shortcourse_874.mseed
# Processing file= /tmp/wf/shortcourse_479.mseed
# Processing file= /tmp/wf/shortcourse_1240.mseed
# Processing file= /tmp/wf/shortcourse_644.mseed
# Processing file= /tmp/wf/shortcourse_849.mseed
# Processing file= /tmp/wf/shortcourse_1126.mseed
# Processing file= /tmp/wf/shortcourse_1192.mseed
# Processing file= /tmp/wf/shortcourse_1110.mseed
# Processing file= /tmp/wf/shortcourse_1200.mseed
# Processing file= /tmp/wf/shortcourse_441.mseed
# Processing file= /tmp/wf/shortcourse_1075.mseed
# Processing file= /tmp/wf/shortcourse_1055.mseed
# Processing file= /tmp/wf/shortcourse_1102.mseed
# Processing file= /tmp/wf/shortcourse_736.mseed
# Processing file= /tmp/wf/shortcourse_1074.mseed
# Processing file= /tmp/wf/shortcourse_1141.mseed
# Processing file= /tmp/wf/shortcourse_345.mseed
# Processing file= /tmp/wf/shortcourse_447.mseed
# Processing file= /tmp/wf/shortcourse_705.mseed
# Processing file= /tmp/wf/shortcourse_371.mseed
# Processing file= /tmp/wf/shortcourse_94.mseed
# Processing file= /tmp/wf/shortcourse_309.mseed
# Processing file= /tmp/wf/shortcourse_992.mseed
# Processing file= /tmp/wf/shortcourse_768.mseed
# Processing file= /tmp/wf/shortcourse_381.mseed
# Processing file= /tmp/wf/shortcourse_305.mseed
# Processing file= /tmp/wf/shortcourse_712.mseed
# Processing file= /tmp/wf/shortcourse_1204.mseed
# Processing file= /tmp/wf/shortcourse_106.mseed
# Processing file= /tmp/wf/shortcourse_227.mseed
# Processing file= /tmp/wf/shortcourse_646.mseed
# Processing file= /tmp/wf/shortcourse_188.mseed
# Processing file= /tmp/wf/shortcourse_554.mseed
# Processing file= /tmp/wf/shortcourse_253.mseed
# Processing file= /tmp/wf/shortcourse_980.mseed
# Processing file= /tmp/wf/shortcourse_899.mseed
# Processing file= /tmp/wf/shortcourse_17.mseed
# Processing file= /tmp/wf/shortcourse_336.mseed
# Processing file= /tmp/wf/shortcourse_203.mseed
# Processing file= /tmp/wf/shortcourse_1042.mseed
# Processing file= /tmp/wf/shortcourse_798.mseed
# Processing file= /tmp/wf/shortcourse_301.mseed
# Processing file= /tmp/wf/shortcourse_1012.mseed
# Processing file= /tmp/wf/shortcourse_708.mseed
# Processing file= /tmp/wf/shortcourse_34.mseed
# Processing file= /tmp/wf/shortcourse_1014.mseed
# Processing file= /tmp/wf/shortcourse_956.mseed
# Processing file= /tmp/wf/shortcourse_1212.mseed
# Processing file= /tmp/wf/shortcourse_1157.mseed
# Processing file= /tmp/wf/shortcourse_507.mseed
# Processing file= /tmp/wf/shortcourse_853.mseed
# Processing file= /tmp/wf/shortcourse_445.mseed
# Processing file= /tmp/wf/shortcourse_378.mseed
# Processing file= /tmp/wf/shortcourse_290.mseed
# Processing file= /tmp/wf/shortcourse_1013.mseed
# Processing file= /tmp/wf/shortcourse_923.mseed
# Processing file= /tmp/wf/shortcourse_690.mseed
# Processing file= /tmp/wf/shortcourse_882.mseed
# Processing file= /tmp/wf/shortcourse_824.mseed
# Processing file= /tmp/wf/shortcourse_135.mseed
# Processing file= /tmp/wf/shortcourse_82.mseed
# Processing file= /tmp/wf/shortcourse_1068.mseed
# Processing file= /tmp/wf/shortcourse_114.mseed
# Processing file= /tmp/wf/shortcourse_72.mseed
# Processing file= /tmp/wf/shortcourse_1131.mseed
# Processing file= /tmp/wf/shortcourse_233.mseed
# Processing file= /tmp/wf/shortcourse_1040.mseed
# Processing file= /tmp/wf/shortcourse_1205.mseed
# Processing file= /tmp/wf/shortcourse_155.mseed
# Processing file= /tmp/wf/shortcourse_878.mseed
# Processing file= /tmp/wf/shortcourse_262.mseed
# Processing file= /tmp/wf/shortcourse_979.mseed
# Processing file= /tmp/wf/shortcourse_1175.mseed
# Processing file= /tmp/wf/shortcourse_1184.mseed
# Processing file= /tmp/wf/shortcourse_1065.mseed
# Processing file= /tmp/wf/shortcourse_1215.mseed
# Processing file= /tmp/wf/shortcourse_1256.mseed
# Processing file= /tmp/wf/shortcourse_1178.mseed
# Processing file= /tmp/wf/shortcourse_140.mseed
# Processing file= /tmp/wf/shortcourse_873.mseed
# Processing file= /tmp/wf/shortcourse_648.mseed
# Processing file= /tmp/wf/shortcourse_769.mseed
# Processing file= /tmp/wf/shortcourse_1124.mseed
# Processing file= /tmp/wf/shortcourse_175.mseed
# Processing file= /tmp/wf/shortcourse_639.mseed
# Processing file= /tmp/wf/shortcourse_787.mseed
# Processing file= /tmp/wf/shortcourse_405.mseed
# Processing file= /tmp/wf/shortcourse_802.mseed
# Processing file= /tmp/wf/shortcourse_510.mseed
# Processing file= /tmp/wf/shortcourse_122.mseed
# Processing file= /tmp/wf/shortcourse_35.mseed
# Processing file= /tmp/wf/shortcourse_898.mseed
# Processing file= /tmp/wf/shortcourse_236.mseed
# Processing file= /tmp/wf/shortcourse_181.mseed
# Processing file= /tmp/wf/shortcourse_263.mseed
# Processing file= /tmp/wf/shortcourse_875.mseed
# Processing file= /tmp/wf/shortcourse_498.mseed
# Processing file= /tmp/wf/shortcourse_1151.mseed
# Processing file= /tmp/wf/shortcourse_431.mseed
# Processing file= /tmp/wf/shortcourse_103.mseed
# Processing file= /tmp/wf/shortcourse_942.mseed
# Processing file= /tmp/wf/shortcourse_91.mseed
# Processing file= /tmp/wf/shortcourse_222.mseed
# Processing file= /tmp/wf/shortcourse_484.mseed
# Processing file= /tmp/wf/shortcourse_221.mseed
# Processing file= /tmp/wf/shortcourse_291.mseed
# Processing file= /tmp/wf/shortcourse_1125.mseed
# Processing file= /tmp/wf/shortcourse_747.mseed
# Processing file= /tmp/wf/shortcourse_395.mseed
# Processing file= /tmp/wf/shortcourse_1015.mseed
# Processing file= /tmp/wf/shortcourse_777.mseed
# Processing file= /tmp/wf/shortcourse_791.mseed
# Processing file= /tmp/wf/shortcourse_752.mseed
# Processing file= /tmp/wf/shortcourse_201.mseed
# Processing file= /tmp/wf/shortcourse_491.mseed
# Processing file= /tmp/wf/shortcourse_687.mseed
# Processing file= /tmp/wf/shortcourse_870.mseed
# Processing file= /tmp/wf/shortcourse_4.mseed
# Processing file= /tmp/wf/shortcourse_732.mseed
# Processing file= /tmp/wf/shortcourse_67.mseed
# Processing file= /tmp/wf/shortcourse_45.mseed
# Processing file= /tmp/wf/shortcourse_186.mseed
# Processing file= /tmp/wf/shortcourse_354.mseed
# Processing file= /tmp/wf/shortcourse_1003.mseed
# Processing file= /tmp/wf/shortcourse_546.mseed
# Processing file= /tmp/wf/shortcourse_105.mseed
# Processing file= /tmp/wf/shortcourse_141.mseed
# Processing file= /tmp/wf/shortcourse_379.mseed
# Processing file= /tmp/wf/shortcourse_969.mseed
# Processing file= /tmp/wf/shortcourse_166.mseed
# Processing file= /tmp/wf/shortcourse_620.mseed
# Processing file= /tmp/wf/shortcourse_717.mseed
# Processing file= /tmp/wf/shortcourse_191.mseed
# Processing file= /tmp/wf/shortcourse_347.mseed
# Processing file= /tmp/wf/shortcourse_718.mseed
# Processing file= /tmp/wf/shortcourse_302.mseed
# Processing file= /tmp/wf/shortcourse_586.mseed
# Processing file= /tmp/wf/shortcourse_1105.mseed
# Processing file= /tmp/wf/shortcourse_1246.mseed
# Processing file= /tmp/wf/shortcourse_1136.mseed
# Processing file= /tmp/wf/shortcourse_493.mseed
# Processing file= /tmp/wf/shortcourse_1199.mseed
# Processing file= /tmp/wf/shortcourse_1282.mseed
# Processing file= /tmp/wf/shortcourse_1019.mseed
# Processing file= /tmp/wf/shortcourse_664.mseed
# Processing file= /tmp/wf/shortcourse_1249.mseed
# Processing file= /tmp/wf/shortcourse_154.mseed
# Processing file= /tmp/wf/shortcourse_827.mseed
# Processing file= /tmp/wf/shortcourse_740.mseed
# Processing file= /tmp/wf/shortcourse_858.mseed
# Processing file= /tmp/wf/shortcourse_388.mseed
# Processing file= /tmp/wf/shortcourse_21.mseed
# Processing file= /tmp/wf/shortcourse_1155.mseed
# Processing file= /tmp/wf/shortcourse_150.mseed
# Processing file= /tmp/wf/shortcourse_1.mseed
# Processing file= /tmp/wf/shortcourse_237.mseed
# Processing file= /tmp/wf/shortcourse_361.mseed
# Processing file= /tmp/wf/shortcourse_250.mseed
# Processing file= /tmp/wf/shortcourse_374.mseed
# Processing file= /tmp/wf/shortcourse_967.mseed
# Processing file= /tmp/wf/shortcourse_61.mseed
# Processing file= /tmp/wf/shortcourse_1072.mseed
# Processing file= /tmp/wf/shortcourse_590.mseed
# Processing file= /tmp/wf/shortcourse_737.mseed
# Processing file= /tmp/wf/shortcourse_320.mseed
# Processing file= /tmp/wf/shortcourse_819.mseed
# Processing file= /tmp/wf/shortcourse_628.mseed
# Processing file= /tmp/wf/shortcourse_880.mseed
# Processing file= /tmp/wf/shortcourse_517.mseed
# Processing file= /tmp/wf/shortcourse_335.mseed
# Processing file= /tmp/wf/shortcourse_184.mseed
# Processing file= /tmp/wf/shortcourse_1250.mseed
# Processing file= /tmp/wf/shortcourse_526.mseed
# Processing file= /tmp/wf/shortcourse_1060.mseed
# Processing file= /tmp/wf/shortcourse_633.mseed
# Processing file= /tmp/wf/shortcourse_1176.mseed
# Processing file= /tmp/wf/shortcourse_1098.mseed
# Processing file= /tmp/wf/shortcourse_694.mseed
# Processing file= /tmp/wf/shortcourse_758.mseed
# Processing file= /tmp/wf/shortcourse_884.mseed
# Processing file= /tmp/wf/shortcourse_223.mseed
# Processing file= /tmp/wf/shortcourse_861.mseed
# Processing file= /tmp/wf/shortcourse_477.mseed
# Processing file= /tmp/wf/shortcourse_183.mseed
# Processing file= /tmp/wf/shortcourse_1180.mseed
# Processing file= /tmp/wf/shortcourse_761.mseed
# Processing file= /tmp/wf/shortcourse_995.mseed
# Processing file= /tmp/wf/shortcourse_1037.mseed
# Processing file= /tmp/wf/shortcourse_360.mseed
# Processing file= /tmp/wf/shortcourse_800.mseed
# Processing file= /tmp/wf/shortcourse_540.mseed
# Processing file= /tmp/wf/shortcourse_24.mseed
# Processing file= /tmp/wf/shortcourse_7.mseed
# Processing file= /tmp/wf/shortcourse_640.mseed
# Processing file= /tmp/wf/shortcourse_1162.mseed
# Processing file= /tmp/wf/shortcourse_1109.mseed
# Processing file= /tmp/wf/shortcourse_1127.mseed
# Processing file= /tmp/wf/shortcourse_701.mseed
# Processing file= /tmp/wf/shortcourse_806.mseed
# Processing file= /tmp/wf/shortcourse_473.mseed
# Processing file= /tmp/wf/shortcourse_729.mseed
# Processing file= /tmp/wf/shortcourse_216.mseed
# Processing file= /tmp/wf/shortcourse_1233.mseed
# Processing file= /tmp/wf/shortcourse_1220.mseed
# Processing file= /tmp/wf/shortcourse_409.mseed
# Processing file= /tmp/wf/shortcourse_661.mseed
# Processing file= /tmp/wf/shortcourse_1266.mseed
# Processing file= /tmp/wf/shortcourse_715.mseed
# Processing file= /tmp/wf/shortcourse_323.mseed
# Processing file= /tmp/wf/shortcourse_209.mseed
# Processing file= /tmp/wf/shortcourse_859.mseed
# Processing file= /tmp/wf/shortcourse_285.mseed
# Processing file= /tmp/wf/shortcourse_331.mseed
# Processing file= /tmp/wf/shortcourse_561.mseed
# Processing file= /tmp/wf/shortcourse_606.mseed
# Processing file= /tmp/wf/shortcourse_1186.mseed
# Processing file= /tmp/wf/shortcourse_1080.mseed
# Processing file= /tmp/wf/shortcourse_189.mseed
# Processing file= /tmp/wf/shortcourse_1260.mseed
# Processing file= /tmp/wf/shortcourse_9.mseed
# Processing file= /tmp/wf/shortcourse_327.mseed
# Processing file= /tmp/wf/shortcourse_796.mseed
# Processing file= /tmp/wf/shortcourse_651.mseed
# Processing file= /tmp/wf/shortcourse_177.mseed
# Processing file= /tmp/wf/shortcourse_538.mseed
# Processing file= /tmp/wf/shortcourse_571.mseed
# Processing file= /tmp/wf/shortcourse_89.mseed
# Processing file= /tmp/wf/shortcourse_68.mseed
# Processing file= /tmp/wf/shortcourse_180.mseed
# Processing file= /tmp/wf/shortcourse_1022.mseed
# Processing file= /tmp/wf/shortcourse_420.mseed
# Processing file= /tmp/wf/shortcourse_243.mseed
# Processing file= /tmp/wf/shortcourse_414.mseed
# Processing file= /tmp/wf/shortcourse_1271.mseed
# Processing file= /tmp/wf/shortcourse_951.mseed
# Processing file= /tmp/wf/shortcourse_521.mseed
# Processing file= /tmp/wf/shortcourse_1265.mseed
# Processing file= /tmp/wf/shortcourse_66.mseed
# Processing file= /tmp/wf/shortcourse_12.mseed
# Processing file= /tmp/wf/shortcourse_989.mseed
# Processing file= /tmp/wf/shortcourse_1179.mseed
# Processing file= /tmp/wf/shortcourse_583.mseed
# Processing file= /tmp/wf/shortcourse_727.mseed
# Processing file= /tmp/wf/shortcourse_213.mseed
# Processing file= /tmp/wf/shortcourse_854.mseed
# Processing file= /tmp/wf/shortcourse_314.mseed
# Processing file= /tmp/wf/shortcourse_532.mseed
# Processing file= /tmp/wf/shortcourse_260.mseed
# Processing file= /tmp/wf/shortcourse_53.mseed
# Processing file= /tmp/wf/shortcourse_256.mseed
# Processing file= /tmp/wf/shortcourse_666.mseed
# Processing file= /tmp/wf/shortcourse_1062.mseed
# Processing file= /tmp/wf/shortcourse_616.mseed
# Processing file= /tmp/wf/shortcourse_1169.mseed
# Processing file= /tmp/wf/shortcourse_560.mseed
# Processing file= /tmp/wf/shortcourse_1054.mseed
# Processing file= /tmp/wf/shortcourse_120.mseed
# Processing file= /tmp/wf/shortcourse_495.mseed
# Processing file= /tmp/wf/shortcourse_766.mseed
# Processing file= /tmp/wf/shortcourse_210.mseed
# Processing file= /tmp/wf/shortcourse_190.mseed
# Processing file= /tmp/wf/shortcourse_1002.mseed
# Processing file= /tmp/wf/shortcourse_1145.mseed
# Processing file= /tmp/wf/shortcourse_719.mseed
# Processing file= /tmp/wf/shortcourse_1232.mseed
# Processing file= /tmp/wf/shortcourse_879.mseed
# Processing file= /tmp/wf/shortcourse_721.mseed
# Processing file= /tmp/wf/shortcourse_65.mseed
# Processing file= /tmp/wf/shortcourse_1052.mseed
# Processing file= /tmp/wf/shortcourse_1284.mseed
# Processing file= /tmp/wf/shortcourse_621.mseed
# Processing file= /tmp/wf/shortcourse_704.mseed
# Processing file= /tmp/wf/shortcourse_218.mseed
# Processing file= /tmp/wf/shortcourse_932.mseed
# Processing file= /tmp/wf/shortcourse_1059.mseed
# Processing file= /tmp/wf/shortcourse_516.mseed
# Processing file= /tmp/wf/shortcourse_295.mseed
# Processing file= /tmp/wf/shortcourse_1121.mseed
# Processing file= /tmp/wf/shortcourse_299.mseed
# Processing file= /tmp/wf/shortcourse_909.mseed
# Processing file= /tmp/wf/shortcourse_1187.mseed
# Processing file= /tmp/wf/shortcourse_1227.mseed
# Processing file= /tmp/wf/shortcourse_64.mseed
# Processing file= /tmp/wf/shortcourse_945.mseed
# Processing file= /tmp/wf/shortcourse_1140.mseed
# Processing file= /tmp/wf/shortcourse_579.mseed
# Processing file= /tmp/wf/shortcourse_1006.mseed
# Processing file= /tmp/wf/shortcourse_548.mseed
# Processing file= /tmp/wf/shortcourse_541.mseed
# Processing file= /tmp/wf/shortcourse_988.mseed
# Processing file= /tmp/wf/shortcourse_220.mseed
# Processing file= /tmp/wf/shortcourse_1262.mseed
# Processing file= /tmp/wf/shortcourse_1079.mseed
# Processing file= /tmp/wf/shortcourse_60.mseed
# Processing file= /tmp/wf/shortcourse_1113.mseed
# Processing file= /tmp/wf/shortcourse_1226.mseed
# Processing file= /tmp/wf/shortcourse_1277.mseed
# Processing file= /tmp/wf/shortcourse_1084.mseed
# Processing file= /tmp/wf/shortcourse_126.mseed
# Processing file= /tmp/wf/shortcourse_614.mseed
# Processing file= /tmp/wf/shortcourse_1174.mseed
# Processing file= /tmp/wf/shortcourse_394.mseed
# Processing file= /tmp/wf/shortcourse_1025.mseed
# Processing file= /tmp/wf/shortcourse_678.mseed
# Processing file= /tmp/wf/shortcourse_244.mseed
# Processing file= /tmp/wf/shortcourse_779.mseed
# Processing file= /tmp/wf/shortcourse_745.mseed
# Processing file= /tmp/wf/shortcourse_1172.mseed
# Processing file= /tmp/wf/shortcourse_438.mseed
# Processing file= /tmp/wf/shortcourse_13.mseed
# Processing file= /tmp/wf/shortcourse_1026.mseed
# Processing file= /tmp/wf/shortcourse_43.mseed
# Processing file= /tmp/wf/shortcourse_603.mseed
# Processing file= /tmp/wf/shortcourse_71.mseed
# Processing file= /tmp/wf/shortcourse_406.mseed
# Processing file= /tmp/wf/shortcourse_423.mseed
# Processing file= /tmp/wf/shortcourse_805.mseed
# Processing file= /tmp/wf/shortcourse_857.mseed
# Processing file= /tmp/wf/shortcourse_486.mseed
# Processing file= /tmp/wf/shortcourse_97.mseed
# Processing file= /tmp/wf/shortcourse_377.mseed
# Processing file= /tmp/wf/shortcourse_1236.mseed
# Processing file= /tmp/wf/shortcourse_206.mseed
# Processing file= /tmp/wf/shortcourse_775.mseed
# Processing file= /tmp/wf/shortcourse_711.mseed
# Processing file= /tmp/wf/shortcourse_841.mseed
# Processing file= /tmp/wf/shortcourse_417.mseed
# Processing file= /tmp/wf/shortcourse_850.mseed
# Processing file= /tmp/wf/shortcourse_229.mseed
# Processing file= /tmp/wf/shortcourse_900.mseed
# Processing file= /tmp/wf/shortcourse_1255.mseed
# Processing file= /tmp/wf/shortcourse_11.mseed
# Processing file= /tmp/wf/shortcourse_29.mseed
# Processing file= /tmp/wf/shortcourse_73.mseed
# Processing file= /tmp/wf/shortcourse_454.mseed
# Processing file= /tmp/wf/shortcourse_343.mseed
# Processing file= /tmp/wf/shortcourse_695.mseed
# Processing file= /tmp/wf/shortcourse_897.mseed
# Processing file= /tmp/wf/shortcourse_845.mseed
# Processing file= /tmp/wf/shortcourse_604.mseed
# Processing file= /tmp/wf/shortcourse_508.mseed
# Processing file= /tmp/wf/shortcourse_267.mseed
# Processing file= /tmp/wf/shortcourse_968.mseed
# Processing file= /tmp/wf/shortcourse_492.mseed
# Processing file= /tmp/wf/shortcourse_383.mseed
# Processing file= /tmp/wf/shortcourse_1133.mseed
# Processing file= /tmp/wf/shortcourse_370.mseed
# Processing file= /tmp/wf/shortcourse_50.mseed
# Processing file= /tmp/wf/shortcourse_1122.mseed
# Processing file= /tmp/wf/shortcourse_990.mseed
# Processing file= /tmp/wf/shortcourse_832.mseed
# Processing file= /tmp/wf/shortcourse_270.mseed
# Processing file= /tmp/wf/shortcourse_1041.mseed
# Processing file= /tmp/wf/shortcourse_722.mseed
# Processing file= /tmp/wf/shortcourse_634.mseed
# Processing file= /tmp/wf/shortcourse_997.mseed
# Processing file= /tmp/wf/shortcourse_536.mseed
# Processing file= /tmp/wf/shortcourse_1242.mseed
# Processing file= /tmp/wf/shortcourse_1093.mseed
# Processing file= /tmp/wf/shortcourse_767.mseed
# Processing file= /tmp/wf/shortcourse_474.mseed
# Processing file= /tmp/wf/shortcourse_8.mseed
# Processing file= /tmp/wf/shortcourse_566.mseed
# Processing file= /tmp/wf/shortcourse_480.mseed
# Processing file= /tmp/wf/shortcourse_535.mseed
# Processing file= /tmp/wf/shortcourse_847.mseed
# Processing file= /tmp/wf/shortcourse_524.mseed
# Processing file= /tmp/wf/shortcourse_432.mseed
# Processing file= /tmp/wf/shortcourse_1106.mseed
# Processing file= /tmp/wf/shortcourse_118.mseed
# Processing file= /tmp/wf/shortcourse_1021.mseed
# Processing file= /tmp/wf/shortcourse_862.mseed
# Processing file= /tmp/wf/shortcourse_605.mseed
# Processing file= /tmp/wf/shortcourse_459.mseed
# Processing file= /tmp/wf/shortcourse_937.mseed
# Processing file= /tmp/wf/shortcourse_119.mseed
# Processing file= /tmp/wf/shortcourse_481.mseed
# Processing file= /tmp/wf/shortcourse_1095.mseed
# Processing file= /tmp/wf/shortcourse_62.mseed
# Processing file= /tmp/wf/shortcourse_505.mseed
# Processing file= /tmp/wf/shortcourse_319.mseed
# Processing file= /tmp/wf/shortcourse_1057.mseed
# Processing file= /tmp/wf/shortcourse_608.mseed
# Processing file= /tmp/wf/shortcourse_1071.mseed
# Processing file= /tmp/wf/shortcourse_307.mseed
# Processing file= /tmp/wf/shortcourse_697.mseed
# Processing file= /tmp/wf/shortcourse_84.mseed
# Processing file= /tmp/wf/shortcourse_572.mseed
# Processing file= /tmp/wf/shortcourse_168.mseed
# Processing file= /tmp/wf/shortcourse_881.mseed
# Processing file= /tmp/wf/shortcourse_635.mseed
# Processing file= /tmp/wf/shortcourse_468.mseed
# Processing file= /tmp/wf/shortcourse_277.mseed
# Processing file= /tmp/wf/shortcourse_960.mseed
# Processing file= /tmp/wf/shortcourse_1254.mseed
# Processing file= /tmp/wf/shortcourse_918.mseed
# Processing file= /tmp/wf/shortcourse_1194.mseed
# Processing file= /tmp/wf/shortcourse_895.mseed
# Processing file= /tmp/wf/shortcourse_582.mseed
# Processing file= /tmp/wf/shortcourse_1171.mseed
# Processing file= /tmp/wf/shortcourse_808.mseed
# Processing file= /tmp/wf/shortcourse_146.mseed
# Processing file= /tmp/wf/shortcourse_613.mseed
# Processing file= /tmp/wf/shortcourse_672.mseed
# Processing file= /tmp/wf/shortcourse_631.mseed
# Processing file= /tmp/wf/shortcourse_851.mseed
# Processing file= /tmp/wf/shortcourse_174.mseed
# Processing file= /tmp/wf/shortcourse_1177.mseed
# Processing file= /tmp/wf/shortcourse_455.mseed
# Processing file= /tmp/wf/shortcourse_1114.mseed
# Processing file= /tmp/wf/shortcourse_1283.mseed
# Processing file= /tmp/wf/shortcourse_1043.mseed
# Processing file= /tmp/wf/shortcourse_754.mseed
# Processing file= /tmp/wf/shortcourse_983.mseed
# Processing file= /tmp/wf/shortcourse_435.mseed
# Processing file= /tmp/wf/shortcourse_556.mseed
# Processing file= /tmp/wf/shortcourse_691.mseed
# Processing file= /tmp/wf/shortcourse_334.mseed
# Processing file= /tmp/wf/shortcourse_1167.mseed
# Processing file= /tmp/wf/shortcourse_600.mseed
# Processing file= /tmp/wf/shortcourse_928.mseed
# Processing file= /tmp/wf/shortcourse_1046.mseed
# Processing file= /tmp/wf/shortcourse_522.mseed
# Processing file= /tmp/wf/shortcourse_985.mseed
# Processing file= /tmp/wf/shortcourse_10.mseed
# Processing file= /tmp/wf/shortcourse_117.mseed
# Processing file= /tmp/wf/shortcourse_297.mseed
# Processing file= /tmp/wf/shortcourse_298.mseed
# Processing file= /tmp/wf/shortcourse_385.mseed
# Processing file= /tmp/wf/shortcourse_1279.mseed
# Processing file= /tmp/wf/shortcourse_39.mseed
# Processing file= /tmp/wf/shortcourse_692.mseed
# Processing file= /tmp/wf/shortcourse_612.mseed
# Processing file= /tmp/wf/shortcourse_329.mseed
# Processing file= /tmp/wf/shortcourse_1269.mseed
# Processing file= /tmp/wf/shortcourse_954.mseed
# Processing file= /tmp/wf/shortcourse_458.mseed
# Processing file= /tmp/wf/shortcourse_810.mseed
# Processing file= /tmp/wf/shortcourse_131.mseed
# Processing file= /tmp/wf/shortcourse_429.mseed
# Processing file= /tmp/wf/shortcourse_1058.mseed
# Processing file= /tmp/wf/shortcourse_1261.mseed
# Processing file= /tmp/wf/shortcourse_1286.mseed
# Processing file= /tmp/wf/shortcourse_476.mseed
# Processing file= /tmp/wf/shortcourse_625.mseed
# Processing file= /tmp/wf/shortcourse_58.mseed
# Processing file= /tmp/wf/shortcourse_366.mseed
# Processing file= /tmp/wf/shortcourse_1156.mseed
# Processing file= /tmp/wf/shortcourse_399.mseed
# Processing file= /tmp/wf/shortcourse_972.mseed
# Processing file= /tmp/wf/shortcourse_562.mseed
# Processing file= /tmp/wf/shortcourse_1032.mseed
# Processing file= /tmp/wf/shortcourse_165.mseed
# Processing file= /tmp/wf/shortcourse_632.mseed
# Processing file= /tmp/wf/shortcourse_3.mseed
# Processing file= /tmp/wf/shortcourse_949.mseed
# Processing file= /tmp/wf/shortcourse_867.mseed
# Processing file= /tmp/wf/shortcourse_872.mseed
# Processing file= /tmp/wf/shortcourse_1225.mseed
# Processing file= /tmp/wf/shortcourse_689.mseed
# Processing file= /tmp/wf/shortcourse_1111.mseed
# Processing file= /tmp/wf/shortcourse_617.mseed
# Processing file= /tmp/wf/shortcourse_112.mseed
# Processing file= /tmp/wf/shortcourse_1190.mseed
# Processing file= /tmp/wf/shortcourse_254.mseed
# Processing file= /tmp/wf/shortcourse_823.mseed
# Processing file= /tmp/wf/shortcourse_123.mseed
# Processing file= /tmp/wf/shortcourse_527.mseed
# Processing file= /tmp/wf/shortcourse_948.mseed
# Processing file= /tmp/wf/shortcourse_1130.mseed
# Processing file= /tmp/wf/shortcourse_489.mseed
# Processing file= /tmp/wf/shortcourse_69.mseed
# Processing file= /tmp/wf/shortcourse_386.mseed
# Processing file= /tmp/wf/shortcourse_574.mseed
# Processing file= /tmp/wf/shortcourse_650.mseed
# Processing file= /tmp/wf/shortcourse_645.mseed
# Processing file= /tmp/wf/shortcourse_380.mseed
# Processing file= /tmp/wf/shortcourse_1153.mseed
# Processing file= /tmp/wf/shortcourse_552.mseed
# Processing file= /tmp/wf/shortcourse_934.mseed
# Processing file= /tmp/wf/shortcourse_728.mseed
# Processing file= /tmp/wf/shortcourse_1100.mseed
# Processing file= /tmp/wf/shortcourse_1198.mseed
# Processing file= /tmp/wf/shortcourse_977.mseed
# Processing file= /tmp/wf/shortcourse_40.mseed
# Processing file= /tmp/wf/shortcourse_317.mseed
# Processing file= /tmp/wf/shortcourse_51.mseed
# Processing file= /tmp/wf/shortcourse_125.mseed
# Processing file= /tmp/wf/shortcourse_1223.mseed
# Processing file= /tmp/wf/shortcourse_1168.mseed
# Processing file= /tmp/wf/shortcourse_1083.mseed
# Processing file= /tmp/wf/shortcourse_702.mseed
# Processing file= /tmp/wf/shortcourse_2.mseed
# Processing file= /tmp/wf/shortcourse_829.mseed
# Processing file= /tmp/wf/shortcourse_1129.mseed
# Processing file= /tmp/wf/shortcourse_1010.mseed
# Processing file= /tmp/wf/shortcourse_1099.mseed
# Processing file= /tmp/wf/shortcourse_1115.mseed
# Processing file= /tmp/wf/shortcourse_794.mseed
# Processing file= /tmp/wf/shortcourse_547.mseed
# Processing file= /tmp/wf/shortcourse_208.mseed
# Processing file= /tmp/wf/shortcourse_280.mseed
# Processing file= /tmp/wf/shortcourse_894.mseed
# Processing file= /tmp/wf/shortcourse_161.mseed
# Processing file= /tmp/wf/shortcourse_274.mseed
# Processing file= /tmp/wf/shortcourse_1213.mseed
# Processing file= /tmp/wf/shortcourse_589.mseed
# Processing file= /tmp/wf/shortcourse_467.mseed
# Processing file= /tmp/wf/shortcourse_782.mseed
# Processing file= /tmp/wf/shortcourse_1195.mseed
# Processing file= /tmp/wf/shortcourse_408.mseed
# Processing file= /tmp/wf/shortcourse_1170.mseed
# Processing file= /tmp/wf/shortcourse_922.mseed
# Processing file= /tmp/wf/shortcourse_567.mseed
# Processing file= /tmp/wf/shortcourse_559.mseed
# Processing file= /tmp/wf/shortcourse_1017.mseed
# Processing file= /tmp/wf/shortcourse_725.mseed
# Processing file= /tmp/wf/shortcourse_734.mseed
# Processing file= /tmp/wf/shortcourse_1245.mseed
# Processing file= /tmp/wf/shortcourse_865.mseed
# Processing file= /tmp/wf/shortcourse_312.mseed
# Processing file= /tmp/wf/shortcourse_665.mseed
# Processing file= /tmp/wf/shortcourse_901.mseed
# Processing file= /tmp/wf/shortcourse_1188.mseed
# Processing file= /tmp/wf/shortcourse_961.mseed
# Processing file= /tmp/wf/shortcourse_151.mseed
# Processing file= /tmp/wf/shortcourse_1135.mseed
# Processing file= /tmp/wf/shortcourse_344.mseed
# Processing file= /tmp/wf/shortcourse_258.mseed
# Processing file= /tmp/wf/shortcourse_324.mseed
# Processing file= /tmp/wf/shortcourse_1094.mseed
# Processing file= /tmp/wf/shortcourse_748.mseed
# Processing file= /tmp/wf/shortcourse_338.mseed
# Processing file= /tmp/wf/shortcourse_1008.mseed
# Processing file= /tmp/wf/shortcourse_746.mseed
# Processing file= /tmp/wf/shortcourse_98.mseed
# Processing file= /tmp/wf/shortcourse_235.mseed
# Processing file= /tmp/wf/shortcourse_826.mseed
# Processing file= /tmp/wf/shortcourse_919.mseed
# Processing file= /tmp/wf/shortcourse_1154.mseed
# Processing file= /tmp/wf/shortcourse_1038.mseed
# Processing file= /tmp/wf/shortcourse_337.mseed
# Processing file= /tmp/wf/shortcourse_101.mseed
# Processing file= /tmp/wf/shortcourse_940.mseed
# Processing file= /tmp/wf/shortcourse_187.mseed
# Processing file= /tmp/wf/shortcourse_363.mseed
# Processing file= /tmp/wf/shortcourse_410.mseed
# Processing file= /tmp/wf/shortcourse_275.mseed
# Processing file= /tmp/wf/shortcourse_247.mseed
# Processing file= /tmp/wf/shortcourse_1023.mseed
# Processing file= /tmp/wf/shortcourse_971.mseed
# Processing file= /tmp/wf/shortcourse_283.mseed
# Processing file= /tmp/wf/shortcourse_1278.mseed
# Processing file= /tmp/wf/shortcourse_504.mseed
# Processing file= /tmp/wf/shortcourse_825.mseed
# Processing file= /tmp/wf/shortcourse_330.mseed
# Processing file= /tmp/wf/shortcourse_47.mseed
# Processing file= /tmp/wf/shortcourse_889.mseed
# Processing file= /tmp/wf/shortcourse_368.mseed
# Processing file= /tmp/wf/shortcourse_470.mseed
# Processing file= /tmp/wf/shortcourse_1257.mseed
# Processing file= /tmp/wf/shortcourse_300.mseed
# Processing file= /tmp/wf/shortcourse_941.mseed
# Processing file= /tmp/wf/shortcourse_677.mseed
# Processing file= /tmp/wf/shortcourse_1033.mseed
# Processing file= /tmp/wf/shortcourse_953.mseed
# Processing file= /tmp/wf/shortcourse_164.mseed
# Processing file= /tmp/wf/shortcourse_202.mseed
# Processing file= /tmp/wf/shortcourse_292.mseed
# Processing file= /tmp/wf/shortcourse_1216.mseed
# Processing file= /tmp/wf/shortcourse_682.mseed
# Processing file= /tmp/wf/shortcourse_911.mseed
# Processing file= /tmp/wf/shortcourse_786.mseed
# Processing file= /tmp/wf/shortcourse_130.mseed
# Processing file= /tmp/wf/shortcourse_271.mseed
# Processing file= /tmp/wf/shortcourse_110.mseed
# Processing file= /tmp/wf/shortcourse_1251.mseed
# Processing file= /tmp/wf/shortcourse_982.mseed
# Processing file= /tmp/wf/shortcourse_887.mseed
# Processing file= /tmp/wf/shortcourse_771.mseed
# Processing file= /tmp/wf/shortcourse_1001.mseed
# Processing file= /tmp/wf/shortcourse_178.mseed
# Processing file= /tmp/wf/shortcourse_471.mseed
# Processing file= /tmp/wf/shortcourse_1268.mseed
# Processing file= /tmp/wf/shortcourse_461.mseed
# Processing file= /tmp/wf/shortcourse_160.mseed
# Processing file= /tmp/wf/shortcourse_496.mseed
# Processing file= /tmp/wf/shortcourse_1209.mseed
# Processing file= /tmp/wf/shortcourse_905.mseed
# Processing file= /tmp/wf/shortcourse_465.mseed
# Processing file= /tmp/wf/shortcourse_240.mseed
# Processing file= /tmp/wf/shortcourse_134.mseed
# Processing file= /tmp/wf/shortcourse_182.mseed
# Processing file= /tmp/wf/shortcourse_46.mseed
# Processing file= /tmp/wf/shortcourse_20.mseed
# Processing file= /tmp/wf/shortcourse_778.mseed
# Processing file= /tmp/wf/shortcourse_843.mseed
# Processing file= /tmp/wf/shortcourse_551.mseed
# Processing file= /tmp/wf/shortcourse_494.mseed
# Processing file= /tmp/wf/shortcourse_797.mseed
# Processing file= /tmp/wf/shortcourse_987.mseed
# Processing file= /tmp/wf/shortcourse_1011.mseed
# Processing file= /tmp/wf/shortcourse_964.mseed
# Processing file= /tmp/wf/shortcourse_199.mseed
# Processing file= /tmp/wf/shortcourse_163.mseed
# Processing file= /tmp/wf/shortcourse_780.mseed
# Processing file= /tmp/wf/shortcourse_95.mseed
# Processing file= /tmp/wf/shortcourse_30.mseed
# Processing file= /tmp/wf/shortcourse_127.mseed
# Processing file= /tmp/wf/shortcourse_304.mseed
# Processing file= /tmp/wf/shortcourse_1244.mseed
# Processing file= /tmp/wf/shortcourse_457.mseed
# Processing file= /tmp/wf/shortcourse_132.mseed
# Processing file= /tmp/wf/shortcourse_770.mseed
# Processing file= /tmp/wf/shortcourse_637.mseed
# Processing file= /tmp/wf/shortcourse_558.mseed
# Processing file= /tmp/wf/shortcourse_25.mseed
# Processing file= /tmp/wf/shortcourse_497.mseed
# Processing file= /tmp/wf/shortcourse_739.mseed
# Processing file= /tmp/wf/shortcourse_760.mseed
# Processing file= /tmp/wf/shortcourse_667.mseed
# Processing file= /tmp/wf/shortcourse_863.mseed
# Processing file= /tmp/wf/shortcourse_955.mseed
# Processing file= /tmp/wf/shortcourse_1128.mseed
# Processing file= /tmp/wf/shortcourse_259.mseed
# Processing file= /tmp/wf/shortcourse_607.mseed
# Processing file= /tmp/wf/shortcourse_1024.mseed
# Processing file= /tmp/wf/shortcourse_142.mseed
# Processing file= /tmp/wf/shortcourse_242.mseed
# Processing file= /tmp/wf/shortcourse_76.mseed
# Processing file= /tmp/wf/shortcourse_225.mseed
# Processing file= /tmp/wf/shortcourse_389.mseed
# Processing file= /tmp/wf/shortcourse_1007.mseed
# Processing file= /tmp/wf/shortcourse_443.mseed
# Processing file= /tmp/wf/shortcourse_5.mseed
# Processing file= /tmp/wf/shortcourse_1159.mseed
# Processing file= /tmp/wf/shortcourse_669.mseed
# Processing file= /tmp/wf/shortcourse_785.mseed
# Processing file= /tmp/wf/shortcourse_1191.mseed
# Processing file= /tmp/wf/shortcourse_426.mseed
# Processing file= /tmp/wf/shortcourse_533.mseed
# Processing file= /tmp/wf/shortcourse_675.mseed
# Processing file= /tmp/wf/shortcourse_449.mseed
# Processing file= /tmp/wf/shortcourse_261.mseed
# Processing file= /tmp/wf/shortcourse_1053.mseed
# Processing file= /tmp/wf/shortcourse_814.mseed
# Processing file= /tmp/wf/shortcourse_966.mseed
# Processing file= /tmp/wf/shortcourse_627.mseed
# Processing file= /tmp/wf/shortcourse_339.mseed
# Processing file= /tmp/wf/shortcourse_594.mseed
# Processing file= /tmp/wf/shortcourse_927.mseed
# Processing file= /tmp/wf/shortcourse_179.mseed
# Processing file= /tmp/wf/shortcourse_933.mseed
# Processing file= /tmp/wf/shortcourse_193.mseed
# Processing file= /tmp/wf/shortcourse_86.mseed
# Processing file= /tmp/wf/shortcourse_674.mseed
# Processing file= /tmp/wf/shortcourse_930.mseed
# Processing file= /tmp/wf/shortcourse_311.mseed
# Processing file= /tmp/wf/shortcourse_1089.mseed
# Processing file= /tmp/wf/shortcourse_506.mseed
# Processing file= /tmp/wf/shortcourse_618.mseed
# Processing file= /tmp/wf/shortcourse_998.mseed
# Processing file= /tmp/wf/shortcourse_815.mseed
# Processing file= /tmp/wf/shortcourse_1264.mseed
# Processing file= /tmp/wf/shortcourse_212.mseed
# Processing file= /tmp/wf/shortcourse_1087.mseed
# Processing file= /tmp/wf/shortcourse_136.mseed
# Processing file= /tmp/wf/shortcourse_0.mseed
# Processing file= /tmp/wf/shortcourse_1103.mseed
# Processing file= /tmp/wf/shortcourse_412.mseed
# Processing file= /tmp/wf/shortcourse_1181.mseed
# Processing file= /tmp/wf/shortcourse_619.mseed
# Processing file= /tmp/wf/shortcourse_453.mseed
# Processing file= /tmp/wf/shortcourse_382.mseed
# Processing file= /tmp/wf/shortcourse_1039.mseed
# Processing file= /tmp/wf/shortcourse_1230.mseed
# Processing file= /tmp/wf/shortcourse_891.mseed
# Processing file= /tmp/wf/shortcourse_197.mseed
# Processing file= /tmp/wf/shortcourse_249.mseed
# Processing file= /tmp/wf/shortcourse_686.mseed
# Processing file= /tmp/wf/shortcourse_626.mseed
# Processing file= /tmp/wf/shortcourse_699.mseed
# Processing file= /tmp/wf/shortcourse_790.mseed
# Processing file= /tmp/wf/shortcourse_92.mseed
# Processing file= /tmp/wf/shortcourse_451.mseed
# Processing file= /tmp/wf/shortcourse_765.mseed
# Processing file= /tmp/wf/shortcourse_679.mseed
# Processing file= /tmp/wf/shortcourse_487.mseed
# Processing file= /tmp/wf/shortcourse_921.mseed
# Processing file= /tmp/wf/shortcourse_1182.mseed
# Processing file= /tmp/wf/shortcourse_358.mseed
# Processing file= /tmp/wf/shortcourse_680.mseed
# Processing file= /tmp/wf/shortcourse_376.mseed
# Processing file= /tmp/wf/shortcourse_685.mseed
# Processing file= /tmp/wf/shortcourse_575.mseed
# Processing file= /tmp/wf/shortcourse_817.mseed
# Processing file= /tmp/wf/shortcourse_906.mseed
# Processing file= /tmp/wf/shortcourse_1045.mseed
# Processing file= /tmp/wf/shortcourse_316.mseed
# Processing file= /tmp/wf/shortcourse_322.mseed
# Processing file= /tmp/wf/shortcourse_422.mseed
# Processing file= /tmp/wf/shortcourse_515.mseed
# Processing file= /tmp/wf/shortcourse_1088.mseed
# Processing file= /tmp/wf/shortcourse_425.mseed
# Processing file= /tmp/wf/shortcourse_864.mseed
# Processing file= /tmp/wf/shortcourse_170.mseed
# Processing file= /tmp/wf/shortcourse_908.mseed
# Processing file= /tmp/wf/shortcourse_647.mseed
# Processing file= /tmp/wf/shortcourse_450.mseed
# Processing file= /tmp/wf/shortcourse_1258.mseed
# Processing file= /tmp/wf/shortcourse_490.mseed
# Processing file= /tmp/wf/shortcourse_653.mseed
# Processing file= /tmp/wf/shortcourse_818.mseed
# Processing file= /tmp/wf/shortcourse_812.mseed
# Processing file= /tmp/wf/shortcourse_839.mseed
# Processing file= /tmp/wf/shortcourse_1092.mseed
# Processing file= /tmp/wf/shortcourse_952.mseed
# Processing file= /tmp/wf/shortcourse_994.mseed
# Processing file= /tmp/wf/shortcourse_904.mseed
# Number of files processed= 1287

# %% [markdown]
# Note the loop builds only an index to the waveform files. For Antelope user's that loop is functionally similar to running miniseed2db. In this case instead of creating a css3.0 "wfdisc" table we are creating a "wf_miniseed" *collection*.   (A *collection* in MongoDB plays the same role as a table/relation in a relational database but as we will see later is handled differently.)

# %% [markdown]
# ### Data Preprocessing
# #### Quick Look
# Any form of data processing requires graphical displays at times to evaluate the results.  In MsPASS we currently have a basic plotter to handle native data types.  We will not cover plotting details in this course, but students are referred to the MsPASS tutorial on graphics for additional information and guidance on alternative approaches.
#
# The following short script selects BHZ channels from the database and plots only the first 10 it finds.

# %%
from mspasspy.ccore.seismic import TimeSeriesEnsemble
from mspasspy.graphics import SeismicPlotter
ensemble=TimeSeriesEnsemble()
query={ 'chan' : 'BHZ'}
n=db.wf_miniseed.count_documents(query)
print('Number of BHZ channels=',n)
print('Plotting only first 10')
curs=db.wf_miniseed.find(query).limit(10)
ensemble = db.read_ensemble_data(curs,collection="wf_miniseed")
plotter=SeismicPlotter(normalize=True)
plotter.change_style('wtva')
plotter.plot(ensemble)
# Out:
# Number of BHZ channels= 429
# Plotting only first 10

# %% [markdown]
# One thing to note about the plot above is that the time scale is unix epoch time, but the matplotlib routines we use for the plotting convert that axis to a readable scale in seconds relative to the start time.
#
# ### Metadata Association
# #### Receiver Metadata
# In a later section of this course we will go into more details about the database we use in MsPASS.  For the present the thing to recognize is that in the first few boxes of this notebook we downloaded source and receiver metadata and saved them to the database.   We also saved the waveform data in one of two methods, but in both cases the end result was a set of data stored as miniseed files.  A property of miniseed is that a unique channel is defined by five key attributes:  network code, station code, channel code, (when set) a location code, and a time stamp.   The miniseed data have absolutely no reference to what source we are examining. Anyone who has dealt with miniseed data knows it is can be a thorny problem to associate the right source and receiver metadata with each channel of data.
#
# We have a standard database method for associating channel metadata to data objects derived from miniseed files illustrated by the following script:

# %%
cursor=db.wf_miniseed.find({})
for doc in cursor:
    net=doc['net']
    sta=doc['sta']
    chan=doc['chan']
    wftime=doc['starttime']
    chandoc=db.get_seed_channel(net,sta,chan,time=wftime)
    sitedoc=db.get_seed_site(net,sta,time=wftime)
    chanid=chandoc['_id']
    siteid=sitedoc['_id']
    wfid=doc['_id']
    match={'_id' : wfid}
    updatedef={'$set' : {'channel_id' : chanid, 'site_id' : siteid}}
    db.wf_miniseed.update_one(match,updatedef)

# %% [markdown]
# There are likely some pieces of the above that at this point you might view as an "incantation", but the key thing to notice are the calls to the database methods _get_seed_channel_ and _get_seed_site_.  Both return a special MongoDB thing called an "ObjectID" that we use extensively in MsPASS for cross-referencing.   The reason is the ObjectIDs involved always have an index defined and yield fast searches at the cost of being defined by a not so human friendly id value.  The script above finds unique records where station metadata are stored and sets an id field in each waveform.   The is done here through the low-level _update_one_ method for the database handle. The above works because of the special property of seed enforced by the FDSN that a channel of data can be uniquely identified by the five keys:  net, sta, chan, loc, and time.  We ignore loc above because we know that the TA did not use any loc codes.
#
# #### Source Metadata
# The data we are working with here is a generalization of the seismic reflection processing idea of a "shot gather", meaning the data all come from a single earthquake with a common origin time.  Miniseed data have no concept of source metadata.  The general problem of linking source information to a given waveform has near infinite complexity, but for this first-order view of MsPASS the algorithm we need is pretty trivial; the complexity is only in the arcane syntax of MongoDB we need to make implement it:

# %%
doc=db.source.find_one()
srcid=doc['_id']
cursor=db.wf_miniseed.find({})
for doc in cursor:
    wfid=doc['_id']
    db.wf_miniseed.update_one({'_id' : wfid},{'$set' : {'source_id' : srcid}})

# %% [markdown]
# To show that did something useful here we read back the first 6 waveforms and show how source and receiver data are stored in the generalized headers for these data:

# %%
cursor=db.wf_miniseed.find({}).limit(6)
print('net sta chan channel_lat channel_lon channel_elev source_lat source_lon source_depth source_time')
normalize_list=['source','channel']
for doc in cursor:
    d=db.read_data(doc,normalize=normalize_list,collection='wf_miniseed')
    print(d['net'],d['sta'],d['chan'],d['channel_lat'],d['channel_lon'],d['channel_elev'],
         d['source_lat'],d['source_lon'],d['source_depth'],UTCDateTime(d['source_time']))
# Out:
# net sta chan channel_lat channel_lon channel_elev source_lat source_lon source_depth source_time
# TA 136A BHZ 32.474602 -96.529701 0.113 38.2513 141.7296 53.2 2011-04-07T14:32:44.100000Z
# TA F32A BHE 45.870499 -97.126404 0.371 38.2513 141.7296 53.2 2011-04-07T14:32:44.100000Z
# TA 737A BHZ 28.763901 -96.440201 0.011 38.2513 141.7296 53.2 2011-04-07T14:32:44.100000Z
# TA E33A BHZ 46.503502 -96.005402 0.428 38.2513 141.7296 53.2 2011-04-07T14:32:44.100000Z
# TA J34A BHZ 43.284401 -95.957901 0.432 38.2513 141.7296 53.2 2011-04-07T14:32:44.100000Z
# TA Q37A BHE 38.876301 -94.452202 0.297 38.2513 141.7296 53.2 2011-04-07T14:32:44.100000Z

# %% [markdown]
# ## Simple Serial Workflows
# In section we illustrate some simple MsPASS workflows that use simple serlia processing driven by for loops.  In the main section following we will show a parallel version of the most elaborate serial workflow.
# ### Cut around P time
# Our first example just reads the first 5 waveforms in the database, applies a simple filter, computes a theoretical P wave arrival time from the source and receiver metadata, windows the data relative to that P wave arrival time, and then plots the data.

# %%
from mspasspy.algorithms.window import WindowData
from mspasspy.algorithms.signals import filter
from mspasspy.ccore.algorithms.basic import TimeWindow
from obspy.taup import TauPyModel
model = TauPyModel(model="iasp91")
from obspy.geodetics import gps2dist_azimuth,kilometers2degrees
# First we load all the data we want to work with into a single ensemble object
# limited to 5 here to keep the plot legible
ensemble=TimeSeriesEnsemble()
#cursor=db.wf_miniseed.find({'chan' : 'BHZ'}).limit(5)
cursor=db.wf_miniseed.find({}).limit(5)
ensemble=db.read_ensemble_data(cursor,collection='wf_miniseed',normalize=normalize_list)

# This a time window in time relative to P arrival around 
# which we cut each waveform
cutwin=TimeWindow(-20.0,100.0)
i=0
for d in ensemble.member:
    filter(d,'bandpass',freqmax=2.0,freqmin=0.005)
    stalat=d['channel_lat']
    stalon=d['channel_lon']
    srclat=d['source_lat']
    srclon=d['source_lon']
    depth=d['source_depth']
    otime=d['source_time']
    georesult=gps2dist_azimuth(srclat,srclon,stalat,stalon)
    # obspy's function we just called returns distance in m in element 0 of a tuple
    # their travel time calculator it is degrees so we need this conversion
    dist=kilometers2degrees(georesult[0]/1000.0)
    arrivals=model.get_travel_times(source_depth_in_km=depth,distance_in_degree=dist,phase_list=['P'])
    # Arrivals are returned in time order 0 is always the first arrival
    # This computes arrival time as an epoch time and shifts the data to put 0 at that time
    d.ator(otime+arrivals[0].time)
    #d=WindowData(d,cutwin)
    ensemble.member[i]=WindowData(d,cutwin.start,cutwin.end)
    i+=1
plotter.plot(ensemble)

# %% [markdown]
# ### Bundle into Seismogram objects
# A novel feature of MsPASS is treating three-component data as a distinct data type.   The following box does that process to a subset of the entire data set.  We only do a subset of the data for two reasons.  (1) The default memory allocation in docker may cause problems on some machines if we used the algorithm below the full event gather.  (2)  An intentiona error allows us to illustrate another key feature of MsPASS.

# %%
from mspasspy.algorithms.bundle import bundle_seed_data
# This query causes the list of TimeSeries to be sorted by sta name
# We need that only because we are also limiting the number of data read
cursor=db.wf_miniseed.find({}).limit(10).sort('sta',1)
ensemble=db.read_ensemble_data(cursor,collection='wf_miniseed',normalize=normalize_list)
print('Ensemble size=',len(ensemble.member))
print('running bundle_seed_ensemble')
d3c=bundle_seed_data(ensemble)
print('Size of bundled ensemble=',len(d3c.member))

db.save_ensemble_data(d3c,data_tag='rawsample')
# Out:
# Ensemble size= 10
# running bundle_seed_ensemble
# Size of bundled ensemble= 4

# %% [markdown]
# Now if we are assembling bundles of 3 from a set of 10 TimeSeries what is the best that could happen?  We'd get 3 groups of 3 and one orphan.   Why did we get 4 bundles then?  This clarifies why as well as allowing me to use the best python joke ever!

# %%
from mspasspy.util.Undertaker import Undertaker
print('station status')
for d in d3c.member:
    print(d['sta'],d.live)
stedronsky=Undertaker(db)
[good_guys,zombies]=stedronsky.bring_out_your_dead(d3c)
print('\nThe undertaker found ',len(good_guys.member),
      ' data objects were marked live and ',len(zombies.member),' were marked dead\n')
print('Error log showing why datum was killed')
for i in range(len(zombies.member)):
    log=zombies.member[i].elog.get_error_log()
    for m in log:
        print(m.algorithm,m.message)
# Out:
# station status
# 109C False
# 035Z True
# 035A True
# 034A True
#
# The undertaker found  3  data objects were marked live and  1  were marked dead
#
# Error log showing why datum was killed
# bundle_seed_data Insufficient data to generate Seismogram object.
# Number of channels received  for bundling=1
# Number marked live=1
# Number live must be at least 3

# %% [markdown]
# This illustrates two important concepts used in MsPASS that you need to recognize:
# 1.   We borrow the ancient practice of marking data dead from from seismic reflection data processing. As we will see later that approach is critical for the parallel processing system to work cleanly.
# 2.   Errors are always something that have to be handled because only a trivial data set is clean enough to not generate one or more problems that have to be handled.  Again because of the parallel framework the cleanest way we found to handle this is to carry the errors along with the data with which that error is associated.   The *elog* symbol contains that error log in each data object.

# %% [markdown]
# ### Database clean method
# Converting data downloaded miniseed into these three component data objects creates a bunch of metadata inconsistencies.  In this case it is pervasive, but a whole range of things can create database inconsistencies a system like MsPASS needs to handled.
#
# To see the specific problem here let's just take a look at the metadata associated with the first
# seismogram.

# %%
from bson import json_util
n3c=db.wf_Seismogram.count_documents({})
print('Database current has ',n3c,' Seismogram objects')
doc=db.wf_Seismogram.find_one()
print(json_util.dumps(doc,indent=2))
# Out:
# Database current has  3  Seismogram objects
# {
#   "_id": {
#     "$oid": "62a11fee982bfdae8393ba41"
#   },
#   "channel_elev": 0.019,
#   "channel_lon": -98.068298,
#   "dfile": "shortcourse_8.mseed",
#   "channel_id": {
#     "$oid": "62a11f78982bfdae8393b024"
#   },
#   "cardinal": false,
#   "channel_endtime": 1321815600.0,
#   "orthogonal": false,
#   "storage_mode": "gridfs",
#   "nbytes": 65536,
#   "tmatrix": [
#     0.0,
#     0.0,
#     1.0,
#     0.00872653549840032,
#     0.9999619230641711,
#     2.6484540326036093e-14,
#     0.9999619230641713,
#     -0.008726535498373787,
#     2.6484540326036093e-14
#   ],
#   "time_standard": "Relative",
#   "format": "mseed",
#   "utc_convertible": false,
#   "dir": "/tmp/wf",
#   "chan": "BHZ",
#   "channel_edepth": 0.0,
#   "delta": 0.025,
#   "last_packet_time": 1302188741.6499999,
#   "starttime": 1302187287.1,
#   "site_id": {
#     "$oid": "62a11f78982bfdae8393b022"
#   },
#   "channel_starttime": 1262995200.0,
#   "foff": 0,
#   "source_id": {
#     "$oid": "62a11f6d982bfdae8393b01b"
#   },
#   "sampling_rate": 40.0,
#   "npts": 55566,
#   "channel_lat": 26.462999,
#   "gridfs_id": {
#     "$oid": "62a11fee982bfdae8393ba3a"
#   },
#   "history_object_id": "a33d01e8-162d-4273-b283-ca000166d203",
#   "data_tag": "rawsample"
# }

# %% [markdown]
# There are a number of attributes that are inconsistent with the data that are relics of single channel concepts, which we call TimeSeries data.   Examples are "chan" and several items with the structure "channel_X" where X is some suffix whose meaning you might guess (e.g. channel_lat is station latitude).
#
# We can fix these easily with a special method in the Database object we call clean_collection

# %%
db.clean_collection('wf_Seismogram',delete_undefined=True)
doc=db.wf_Seismogram.find_one()
print(json_util.dumps(doc,indent=2))
# Out:
# {
#   "_id": {
#     "$oid": "62a11fee982bfdae8393ba41"
#   },
#   "dfile": "shortcourse_8.mseed",
#   "cardinal": false,
#   "orthogonal": false,
#   "storage_mode": "gridfs",
#   "tmatrix": [
#     0.0,
#     0.0,
#     1.0,
#     0.00872653549840032,
#     0.9999619230641711,
#     2.6484540326036093e-14,
#     0.9999619230641713,
#     -0.008726535498373787,
#     2.6484540326036093e-14
#   ],
#   "time_standard": "Relative",
#   "format": "mseed",
#   "utc_convertible": false,
#   "dir": "/tmp/wf",
#   "delta": 0.025,
#   "starttime": 1302187287.1,
#   "site_id": {
#     "$oid": "62a11f78982bfdae8393b022"
#   },
#   "foff": 0,
#   "source_id": {
#     "$oid": "62a11f6d982bfdae8393b01b"
#   },
#   "sampling_rate": 40.0,
#   "npts": 55566,
#   "gridfs_id": {
#     "$oid": "62a11fee982bfdae8393ba3a"
#   },
#   "history_object_id": "a33d01e8-162d-4273-b283-ca000166d203",
#   "data_tag": "rawsample"
# }

# %% [markdown]
# Most of the relics are gone now, although there are a few that require a different approach to repair we will not inflict on you for now.
#
# The final point about data saved as *Seismogram* objectgs is they contain all the data and internal methods needed to handle any coordinate transformation. The next box illustrates this further:

# %%
doc=db.wf_Seismogram.find_one()
print('transformation matrix defined in database')
print(doc['tmatrix'])
d=db.read_data(doc,collection='wf_Seismogram')
# this just makes the data look a little better
filter(d,'bandpass',freqmax=2.0,freqmin=0.01)
plotter.title='Data read from database'
plotter.plot(d)
# Out:
# transformation matrix defined in database
# [0.0, 0.0, 1.0, 0.00872653549840032, 0.9999619230641711, 2.6484540326036093e-14, 0.9999619230641713, -0.008726535498373787, 2.6484540326036093e-14]

# %% [markdown]
# What the printed output and the graphic show is that the data bundle assembled are not in cardinal directions (EW, NS, Z).  There are two reasons for that in this case:  (1) the TA measured orientations to high accuracy and the metadata told the system the measured orientations that were used to compute the transformation matrix, and (2) the bundle algorithm we ran didn't bother to try to assemble the components in any standard order.  We can regularize the data with a method in Seismogram used like this:

# %%
d.rotate_to_standard()
plotter.title='Data in cardinal coordinates'
plotter.plot(d)

# %% [markdown]
# Finally, we want to do some more things with Seismogram data in the next session.  What we did above was intentionally small to keep the output small.  Here we do the same process, but aim for 100 Seismogram objects in the read and add a line to save the result to the database.

# %%
cursor=db.wf_miniseed.find({}).limit(300).sort('sta',1)
ensemble=db.read_ensemble_data(cursor,collection='wf_miniseed',normalize=normalize_list)
print('Ensemble size=',len(ensemble.member))
d3c=bundle_seed_data(ensemble)
print('Size of bundled ensemble=',len(d3c.member))
db.save_ensemble_data(d3c,data_tag='rawdataset')
# Out:
# Ensemble size= 300
# Size of bundled ensemble= 100
