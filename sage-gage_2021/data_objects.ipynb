# %% [markdown]
# # Session 2:  MsPASS Generalized Headers (Metadata container)
# ## Basic Metadata Operations
# This tutorial assumes you have already completed the session 1 getting started tutorial.  There we saved waveform data downloaded with FDSN web services to a folder called "./wf".  In this session we are going to build an alternative form for handling input with raw miniseed data rather than converting the data immediately to MsPASS data objects.  Reading directly from miniseed is a useful feature, but since most of the students in this course are likely to have some experience with miniseed the hope is the header namespace this creates will be familiar ground. We will also be using the paradigm of one file per channel of data that SAC users are familiar with.   We do that for the educational benefit.  We presume it is familiar ground to most students and helps clarify a key relationship of what metadata belong to which signal. A noteworth point, however, is we consider the model of one file per signal an abomination that needs to be exorcised from data management dogma because it creates horrible performance problems on HPC systems.
#
# Our first step is to read the set of miniseed files we created in session1.  First, let's just use a python way to look into that directory:

# %%
import os
with os.scandir('./wf') as entries:
    for entry in entries:
        print(entry.name)
# Out:
# wfshortcourse_1091.mseed
# wfshortcourse_1186.mseed
# wfshortcourse_450.mseed
# wfshortcourse_584.mseed
# wfshortcourse_255.mseed
# wfshortcourse_522.mseed
# wfshortcourse_539.mseed
# wfshortcourse_1019.mseed
# wfshortcourse_781.mseed
# wfshortcourse_761.mseed
# wfshortcourse_109.mseed
# wfshortcourse_637.mseed
# wfshortcourse_668.mseed
# wfshortcourse_849.mseed
# wfshortcourse_565.mseed
# wfshortcourse_138.mseed
# wfshortcourse_1117.mseed
# wfshortcourse_24.mseed
# wfshortcourse_729.mseed
# wfshortcourse_645.mseed
# wfshortcourse_985.mseed
# wfshortcourse_474.mseed
# wfshortcourse_1115.mseed
# wfshortcourse_33.mseed
# wfshortcourse_967.mseed
# wfshortcourse_424.mseed
# wfshortcourse_180.mseed
# wfshortcourse_1063.mseed
# wfshortcourse_994.mseed
# wfshortcourse_757.mseed
# wfshortcourse_316.mseed
# wfshortcourse_332.mseed
# wfshortcourse_618.mseed
# wfshortcourse_499.mseed
# wfshortcourse_1262.mseed
# wfshortcourse_1207.mseed
# wfshortcourse_276.mseed
# wfshortcourse_1018.mseed
# wfshortcourse_913.mseed
# wfshortcourse_1102.mseed
# wfshortcourse_1208.mseed
# wfshortcourse_826.mseed
# wfshortcourse_404.mseed
# wfshortcourse_834.mseed
# wfshortcourse_1083.mseed
# wfshortcourse_340.mseed
# wfshortcourse_599.mseed
# wfshortcourse_1215.mseed
# wfshortcourse_620.mseed
# wfshortcourse_309.mseed
# wfshortcourse_83.mseed
# wfshortcourse_25.mseed
# wfshortcourse_428.mseed
# wfshortcourse_771.mseed
# wfshortcourse_1271.mseed
# wfshortcourse_308.mseed
# wfshortcourse_306.mseed
# wfshortcourse_573.mseed
# wfshortcourse_373.mseed
# wfshortcourse_438.mseed
# wfshortcourse_436.mseed
# wfshortcourse_62.mseed
# wfshortcourse_671.mseed
# wfshortcourse_425.mseed
# wfshortcourse_49.mseed
# wfshortcourse_1057.mseed
# wfshortcourse_385.mseed
# wfshortcourse_1032.mseed
# wfshortcourse_34.mseed
# wfshortcourse_1074.mseed
# wfshortcourse_915.mseed
# wfshortcourse_714.mseed
# wfshortcourse_301.mseed
# wfshortcourse_61.mseed
# wfshortcourse_551.mseed
# wfshortcourse_925.mseed
# wfshortcourse_587.mseed
# wfshortcourse_8.mseed
# wfshortcourse_593.mseed
# wfshortcourse_507.mseed
# wfshortcourse_5.mseed
# wfshortcourse_1246.mseed
# wfshortcourse_106.mseed
# wfshortcourse_1003.mseed
# wfshortcourse_479.mseed
# wfshortcourse_989.mseed
# wfshortcourse_927.mseed
# wfshortcourse_1082.mseed
# wfshortcourse_559.mseed
# wfshortcourse_1175.mseed
# wfshortcourse_748.mseed
# wfshortcourse_235.mseed
# wfshortcourse_513.mseed
# wfshortcourse_614.mseed
# wfshortcourse_342.mseed
# wfshortcourse_1231.mseed
# wfshortcourse_894.mseed
# wfshortcourse_953.mseed
# wfshortcourse_1029.mseed
# wfshortcourse_31.mseed
# wfshortcourse_1179.mseed
# wfshortcourse_268.mseed
# wfshortcourse_1227.mseed
# wfshortcourse_320.mseed
# wfshortcourse_952.mseed
# wfshortcourse_662.mseed
# wfshortcourse_228.mseed
# wfshortcourse_920.mseed
# wfshortcourse_305.mseed
# wfshortcourse_2.mseed
# wfshortcourse_1268.mseed
# wfshortcourse_880.mseed
# wfshortcourse_348.mseed
# wfshortcourse_1045.mseed
# wfshortcourse_28.mseed
# wfshortcourse_388.mseed
# wfshortcourse_670.mseed
# wfshortcourse_1111.mseed
# wfshortcourse_161.mseed
# wfshortcourse_926.mseed
# wfshortcourse_1251.mseed
# wfshortcourse_392.mseed
# wfshortcourse_678.mseed
# wfshortcourse_561.mseed
# wfshortcourse_589.mseed
# wfshortcourse_858.mseed
# wfshortcourse_152.mseed
# wfshortcourse_1166.mseed
# wfshortcourse_800.mseed
# wfshortcourse_793.mseed
# wfshortcourse_219.mseed
# wfshortcourse_801.mseed
# wfshortcourse_382.mseed
# wfshortcourse_1282.mseed
# wfshortcourse_351.mseed
# wfshortcourse_641.mseed
# wfshortcourse_258.mseed
# wfshortcourse_440.mseed
# wfshortcourse_938.mseed
# wfshortcourse_887.mseed
# wfshortcourse_261.mseed
# wfshortcourse_80.mseed
# wfshortcourse_100.mseed
# wfshortcourse_137.mseed
# wfshortcourse_469.mseed
# wfshortcourse_211.mseed
# wfshortcourse_616.mseed
# wfshortcourse_322.mseed
# wfshortcourse_1217.mseed
# wfshortcourse_788.mseed
# wfshortcourse_621.mseed
# wfshortcourse_1286.mseed
# wfshortcourse_1131.mseed
# wfshortcourse_652.mseed
# wfshortcourse_275.mseed
# wfshortcourse_1056.mseed
# wfshortcourse_230.mseed
# wfshortcourse_731.mseed
# wfshortcourse_613.mseed
# wfshortcourse_54.mseed
# wfshortcourse_1150.mseed
# wfshortcourse_1263.mseed
# wfshortcourse_226.mseed
# wfshortcourse_1195.mseed
# wfshortcourse_976.mseed
# wfshortcourse_457.mseed
# wfshortcourse_173.mseed
# wfshortcourse_831.mseed
# wfshortcourse_1028.mseed
# wfshortcourse_177.mseed
# wfshortcourse_460.mseed
# wfshortcourse_608.mseed
# wfshortcourse_609.mseed
# wfshortcourse_169.mseed
# wfshortcourse_167.mseed
# wfshortcourse_679.mseed
# wfshortcourse_270.mseed
# wfshortcourse_996.mseed
# wfshortcourse_405.mseed
# wfshortcourse_57.mseed
# wfshortcourse_1135.mseed
# wfshortcourse_1027.mseed
# wfshortcourse_1167.mseed
# wfshortcourse_455.mseed
# wfshortcourse_52.mseed
# wfshortcourse_204.mseed
# wfshortcourse_1216.mseed
# wfshortcourse_399.mseed
# wfshortcourse_511.mseed
# wfshortcourse_883.mseed
# wfshortcourse_1040.mseed
# wfshortcourse_909.mseed
# wfshortcourse_918.mseed
# wfshortcourse_542.mseed
# wfshortcourse_600.mseed
# wfshortcourse_123.mseed
# wfshortcourse_487.mseed
# wfshortcourse_604.mseed
# wfshortcourse_1244.mseed
# wfshortcourse_1026.mseed
# wfshortcourse_881.mseed
# wfshortcourse_483.mseed
# wfshortcourse_476.mseed
# wfshortcourse_873.mseed
# wfshortcourse_297.mseed
# wfshortcourse_924.mseed
# wfshortcourse_353.mseed
# wfshortcourse_991.mseed
# wfshortcourse_172.mseed
# wfshortcourse_940.mseed
# wfshortcourse_957.mseed
# wfshortcourse_505.mseed
# wfshortcourse_721.mseed
# wfshortcourse_541.mseed
# wfshortcourse_114.mseed
# wfshortcourse_65.mseed
# wfshortcourse_431.mseed
# wfshortcourse_978.mseed
# wfshortcourse_250.mseed
# wfshortcourse_32.mseed
# wfshortcourse_820.mseed
# wfshortcourse_825.mseed
# wfshortcourse_959.mseed
# wfshortcourse_806.mseed
# wfshortcourse_1014.mseed
# wfshortcourse_1092.mseed
# wfshortcourse_979.mseed
# wfshortcourse_1169.mseed
# wfshortcourse_1065.mseed
# wfshortcourse_892.mseed
# wfshortcourse_66.mseed
# wfshortcourse_287.mseed
# wfshortcourse_1171.mseed
# wfshortcourse_1272.mseed
# wfshortcourse_669.mseed
# wfshortcourse_916.mseed
# wfshortcourse_983.mseed
# wfshortcourse_627.mseed
# wfshortcourse_1002.mseed
# wfshortcourse_1147.mseed
# wfshortcourse_1009.mseed
# wfshortcourse_35.mseed
# wfshortcourse_832.mseed
# wfshortcourse_366.mseed
# wfshortcourse_112.mseed
# wfshortcourse_946.mseed
# wfshortcourse_890.mseed
# wfshortcourse_819.mseed
# wfshortcourse_582.mseed
# wfshortcourse_632.mseed
# wfshortcourse_402.mseed
# wfshortcourse_945.mseed
# wfshortcourse_610.mseed
# wfshortcourse_376.mseed
# wfshortcourse_720.mseed
# wfshortcourse_531.mseed
# wfshortcourse_655.mseed
# wfshortcourse_822.mseed
# wfshortcourse_191.mseed
# wfshortcourse_765.mseed
# wfshortcourse_429.mseed
# wfshortcourse_44.mseed
# wfshortcourse_202.mseed
# wfshortcourse_168.mseed
# wfshortcourse_94.mseed
# wfshortcourse_126.mseed
# wfshortcourse_795.mseed
# wfshortcourse_470.mseed
# wfshortcourse_291.mseed
# wfshortcourse_876.mseed
# wfshortcourse_163.mseed
# wfshortcourse_466.mseed
# wfshortcourse_411.mseed
# wfshortcourse_827.mseed
# wfshortcourse_1047.mseed
# wfshortcourse_69.mseed
# wfshortcourse_39.mseed
# wfshortcourse_712.mseed
# wfshortcourse_1059.mseed
# wfshortcourse_935.mseed
# wfshortcourse_1213.mseed
# wfshortcourse_1054.mseed
# wfshortcourse_734.mseed
# wfshortcourse_1125.mseed
# wfshortcourse_1219.mseed
# wfshortcourse_684.mseed
# wfshortcourse_749.mseed
# wfshortcourse_472.mseed
# wfshortcourse_1000.mseed
# wfshortcourse_200.mseed
# wfshortcourse_1104.mseed
# wfshortcourse_345.mseed
# wfshortcourse_710.mseed
# wfshortcourse_1177.mseed
# wfshortcourse_288.mseed
# wfshortcourse_813.mseed
# wfshortcourse_674.mseed
# wfshortcourse_838.mseed
# wfshortcourse_673.mseed
# wfshortcourse_1023.mseed
# wfshortcourse_179.mseed
# wfshortcourse_898.mseed
# wfshortcourse_707.mseed
# wfshortcourse_75.mseed
# wfshortcourse_844.mseed
# wfshortcourse_698.mseed
# wfshortcourse_579.mseed
# wfshortcourse_51.mseed
# wfshortcourse_110.mseed
# wfshortcourse_687.mseed
# wfshortcourse_878.mseed
# wfshortcourse_980.mseed
# wfshortcourse_271.mseed
# wfshortcourse_93.mseed
# wfshortcourse_853.mseed
# wfshortcourse_961.mseed
# wfshortcourse_969.mseed
# wfshortcourse_1038.mseed
# wfshortcourse_59.mseed
# wfshortcourse_105.mseed
# wfshortcourse_408.mseed
# wfshortcourse_1119.mseed
# wfshortcourse_797.mseed
# wfshortcourse_1204.mseed
# wfshortcourse_1103.mseed
# wfshortcourse_886.mseed
# wfshortcourse_1005.mseed
# wfshortcourse_1149.mseed
# wfshortcourse_409.mseed
# wfshortcourse_1196.mseed
# wfshortcourse_222.mseed
# wfshortcourse_824.mseed
# wfshortcourse_434.mseed
# wfshortcourse_437.mseed
# wfshortcourse_948.mseed
# wfshortcourse_625.mseed
# wfshortcourse_690.mseed
# wfshortcourse_1161.mseed
# wfshortcourse_802.mseed
# wfshortcourse_1071.mseed
# wfshortcourse_478.mseed
# wfshortcourse_406.mseed
# wfshortcourse_497.mseed
# wfshortcourse_779.mseed
# wfshortcourse_780.mseed
# wfshortcourse_367.mseed
# wfshortcourse_249.mseed
# wfshortcourse_136.mseed
# wfshortcourse_1199.mseed
# wfshortcourse_1114.mseed
# wfshortcourse_426.mseed
# wfshortcourse_1178.mseed
# wfshortcourse_635.mseed
# wfshortcourse_262.mseed
# wfshortcourse_495.mseed
# wfshortcourse_1132.mseed
# wfshortcourse_22.mseed
# wfshortcourse_1224.mseed
# wfshortcourse_977.mseed
# wfshortcourse_42.mseed
# wfshortcourse_357.mseed
# wfshortcourse_246.mseed
# wfshortcourse_891.mseed
# wfshortcourse_677.mseed
# wfshortcourse_756.mseed
# wfshortcourse_92.mseed
# wfshortcourse_334.mseed
# wfshortcourse_726.mseed
# wfshortcourse_724.mseed
# wfshortcourse_369.mseed
# wfshortcourse_816.mseed
# wfshortcourse_1200.mseed
# wfshortcourse_1257.mseed
# wfshortcourse_569.mseed
# wfshortcourse_486.mseed
# wfshortcourse_942.mseed
# wfshortcourse_1236.mseed
# wfshortcourse_358.mseed
# wfshortcourse_526.mseed
# wfshortcourse_1137.mseed
# wfshortcourse_154.mseed
# wfshortcourse_1221.mseed
# wfshortcourse_951.mseed
# wfshortcourse_344.mseed
# wfshortcourse_850.mseed
# wfshortcourse_1226.mseed
# wfshortcourse_990.mseed
# wfshortcourse_867.mseed
# wfshortcourse_1073.mseed
# wfshortcourse_243.mseed
# wfshortcourse_1220.mseed
# wfshortcourse_1122.mseed
# wfshortcourse_862.mseed
# wfshortcourse_739.mseed
# wfshortcourse_933.mseed
# wfshortcourse_212.mseed
# wfshortcourse_414.mseed
# wfshortcourse_349.mseed
# wfshortcourse_150.mseed
# wfshortcourse_527.mseed
# wfshortcourse_64.mseed
# wfshortcourse_1238.mseed
# wfshortcourse_908.mseed
# wfshortcourse_127.mseed
# wfshortcourse_1241.mseed
# wfshortcourse_1031.mseed
# wfshortcourse_702.mseed
# wfshortcourse_1163.mseed
# wfshortcourse_1070.mseed
# wfshortcourse_815.mseed
# wfshortcourse_335.mseed
# wfshortcourse_1064.mseed
# wfshortcourse_343.mseed
# wfshortcourse_960.mseed
# wfshortcourse_327.mseed
# wfshortcourse_665.mseed
# wfshortcourse_769.mseed
# wfshortcourse_142.mseed
# wfshortcourse_1230.mseed
# wfshortcourse_374.mseed
# wfshortcourse_789.mseed
# wfshortcourse_596.mseed
# wfshortcourse_1141.mseed
# wfshortcourse_738.mseed
# wfshortcourse_676.mseed
# wfshortcourse_554.mseed
# wfshortcourse_703.mseed
# wfshortcourse_595.mseed
# wfshortcourse_463.mseed
# wfshortcourse_747.mseed
# wfshortcourse_696.mseed
# wfshortcourse_753.mseed
# wfshortcourse_563.mseed
# wfshortcourse_642.mseed
# wfshortcourse_536.mseed
# wfshortcourse_102.mseed
# wfshortcourse_956.mseed
# wfshortcourse_737.mseed
# wfshortcourse_77.mseed
# wfshortcourse_728.mseed
# wfshortcourse_889.mseed
# wfshortcourse_699.mseed
# wfshortcourse_570.mseed
# wfshortcourse_11.mseed
# wfshortcourse_503.mseed
# wfshortcourse_842.mseed
# wfshortcourse_159.mseed
# wfshortcourse_1052.mseed
# wfshortcourse_868.mseed
# wfshortcourse_863.mseed
# wfshortcourse_1120.mseed
# wfshortcourse_514.mseed
# wfshortcourse_943.mseed
# wfshortcourse_1187.mseed
# wfshortcourse_453.mseed
# wfshortcourse_543.mseed
# wfshortcourse_456.mseed
# wfshortcourse_775.mseed
# wfshortcourse_224.mseed
# wfshortcourse_1033.mseed
# wfshortcourse_164.mseed
# wfshortcourse_1076.mseed
# wfshortcourse_590.mseed
# wfshortcourse_1068.mseed
# wfshortcourse_523.mseed
# wfshortcourse_489.mseed
# wfshortcourse_273.mseed
# wfshortcourse_207.mseed
# wfshortcourse_1143.mseed
# wfshortcourse_634.mseed
# wfshortcourse_467.mseed
# wfshortcourse_354.mseed
# wfshortcourse_902.mseed
# wfshortcourse_156.mseed
# wfshortcourse_1237.mseed
# wfshortcourse_384.mseed
# wfshortcourse_289.mseed
# wfshortcourse_619.mseed
# wfshortcourse_1130.mseed
# wfshortcourse_1158.mseed
# wfshortcourse_1165.mseed
# wfshortcourse_1021.mseed
# wfshortcourse_1245.mseed
# wfshortcourse_564.mseed
# wfshortcourse_1030.mseed
# wfshortcourse_37.mseed
# wfshortcourse_906.mseed
# wfshortcourse_296.mseed
# wfshortcourse_475.mseed
# wfshortcourse_751.mseed
# wfshortcourse_580.mseed
# wfshortcourse_1046.mseed
# wfshortcourse_220.mseed
# wfshortcourse_328.mseed
# wfshortcourse_197.mseed
# wfshortcourse_535.mseed
# wfshortcourse_576.mseed
# wfshortcourse_1004.mseed
# wfshortcourse_76.mseed
# wfshortcourse_615.mseed
# wfshortcourse_403.mseed
# wfshortcourse_611.mseed
# wfshortcourse_484.mseed
# wfshortcourse_528.mseed
# wfshortcourse_58.mseed
# wfshortcourse_810.mseed
# wfshortcourse_746.mseed
# wfshortcourse_1086.mseed
# wfshortcourse_213.mseed
# wfshortcourse_770.mseed
# wfshortcourse_733.mseed
# wfshortcourse_932.mseed
# wfshortcourse_550.mseed
# wfshortcourse_236.mseed
# wfshortcourse_667.mseed
# wfshortcourse_199.mseed
# wfshortcourse_1123.mseed
# wfshortcourse_1049.mseed
# wfshortcourse_1201.mseed
# wfshortcourse_847.mseed
# wfshortcourse_742.mseed
# wfshortcourse_162.mseed
# wfshortcourse_704.mseed
# wfshortcourse_586.mseed
# wfshortcourse_1099.mseed
# wfshortcourse_949.mseed
# wfshortcourse_719.mseed
# wfshortcourse_337.mseed
# wfshortcourse_888.mseed
# wfshortcourse_1154.mseed
# wfshortcourse_884.mseed
# wfshortcourse_101.mseed
# wfshortcourse_135.mseed
# wfshortcourse_540.mseed
# wfshortcourse_1061.mseed
# wfshortcourse_1239.mseed
# wfshortcourse_372.mseed
# wfshortcourse_1062.mseed
# wfshortcourse_644.mseed
# wfshortcourse_203.mseed
# wfshortcourse_864.mseed
# wfshortcourse_363.mseed
# wfshortcourse_1124.mseed
# wfshortcourse_835.mseed
# wfshortcourse_964.mseed
# wfshortcourse_965.mseed
# wfshortcourse_577.mseed
# wfshortcourse_633.mseed
# wfshortcourse_846.mseed
# wfshortcourse_937.mseed
# wfshortcourse_1156.mseed
# wfshortcourse_799.mseed
# wfshortcourse_452.mseed
# wfshortcourse_234.mseed
# wfshortcourse_441.mseed
# wfshortcourse_7.mseed
# wfshortcourse_381.mseed
# wfshortcourse_1225.mseed
# wfshortcourse_705.mseed
# wfshortcourse_544.mseed
# wfshortcourse_194.mseed
# wfshortcourse_86.mseed
# wfshortcourse_598.mseed
# wfshortcourse_45.mseed
# wfshortcourse_1129.mseed
# wfshortcourse_517.mseed
# wfshortcourse_502.mseed
# wfshortcourse_686.mseed
# wfshortcourse_229.mseed
# wfshortcourse_905.mseed
# wfshortcourse_646.mseed
# wfshortcourse_1280.mseed
# wfshortcourse_560.mseed
# wfshortcourse_209.mseed
# wfshortcourse_285.mseed
# wfshortcourse_201.mseed
# wfshortcourse_430.mseed
# wfshortcourse_139.mseed
# wfshortcourse_804.mseed
# wfshortcourse_897.mseed
# wfshortcourse_697.mseed
# wfshortcourse_1261.mseed
# wfshortcourse_1168.mseed
# wfshortcourse_443.mseed
# wfshortcourse_318.mseed
# wfshortcourse_1198.mseed
# wfshortcourse_371.mseed
# wfshortcourse_1140.mseed
# wfshortcourse_1247.mseed
# wfshortcourse_792.mseed
# wfshortcourse_628.mseed
# wfshortcourse_418.mseed
# wfshortcourse_682.mseed
# wfshortcourse_1142.mseed
# wfshortcourse_314.mseed
# wfshortcourse_987.mseed
# wfshortcourse_462.mseed
# wfshortcourse_329.mseed
# wfshortcourse_659.mseed
# wfshortcourse_401.mseed
# wfshortcourse_1036.mseed
# wfshortcourse_1283.mseed
# wfshortcourse_251.mseed
# wfshortcourse_534.mseed
# wfshortcourse_743.mseed
# wfshortcourse_1223.mseed
# wfshortcourse_1234.mseed
# wfshortcourse_1050.mseed
# wfshortcourse_578.mseed
# wfshortcourse_1112.mseed
# wfshortcourse_982.mseed
# wfshortcourse_903.mseed
# wfshortcourse_851.mseed
# wfshortcourse_284.mseed
# wfshortcourse_837.mseed
# wfshortcourse_882.mseed
# wfshortcourse_1139.mseed
# wfshortcourse_934.mseed
# wfshortcourse_508.mseed
# wfshortcourse_791.mseed
# wfshortcourse_1007.mseed
# wfshortcourse_232.mseed
# wfshortcourse_701.mseed
# wfshortcourse_1275.mseed
# wfshortcourse_15.mseed
# wfshortcourse_766.mseed
# wfshortcourse_1015.mseed
# wfshortcourse_1206.mseed
# wfshortcourse_768.mseed
# wfshortcourse_277.mseed
# wfshortcourse_515.mseed
# wfshortcourse_1270.mseed
# wfshortcourse_617.mseed
# wfshortcourse_391.mseed
# wfshortcourse_116.mseed
# wfshortcourse_808.mseed
# wfshortcourse_1259.mseed
# wfshortcourse_998.mseed
# wfshortcourse_1209.mseed
# wfshortcourse_649.mseed
# wfshortcourse_1041.mseed
# wfshortcourse_1181.mseed
# wfshortcourse_664.mseed
# wfshortcourse_449.mseed
# wfshortcourse_750.mseed
# wfshortcourse_1194.mseed
# wfshortcourse_812.mseed
# wfshortcourse_146.mseed
# wfshortcourse_900.mseed
# wfshortcourse_1160.mseed
# wfshortcourse_911.mseed
# wfshortcourse_630.mseed
# wfshortcourse_217.mseed
# wfshortcourse_1180.mseed
# wfshortcourse_1278.mseed
# wfshortcourse_448.mseed
# wfshortcourse_968.mseed
# wfshortcourse_60.mseed
# wfshortcourse_221.mseed
# wfshortcourse_303.mseed
# wfshortcourse_519.mseed
# wfshortcourse_233.mseed
# wfshortcourse_1229.mseed
# wfshortcourse_1022.mseed
# wfshortcourse_547.mseed
# wfshortcourse_1138.mseed
# wfshortcourse_1034.mseed
# wfshortcourse_955.mseed
# wfshortcourse_227.mseed
# wfshortcourse_857.mseed
# wfshortcourse_546.mseed
# wfshortcourse_1164.mseed
# wfshortcourse_79.mseed
# wfshortcourse_1273.mseed
# wfshortcourse_654.mseed
# wfshortcourse_735.mseed
# wfshortcourse_538.mseed
# wfshortcourse_130.mseed
# wfshortcourse_41.mseed
# wfshortcourse_1193.mseed
# wfshortcourse_711.mseed
# wfshortcourse_1157.mseed
# wfshortcourse_709.mseed
# wfshortcourse_1108.mseed
# wfshortcourse_861.mseed
# wfshortcourse_583.mseed
# wfshortcourse_907.mseed
# wfshortcourse_839.mseed
# wfshortcourse_181.mseed
# wfshortcourse_1067.mseed
# wfshortcourse_498.mseed
# wfshortcourse_27.mseed
# wfshortcourse_754.mseed
# wfshortcourse_591.mseed
# wfshortcourse_727.mseed
# wfshortcourse_1188.mseed
# wfshortcourse_46.mseed
# wfshortcourse_1088.mseed
# wfshortcourse_1097.mseed
# wfshortcourse_310.mseed
# wfshortcourse_1210.mseed
# wfshortcourse_71.mseed
# wfshortcourse_845.mseed
# wfshortcourse_774.mseed
# wfshortcourse_272.mseed
# wfshortcourse_658.mseed
# wfshortcourse_1183.mseed
# wfshortcourse_108.mseed
# wfshortcourse_282.mseed
# wfshortcourse_518.mseed
# wfshortcourse_524.mseed
# wfshortcourse_594.mseed
# wfshortcourse_473.mseed
# wfshortcourse_237.mseed
# wfshortcourse_1100.mseed
# wfshortcourse_464.mseed
# wfshortcourse_241.mseed
# wfshortcourse_182.mseed
# wfshortcourse_1182.mseed
# wfshortcourse_695.mseed
# wfshortcourse_252.mseed
# wfshortcourse_311.mseed
# wfshortcourse_395.mseed
# wfshortcourse_171.mseed
# wfshortcourse_82.mseed
# wfshortcourse_1095.mseed
# wfshortcourse_685.mseed
# wfshortcourse_717.mseed
# wfshortcourse_612.mseed
# wfshortcourse_206.mseed
# wfshortcourse_103.mseed
# wfshortcourse_1218.mseed
# wfshortcourse_784.mseed
# wfshortcourse_855.mseed
# wfshortcourse_723.mseed
# wfshortcourse_1205.mseed
# wfshortcourse_84.mseed
# wfshortcourse_585.mseed
# wfshortcourse_836.mseed
# wfshortcourse_794.mseed
# wfshortcourse_870.mseed
# wfshortcourse_1037.mseed
# wfshortcourse_118.mseed
# wfshortcourse_895.mseed
# wfshortcourse_325.mseed
# wfshortcourse_893.mseed
# wfshortcourse_1080.mseed
# wfshortcourse_833.mseed
# wfshortcourse_1008.mseed
# wfshortcourse_653.mseed
# wfshortcourse_339.mseed
# wfshortcourse_468.mseed
# wfshortcourse_370.mseed
# wfshortcourse_352.mseed
# wfshortcourse_78.mseed
# wfshortcourse_516.mseed
# wfshortcourse_95.mseed
# wfshortcourse_43.mseed
# wfshortcourse_446.mseed
# wfshortcourse_680.mseed
# wfshortcourse_555.mseed
# wfshortcourse_736.mseed
# wfshortcourse_298.mseed
# wfshortcourse_1249.mseed
# wfshortcourse_1255.mseed
# wfshortcourse_829.mseed
# wfshortcourse_504.mseed
# wfshortcourse_783.mseed
# wfshortcourse_914.mseed
# wfshortcourse_73.mseed
# wfshortcourse_718.mseed
# wfshortcourse_190.mseed
# wfshortcourse_1090.mseed
# wfshortcourse_290.mseed
# wfshortcourse_225.mseed
# wfshortcourse_50.mseed
# wfshortcourse_87.mseed
# wfshortcourse_553.mseed
# wfshortcourse_763.mseed
# wfshortcourse_81.mseed
# wfshortcourse_1172.mseed
# wfshortcourse_244.mseed
# wfshortcourse_253.mseed
# wfshortcourse_1264.mseed
# wfshortcourse_1016.mseed
# wfshortcourse_1197.mseed
# wfshortcourse_368.mseed
# wfshortcourse_660.mseed
# wfshortcourse_1192.mseed
# wfshortcourse_622.mseed
# wfshortcourse_981.mseed
# wfshortcourse_1170.mseed
# wfshortcourse_416.mseed
# wfshortcourse_165.mseed
# wfshortcourse_72.mseed
# wfshortcourse_89.mseed
# wfshortcourse_1153.mseed
# wfshortcourse_189.mseed
# wfshortcourse_798.mseed
# wfshortcourse_879.mseed
# wfshortcourse_755.mseed
# wfshortcourse_1107.mseed
# wfshortcourse_280.mseed
# wfshortcourse_661.mseed
# wfshortcourse_1256.mseed
# wfshortcourse_68.mseed
# wfshortcourse_1116.mseed
# wfshortcourse_1085.mseed
# wfshortcourse_394.mseed
# wfshortcourse_744.mseed
# wfshortcourse_509.mseed
# wfshortcourse_1155.mseed
# wfshortcourse_247.mseed
# wfshortcourse_451.mseed
# wfshortcourse_592.mseed
# wfshortcourse_239.mseed
# wfshortcourse_398.mseed
# wfshortcourse_1174.mseed
# wfshortcourse_379.mseed
# wfshortcourse_549.mseed
# wfshortcourse_1096.mseed
# wfshortcourse_111.mseed
# wfshortcourse_640.mseed
# wfshortcourse_147.mseed
# wfshortcourse_198.mseed
# wfshortcourse_107.mseed
# wfshortcourse_482.mseed
# wfshortcourse_643.mseed
# wfshortcourse_1024.mseed
# wfshortcourse_931.mseed
# wfshortcourse_988.mseed
# wfshortcourse_683.mseed
# wfshortcourse_875.mseed
# wfshortcourse_0.mseed
# wfshortcourse_214.mseed
# wfshortcourse_141.mseed
# wfshortcourse_267.mseed
# wfshortcourse_859.mseed
# wfshortcourse_663.mseed
# wfshortcourse_400.mseed
# wfshortcourse_330.mseed
# wfshortcourse_997.mseed
# wfshortcourse_1128.mseed
# wfshortcourse_23.mseed
# wfshortcourse_525.mseed
# wfshortcourse_713.mseed
# wfshortcourse_923.mseed
# wfshortcourse_208.mseed
# wfshortcourse_274.mseed
# wfshortcourse_828.mseed
# wfshortcourse_856.mseed
# wfshortcourse_1136.mseed
# wfshortcourse_1075.mseed
# wfshortcourse_491.mseed
# wfshortcourse_390.mseed
# wfshortcourse_1265.mseed
# wfshortcourse_263.mseed
# wfshortcourse_265.mseed
# wfshortcourse_562.mseed
# wfshortcourse_319.mseed
# wfshortcourse_843.mseed
# wfshortcourse_119.mseed
# wfshortcourse_995.mseed
# wfshortcourse_912.mseed
# wfshortcourse_1250.mseed
# wfshortcourse_760.mseed
# wfshortcourse_299.mseed
# wfshortcourse_1121.mseed
# wfshortcourse_537.mseed
# wfshortcourse_300.mseed
# wfshortcourse_193.mseed
# wfshortcourse_1084.mseed
# wfshortcourse_242.mseed
# wfshortcourse_396.mseed
# wfshortcourse_958.mseed
# wfshortcourse_383.mseed
# wfshortcourse_480.mseed
# wfshortcourse_493.mseed
# wfshortcourse_651.mseed
# wfshortcourse_85.mseed
# wfshortcourse_91.mseed
# wfshortcourse_706.mseed
# wfshortcourse_762.mseed
# wfshortcourse_1202.mseed
# wfshortcourse_1094.mseed
# wfshortcourse_53.mseed
# wfshortcourse_1248.mseed
# wfshortcourse_1184.mseed
# wfshortcourse_807.mseed
# wfshortcourse_772.mseed
# wfshortcourse_556.mseed
# wfshortcourse_117.mseed
# wfshortcourse_56.mseed
# wfshortcourse_1267.mseed
# wfshortcourse_1110.mseed
# wfshortcourse_974.mseed
# wfshortcourse_869.mseed
# wfshortcourse_790.mseed
# wfshortcourse_648.mseed
# wfshortcourse_623.mseed
# wfshortcourse_1039.mseed
# wfshortcourse_1113.mseed
# wfshortcourse_1176.mseed
# wfshortcourse_174.mseed
# wfshortcourse_657.mseed
# wfshortcourse_865.mseed
# wfshortcourse_283.mseed
# wfshortcourse_552.mseed
# wfshortcourse_963.mseed
# wfshortcourse_947.mseed
# wfshortcourse_1109.mseed
# wfshortcourse_128.mseed
# wfshortcourse_558.mseed
# wfshortcourse_896.mseed
# wfshortcourse_725.mseed
# wfshortcourse_1093.mseed
# wfshortcourse_624.mseed
# wfshortcourse_63.mseed
# wfshortcourse_647.mseed
# wfshortcourse_1044.mseed
# wfshortcourse_872.mseed
# wfshortcourse_148.mseed
# wfshortcourse_160.mseed
# wfshortcourse_389.mseed
# wfshortcourse_1211.mseed
# wfshortcourse_158.mseed
# wfshortcourse_922.mseed
# wfshortcourse_29.mseed
# wfshortcourse_629.mseed
# wfshortcourse_38.mseed
# wfshortcourse_910.mseed
# wfshortcourse_1266.mseed
# wfshortcourse_264.mseed
# wfshortcourse_941.mseed
# wfshortcourse_1243.mseed
# wfshortcourse_1285.mseed
# wfshortcourse_899.mseed
# wfshortcourse_266.mseed
# wfshortcourse_588.mseed
# wfshortcourse_638.mseed
# wfshortcourse_1190.mseed
# wfshortcourse_581.mseed
# wfshortcourse_929.mseed
# wfshortcourse_1152.mseed
# wfshortcourse_606.mseed
# wfshortcourse_730.mseed
# wfshortcourse_323.mseed
# wfshortcourse_568.mseed
# wfshortcourse_20.mseed
# wfshortcourse_10.mseed
# wfshortcourse_809.mseed
# wfshortcourse_88.mseed
# wfshortcourse_97.mseed
# wfshortcourse_557.mseed
# wfshortcourse_1013.mseed
# wfshortcourse_1253.mseed
# wfshortcourse_566.mseed
# wfshortcourse_1233.mseed
# wfshortcourse_672.mseed
# wfshortcourse_361.mseed
# wfshortcourse_13.mseed
# wfshortcourse_359.mseed
# wfshortcourse_1134.mseed
# wfshortcourse_1228.mseed
# wfshortcourse_758.mseed
# wfshortcourse_841.mseed
# wfshortcourse_1081.mseed
# wfshortcourse_814.mseed
# wfshortcourse_176.mseed
# wfshortcourse_567.mseed
# wfshortcourse_122.mseed
# wfshortcourse_626.mseed
# wfshortcourse_700.mseed
# wfshortcourse_520.mseed
# wfshortcourse_1133.mseed
# wfshortcourse_874.mseed
# wfshortcourse_605.mseed
# wfshortcourse_506.mseed
# wfshortcourse_1072.mseed
# wfshortcourse_14.mseed
# wfshortcourse_954.mseed
# wfshortcourse_1078.mseed
# wfshortcourse_215.mseed
# wfshortcourse_315.mseed
# wfshortcourse_407.mseed
# wfshortcourse_852.mseed
# wfshortcourse_962.mseed
# wfshortcourse_485.mseed
# wfshortcourse_966.mseed
# wfshortcourse_782.mseed
# wfshortcourse_939.mseed
# wfshortcourse_501.mseed
# wfshortcourse_904.mseed
# wfshortcourse_279.mseed
# wfshortcourse_532.mseed
# wfshortcourse_459.mseed
# wfshortcourse_708.mseed
# wfshortcourse_530.mseed
# wfshortcourse_490.mseed
# wfshortcourse_12.mseed
# wfshortcourse_574.mseed
# wfshortcourse_639.mseed
# wfshortcourse_187.mseed
# wfshortcourse_433.mseed
# wfshortcourse_471.mseed
# wfshortcourse_248.mseed
# wfshortcourse_445.mseed
# wfshortcourse_693.mseed
# wfshortcourse_1279.mseed
# wfshortcourse_970.mseed
# wfshortcourse_183.mseed
# wfshortcourse_365.mseed
# wfshortcourse_19.mseed
# wfshortcourse_397.mseed
# wfshortcourse_145.mseed
# wfshortcourse_238.mseed
# wfshortcourse_70.mseed
# wfshortcourse_333.mseed
# wfshortcourse_1146.mseed
# wfshortcourse_125.mseed
# wfshortcourse_1017.mseed
# wfshortcourse_1214.mseed
# wfshortcourse_971.mseed
# wfshortcourse_1105.mseed
# wfshortcourse_133.mseed
# wfshortcourse_1258.mseed
# wfshortcourse_1281.mseed
# wfshortcourse_1098.mseed
# wfshortcourse_1191.mseed
# wfshortcourse_18.mseed
# wfshortcourse_973.mseed
# wfshortcourse_1203.mseed
# wfshortcourse_848.mseed
# wfshortcourse_1055.mseed
# wfshortcourse_307.mseed
# wfshortcourse_380.mseed
# wfshortcourse_99.mseed
# wfshortcourse_375.mseed
# wfshortcourse_732.mseed
# wfshortcourse_1001.mseed
# wfshortcourse_871.mseed
# wfshortcourse_818.mseed
# wfshortcourse_521.mseed
# wfshortcourse_786.mseed
# wfshortcourse_1069.mseed
# wfshortcourse_764.mseed
# wfshortcourse_972.mseed
# wfshortcourse_803.mseed
# wfshortcourse_716.mseed
# wfshortcourse_419.mseed
# wfshortcourse_823.mseed
# wfshortcourse_944.mseed
# wfshortcourse_930.mseed
# wfshortcourse_921.mseed
# wfshortcourse_722.mseed
# wfshortcourse_447.mseed
# wfshortcourse_331.mseed
# wfshortcourse_387.mseed
# wfshortcourse_1185.mseed
# wfshortcourse_286.mseed
# wfshortcourse_294.mseed
# wfshortcourse_854.mseed
# wfshortcourse_143.mseed
# wfshortcourse_17.mseed
# wfshortcourse_4.mseed
# wfshortcourse_656.mseed
# wfshortcourse_157.mseed
# wfshortcourse_90.mseed
# wfshortcourse_196.mseed
# wfshortcourse_155.mseed
# wfshortcourse_151.mseed
# wfshortcourse_432.mseed
# wfshortcourse_3.mseed
# wfshortcourse_778.mseed
# wfshortcourse_98.mseed
# wfshortcourse_773.mseed
# wfshortcourse_281.mseed
# wfshortcourse_631.mseed
# wfshortcourse_362.mseed
# wfshortcourse_461.mseed
# wfshortcourse_312.mseed
# wfshortcourse_745.mseed
# wfshortcourse_260.mseed
# wfshortcourse_153.mseed
# wfshortcourse_811.mseed
# wfshortcourse_134.mseed
# wfshortcourse_350.mseed
# wfshortcourse_254.mseed
# wfshortcourse_317.mseed
# wfshortcourse_465.mseed
# wfshortcourse_597.mseed
# wfshortcourse_321.mseed
# wfshortcourse_16.mseed
# wfshortcourse_454.mseed
# wfshortcourse_984.mseed
# wfshortcourse_1010.mseed
# wfshortcourse_675.mseed
# wfshortcourse_602.mseed
# wfshortcourse_326.mseed
# wfshortcourse_928.mseed
# wfshortcourse_313.mseed
# wfshortcourse_993.mseed
# wfshortcourse_1126.mseed
# wfshortcourse_1276.mseed
# wfshortcourse_132.mseed
# wfshortcourse_571.mseed
# wfshortcourse_1043.mseed
# wfshortcourse_47.mseed
# wfshortcourse_364.mseed
# wfshortcourse_1127.mseed
# wfshortcourse_21.mseed
# wfshortcourse_192.mseed
# wfshortcourse_787.mseed
# wfshortcourse_999.mseed
# wfshortcourse_741.mseed
# wfshortcourse_689.mseed
# wfshortcourse_510.mseed
# wfshortcourse_410.mseed
# wfshortcourse_1240.mseed
# wfshortcourse_341.mseed
# wfshortcourse_477.mseed
# wfshortcourse_1011.mseed
# wfshortcourse_259.mseed
# wfshortcourse_40.mseed
# wfshortcourse_26.mseed
# wfshortcourse_821.mseed
# wfshortcourse_36.mseed
# wfshortcourse_1077.mseed
# wfshortcourse_796.mseed
# wfshortcourse_1089.mseed
# wfshortcourse_1162.mseed
# wfshortcourse_1025.mseed
# wfshortcourse_548.mseed
# wfshortcourse_830.mseed
# wfshortcourse_1269.mseed
# wfshortcourse_1101.mseed
# wfshortcourse_175.mseed
# wfshortcourse_917.mseed
# wfshortcourse_777.mseed
# wfshortcourse_715.mseed
# wfshortcourse_439.mseed
# wfshortcourse_681.mseed
# wfshortcourse_427.mseed
# wfshortcourse_195.mseed
# wfshortcourse_338.mseed
# wfshortcourse_805.mseed
# wfshortcourse_74.mseed
# wfshortcourse_1048.mseed
# wfshortcourse_442.mseed
# wfshortcourse_1051.mseed
# wfshortcourse_1274.mseed
# wfshortcourse_149.mseed
# wfshortcourse_1151.mseed
# wfshortcourse_115.mseed
# wfshortcourse_435.mseed
# wfshortcourse_304.mseed
# wfshortcourse_412.mseed
# wfshortcourse_218.mseed
# wfshortcourse_572.mseed
# wfshortcourse_1277.mseed
# wfshortcourse_607.mseed
# wfshortcourse_1159.mseed
# wfshortcourse_688.mseed
# wfshortcourse_992.mseed
# wfshortcourse_346.mseed
# wfshortcourse_295.mseed
# wfshortcourse_759.mseed
# wfshortcourse_166.mseed
# wfshortcourse_415.mseed
# wfshortcourse_1189.mseed
# wfshortcourse_170.mseed
# wfshortcourse_877.mseed
# wfshortcourse_691.mseed
# wfshortcourse_1144.mseed
# wfshortcourse_776.mseed
# wfshortcourse_356.mseed
# wfshortcourse_694.mseed
# wfshortcourse_512.mseed
# wfshortcourse_692.mseed
# wfshortcourse_986.mseed
# wfshortcourse_210.mseed
# wfshortcourse_1252.mseed
# wfshortcourse_129.mseed
# wfshortcourse_393.mseed
# wfshortcourse_55.mseed
# wfshortcourse_860.mseed
# wfshortcourse_423.mseed
# wfshortcourse_492.mseed
# wfshortcourse_1284.mseed
# wfshortcourse_1079.mseed
# wfshortcourse_1087.mseed
# wfshortcourse_186.mseed
# wfshortcourse_378.mseed
# wfshortcourse_184.mseed
# wfshortcourse_386.mseed
# wfshortcourse_1173.mseed
# wfshortcourse_458.mseed
# wfshortcourse_481.mseed
# wfshortcourse_666.mseed
# wfshortcourse_1.mseed
# wfshortcourse_533.mseed
# wfshortcourse_104.mseed
# wfshortcourse_500.mseed
# wfshortcourse_496.mseed
# wfshortcourse_1260.mseed
# wfshortcourse_257.mseed
# wfshortcourse_901.mseed
# wfshortcourse_1053.mseed
# wfshortcourse_740.mseed
# wfshortcourse_444.mseed
# wfshortcourse_636.mseed
# wfshortcourse_413.mseed
# wfshortcourse_278.mseed
# wfshortcourse_360.mseed
# wfshortcourse_205.mseed
# wfshortcourse_421.mseed
# wfshortcourse_256.mseed
# wfshortcourse_575.mseed
# wfshortcourse_355.mseed
# wfshortcourse_919.mseed
# wfshortcourse_240.mseed
# wfshortcourse_223.mseed
# wfshortcourse_6.mseed
# wfshortcourse_1006.mseed
# wfshortcourse_1020.mseed
# wfshortcourse_817.mseed
# wfshortcourse_336.mseed
# wfshortcourse_178.mseed
# wfshortcourse_785.mseed
# wfshortcourse_144.mseed
# wfshortcourse_347.mseed
# wfshortcourse_185.mseed
# wfshortcourse_601.mseed
# wfshortcourse_48.mseed
# wfshortcourse_1212.mseed
# wfshortcourse_422.mseed
# wfshortcourse_529.mseed
# wfshortcourse_231.mseed
# wfshortcourse_1066.mseed
# wfshortcourse_292.mseed
# wfshortcourse_1235.mseed
# wfshortcourse_30.mseed
# wfshortcourse_950.mseed
# wfshortcourse_488.mseed
# wfshortcourse_1222.mseed
# wfshortcourse_936.mseed
# wfshortcourse_603.mseed
# wfshortcourse_377.mseed
# wfshortcourse_131.mseed
# wfshortcourse_1012.mseed
# wfshortcourse_1035.mseed
# wfshortcourse_767.mseed
# wfshortcourse_1148.mseed
# wfshortcourse_120.mseed
# wfshortcourse_417.mseed
# wfshortcourse_124.mseed
# wfshortcourse_494.mseed
# wfshortcourse_1042.mseed
# wfshortcourse_975.mseed
# wfshortcourse_113.mseed
# wfshortcourse_752.mseed
# wfshortcourse_1060.mseed
# wfshortcourse_840.mseed
# wfshortcourse_269.mseed
# wfshortcourse_96.mseed
# wfshortcourse_1254.mseed
# wfshortcourse_245.mseed
# wfshortcourse_885.mseed
# wfshortcourse_1242.mseed
# wfshortcourse_121.mseed
# wfshortcourse_188.mseed
# wfshortcourse_293.mseed
# wfshortcourse_216.mseed
# wfshortcourse_324.mseed
# wfshortcourse_140.mseed
# wfshortcourse_1106.mseed
# wfshortcourse_1145.mseed
# wfshortcourse_302.mseed
# wfshortcourse_1118.mseed
# wfshortcourse_9.mseed
# wfshortcourse_67.mseed
# wfshortcourse_1058.mseed
# wfshortcourse_545.mseed
# wfshortcourse_1232.mseed
# wfshortcourse_866.mseed
# wfshortcourse_420.mseed
# wfshortcourse_650.mseed

# %% [markdown]
# The names are meaningless, but let's now build an index for this set of files and store them in our database.  To do that we first have to build the MsPASS handle used to access the data.  Variations of the following incantation will normally appear at the top of any MsPASS job script:

# %%
from mspasspy.db.client import DBClient
from mspasspy.db.database import Database
dbclient=DBClient()
dbh=Database(dbclient,'shortcourse')

# %% [markdown]
# There are two things created here that are important to understand:
# 1.  *dbclient* is an instance of a communication handle created to interact with MongoDB.  It is a minor variant of a pymongo class called *Client*.  (For those familiar with object oriented programming *DBClient* is a subclass/child of *Client*.).  It can be thought of as a top level handle for the entire database system.  It is normally created once and referenced only in calls like the last line of the box above.
# 2.  *dbh* is an instance of the MsPASS *Database* class.  *dbh* is a handle that we will use to manipulate a particular database, which in this case we called "shortcourse".  We will get more into the weeds of MongoDB later, but for now think of this as an abstract handle we use to interact with the database.
#
# With that our next step is to build an index to each of the files in "./wf".

# %%
with os.scandir('./wf') as entries:
    for entry in entries:
        if entry.is_file():
            filename='./wf'+'/'+entry.name
            dbh.index_mseed_file(filename)

# %%
n=dbh.wf_miniseed.count_documents({})
print('Number of documents in wf_miniseed collection=',n)
# Out:
# Number of documents in wf_miniseed collection= 1287

# %%
cursor=dbh.wf_miniseed.find({}).limit(3)
# This form is currently broken. Replace next block with this when read_ensemble_data is repaired
#ensemble=dbh.read_ensemble_data(cursor)

# %%
# This box is temporary until read_ensemble_data gets repaired
from mspasspy.ccore.seismic import TimeSeriesEnsemble
ensemble=TimeSeriesEnsemble(3)
cursor=dbh.wf_miniseed.find({}).limit(3)
for doc in cursor:
    d=dbh.read_data(doc,collection='wf_miniseed')
    ensemble.member.append(d)

# %% [markdown]
# Let's first look at what the headers contain.   We can start with a simple print of the first member of the
# ensemble:

# %%
print(ensemble.member[0])
# Out:
# {'_id': ObjectId('60e7003608bbf0c506fbfb95'), 'chan': 'BHZ', 'delta': 0.025000, 'dfile': './wf/wfshortcourse_1091.mseed', 'dir': '/home/pavlis/MsPASSShortCourse2021/Notebooks', 'foff': 0, 'format': 'mseed', 'last_packet_time': 1302188679.900000, 'nbytes': 53248, 'net': 'TA', 'npts': 55712, 'sampling_rate': 40.000000, 'sta': 'T36A', 'starttime': 1302187287.100000, 'storage_mode': 'file'}

# %% [markdown]
# The default print is hard to read.  Here is an alternative display that will be helpful for class discussion:

# %%
# This copy is not efficient but makes the syntax less obscure
d=ensemble.member[0]
print('python type of symbol d=',type(d))
print('\nkey-value pairs in d:\n')
for k in d:
    print(k,d[k])
# Out:
# python type of symbol d= <class 'mspasspy.ccore.seismic.TimeSeries'>
#
# key-value pairs in d:
#
# _id 60e7003608bbf0c506fbfb95
# chan BHZ
# delta 0.025
# dfile ./wf/wfshortcourse_1091.mseed
# dir /home/pavlis/MsPASSShortCourse2021/Notebooks
# foff 0
# format mseed
# last_packet_time 1302188679.9
# nbytes 53248
# net TA
# npts 55712
# sampling_rate 40.0
# sta T36A
# starttime 1302187287.1
# storage_mode file

# %% [markdown]
# We can also print a summary of the entire ensemble in tabular form as follows:

# %%
from obspy import UTCDateTime
print('number  net sta chan ->loc<- starttime endtime dt npts')
i=0
for d in ensemble.member:
    net=d['net']
    sta=d['sta']
    chan=d['chan']
    if d.is_defined('loc'):
        loc=d['loc']
    else:
        loc='  '
    stime=d.t0
    etime=d.endtime()
    dt=d.dt
    npts=d.npts
    print(i,net,sta,chan,'->',loc,'<-',UTCDateTime(stime),UTCDateTime(etime),dt,npts)
    i+=1
# Out:
# number  net sta chan ->loc<- starttime endtime dt npts
# 0 TA T36A BHZ ->    <- 2011-04-07T14:41:27.100000Z 2011-04-07T15:04:39.875000Z 0.025 55712
# 1 TA W37B BHN ->    <- 2011-04-07T14:41:27.100000Z 2011-04-07T15:06:01.025000Z 0.025 58958
# 2 TA D35A BHE ->    <- 2011-04-07T14:41:27.100000Z 2011-04-07T15:04:30.000000Z 0.025 55317

# %% [markdown]
# A few points of clarification as a lead in to a class discussion:
#
# * Notice the use of the "member" container in TimeSeriesEnsemble.  The code above shows it is python
#   "iterable".  Loops like th above are a common construct.
# * The "member" elements of the ensemble are *TimeSeries* objects.  The ugly print box shows that explicitly
#   for member 0.
# * Notice the use of the dict like syntax for the getters like "net=d['net']"
# * The tabular print shows a method used to display a property of d that isn't appropriate as "Metadata":
#   the calls to d.npts, d.dt, and d.endtime()
