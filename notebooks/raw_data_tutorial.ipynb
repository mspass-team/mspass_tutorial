# %% [markdown]
# # Constructing an Event Dataset from CSS3.0 database tables
# ## Prof. Gary L. Pavlis, Dept. Earth and Atmos. Sci., Indiana University

# %% [markdown]
# # 1. Overview
# The purpose of this tutorial is to show how to use MsPASS to assemble a working data set using catalog data from an Antelope (CSS3.0) database as a template.  This is one example of many workflows that seismologists may want to use to assemble a working data set for processing by MsPASS.   We use it as an example because (a) it was a data set the author wanted to assemble, and (b) it is a useful example that exercises many of the tools seismologists would need to use to assemble a data set, and (c) it illustrates some of the idiosyncracies of real data downloaded from IRIS and the FDSN.
#
# The data set we will be building in this exercise are waveform segments appropriate for estimation of so called "receiver functions" from teleseismic P wave data.  We will be exploiting a useful but underutilized data set produced by Earthscope's USArray facility of analyst picks of teleseismic P waves recorded by USArray.   The concept I'm using here is that if the analyst can observe the phase well enough that he or she are confident enough to measure the P wave arrival time it is a candidate for receiver function processing.   We can thus use the picks as a screen to reduce the amount of debris from data with a signal so small that there is no way it can work for the processing we aim to accomplish.   An alternative workflow for accomplishing that prefiltering task is to use an automated procedure to screen junk later in the processing chain.  That would be feasible in MsPASS, but is not the approach used in this tutorial.
#
# The data set we will be using in this exercise was assembled with two tools the reader may already be familiar with:  (1) obspy's FDSN web service functions, and (2) Antelope's database tools.   As we use them I will explain how these data were assembled for your education, but the idea of this tutorial is that most of the data you will need for this exercise is already assembled for you to load.  The key educational objective is to help you understand how MongoDB can be used to manage raw data and what it takes to define what we call a working input data set for MsPASS.

# %% [markdown]
# # 2. Creating An Empty MongoDB Database
# We first need to create an instance of a MongoDB database into which we will be writing the data for this exercise.  For this tutorial I need to assume two things:
# 1.  You have a local instance of MongoDB running and accessible from the machine on which you are running this tutorial.  If that is not true, you need to follow the procedure described in this page_:<https://github.com/wangyinz/mspass/wiki/Using-MsPASS-with-Docker> for docker or this page: <https://github.com/wangyinz/mspass/wiki/Using-MsPASS-with-Singularity-(on-HPC)> for singularity.
# 2.  We assume the database we will be used, which we will call *raw_data_tutorial*, does not exist.   If you reenter this tutorial or something goes wrong and the tutorial database gets clobbered, we show below how to clear the contents quickly.\
#
# With that (long winded) background, if you satisfy the assumptions above run the following:

# %%
from pymongo import MongoClient
from mspasspy.db.database import Database
from mspasspy.db.client import Client
client=Client()
db=Database(client,'raw_data_tutorial')

# %% [markdown]
# The variable *db* is now a top level handle to MongoDB.   It is an abstraction that should be viewed as a handle to the "database" with the name "raw_data_tutorial".  Under this top level handle are "collections", which are MongoDB's equivalent to a *relation* (or equivalently a *table*) in a relational database.   You can see what collections are defined running the following at any time:

# %%
colnames=db.list_collections()
for nm in colnames:
    print(nm)
# Out:
# {'name': 'site', 'type': 'collection', 'options': {}, 'info': {'readOnly': False, 'uuid': UUID('0e908145-050f-4655-a99c-4bd25787840a')}, 'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_', 'ns': 'raw_data_tutorial.site'}}
# {'name': 'arrival', 'type': 'collection', 'options': {}, 'info': {'readOnly': False, 'uuid': UUID('9d1b0af8-4110-441d-a5dd-22d7b728adba')}, 'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_', 'ns': 'raw_data_tutorial.arrival'}}
# {'name': 'wf_miniseed', 'type': 'collection', 'options': {}, 'info': {'readOnly': False, 'uuid': UUID('d383524c-1ce0-4da3-8bb2-ac5c84f9238b')}, 'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_', 'ns': 'raw_data_tutorial.wf_miniseed'}}
# {'name': 'channel', 'type': 'collection', 'options': {}, 'info': {'readOnly': False, 'uuid': UUID('e5087c60-4fbd-493e-a0ac-fab4869cda9f')}, 'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_', 'ns': 'raw_data_tutorial.channel'}}
# {'name': 'source', 'type': 'collection', 'options': {}, 'info': {'readOnly': False, 'uuid': UUID('f02bd014-2b8d-4e32-8270-af073dcab237')}, 'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_', 'ns': 'raw_data_tutorial.source'}}

# %% [markdown]
# For the present you should get nothing if you run that cell.  Later after we start adding data you can rerun that cell and see as we add a set of data to multiple "collections".  If you get output that is not clearly an error you can clear the database completely with this (very dangerous) command:

# %%
client.drop_database('raw_data_tutorial')
client=MongoClient()
db=client['raw_data_tutorial']

# %% [markdown]
# where we have repeated initalizing db as above.

# %% [markdown]
# # 3. Retrieving raw data with web services
# Over the past three decades IRIS developed a long suite of methods to retieve seismic data from their archives.  Many are still available, and without doubt the best alternative to the methods describe here is their "breqfast" request mechanism.   For the past decade, however, IRIS DMC has moved toward a solution using modern web services as their recommended data retrieval method.   We used obspy's FDSN mass download function to accomplish this objective.  (see <https://docs.obspy.org/packages/obspy.clients.fdsn.html> for a starting point on their documentation of this methodology.)
#
# You are welcome to use our actual procedure to download the data in this tutorial by running the python functions supplied with this tutorial.  From the directory you launched this tutorial cd to the directory *download_scripts* and run `python download2012.py`.   If you choose that route, however, you will need to be patient because when I ran this on a completely unloaded machine on a gigabit network it took about 5 days to complete.   Because that step is so time consuming we supply all the required file that process would yield in the directory where you are running this tutorial.   We do, however, only supply a small fraction of the actual waveform data as the size of that request is the main reason this takes 5 days - when I ran this script it returned approximately 0.65 TB.
#
# Since I doubt many readers will want to wait 5 days and consume over half a terrabyte of disk to run this tutorial we supply the following that we extracted from the output of that procedure:
# 1. We supply miniseed format waveform data for the first 10 events the download2012.py procedure will retieve.   You could recreate this in far shorter time if you hacked the script to count to 10 or just killed it after a few hours, but I recommend you start by looking in the directory wf/2012.   There you should see a set of "event" files.   Those files are not small because they were produced by concantenation of the miniseed files obspy downloads.  I did that to reduce the (absurd) number of files the original obspy script creates.  That is, obspy's function writes one file per channel per event.   Since the query I used in this script (all broadband stations running in 2012 within a rectangle around the lower 48 states of the US) yields over 1700 stations and around 5000 channels that gets out of control very quickly.  That means the data for that one year alone contains around 5 million files.  That is bad for a whole lot of reasons from simple things like many unix commands won't function on file lists for a directory that large to truly terrible performance problems on HPC systems (e.g. I found using the unix du query to query the data volume of the directory chain took hours to complete on a HPC disk farm using the Lustre file system at Indiana.)   I note we can use the concantenated miniseed files without any issues because of the way miniseed files are constructed and how they interact with obspy's reader we will be using later.
# 2.  The procedure we will be using is driven by events obspy downloads as the new xml format recently defined for web services by the FDSN.  The file downloaded is `./eventdata/events_2012.xml`.  Note we will load that data, but override it later using an alternative event catalog.  I include that for completeness and hope it will not prove too confusing.  It is useful to emphasize the lesson that in passive data handling we often have to face the issue of multiple source parameters for the same seismic "event".   In this exercise we will have conflicting source information from two sources:  (a) the FDSN download that process this xml file, and (b) the catalog Array Network Facility analysts used to construct their event catalog.
# 3.  During downloading obypy dynamically assembles station metadata in a custom scheme used by the download procedure using in the download2012.py script.  Some of the details of how they (obspy) handle this can be found in their documentation, but a key point for this tutorial is you will not be able to reproduce the station metadata we supply here exactly unless you run the download2012.py script to completion. We supply the output in the directory site_2012.dir, which is the name their script creates and populates with the files you will find there.  That directory contains 1712 small files.  There is one file for each seed network-station code combinations of data downloaded.  Each file is a recently standardized FDSN web service xml representation of station metadata.  Seismologists unfamiliar with station xml should realize it is simply a different format to contain the same information previously stored in the SEED blockettes used to define station metadata.  That information is also sometimes stored as "dataless seed" files (e.g. the Array Network Facility distributes these through their web site at <https://anf.ucsd.edu/data/products/dataless_sta/>).
#
# The next three sections describe how we assemble complete metadata for the tutorial data set we will build and load into MongoDB here.  The sections are headed by a useful classification of the type of data involved:  (a) receiver metadata, (b) source metadata, and (c) waveform data and metadata.

# %% [markdown]
# # 4. Assembling the pieces
# ## 4.1. Receiver metadata
# With tools we presently supply this is by far the easiest thing to do.   For this tutorial, just run this simple set of command:

# %%
from obspy import read_inventory
inv=read_inventory('data/raw_data_tutorial/site_2012.dir/*.xml')
db.save_inventory(inv)
inv=read_inventory('data/raw_data_tutorial/site_2011.dir/*.xml')
db.save_inventory(inv)
# Out:
# BK : BRIB : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   37.91886 -122.15179 0.21969999999999998
# loc code section coordinates:   37.91881 -122.15176 0.2189
# BK : HAST : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   36.3887 -121.5514 0.542
# loc code section coordinates:   36.3887 -121.5514 0.5395
# BK : HATC : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   40.8161 -121.46117 1.0092999999999999
# loc code section coordinates:   40.8161 -121.46117 1.0086
# BK : HELL : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   36.68011 -119.02282 1.14
# loc code section coordinates:   36.68011 -119.02282 1.1375
# BK : RAMR : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   35.63597 -120.86984 0.4168
# loc code section coordinates:   35.63597 -120.86984 0.4143
# BK : SUTB : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   39.2291 -121.7861 0.252
# loc code section coordinates:   39.2291 -121.7861 0.2495
# CI : CWC :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   36.439047 -118.080495 1.5695
# loc code section coordinates:   36.43988 -118.08016 1.595
# CI : FUR :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   36.46703 -116.86322 -0.037
# loc code section coordinates:   36.46719 -116.86322 -0.038
# CI : SHO :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   35.899529 -116.275299 0.451
# loc code section coordinates:   35.899601 -116.275146 0.451
# CI : SNR :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   32.86184 -115.43602 -0.063
# loc code section coordinates:   32.86189 -115.43596 -0.063
# CI : SYP :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   34.52781 -119.97832 1.278
# loc code section coordinates:   34.52775 -119.97834 1.278
# G : SCZ :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   36.59798 -121.40481 0.261
# loc code section coordinates:   36.598 -121.403 0.261
# IU : ANMO : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   34.94591 -106.4572 1.82
# loc code section coordinates:   34.945981 -106.457133 1.671
# IU : BBSR : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   32.371299 -64.696299 0.03
# loc code section coordinates:   32.371299 -64.696299 -0.0013
# IU : CCM : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   38.0557 -91.2446 0.222
# loc code section coordinates:   38.0557 -91.2446 0.1715
# IU : DWPF : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   28.1103 -81.4327 0.03
# loc code section coordinates:   28.1103 -81.4327 -0.132
# IU : HKT : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   29.9618 -95.8384 -0.413
# loc code section coordinates:   29.9618 -95.8384 -0.863
# IU : RSSD : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   44.1212 -104.0359 2.09
# loc code section coordinates:   44.1212 -104.0359 2.0227
# IU : SSPA : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   40.6358 -77.8876 0.27
# loc code section coordinates:   40.6358 -77.8876 0.17
# IU : TEIG : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   20.2263 -88.2763 0.04
# loc code section coordinates:   20.2263 -88.2763 -0.071
# IU : TUC : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   32.3098 -110.7847 0.91
# loc code section coordinates:   32.3098 -110.7847 0.909
# IU : WCI : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   38.2289 -86.2939 0.21
# loc code section coordinates:   38.2289 -86.2939 0.078
# LB : BMN :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   40.4314 -117.221001 1.594
# loc code section coordinates:   40.4314 -117.220993 1.594
# LD : NCB :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   43.973468 -74.22307 0.575
# loc code section coordinates:   43.9734 -74.222801 0.575
# LD : PAL :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   41.0056 -73.9079 0.066
# loc code section coordinates:   41.0056 -73.907898 0.066
# NE : BCX :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   42.335 -71.1705 0.06
# loc code section coordinates:   42.334999 -71.170502 0.06
# NE : BRYW :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   41.917 -71.5378 0.116
# loc code section coordinates:   41.917 -71.537804 0.116
# NE : EMMW :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   44.7075 -67.4573 0.035
# loc code section coordinates:   44.7075 -67.457298 0.035
# NE : FFD :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   43.4701 -71.6537 0.131
# loc code section coordinates:   43.4701 -71.653702 0.131
# NE : HNH :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   43.7051 -72.2865 0.18
# loc code section coordinates:   43.705101 -72.286499 0.18
# NE : PQI :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   46.6713 -68.019 0.162
# loc code section coordinates:   46.671299 -68.018997 0.162
# NE : QUA2 :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   42.279 -72.352 0.168
# loc code section coordinates:   42.278999 -72.351997 0.168
# NE : TRY :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   42.7313 -73.6664 0.089
# loc code section coordinates:   42.7313 -73.666397 0.089
# NE : WSPT :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   41.1712 -73.3278 0.091
# loc code section coordinates:   41.1712 -73.327797 0.091
# NE : WVL :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   44.5646 -69.6617 0.05
# loc code section coordinates:   44.564602 -69.661697 0.05
# US : ECSD : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   43.7337 -96.6141 0.478
# loc code section coordinates:   43.7337 -96.6141 0.43289999999999995
# US : GOGA : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   33.4112 -83.4666 0.1165
# loc code section coordinates:   33.4112 -83.4666 0.083
# US : KSU1 : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   39.1009 -96.6094 0.317
# loc code section coordinates:   39.1009 -96.6094 0.2963
# UU : SRU :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   39.11083 -110.52383 1.804
# loc code section coordinates:   39.110828 -110.523827 1.804
# UW : BLOW :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   44.6837 -122.1862 0.6573
# loc code section coordinates:   44.683701 -122.186203 0.652
# UW : GNW :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   47.56413 -122.82498 0.22
# loc code section coordinates:   47.564129 -122.824982 0.22
# UW : LTY :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   47.25451 -120.66636 0.807
# loc code section coordinates:   47.254509 -120.666359 0.807
# UW : TAKO :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   43.74313 -124.08337 0.012
# loc code section coordinates:   43.74334 -124.082474 0.046
# UW : TOLT :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   47.6947 -121.6895 0.541
# loc code section coordinates:   47.694698 -121.689499 0.541
# Database.save_inventory processing summary:
# Number of site records processed= 1712
# number of site records saved= 1712
# number of channel records processed= 5148
# number of channel records saved= 5148
# BK : BRIB : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   37.91886 -122.15179 0.21969999999999998
# loc code section coordinates:   37.91881 -122.15176 0.2189
# BK : HAST : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   36.3887 -121.5514 0.542
# loc code section coordinates:   36.3887 -121.5514 0.5395
# BK : HATC : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   40.8161 -121.46117 1.0092999999999999
# loc code section coordinates:   40.8161 -121.46117 1.0086
# BK : HELL : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   36.68011 -119.02282 1.14
# loc code section coordinates:   36.68011 -119.02282 1.1375
# BK : RAMR : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   35.63597 -120.86984 0.4168
# loc code section coordinates:   35.63597 -120.86984 0.4143
# BK : SUTB : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   39.2291 -121.7861 0.252
# loc code section coordinates:   39.2291 -121.7861 0.2495
# CI : CWC :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   36.439049 -118.080498 1.5695
# loc code section coordinates:   36.43988 -118.080162 1.595
# CI : FUR :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   36.46703 -116.86322 -0.037
# loc code section coordinates:   36.46719 -116.86322 -0.038
# CI : IBP :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   32.661121 -116.092857 0.879
# loc code section coordinates:   32.661152 -116.092903 0.879
# CI : SHO :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   35.89953 -116.2753 0.451
# loc code section coordinates:   35.8996 -116.27515 0.451
# CI : SYP :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   34.52781 -119.97832 1.278
# loc code section coordinates:   34.52775 -119.97834 1.278
# G : SCZ :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   36.59798 -121.40481 0.261
# loc code section coordinates:   36.598 -121.403 0.261
# IU : ANMO : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   34.94591 -106.4572 1.82
# loc code section coordinates:   34.945981 -106.457133 1.671
# IU : BBSR : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   32.371299 -64.696299 0.03
# loc code section coordinates:   32.371299 -64.696299 -0.0013
# IU : CCM : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   38.0557 -91.2446 0.222
# loc code section coordinates:   38.0557 -91.2446 0.1715
# IU : DWPF : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   28.1103 -81.4327 0.03
# loc code section coordinates:   28.1103 -81.4327 -0.132
# IU : HKT : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   29.9618 -95.8384 -0.413
# loc code section coordinates:   29.9618 -95.8384 -0.863
# IU : RSSD : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   44.1212 -104.0359 2.09
# loc code section coordinates:   44.1212 -104.0359 2.0227
# IU : SSPA : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   40.6358 -77.8876 0.27
# loc code section coordinates:   40.6358 -77.8876 0.17
# IU : TEIG : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   20.2263 -88.2763 0.04
# loc code section coordinates:   20.2263 -88.2763 -0.071
# IU : TUC : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   32.3098 -110.7847 0.91
# loc code section coordinates:   32.3098 -110.7847 0.909
# IU : WCI : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   38.2289 -86.2939 0.21
# loc code section coordinates:   38.2289 -86.2939 0.078
# LB : BMN :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   40.4314 -117.221001 1.594
# loc code section coordinates:   40.4314 -117.220993 1.594
# LD : MVL :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   39.999395 -76.348888 0.106
# loc code section coordinates:   39.999199 -76.350601 0.091
# LD : NCB :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   43.973468 -74.22307 0.575
# loc code section coordinates:   43.9734 -74.222801 0.575
# LD : PAL :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   41.0056 -73.9079 0.066
# loc code section coordinates:   41.0056 -73.907898 0.066
# NE : BCX :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   42.335 -71.1705 0.06
# loc code section coordinates:   42.334999 -71.170502 0.06
# NE : BRYW :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   41.917 -71.5378 0.116
# loc code section coordinates:   41.917 -71.537804 0.116
# NE : EMMW :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   44.7075 -67.4573 0.035
# loc code section coordinates:   44.710201 -67.458 0.034
# NE : FFD :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   43.4701 -71.6537 0.131
# loc code section coordinates:   43.4701 -71.653702 0.131
# NE : HNH :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   43.7051 -72.2865 0.18
# loc code section coordinates:   43.705101 -72.286499 0.18
# NE : PQI :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   46.6713 -68.019 0.162
# loc code section coordinates:   46.671299 -68.018997 0.162
# NE : QUA2 :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   42.279 -72.352 0.168
# loc code section coordinates:   42.278999 -72.351997 0.168
# NE : TRY :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   42.7313 -73.6664 0.089
# loc code section coordinates:   42.7313 -73.666397 0.089
# NE : WSPT :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   41.1712 -73.3278 0.091
# loc code section coordinates:   41.1712 -73.327797 0.091
# NE : WVL :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   44.5646 -69.6617 0.05
# loc code section coordinates:   44.564701 -69.661697 0.085
# NE : YLE :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   41.3165 -72.9208 0.041
# loc code section coordinates:   41.3165 -72.9208 0.005
# US : ECSD :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   43.7337 -96.6141 0.478
# loc code section coordinates:   43.7337 -96.6141 0.43289999999999995
# US : GOGA :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   33.4112 -83.4666 0.1165
# loc code section coordinates:   33.4112 -83.4666 0.083
# UU : SRU :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   39.11083 -110.52383 1.804
# loc code section coordinates:   39.110828 -110.523827 1.804
# UW : BLOW :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   44.6837 -122.1862 0.6573
# loc code section coordinates:   44.683701 -122.186203 0.652
# UW : GNW :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   47.56413 -122.82498 0.22
# loc code section coordinates:   47.564129 -122.824982 0.22
# UW : LTY :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   47.25451 -120.66636 0.807
# loc code section coordinates:   47.254509 -120.666359 0.807
# UW : TAKO :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   43.74313 -124.08337 0.012
# loc code section coordinates:   43.74334 -124.082474 0.046
# UW : TOLT :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   47.6947 -121.6895 0.541
# loc code section coordinates:   47.694698 -121.689499 0.541
# Database.save_inventory processing summary:
# Number of site records processed= 1569
# number of site records saved= 380
# number of channel records processed= 4700
# number of channel records saved= 1500
# (380, 1500, 1569, 4700)

# %% [markdown]
# You will notice this generates a fair number of warnings.  Those warning are intentional and should be inspected if you repeat this process for other data.   In all cases here these seem to be a combination of two issues: (1) many stations seem to have a mismatch in precision of location information stored in the station and channels section of the xml data, and (2) some of the mismatches in the station and channels section reflect a real geometric difference (e.g. RSSD loc code 00 is a borehole instrument so the elevation field differs from the station location which is at surface elevation).
#
# Notice for this process we are using obspy's read_inventory function to crack the station xml files and turn them into something we can manipulate.  That something is their Inventory object (<https://docs.obspy.org/packages/autogen/obspy.core.inventory.inventory.Inventory.html#obspy.core.inventory.inventory.Inventory>) which is pretty much a python translation of the station xml.  The save_inventory method of our Database class translates the Inventory data into the structure MongoDB requires to manage the data we just saved.   In MongoDB lingo that information is a "document".  We write one document in a collection called *site* for each "station" defined by a unique SEED network (net) and station (sta) code.  Each station always has one or more "channels" associated with it.  In SEED each channel is defined by two additional keys:  a channel (chan) code, and a location (loc) code.  SEED thus indexes a single channel of seismic data with a key defined by all four code:  net, sta, chan, and loc.  In MsPASS we map the Channels data assembled in the obspy Inventory object to produce one or more MongoDB documents we write to a collection we call *channel*.
#
# A further huge complication is that station and channel metadata can and often are time variable.   The most common example is a sensor change where the response data and/or the orientation of the instrument can change.  Furthermore, all channels operate only over a finite time range.  Hence, the *channel* collection commonly contain multiple documents for some channels.   There are no examples in this tutorial data with a *site* having multiple documents for the same SEED net-sta keys, but the schema we use allows that by using the time interval defined by attributes *starttime* and *endtime* as an additional constraint.   (Note using net-sta-opeational_time as a unique site idenifier was borrowed completely from CSS3.0 which uses that same concept.)
#
# To clarify this further, you can run the following optional code block to get a basic report of the number of channels per site.  You can also easily alter the report to print station location information using the interactive feature of jupyter.

# %%
def print_station_report(db):
    """
    Simple example function to print a basic report on contents of the site collection.

    :param db:  is a mspasspy.db Database object assumed pointed at an operating MongoDB server
    """
    dbsite=db.site
    curs=dbsite.find({})
    print('net sta lat lon elev')
    for doc in curs:
        net=doc['net']
        sta=doc['sta']
        lat=doc['latitude']
        lon=doc['longitude']
        elev=doc['elevation']
        print(net,sta,lat,lon,elev)

print_station_report(db)
# Out:
# net sta lat lon elev
# 2G IUGFS 45.728371 -111.970802 1.6337000000000002
# 7D FS01B 40.326801 -124.949203 -0.94
# 7D FS05B 40.3866 -124.899597 -2.316
# 7D FS06B 40.381199 -124.785301 -2.198
# 7D FS09B 40.438702 -124.808502 -2.161
# 7D FS14B 40.495499 -124.591797 -0.107
# 7D G02B 40.048599 -125.296898 -1.92
# 7D G03A 40.059101 -126.162498 -4.113
# 7D G03B 40.057999 -126.163399 -4.051
# 7D G04B 40.058498 -126.928497 -4.368
# 7D G05B 40.070599 -127.747803 -4.462
# 7D G10B 40.677898 -125.553299 -2.936
# 7D G11B 40.6875 -126.376404 -3.123
# 7D G12B 40.686901 -127.228897 -3.08
# 7D G13B 40.683998 -128.028305 -3.215
# 7D G19B 41.3074 -125.773598 -3.071
# 7D G20B 41.298698 -126.613297 -3.141
# 7D G21B 41.316002 -127.453697 -3.156
# 7D G22B 41.3092 -128.274002 -3.038
# 7D G27B 41.916599 -126.016701 -3.48
# 7D G28B 41.942799 -126.733902 -3.327
# 7D G29B 41.9772 -127.483398 -3.197
# 7D G30A 41.955002 -128.319305 -3.124
# 7D G30B 41.956501 -128.319794 -3.119
# 7D G35B 42.5658 -126.055801 -2.367
# 7D G36B2 42.5994 -126.903801 -2.423
# 7D G37B 42.591301 -127.721298 -3.004
# 7D J06A 43.251499 -128.800995 -3.224
# 7D J06B 43.265202 -128.799698 -3.22
# 7D J09B 43.151001 -124.726997 -0.252
# 7D J10B 43.3494 -125.543503 -3.093
# 7D J11B 43.541401 -126.367302 -3.03
# 7D J18B 44.008301 -125.466003 -3.047
# 7D J19B 44.1777 -126.271698 -2.968
# 7D J20B 44.354198 -127.0952 -2.934
# 7D J23A 44.844002 -129.682495 -2.655
# 7D J23B 44.845901 -129.682098 -2.65
# 7D J25A 44.4729 -124.621597 -0.1428
# 7D J27B 44.847599 -126.3069 -2.824
# 7D J28A 45.063599 -127.156403 -2.867
# 7D J28B 45.063099 -127.155197 -2.866
# 7D J29A 45.175701 -128.008408 -2.849
# 7D J30A 45.424198 -128.906906 -2.824
# 7D J31A 45.553101 -129.672699 -2.657
# 7D J33A 45.106602 -124.570801 -0.3487
# CI CJM 34.27117 -117.42448 1.616
# CI CLC 35.81574 -117.59751 0.775
# CI CLT 34.09284 -117.31687 0.325
# CI CTC 33.65516 -115.99006 0.538
# CI CWC 36.43988 -118.08016 1.595
# CI DAN 34.63745 -115.38115 0.428
# CI DEC 34.25353 -118.33383 0.519
# CI DEV 33.93597 -116.57794 0.337
# CI DGR 33.65001 -117.00947 0.65
# CI DJJ 34.10618 -118.45505 0.268
# CI DLA 33.84822 -118.09624 0.014
# CI DNR 33.56667 -116.63056 1.274
# CI DPP 32.99889 -116.94187 0.463
# CI DRE 32.80532 -115.44679 -0.013
# CI DSC 35.14255 -116.10395 0.283
# CI EDW2 34.8811 -117.99388 0.772
# CI EML 32.89083 -116.84566 0.161
# CI ERR 33.11675 -115.82267 -0.056
# CI FHO 34.09355 -116.93588 1.614
# CI FIG 34.72832 -119.98803 0.945
# CI FMP 33.71264 -118.29381 0.089
# CI FUR 36.46719 -116.86322 -0.038
# CI GATR 34.55266 -120.50235 0.59
# CI GLA 33.05149 -114.82706 0.61
# CI GMR 34.78457 -115.65994 1.326
# CI GOR 33.1537 -117.22921 0.138
# CI GR2 34.11816 -118.30024 0.342
# CI GRA 36.99608 -117.36621 0.689
# CI GSC 35.30177 -116.80574 1.0
# CI HEC 34.8294 -116.335 0.92
# CI HLL 34.17643 -118.35967 0.193
# CI IDO 33.79678 -116.22152 0.469
# CI IKP 32.65012 -116.10948 0.906
# CI IPT 34.19701 -117.28498 0.943
# CI IRM 34.15738 -115.14513 0.567
# CI ISA 35.66278 -118.47403 0.873
# CI JEM 33.08098 -116.59755 1.308
# CI JRC2 35.98249 -117.80885 1.469
# CI JVA 34.36622 -116.61266 0.904
# CI LAF 33.86889 -118.33143 0.02
# CI LCG 34.00033 -118.37794 0.108
# CI LCP 34.73551 -120.27996 0.199
# CI LDF 35.13066 -115.18416 1.239
# CI LDR 34.9906 -118.34156 1.121
# CI LFP 34.30529 -118.48805 0.368
# CI LGB 33.9753 -118.14918 0.042
# CI LGU 34.10819 -119.06587 0.416
# CI LJR 34.80762 -118.86775 1.443
# CI LLS 33.68447 -117.94304 0.008
# CI LMR2 34.93439 -117.69629 0.964
# CI LPC 34.31478 -117.54642 1.351
# CI LRL 35.47954 -117.68212 1.34
# CI LTP 33.8811 -118.17568 0.02
# CI LUG 34.3656 -117.36683 1.14
# CI MCT 34.22645 -116.04073 0.661
# CI MGE 33.81841 -116.36874 0.068
# CI MLAC 37.63019 -118.83605 2.162
# CI MLS 34.0046 -117.56162 0.23
# CI MOP 34.28096 -118.90469 0.141
# CI MPI 34.81258 -119.1453 2.673
# CI MPM 36.05799 -117.48901 1.839
# CI MPP 34.88848 -119.81362 1.739
# CI MSC 34.03852 -116.64795 0.938
# CI MSJ 33.80801 -116.96789 0.466
# CI MTP 35.48434 -115.5532 1.588
# CI MUR 33.59999 -117.19543 0.562
# CI MWC 34.22362 -118.05832 1.725
# CI NBS 34.78035 -116.55798 0.59
# CI NEE2 34.76759 -114.61881 0.271
# CI NJQ 34.53412 -120.17737 0.219
# CI NSS2 33.55553 -115.94586 0.017
# CI OLI 33.94539 -117.92372 0.162
# CI OLP 32.60771 -116.93019 0.159
# CI OSI 34.6145 -118.7235 0.718
# CI PASC 34.17141 -118.18523 0.341
# CI PDE 34.44199 -118.58215 0.328
# CI PDM 34.30336 -114.14152 0.144
# CI PDR 33.96273 -118.43702 0.045
# CI PDU 34.1207 -117.63808 0.445
# CI PER 33.86164 -117.20529 0.468
# CI PHL 35.40773 -120.54556 0.355
# CI PLM 33.35361 -116.86265 1.691
# CI PLS 33.7953 -117.60906 1.199
# CI PMD 33.64785 -116.37769 0.296
# CI PSD 33.82393 -116.55026 0.144
# CI PSR 34.09181 -117.80709 0.305
# CI RCT 36.30523 -119.24384 0.107
# CI RIN 34.28196 -118.47925 0.304
# CI RIO 34.10473 -117.97956 0.118
# CI RPV 33.74346 -118.40412 0.107
# CI RRX 34.875332 -116.996841 0.6762
# CI RSS 33.97327 -117.32674 0.298
# CI RUS 34.05075 -118.08078 0.07
# CI RVR 33.99351 -117.37545 0.266
# CI RXH 33.18313 -115.62257 -0.059
# CI SAL 33.2801 -115.98585 0.014
# CI SBB2 34.68844 -117.82424 0.825
# CI SBC 34.44076 -119.71492 0.094
# CI SBI 33.48046 -119.02986 0.041
# CI SBPX 34.2324 -117.23484 1.86
# CI SCI2 32.9799 -118.54697 0.199
# CI SCZ2 33.99543 -119.6351 0.44
# CI SDD 33.55259 -117.66171 0.12
# CI SDG 32.784 -117.13805 0.101
# CI SDR 32.73561 -116.94241 0.113
# CI SES 34.43692 -119.1375 0.48
# CI SHO 35.899601 -116.275146 0.451
# CI SLA 35.89095 -117.28332 1.174
# CI SLB 33.48519 -115.86643 0.0
# CI SLR 33.83359 -116.79737 1.567
# CI SMF2 34.02201 -118.44627 0.0522
# CI SMI 34.03818 -120.35132 0.165
# CI SMM 35.3142 -119.99581 0.599
# CI SMR 35.37699 -120.61247 0.341
# CI SMS 34.01438 -118.45617 0.043
# CI SMW 35.01108 -120.40997 0.169
# CI SNCC 33.24787 -119.52437 0.275
# CI SNO 34.03515 -116.80778 2.339
# CI SNR 32.86189 -115.43596 -0.063
# CI SPF 34.05933 -118.64614 0.47
# CI SPG2 36.20057 -118.76624 0.627
# CI SRI 33.97875 -120.07886 0.392
# CI SRN 33.82854 -117.78938 0.208
# CI STC 34.30302 -119.18676 0.18
# CI STG 33.664 -117.76856 0.049
# CI STS 33.79033 -118.19878 0.004
# CI SVD 34.10647 -117.09822 0.605
# CI SWS 32.94508 -115.79988 0.14
# CI SYP 34.52775 -119.97834 1.278
# CI TA2 34.38203 -117.67822 2.249
# CI TEH 35.2913 -118.42079 0.846
# CI TFT 35.14592 -119.41946 0.233
# CI TIN 37.05422 -118.23009 1.197
# CI TOR 33.57526 -116.22584 0.004
# CI TUQ 35.435841 -115.923889 1.35
# CI USC 34.01919 -118.28631 0.058
# CI VCS 34.48372 -118.11781 0.992
# CI VES 35.840889 -119.084686 0.154
# CI VOG 36.32098 -119.38226 0.09
# CI CIA 33.401897 -118.415024 0.477
# CI CWC 36.43988 -118.080162 1.595
# CI DEC 34.253529 -118.333832 0.519
# CI DGR 33.65001 -117.00947 0.65
# CI DJJ 34.10618 -118.45505 0.268
# CI EDW2 34.8811 -117.993881 0.772
# CI GLA 33.051491 -114.827057 0.61
# CI GMR 34.784569 -115.659943 1.326
# CI GRA 36.996078 -117.366211 0.689
# CI IBP 32.661152 -116.092903 0.879
# CI IKP 32.65012 -116.109482 0.906
# CI ISA 35.662781 -118.47403 0.873
# CI LRL 35.47954 -117.68212 1.34
# CI MLAC 37.630192 -118.836052 2.162
# CI MPM 36.05799 -117.48901 1.839
# CI MUR 33.599991 -117.195427 0.562
# CI MWC 34.22362 -118.05832 1.725
# CI NEE2 34.76759 -114.618813 0.271
# CI OSI 34.614498 -118.723503 0.718
# CI PASC 34.17141 -118.18523 0.341
# CI PHL 35.40773 -120.54556 0.355
# CI RCT 36.305229 -119.243843 0.107
# CI RPV 33.743462 -118.404121 0.107
# CI SBC 34.440762 -119.71492 0.094
# CI SCI2 32.9799 -118.546967 0.199
# CI SDD 33.552589 -117.661713 0.12
# CI SHO 35.8996 -116.27515 0.451
# CI SMM 35.3142 -119.99581 0.599
# CI SNCC 33.247871 -119.524368 0.275
# CI SVD 34.106468 -117.098221 0.605
# CI SWS 32.94508 -115.79988 0.14
# CI USC 34.019192 -118.286308 0.058
# CI VCS 34.48372 -118.11781 0.992
# CN BMSB 48.8356 -125.1355 0.01
# CN SNB 48.7751 -123.1723 0.402
# IU CCM 38.0557 -91.2446 0.1715
# IU HKT 29.9618 -95.8384 -0.863
# IU WVT 36.1297 -87.83 0.17
# LD BMNY 44.83987 -74.5065 0.115
# LD LUPA 40.5987 -75.3718 0.255
# LD MVL 39.999199 -76.350601 0.091
# NE YLE 41.3165 -72.9208 0.005
# NM SIUC 37.714802 -89.2174 0.12
# PN PPBNL 38.882999 -86.450996 0.203
# PN PPPHS 40.861 -86.494003 0.223
# TA 034A 27.064699 -98.683296 0.155
# TA 035A 26.937901 -98.102303 0.029
# TA 035Z 26.462999 -98.068298 0.019
# TA 130A 32.5961 -100.965202 0.676
# TA 131A 32.673698 -100.388802 0.622
# TA 133A 32.608299 -98.916199 0.418
# TA 134A 32.572899 -98.079498 0.297
# TA 135A 32.557301 -97.409897 0.27
# TA 230A 31.8878 -101.112396 0.742
# TA 231A 31.935301 -100.316299 0.574
# TA 232A 31.888 -99.646896 0.621
# TA 233A 32.017899 -98.899803 0.539
# TA 234A 32.004002 -98.136803 0.358
# TA 238A 32.003399 -95.1203 0.126
# TA 239A 32.017899 -94.470703 0.1
# TA 330A 31.4063 -101.175201 0.742
# TA 331A 31.3085 -100.426598 0.615
# TA 332A 31.3829 -99.742302 0.513
# TA 333A 31.3249 -98.9841 0.443
# TA 334A 31.3325 -98.2379 0.389
# TA 335A 31.2819 -97.427101 0.217
# TA 336A 31.386999 -96.844299 0.14
# TA 337A 31.315901 -95.885399 0.15
# TA 338A 31.356701 -95.3106 0.137
# US ISCO 39.7997 -105.6134 2.743
# US JCT 30.4794 -99.8022 0.591
# US JFWS 42.9142 -90.2481 0.335
# US KSU1 39.1009 -96.6094 0.317
# US KVTX 27.5459 -97.8929 0.0146
# US LAO 46.6885 -106.2231 0.902
# US LBNH 44.2401 -71.9259 0.367
# US LONY 44.6197 -74.5829 0.44
# US LRAL 33.0399 -86.9978 0.13
# US MCWV 39.6581 -79.8456 0.28
# US MIAR 34.5454 -93.5765 0.207
# US MNTX 31.6985 -105.3821 0.4048
# US MSO 46.8292 -113.9406 1.264
# US MVCO 37.19956 -108.49251 2.1699
# US NATX 31.7598 -94.661 0.168
# US NCB 43.9708 -74.2236 0.5
# US NEW 48.2642 -117.1227 0.76
# US NHSC 33.1067 -80.1778 0.011
# US NLWA 47.3917 -123.8691 0.64
# US OGNE 40.9451 -102.033 1.054
# US OXF 34.5118 -89.4092 0.101
# US PKME 45.2644 -69.2917 0.1085
# US RLMT 45.1221 -109.2673 2.086
# US SCIA 41.9069 -93.2153 0.3115
# US SDCO 37.7456 -105.5012 2.569
# US TPNV 36.9488 -116.2495 1.6
# US VBMS 32.21851 -90.517671 0.016
# US WMOK 34.7379 -98.7807 0.486
# US WUAZ 35.5169 -111.3739 1.592
# US WVOR 42.4339 -118.6367 1.344
# UW GRCC 47.31237 -122.180283 0.134
# UW SQM 48.073681 -123.048058 0.045
# UW YACT 45.932499 -122.419296 0.2112
# XD A07 32.632999 -116.556099 0.925
# XD A26 32.945801 -115.406502 -0.025
# XD B03 33.030201 -115.543198 -0.053
# XD M01 32.1731 -116.706398 0.266
# XD M02 32.246899 -116.004204 1.513
# XD N01 33.547699 -114.912102 0.145
# XD S01 32.772099 -114.332298 0.058
# XO LG25 37.663898 -88.455704 0.12
# XR SC04 34.5228 -105.811897 1.944
# XR SC19 33.518799 -105.974403 1.413
# XR SC50 32.3895 -105.615303 1.427
# XR SC71 31.646299 -103.065498 0.83
# XT L10 44.429001 -115.2948 2.004
# Y5 CLA 50.009998 -113.519997 1.039
# YN JORD 33.4722 -116.645 1.235
# YX C03 40.590698 -115.951202 1.775
# YX D02 40.530602 -114.635101 1.862
# YX D04 40.195702 -115.978401 1.897
# YX D05 40.869099 -116.2117 1.595

# %% [markdown]
# A related problem is that save_inventory created a similar collection called *channel* that stores additional information that is tied to a specific channel.   The *channel* collection is always much larger than *site* because today most if not all instruments will record three-component data and have at least three channels.  Channel data contains instrument response data and orientation information so you will find it nearly always has many more documents than site because of instrumentation changes.
#
# To see that here is a similar summary report for the *channel* collection:

# %%
def print_channel_report(db):
    """
    Simple example function to print a basic report on contents of the site and channel collections.
    The example uses the low level MongoDB API using json.  
    :param db:  is a mspasspy.db Database object assumed pointed at an operating MongoDB server
    """
    dbsite=db.site
    dbchannel=db.channel
    curs=dbsite.find({})
    print('net sta Number_channels')
    for doc in curs:
        net=doc['net']
        sta=doc['sta']
        query=dict()
        query['net']=net
        query['sta']=sta
        n=dbchannel.count_documents(query)
        print(net,sta,n)

print_channel_report(db)
# CI BAK 3
# CI BAR 6
# CI BBR 3
# CI BBS 3
# CI BC3 3
# CI BCW 3
# CI BEL 3
# CI BFS 3
# CI BHP 3
# CI BLA2 3
# CI BLY 3
# CI BOM 6
# CI BOR 3
# CI BRE 3
# CI BTC 3
# CI BTP 3
# CI CAR 3
# CI CCC 3
# CI CGO 3
# CI CHF 3
# CI CHN 6
# CI CIA 6
# CI CJM 3
# CI CLC 3
# CI CLT 6
# CI CTC 6
# CI CWC 6
# CI DAN 6
# CI DEC 6
# CI DEV 6
# CI DGR 3
# CI DJJ 3
# CI DLA 6
# CI DNR 3
# CI DPP 3
# CI DRE 3
# CI DSC 3
# CI EDW2 3
# CI EML 3
# CI ERR 3
# CI FHO 3
# CI FIG 3
# CI FMP 3
# CI FUR 6
# CI GATR 3
# CI GLA 3
# CI GMR 3
# CI GOR 3
# CI GR2 6
# CI GRA 3
# CI GSC 3
# CI HEC 6
# CI HLL 6
# CI IDO 3
# CI IKP 6
# CI IPT 3
# CI IRM 6
# CI ISA 3
# CI JEM 3
# CI JRC2 3
# CI JVA 3
# CI LAF 6
# CI LCG 3
# CI LCP 3
# CI LDF 3
# CI LDR 3
# CI LFP 3
# CI LGB 6
# CI LGU 3
# CI LJR 3
# CI LLS 3
# CI LMR2 3
# CI LPC 6
# CI LRL 3
# CI LTP 6
# CI LUG 3
# CI MCT 3
# CI MGE 6
# CI MLAC 3
# CI MLS 6
# CI MOP 3
# CI MPI 3
# CI MPM 6
# CI MPP 6
# CI MSC 6
# CI MSJ 6
# CI MTP 6
# CI MUR 6
# CI MWC 3
# CI NBS 3
# CI NEE2 3
# CI NJQ 3
# CI NSS2 6
# CI OLI 3
# CI OLP 3
# CI OSI 4
# CI PASC 9
# CI PDE 3
# CI PDM 6
# CI PDR 3
# CI PDU 3
# CI PER 3
# CI PHL 3
# CI PLM 3
# CI PLS 3
# CI PMD 6
# CI PSD 6
# CI PSR 6
# CI RCT 3
# CI RIN 6
# CI RIO 3
# CI RPV 6
# CI RRX 3
# CI RSS 6
# CI RUS 3
# CI RVR 3
# CI RXH 3
# CI SAL 3
# CI SBB2 3
# CI SBC 3
# CI SBI 3
# CI SBPX 3
# CI SCI2 3
# CI SCZ2 6
# CI SDD 6
# CI SDG 3
# CI SDR 6
# CI SES 3
# CI SHO 6
# CI SLA 9
# CI SLB 3
# CI SLR 3
# CI SMF2 3
# CI SMI 3
# CI SMM 3
# CI SMR 6
# CI SMS 3
# CI SMW 3
# CI SNCC 3
# CI SNO 3
# CI SNR 3
# CI SPF 3
# CI SPG2 3
# CI SRI 3
# CI SRN 6
# CI STC 3
# CI STG 3
# CI STS 3
# CI SVD 6
# CI SWS 6
# CI SYP 3
# CI TA2 3
# CI TEH 3
# CI TFT 3
# CI TIN 3
# CI TOR 6
# CI TUQ 3
# CI USC 6
# CI VCS 6
# CI VES 3
# CI VOG 3
# CI VTV 6
# CI WBS 3
# CI WES 3
# CI WGR 3
# CI WLT 3
# CI WSS 3
# CI WTT2 3
# CI WWC 6
# CN BBB 3
# CN CBB 6
# CN DRLN 3
# CN EDB 3
# CN EDM 3
# CN GAC 3
# CN GGN 3
# CN ICQ 3
# CN KAPO 3
# CN KGNO 3
# CN LLLB 3
# CN LMN 3
# CN LMQ 6
# CN LZB 3
# CN MNTQ 3
# CN MOBC 3
# CN NLLB 3
# CN OZB 3
# CN PGC 3
# CN PHC 3
# CN PNT 3
# CN SADO 3
# CN SHB 3
# CN SLEB 3
# CN ULM 3
# CN VLDQ 3
# CN WALA 3
# CN WSLR 3
# CU GRTK 3
# EP KIDD 3
# G SCZ 3
# GS CVRD 3
# GS HGTCO 6
# GS LA01 3
# GS LA02 3
# GS LA03 3
# GS LA06 3
# GS LA07 3
# GS LA08 3
# GS LA09 3
# GS MHTCO 3
# GS OK020 3
# GS OK021 3
# GS OK022 3
# GS PTRD 3
# GS RDG11 3
# GS RDG12 3
# GS RDG13 3
# GS RDG14 3
# GS RDG21 3
# GS RDG22 3
# GS RDG23 3
# GS RDG24 3
# GS SPFD 3
# GS SPRD 3
# HW CCRK 3
# HW DDRF 3
# HW PHIN 3
# II PFO 3
# IM NV31 6
# IM PD31 3
# IM TKL 3
# IM TX32 3
# IU ANMO 9
# IU BBSR 6
# IU CCM 6
# IU COR 6
# IU DWPF 6
# IU HKT 6
# IU HRV 6
# IU RSSD 6
# IU SLBS 3
# IU SSPA 3
# IU TEIG 3
# IU TUC 6
# IU WCI 3
# IU WVT 6
# IW DLMT 3
# IW FLWY 3
# IW FXWY 6
# IW IMW 3
# IW LOHW 3
# IW MFID 3
# IW MOOW 3
# IW PHWY 3
# IW PLID 3
# IW REDW 3
# IW RWWY 6
# IW SMCO 3
# IW SNOW 3
# IW TPAW 3
# LB BMN 3
# LB DAC 3
# LD ACCN 3
# LD ALLY 3
# LD BMNY 3
# LD BRNJ 3
# LD BRNY 3
# LD CPNY 6
# LD FOR 3
# LD FRNY 3
# LD HCNY 3
# LD KSCT 3
# LD KSPA 3
# LD MCVT 3
# LD NCB 3
# LD NPNY 3
# LD ODNJ 3
# LD PAL 6
# LD PANJ 3
# LD WCNY 3
# LD WVNY 3
# MB JTMT 3
# NE BCX 3
# NE BRYW 3
# NE DUNH 3
# NE EMMW 6
# NE FFD 3
# NE HNH 3
# NE ORNO 3
# NE PQI 6
# NE QUA2 3
# NE TRY 6
# NE VT1 3
# NE WES 3
# NE WSPT 3
# NE WVL 6
# NE YLE 6
# NM BLO 3
# NM FVM 3
# NM MGMO 3
# NM MPH 3
# NM OLIL 3
# NM PBMO 6
# NM PLAL 3
# NM PVMO 3
# NM SIUC 6
# NM SLM 3
# NM UALR 3
# NM USIN 3
# NM UTMT 3
# OK U32A 3
# OK X37A 3
# PE PAGS 3
# PE PSDB 3
# PE PSUB 3
# PE PSWB 3
# PE UPAO 3
# PE WRPS 3
# PN PPBLO 1
# PN PPCWF 1
# PN PPEGH 1
# PN PPMOO 1
# PN PPNAF 1
# PN PPPCH 1
# SC SRGE 3
# SC Y22A 6
# SS NCAT 3
# TA 058A 3
# US EGMT 6
# US ELK 6
# US ERPA 6
# US EYMN 6
# US GLMI 6
# US GOGA 6
# US HAWA 6
# US HDIL 6
# US HLID 6
# US HWUT 3
# US ISCO 6
# US JCT 6
# US JFWS 6
# US KSU1 6
# US KVTX 6
# US LAO 6
# US LBNH 6
# US LKWY 6
# US LONY 6
# US LRAL 6
# US MCWV 6
# US MIAR 6
# US MNTX 6
# US MSO 6
# US MVCO 6
# US NATX 6
# US NEW 6
# US NHSC 6
# US NLWA 6
# US OGNE 6
# US OXF 6
# US PKME 6
# US RLMT 6
# US SCIA 6
# US SDCO 6
# US TPNV 6
# US TZTN 6
# US VBMS 6
# US WMOK 6
# US WUAZ 6
# US WVOR 6
# UU SRU 3
# UW BABR 3
# UW BLOW 3
# UW BRAN 3
# UW CCRK 3
# UW DAVN 3
# UW DDRF 3
# UW DOSE 3
# UW FISH 3
# UW FORK 3
# UW GNW 3
# UW HEBO 6
# UW HOOD 6
# UW IRON 3
# UW IZEE 3
# UW JEDS 3
# UW KENT 3
# UW LCCR 3
# UW LEBA 3
# UW LON 6
# UW LRIV 3
# UW LTY 6
# UW MEGW 3
# UW MRBL 3
# UW OFR 3
# UW OMAK 3
# UW PASS 3
# UW PHIN 3
# UW RADR 3
# UW RATT 3
# UW SHUK 6
# UW SP2 6
# UW STOR 3
# UW TAKO 3
# UW TOLT 6
# UW TREE 3
# UW TUCA 3
# UW UMAT 3
# UW WISH 6
# UW WOLL 6
# X4 GC01 3
# X4 GC03 3
# X4 GC04 3
# X4 GC05 3
# X4 GC06 3
# X4 GC07 3
# X4 GC08 3
# X4 GC09 6
# X4 GC10 3
# X4 GC11 3
# X4 GC12 6
# X4 GC13 3
# X4 GC14 3
# X4 GC15 6
# X4 GC16 3
# X4 GC17 6
# X4 GC18 3
# X4 GC19 3
# X4 GC20 3
# X4 GC24 3
# X4 GC25 3
# X4 GC26 3
# X8 QM40 3
# XD A01 3
# XD A02 6
# XD A03 3
# XD A04 3
# XD A05 3
# XD A06 3
# XD A07A 3
# XD A08 3
# XD A09 3
# XD A10 3
# XD A11 6
# XD A12 3
# XD A13 6
# XD A14 6
# XD A15 3
# XD A16 6
# XD A17 3
# XD A18 3
# XD A19 3
# XD A20 3
# XD A21 3
# XD A22 3
# XD A23 6
# XD A24 6
# XD A25 3
# XD A26A 6
# XD A27 3
# XD A29 3
# XD A30 6
# XD A32 3
# XD A33 3
# XD A34 3
# XD A35 6
# XD A36 6
# XD A38 3
# XD A39 6
# XD A40 6
# XD B01 6
# XD B02 6
# XD C02 6
# XI SC01 3
# XI SC02 3
# XI SC03 3
# XI SC04 3
# XI SC05 3
# XI SC06 6
# XI SC07 3
# XI SC08 3
# XI SC09 3
# XI SC10 3
# XI SC11 3
# XI SC12 3
# XI SC13 3
# XI SC14 3
# XI SC15 3
# XI SC16 3
# XI SM17 3
# XI SM18 3
# XI SM19 3
# XI SM20 6
# XI SM21 3
# XI SM22 3
# XI SM23 3
# XI SM24 3
# XI SM25 6
# XI SM26 3
# XI SM27 3
# Z9 W13 3
# Z9 W14 3
# Z9 W15A 3
# Z9 W16 3
# Z9 W17 3
# Z9 W18 6
# Z9 W19 3
# Z9 W20 3
# Z9 W21 3
# Z9 W22 3
# Z9 W23 3
# Z9 W24 3
# Z9 W26 6
# Z9 W27 3
# Z9 W28 3
# Z9 W29 3
# Z9 W30 3
# Z9 W31 3
# Z9 W315 3
# Z9 W32 3
# Z9 W33 3
# Z9 W34 3
# Z9 W35 3
# ZL N01A 3
# ZL N02A 3
# ZL N03A 3
# ZL N04A 3
# ZL N05M 6
# ZL N06M 6
# ZL N08A 3
# ZL N09A 3
# ZL N10A 3
# ZL N11M 3
# ZL N12M 3
# ZL N19M 3
# ZL N20M 3
# ZL N21M 3
# ZL N22I 3
# ZL N23I 3
# ZL N24I 3
# ZL N26I 3
# ZL N27M 3
# ZL N28M 3
# 2D OBS03 3
# 2D OBS06 3
# 2D OBS07 3
# 2D OBS08 3
# 2D OBS09 3
# 2D OBS10 3
# 2D OBS11 3
# 2D OBS12 3
# 2D OBS13 3
# 2D OBS15 3
# 2D OBS16 3
# 2D OBS17 3
# 2D OBS18 3
# 2D OBS19 3
# 2D OBS20 3
# 2D OBS21 3
# 2D OBS22 3
# 2D OBS23 3
# 2D OBS24 3
# 2D OBS25 3
# 2D OBS28 3
# 2D OBS32 3
# 7A W01 3
# 7A W02 3
# 7A W03 3
# 7A W04 3
# 7A W05 3
# 7A W06 3
# 7A W07 3
# 7A W08 3
# 7A W09 3
# 7A W10 3
# AR 113A 3
# AR 319A 3
# AR U15A 3
# AR W13A 3
# AR X18A 3
# AR Y14A 3
# AZ FRD 3
# BK BDM 6
# BK BKS 6
# BK GASB 6
# BK WDC 6
# BK YBH 8
# CI ADO 3
# CI BAK 3
# CI BBR 3
# CI BC3 3
# CI BFS 3
# CI CHF 3
# CI CIA 6
# CI CWC 6
# CI DEC 6
# CI DGR 3
# CI DJJ 3
# CI EDW2 3
# CI GLA 3
# CI GMR 3
# CI GRA 3
# CI IBP 3
# CI IKP 6
# CI ISA 3
# CI LRL 3
# CI MLAC 3
# CI MPM 6
# CI MUR 6
# CI MWC 3
# CI NEE2 3
# CI OSI 4
# CI PASC 9
# CI PHL 3
# CI RCT 3
# CI RPV 6
# CI SBC 3
# CI SCI2 3
# CI SDD 6
# CI SHO 6
# CI SMM 3
# CI SNCC 3
# CI SVD 6
# CI SWS 6
# CI USC 6
# CI VCS 6
# CN BMSB 3
# CN SNB 3
# IU CCM 6
# IU HKT 6
# IU WVT 6
# LD BMNY 3
# LD LUPA 3
# LD MVL 3
# NE YLE 6
# NM SIUC 6
# PN PPBNL 1
# PN PPPHS 1
# TA 034A 3
# TA 035A 3
# TA 035Z 3
# TA 130A 3
# TA 131A 3
# TA 133A 3
# TA 134A 3
# TA 135A 3
# TA 230A 3
# TA 231A 3
# TA 232A 3
# TA 233A 3
# TA 234A 3
# TA 238A 3
# TA 239A 3
# TA 330A 3
# TA 331A 3
# TA 332A 3
# TA 333A 3
# TA 334A 3
# TA 335A 3
# TA W34A 3
# TA W41A 3
# TA X30A 3
# TA X31A 3
# TA X32A 3
# TA X33A 3
# TA X34A 3
# TA Y30A 3
# TA Y31A 3
# TA Y32A 3
# TA Y33A 3
# TA Y34A 3
# TA Z30A 3
# TA Z31A 3
# TA Z32A 3
# TA Z33A 3
# TA Z34A 3
# TA Z35A 3
# US AAM 6
# US ACSO 6
# US AGMN 6
# US AMTX 6
# US BINY 6
# US BLA 6
# US BMO 6
# US BOZ 6
# US BRAL 6
# US CBKS 6
# US CBN 6
# US CNNC 6
# US COWI 6
# US DGMT 6
# US DUG 6
# US ECSD 6
# US EGMT 6
# US ELK 6
# US ERPA 6
# US EYMN 6
# US GLMI 6
# US GOGA 6
# US HAWA 6
# US HDIL 6
# US HLID 6
# US ISCO 6
# US JCT 6
# US JFWS 6
# US KSU1 6
# US KVTX 6
# US LAO 6
# US LBNH 6
# US LONY 6
# US LRAL 6
# US MCWV 6
# US MIAR 6
# US MNTX 6
# US MSO 6
# US MVCO 6
# US NATX 6
# US NCB 3
# US NEW 6
# US NHSC 6
# US NLWA 6
# US OGNE 6
# US OXF 6
# US PKME 6
# US RLMT 6
# US SCIA 6
# US SDCO 6
# US TPNV 6
# US VBMS 6
# US WMOK 6
# US WUAZ 6
# US WVOR 6
# UW GRCC 1
# UW SQM 3
# UW YACT 3
# XD A07 3
# XD A26 3
# XD B03 3
# XD M01 3
# XD M02 3
# XD N01 3
# XD S01 3
# XO LG25 3
# XR SC04 3
# XR SC19 3
# XR SC50 3
# XR SC71 3
# XT L10 3
# Y5 CLA 3
# YN JORD 3
# YX C03 6
# YX D02 3
# YX D04 3
# YX D05 3

# %% [markdown]
# Notice that most of the stations have exactly 3 components, but a few have 6. The reason is that those with only 3 components had no configuration changes in the time period and only one sensor attached.  Stations with a number greater than 3 in the table above have one of two issues MsPASS handles:  (1) the instrumentation changed changing response and/or orientation, and/or (2) the station has multiple sensors attached (e.g. IU:ANMO) with different "location" codes.
#
# A deficiency in the data currently stored with this tutorial is that the stationxml files we used above created by obspy are incomplete.   For the purpose of this exercise it doesn't matter, but for a full workflow you would want at this stage to be sure your station metadata are complete.  We leave that process as an exercise for the student because different people have different needs with regard to this issue.
#
# A final point about the Database object in MsPASS and the save_inventory method.  That method can be called repeatedly with duplicate data and the function will assure pure duplicates are not added to the site or channel collections. That makes adding collections of stationxml files downloaded independently easy to add without worries about adding clutter.  That is common, for example, when downloading data like the TA by year; each download run will produce a new pile of stationxml files with many duplicates. To demonstrate this, run this block again which will attempt to save the same Inventory object read earlier a second time.

# %%
db.save_inventory(inv)
# Out:
# BK : BRIB : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   37.91886 -122.15179 0.21969999999999998
# loc code section coordinates:   37.91881 -122.15176 0.2189
# BK : HAST : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   36.3887 -121.5514 0.542
# loc code section coordinates:   36.3887 -121.5514 0.5395
# BK : HATC : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   40.8161 -121.46117 1.0092999999999999
# loc code section coordinates:   40.8161 -121.46117 1.0086
# BK : HELL : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   36.68011 -119.02282 1.14
# loc code section coordinates:   36.68011 -119.02282 1.1375
# BK : RAMR : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   35.63597 -120.86984 0.4168
# loc code section coordinates:   35.63597 -120.86984 0.4143
# BK : SUTB : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   39.2291 -121.7861 0.252
# loc code section coordinates:   39.2291 -121.7861 0.2495
# CI : CWC :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   36.439047 -118.080495 1.5695
# loc code section coordinates:   36.43988 -118.08016 1.595
# CI : FUR :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   36.46703 -116.86322 -0.037
# loc code section coordinates:   36.46719 -116.86322 -0.038
# CI : SHO :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   35.899529 -116.275299 0.451
# loc code section coordinates:   35.899601 -116.275146 0.451
# CI : SNR :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   32.86184 -115.43602 -0.063
# loc code section coordinates:   32.86189 -115.43596 -0.063
# CI : SYP :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   34.52781 -119.97832 1.278
# loc code section coordinates:   34.52775 -119.97834 1.278
# G : SCZ :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   36.59798 -121.40481 0.261
# loc code section coordinates:   36.598 -121.403 0.261
# IU : ANMO : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   34.94591 -106.4572 1.82
# loc code section coordinates:   34.945981 -106.457133 1.671
# IU : BBSR : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   32.371299 -64.696299 0.03
# loc code section coordinates:   32.371299 -64.696299 -0.0013
# IU : CCM : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   38.0557 -91.2446 0.222
# loc code section coordinates:   38.0557 -91.2446 0.1715
# IU : DWPF : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   28.1103 -81.4327 0.03
# loc code section coordinates:   28.1103 -81.4327 -0.132
# IU : HKT : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   29.9618 -95.8384 -0.413
# loc code section coordinates:   29.9618 -95.8384 -0.863
# IU : RSSD : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   44.1212 -104.0359 2.09
# loc code section coordinates:   44.1212 -104.0359 2.0227
# IU : SSPA : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   40.6358 -77.8876 0.27
# loc code section coordinates:   40.6358 -77.8876 0.17
# IU : TEIG : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   20.2263 -88.2763 0.04
# loc code section coordinates:   20.2263 -88.2763 -0.071
# IU : TUC : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   32.3098 -110.7847 0.91
# loc code section coordinates:   32.3098 -110.7847 0.909
# IU : WCI : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   38.2289 -86.2939 0.21
# loc code section coordinates:   38.2289 -86.2939 0.078
# LB : BMN :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   40.4314 -117.221001 1.594
# loc code section coordinates:   40.4314 -117.220993 1.594
# LD : NCB :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   43.973468 -74.22307 0.575
# loc code section coordinates:   43.9734 -74.222801 0.575
# LD : PAL :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   41.0056 -73.9079 0.066
# loc code section coordinates:   41.0056 -73.907898 0.066
# NE : BCX :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   42.335 -71.1705 0.06
# loc code section coordinates:   42.334999 -71.170502 0.06
# NE : BRYW :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   41.917 -71.5378 0.116
# loc code section coordinates:   41.917 -71.537804 0.116
# NE : EMMW :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   44.7075 -67.4573 0.035
# loc code section coordinates:   44.7075 -67.457298 0.035
# NE : FFD :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   43.4701 -71.6537 0.131
# loc code section coordinates:   43.4701 -71.653702 0.131
# NE : HNH :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   43.7051 -72.2865 0.18
# loc code section coordinates:   43.705101 -72.286499 0.18
# NE : PQI :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   46.6713 -68.019 0.162
# loc code section coordinates:   46.671299 -68.018997 0.162
# NE : QUA2 :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   42.279 -72.352 0.168
# loc code section coordinates:   42.278999 -72.351997 0.168
# NE : TRY :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   42.7313 -73.6664 0.089
# loc code section coordinates:   42.7313 -73.666397 0.089
# NE : WSPT :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   41.1712 -73.3278 0.091
# loc code section coordinates:   41.1712 -73.327797 0.091
# NE : WVL :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   44.5646 -69.6617 0.05
# loc code section coordinates:   44.564602 -69.661697 0.05
# US : ECSD : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   43.7337 -96.6141 0.478
# loc code section coordinates:   43.7337 -96.6141 0.43289999999999995
# US : GOGA : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   33.4112 -83.4666 0.1165
# loc code section coordinates:   33.4112 -83.4666 0.083
# US : KSU1 : 00  (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   39.1009 -96.6094 0.317
# loc code section coordinates:   39.1009 -96.6094 0.2963
# UU : SRU :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   39.11083 -110.52383 1.804
# loc code section coordinates:   39.110828 -110.523827 1.804
# UW : BLOW :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   44.6837 -122.1862 0.6573
# loc code section coordinates:   44.683701 -122.186203 0.652
# UW : GNW :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   47.56413 -122.82498 0.22
# loc code section coordinates:   47.564129 -122.824982 0.22
# UW : LTY :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   47.25451 -120.66636 0.807
# loc code section coordinates:   47.254509 -120.666359 0.807
# UW : TAKO :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   43.74313 -124.08337 0.012
# loc code section coordinates:   43.74334 -124.082474 0.046
# UW : TOLT :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   47.6947 -121.6895 0.541
# loc code section coordinates:   47.694698 -121.689499 0.541
# Database.save_inventory processing summary:
# Number of site records processed= 1712
# number of site records saved= 0
# number of channel records processed= 5148
# number of channel records saved= 0
# (0, 0, 1712, 5148)

# %% [markdown]
# To see the key point you will need to scroll to the bottom of the output to bypass the warning messages.  The summary should say that 0 site and 0 channel records were saved.

# %% [markdown]
# ## 4.2. Source metadata
# ### 4.2.1. Extracting data from stationml files
# MsPASS has a similar, simple method to import event (source) data stored as a file in the so called QuakeML format defined by the FDSN (<https://www.fdsn.org/webservices/>) for web services.  Obspy has a direct translation of the XML format file to a python object they call a Catalog (<https://docs.obspy.org/packages/autogen/obspy.core.event.Catalog.html#obspy.core.event.Catalog>) object.  You can load the QuakeML data file for this tutorial by a pair of commands very similar to that used above to read the station metadata:

# %%
from obspy import read_events
#db.drop_collection('source')
cat=read_events('data/raw_data_tutorial/eventdata/events_2012.xml',format='QUAKEML')
n=db.save_catalog(cat)
print('Number of events stored by save_catalog in source collection=',n)
# Out:
# Number of events stored by save_catalog in source collection= 961

# %% [markdown]
# Note the method returns the count of the number of documents added that is printed with an explanation in the last line.  In MsPASS we store event information in a separate collection we call *source*.
#
# It is important to realize one key difference between this method and save_inventory.   Unlike seismic instruments that fixed objects an earthquake location is intrinsically fuzzy.  Multiple institutions often estimate the location from a different mix of instruments.   The CSS3.0 schema has a fairly elaborate way to handle this problem that causes major bookkeeping headaches for all seismic network operators or any experiment that requires preparing an event bulletin (meaning location estimates and a set of measure arrival times).   In MsPASS we treat that problem as a preprocessing issue that we will need to address below.   That is, in the next section we will add a second set of earthquake location estimates to our *source* collection and use a method to define which document in *source* to link to other documents.  A WARNING, however, is you should not rerun save_catalog on data from the same input file.  It will silently insert exact duplicates of the first run.

# %% [markdown]
# ### 4.2.2. Import data from Antelope (CSS3.0 database)
# #### 4.2.2.1. Background
# Antelope is a software package developed and supported by a small company called Boulder Real Time Technologies (BRTT).   A component of Antelope is a specialized relational database package sometimes called Datascope because the current version is a descendent of an open source package with that name developed in the 1990s.   There are several key points about Antelope that are important to recognize as a preface to this tutorial:
# - Although Antelope is a commerical package it is widely available and used in the US because of a generous licensing arrangement by BRTT.  Thus most readers of this tutorial in the US can obtain Antelope at no cost.  If that is you then you can recreate the steps here and create the catalog file we will be using yourself.  For others we supply an export file that can be used directly.  If you are the later, you need only skim this section to get an idea of what the file is and how it was generated.
# - Antelope is used by a number of regional seismic networks, notably the Alaska and Nevada networks.   More importantly to many seismologists is the fact that Antelope was the processing system used to manage the real time data from the USArray project at the Array Network Facility.   Important data relevant to this tutorial is the set of monthly catalogs of data distributed by ANF at this location:  <https://anf.ucsd.edu/tools/events/>.  In this tutorial we will be using data from the USArray recorded in 2012.   The unpacked tar files are found in a directory *anf* in the folder where you launched this tutorial.   I used a shell script found in a different directory, *catalog_data*, to use Antelope database command line tools to create a file *./catalog_data/usarray_tele2012.txt*. That script is found in *./catalog_data/export2012.csh* and for reference is this:
# ```
# !/bin/csh
# set yr=2012
# set outfile="usarray_tele${yr}.txt"
# #rm $outfile
# set dbdir="../anf"
# foreach mon (01 02 03 04 05 06 07 08 09 10 11 12)
#   set dbname=usarray_${yr}_${mon}
#   set dbpath=${dbdir}/events_${dbname}/$dbname
#   echo Working on database $dbname
#   dbjoin ${dbpath}.event origin \
#   | dbsubset - "orid==prefor" \
#   | dbjoin - netmag \
#   | dbsubset - "magnitude>5.0" \
#   | dbjoin - assoc arrival \
#   | dbsubset - "assoc.delta>30.0 && assoc.delta<95.0" \
#   | dbselect - event.evid origin.lat origin.lon origin.depth origin.time origin.mb origin.ms assoc.sta assoc.phase arrival.iphase assoc.delta assoc.seaz assoc.esaz assoc.timeres arrival.time arrival.deltim \
#   >> $outfile
# ```
# - Although that shell script is not elegant it accomplishes the object I was seeking.  It produces the main attributes I need from the css3.0 database for defining the data set we will build in this tutorial.   That is, a subset of teleseismic events recorded by USArray in 2012.   In particular, our objective is to produce a data set appropriate for P wave receiver function analysis.   We select only larger events (the *magnitude>5.0* dbsubset command) and arrivals measured at stations between 30 and 95 degrees epicentral distances (the dbsubset querry using *assoc.delta*).  We use Antelope's dbselect command to extract only attributes we might need for this analysis. You should recognize the argument list to dbselect does not extract all attributes possible, but the specific list there is intimately linked to a step below when we parse the output of this script (the file *./catalog_data/usarray_tele2012.txt*).
# - The approach we use here can and should be thought of as a way to general way export data in an antelope css3.0 database to MsPASS.  Here the emphasis is "catalog" data, but the same general idea could be done for any relational database view that can be constructed with Antelope tools.   This particular example is a custom export to match python functions we will be used that are distributed with MsPASS and which we will be using below.

# %% [markdown]
# #### 4.2.2.2. The *arrival* collection
# Previously we added data to collections called *site*, *channel*, and *source*.   Those three collections contain fundamental data comparable to geometry in seismic reflection processing and are required information for most processing work flows with MsPASS.   For raw processing, however, we need an additional concept that is not as univeral as those three core concepts.   That new concept is what seismologists universally call an "arrival".  We define an *arrival document* as a set of parametric data measured in a time window of data that defines a particular "seismic phase".  For this tutorial we will be working with arrivals defined by teleseismic P waves.  The main parametric data of interest for this tutorial will be the measured arrival time of P by an analyst at the Array Network Facility.   In the script above, that is the CSS3.0 attribute with the tag "arrival.time".
#
# We first want to load the output from the shell script described in the previous section.   Note compared to what we did previously, this data set is huge.  The table that script generates has 353,482 rows.  Run the following script to load that data in this tutorial:

# %%
from mspasspy.preprocessing.css30.dbarrival import load_css30_arrivals
valret=load_css30_arrivals(db,'data/raw_data_tutorial/catalog_data/usarray_tele2012.txt')

# %% [markdown]
# We can confirm this worked and inserted the number we expected with this pair of commands.

# %%
dbarrival=db.arrival
print('Number of arrivals added=number of documents in arrival=',dbarrival.count_documents({}))
# Out:
# Number of arrivals added=number of documents in arrival= 353482

# %% [markdown]
# #### 4.2.2.3. CSS3.0 Limitation History and Solution - background you may elect to skip
# The CSS3.0 schema was developed in the late 1970s when storage and computer speeds were orders of magnitude smaller than today.  At the time few had the vision to think the number of seismic instruments on the planet would grow as large as it has.  The schema relied on the concept of an alphanumeric "station code", which had a long history in seismology as a filing system for analog records.  Hence, it was natural to use station codes as an index for many database tables.  One of them was the arrival table, which is what we are working to translate here. The catalog tables (event, origin, assoc, and arrival) use the station code as a primary join key.  The data we just loaded extracted that field in the shell script above a assoc.sta, which is the copy of the station code in the CSS3.0 assoc table.
#
# In the mid 1980s with the birth of the Global Seismic Network and IRIS the global seismic community developed the Standard Earthquake Exchange Data (SEED) format.  The committee that drafted the standard recognized that a station code alone created a problem by limiting the namespace to define a unique key to identify a single channel of seismic data.  They elected to define a four part key that has constrained earthquake data management since that decision was made.  That four part key in MsPASS have the abbreviations:  net, sta, chan, and loc.  (Obspy refers to these in the more verbose form network, station, channel, and location.)  The SEED standard created a collision with the CSS3.0 schema standard because CSS3.0 did not use the concept of a network or location code.   The developers of the original Datascope package, the ancestor of Antelope's database, had a significant code base that utilized the CSS3.0 schema - notably dbpick written by Danny Harvey that remains a workhorse in Antelope. Hence, Datascope did not use a revised schema but instead built their tools directly on the CSS3.0 schema.  As their code base grew it became too difficult for them the move to a different schema that would handle SEED data more easily.  They instead chose a band-aid solution that had several elements:
# 1.  The station code tag was treated as a unique identifier in all tables as defined in CSS3.0
# 2.  Similarly the channel (chan) code was treated as a unique identifier for each seismic channel as defined in CSS3.0
# 3.  If a SEED (miniseed) file was read that created a name collision with the station code (i.e. two or more stations with the same station code but a different network code) the name of all secondary stations encountered would use an altered station code.  (e.g. in this data we have net=BK and sta=HELL and net=TA and sta=HELL.  If TA:HELL had been handled earlier BK:HELL would be tagged as HELLBK.  Similarly if BK:HELL were handled first TA:HELL would be treated as HELLTA.)
# 4.  Many observatory style seismic stations have multiple sensors at the same location.  GSN stations, for example, all (at least nearly all) have 2 or more sensors.   Unfortunately, the SEED standard also adopted ridid rules about how a channel codes should be defined that further limited the namespace (<https://ds.iris.edu/ds/nodes/dmc/data/formats/seed-channel-naming/>).  Hence, we have only a small namespace for channel names like BHZ, HHZ, BH1, HHE, etc.  A SEED defined channel with that restriction will always be ambiguous if a seismic station has more than one sensor.   e.g. Many GSN stations have a BHZ channel defined for location codes 00 and 01.  To adapt CSS3.0 to this ambiguity the authors of Datascope elected to use similar rules as for the station information.  The first channel code with a unique name would drop the loc code and subsequently appearances would include the loc code.

# %% [markdown]
# ### 4.3. Resolving arrival ambiguities
# The point of the admittedly long winded discussion above about css3.0 limitations and net:sta:chan:loc code in SEED is that the arrival data we just loaded currently have an ambiguous relationship with the data we stored in the site and channel collections.  To see that run the cell below:

# %%
from mspasspy.preprocessing.css30.dbarrival import find_duplicate_sta
dups=find_duplicate_sta(db)
print('There are ',len(dups),' stations in site with ambiguous sta codes')
print('List of station with multiple net codes for that sta code')
for k in dups:
    print(k,dups[k])
# Out:
# There are  84  stations in site with ambiguous sta codes
# List of station with multiple net codes for that sta code
# G30A {'TA', '7D'}
# J25A {'TA', '7D'}
# J28A {'TA', '7D'}
# J29A {'TA', '7D'}
# J30A {'TA', '7D'}
# J31A {'TA', '7D'}
# J33A {'TA', '7D'}
# J35A {'TA', '7D'}
# J36A {'TA', '7D'}
# J37A {'TA', '7D'}
# J38A {'TA', '7D'}
# J39A {'TA', '7D'}
# J43A {'TA', '7D'}
# J45A {'TA', '7D'}
# J46A {'TA', '7D'}
# J47A {'TA', '7D'}
# J48A {'TA', '7D'}
# J52A {'TA', '7D'}
# J54A {'TA', '7D'}
# J55A {'TA', '7D'}
# 113A {'AE', 'AR'}
# 319A {'AE', 'AR'}
# U15A {'AE', 'AR'}
# W13A {'AE', 'AR'}
# X18A {'AE', 'AR'}
# Y14A {'AE', 'AR'}
# PFO {'AZ', 'II'}
# SCI2 {'AZ', 'CI'}
# PER {'Y5', 'CI'}
# WES {'NE', 'CI'}
# CCRK {'UW', 'HW'}
# DDRF {'UW', 'HW'}
# PHIN {'UW', 'HW'}
# NCB {'LD', 'US'}
# U32A {'TA', 'OK'}
# X37A {'TA', 'OK'}
# A01 {'YX', 'XD'}
# A02 {'YX', 'XD'}
# A03 {'YX', 'XD'}
# A04 {'YX', 'XD'}
# A05 {'YX', 'XD'}
# A06 {'YX', 'XD'}
# A08 {'YX', 'XD'}
# A09 {'YX', 'XD'}
# A10 {'YX', 'XD'}
# A11 {'YX', 'XD'}
# A13 {'YX', 'XD'}
# A14 {'YX', 'XD'}
# A15 {'YX', 'XD'}
# A26A {'TA', 'XD'}
# B01 {'YX', 'XD'}
# B02 {'YX', 'XD'}
# C02 {'YX', 'XD'}
# SC04 {'XR', 'XI'}
# D02 {'XT', 'YX', 'Z9'}
# D03 {'XT', 'Z9'}
# D04 {'XT', 'YX', 'Z9'}
# D05 {'XT', 'YX', 'Z9'}
# D06 {'XT', 'Z9'}
# D07 {'XT', 'Z9'}
# D08 {'XT', 'Z9'}
# D09 {'XT', 'Z9'}
# D10 {'XT', 'Z9'}
# D11 {'XT', 'Z9'}
# D12 {'XT', 'Z9'}
# D13 {'XT', 'Z9'}
# D14 {'XT', 'Z9'}
# D15 {'XT', 'Z9'}
# D17 {'XT', 'Z9'}
# D18 {'XT', 'Z9'}
# D20 {'XT', 'Z9'}
# D21 {'XT', 'Z9'}
# A07 {'YX', 'XD'}
# B03 {'YX', 'XD'}
# W01 {'Z9', '7A'}
# W02 {'Z9', '7A'}
# W03 {'Z9', '7A'}
# W04 {'Z9', '7A'}
# W05 {'Z9', '7A'}
# W06 {'Z9', '7A'}
# W07 {'Z9', '7A'}
# W08 {'Z9', '7A'}
# W09 {'Z9', '7A'}
# W10 {'Z9', '7A'}

# %% [markdown]
# The above shows we have 58 potentially ambiguous station codes.  That small function, whoever, just looks at site.  The more relevant output for the problem at hand, which is to unambiguously associate arrival times we loaded in arrival with the right documents in site and channel, comes form this related function:

# %%
from mspasspy.preprocessing.css30.dbarrival import check_for_ambiguous_sta
# this is using the dups list created above and extracting only the sta code into a python list
stalist=list()
for k in dups:
    stalist.append(k)
retval=check_for_ambiguous_sta(db,stalist)
# Out:
# station count
# G30A 0
# J25A 0
# J28A 0
# J29A 0
# J30A 0
# J31A 190
# J33A 209
# J35A 161
# J36A 518
# J37A 512
# J38A 481
# J39A 761
# J43A 645
# J45A 87
# J46A 133
# J47A 178
# J48A 149
# J52A 45
# J54A 7
# J55A 4
# 113A 0
# 319A 0
# U15A 0
# W13A 0
# X18A 0
# Y14A 0
# PFO 983
# SCI2 449
# PER 0
# WES 0
# CCRK 0
# DDRF 0
# PHIN 0
# NCB 0
# U32A 80
# X37A 87
# A01 0
# A02 0
# A03 0
# A04 0
# A05 0
# A06 0
# A08 0
# A09 0
# A10 0
# A11 0
# A13 0
# A14 0
# A15 0
# A26A 0
# B01 0
# B02 0
# C02 0
# SC04 0
# D02 0
# D03 0
# D04 0
# D05 0
# D06 0
# D07 0
# D08 0
# D09 0
# D10 0
# D11 0
# D12 0
# D13 0
# D14 0
# D15 0
# D17 0
# D18 0
# D20 0
# D21 0
# A07 0
# B03 0
# W01 0
# W02 0
# W03 0
# W04 0
# W05 0
# W06 0
# W07 0
# W08 0
# W09 0
# W10 0

# %% [markdown]
# This shows we can ignore some stations like A01 that have no picks in arrival, but we have a big issue with stations like PFO with hundreds of picks in arrival.
#
# We can patch part of this problem using a nonstandard Datascope (Antelope) table I obtained directly from ANF, that is, unfortunately, not distributed from the ANF web site.  The reasons for that are complicated and irrelevant, but for now the key data is in the file snetsta/usarray.snetsta.  The snetsta table is a patch method Antelope uses to workaround the station ambiguity problem.  Here are few selected lines from that file that show how we use it:
# ```
# TA       934A   934A    1503120361.98014
# TA       834A   834A    1503120736.28809
# TA       835A   835A    1503120736.92130
# AE       X16A   X16AAE  1600860674.47829
# AZ       BZN    BZN     1600860676.10732
# AZ       CPE    CPE     1600860677.78964
# ```
# In this table the net code is column 1, the seed station code is column2, and the sta code we can expect to find in arrival is column 3.  Column 4 is an internal time stamp used in Datascope that defines the epoch time of that tuple was last updated.  The key tuple to note is the 4th one in this list.  Note net AE and sta X16A are aliased to X16AAE.   The next step will exploit this to fix part of our ambiguity issue.

# %%
from mspasspy.preprocessing.css30.dbarrival import (parse_snetsta,set_netcode_snetsta)
staxref=parse_snetsta('data/raw_data_tutorial/snetsta/usarray.snetsta')
print('Example station cross reference created from snetsta for sta=120A:',staxref['120A'])
print('Using staxref to set net codes in arrival collection')
rettuple=set_netcode_snetsta(db,staxref)
print('Number of arrival documents scanned=',rettuple[0])
print('Number of arrival documents updated=',rettuple[1])
# Out:
# Example station cross reference created from snetsta for sta=120A: {'fsta': '120A', 'net': 'TA'}
# Using staxref to set net codes in arrival collection
# 353482
# Number of arrival documents scanned= 353482
# Number of arrival documents updated= 98149

# %% [markdown]
# I intentionally didn't print all the components of the rettuple.   We will use the 3rd component of that tuple in the next step.  First, let's see what it contains:

# %%
stations_not_found=rettuple[2]
print('Number of stations with unset net code=',len(stations_not_found))
print(stations_not_found)
# Out:
# Number of stations with unset net code= 666
# {'R35A', 'F39A', 'O47A', '554A', 'D31A', 'I39A', 'I37A', 'F49A', 'K42A', 'TYNO', 'W39A', 'E47A', 'X52A', 'L40A', 'U41A', 'L38A', '152A', 'BASO', 'TASM', 'C37A', 'X49A', 'GLMI', 'L48A', 'EPYK', '541A', 'I43A', 'G42A', 'Y46A', 'LATQ', 'Y51A', 'I35A', 'H55A', '153A', 'TFRD', 'W42A', 'V35A', 'F32A', 'K43A', 'Z43A', 'U44A', 'H31A', '450A', '149A', 'U45A', 'J01E', 'D04E', '252A', 'J54A', 'X50A', 'CCM', '344A', 'P45A', '555A', 'H39A', 'S45A', 'ERPA', 'NHSC', '452A', 'O41A', 'U47A', '443A', '136A', 'ACSO', 'P38A', 'E38A', 'M47A', '061Z', '342A', 'LSQQ', 'F38A', 'C40A', 'E52A', 'S41A', 'SNCC', 'P52A', 'F52A', 'Y42A', 'M33A', 'T41A', 'G45A', 'I42A', 'R51A', 'M41A', 'B34A', 'O53A', 'J36A', 'BW06', 'O54A', 'S35A', '453A', 'H47A', 'E33A', 'H41A', 'S38A', 'N48A', 'K49A', 'L41A', 'Z45A', 'Q42A', 'L50A', 'H38A', 'Y50A', 'K55A', 'Y35A', 'C06D', 'L42A', 'W50A', 'L33A', 'O37A', '240A', 'U36A', 'Z50A', 'Y54A', 'D41A', 'N49A', 'N44A', 'P47A', '242A', 'N40A', '140A', 'TORO', 'R49A', 'F34A', 'W35A', 'F37A', 'V36A', 'P37A', 'H35A', '348A', 'S47A', 'W36A', 'O44A', '250A', 'A31A', 'H42A', '243A', 'C39A', 'I49A', 'I45A', 'S39A', 'X36A', 'L49A', 'F51A', 'DELO', '141A', 'E32A', 'KLBO', 'G43A', '255A', 'WLVO', '553A', 'T52A', 'R52A', 'Z37A', 'D48A', 'L46A', 'K39A', '352A', 'E46A', 'I47A', 'IKP', 'F31A', 'U51A', 'I31A', 'M54A', 'AAM', 'E50A', 'I48A', 'J46A', 'I32A', 'W51A', 'D33A', 'W53A', 'BANO', 'B35A', '137A', 'J40A', 'V50A', 'R43A', 'R58B', 'U40A', 'E45A', 'O35A', 'J41A', 'Y36A', 'V51A', 'L04D', 'J42A', 'T46A', 'E54A', 'TCOL', 'S42A', 'K52A', 'PLIO', 'X53A', 'BWLO', 'G32A', 'DRWO', 'D51A', 'Q49A', '
', '256A', 'O48A', '059A', '645A', 'O40A', 'X48A', 'W49A', 'F40A', 'M37A', 'H04D', '435B', 'D54A', 'Z47A', 'Q43A', 'I41A', 'K48A', 'U43A', 'M40A', 'V45A', 'X40A', '060Z', '146A', '241A', 'X43A', '957A', 'Z52A', 'E36A', 'N35A', '449A', 'J37A', 'H37A', 'BMRO', '454A', '058A', 'S40A', 'J01D', 'G41A', 'PKRO', 'N47A', 'Z4 ...

# %% [markdown]
# Which shows snetsta solved only part of our problem.   We have a devil of problem to fix here with 666 stations having no entry in the snetsta table we used. (Bad joke, but couldn't resist.)
#
# The first fix we will apply makes a simple assumption that is reasonable here and probably usually would be for other data sets assembled by a similar mechanism (i.e. web service download of waveforms from IRIS and the FDSN).  We assume that the station data we wrote in the site collection from the download procedure is close to definitive but not completely.  The exact assumption is that if there is a unique match for a station code in site set the net code for an arrival to that value.  If it is not found put it in one list to be returned.  If it is ambiguous, meaning there are multiple net codes for the same sta name, return it in a different list. The next code block applies that algorithm:

# %%
from mspasspy.preprocessing.css30.dbarrival import set_netcode_from_site
rt_setsite=set_netcode_from_site(db)
nprocessed=rt_setsite[0]
nupdated=rt_setsite[1]
ambiguous=rt_setsite[2]
sta_not_found=rt_setsite[3]
print('set_netcode_from_site processed ',nprocessed,' documents in arrival collection')
print('number of documents with net code update=',nupdated)
# Out:
# set_netcode_from_site processed  353482  documents in arrival collection
# number of documents with net code update= 1388

# %% [markdown]
# You will likely find that that function takes a while to run because it is doing a lot of updates in a modest sized collection.   Let's print the two larger containers returned in the rt_setsite tuple in a pretty form:

# %%
from obspy import UTCDateTime
print('ambiguous site entries matched against arrival')
# first sort by sta - put tuples in a list container first to allow sorting
amblist=list()
for t in ambiguous:
    amblist.append(t)
amblist.sort(key = lambda x: x[1])
for t in amblist:
    print(t[0],t[1],UTCDateTime(t[2]),' to ',UTCDateTime(t[3]))
print('These sta codes had entries in arrival but were not found in site')
for nullsta in sta_not_found:
    print(nullsta)
# Out:
# ambiguous site entries matched against arrival
# TA J31A 2010-07-31T00:00:00.000000Z  to  2012-05-18T23:59:59.000000Z
# 7D J31A 2011-11-21T00:00:00.000000Z  to  2012-05-16T23:59:59.000000Z
# TA J33A 2010-07-27T00:00:00.000000Z  to  2012-05-17T23:59:59.000000Z
# 7D J33A 2011-10-16T00:00:00.000000Z  to  2012-07-19T23:59:59.000000Z
# TA J35A 2010-07-29T00:00:00.000000Z  to  2012-05-16T23:59:59.000000Z
# 7D J35A 2011-10-19T00:00:00.000000Z  to  2012-07-18T23:59:59.000000Z
# 7D J36A 2011-10-19T00:00:00.000000Z  to  2012-07-18T23:59:59.000000Z
# TA J36A 2010-10-07T00:00:00.000000Z  to  2012-09-16T23:59:59.000000Z
# 7D J37A 2011-11-28T00:00:00.000000Z  to  2012-05-16T23:59:59.000000Z
# TA J37A 2010-10-06T00:00:00.000000Z  to  2012-09-10T23:59:59.000000Z
# TA J38A 2010-10-11T00:00:00.000000Z  to  2012-09-14T23:59:59.000000Z
# 7D J38A 2011-11-23T00:00:00.000000Z  to  2012-05-17T23:59:59.000000Z
# 7D J39A 2011-11-22T00:00:00.000000Z  to  2012-05-17T23:59:59.000000Z
# TA J39A 2011-06-12T00:00:00.000000Z  to  2013-06-03T23:59:59.000000Z
# TA J43A 2011-10-12T00:00:00.000000Z  to  2013-06-11T23:59:59.000000Z
# 7D J43A 2011-10-19T00:00:00.000000Z  to  2012-07-17T23:59:59.000000Z
# 7D J45A 2011-11-28T00:00:00.000000Z  to  2012-05-18T23:59:59.000000Z
# TA J45A 2012-09-13T00:00:00.000000Z  to  2014-07-14T23:59:59.000000Z
# 7D J46A 2011-11-23T00:00:00.000000Z  to  2012-05-18T23:59:59.000000Z
# TA J46A 2012-09-11T00:00:00.000000Z  to  2014-06-13T23:59:59.000000Z
# TA J47A 2012-09-14T00:00:00.000000Z  to  2014-06-23T23:59:59.000000Z
# 7D J47A 2011-11-23T00:00:00.000000Z  to  2012-05-17T23:59:59.000000Z
# 7D J48A 2011-11-23T00:00:00.000000Z  to  2012-05-17T23:59:59.000000Z
# TA J48A 2012-10-13T00:00:00.000000Z  to  2014-06-28T23:59:59.000000Z
# TA J52A 2012-12-01T00:00:00.000000Z  to  2014-07-30T23:59:59.000000Z
# 7D J52A 2011-11-28T00:00:00.000000Z  to  2012-05-18T23:59:59.000000Z
# 7D J54A 2011-11-27T00:00:00.000000Z  to  2012-05-18T23:59:59.000000Z
# TA J54A 2012-12-11T00:00:00.000000Z  to  2014-10-17T23:59:59.000000Z
# TA J55A 2012-12-12T00:00:00.000000Z  to  2014-10-10T23:59:59.000000Z
# 7D J55A 2011-11-24T00:00:00.000000Z  to  2012-05-19T23:59:59.000000Z
# US SCIA 2006-06-01T00:00:00.000000Z  to  2051-01-01T00:00:00.000000Z
# US TPNV 1992-06-15T00:00:00.000000Z  to  2051-01-01T00:00:00.000000Z
# TA X37A 2010-04-21T00:00:00.000000Z  to  2012-02-27T23:59:59.000000Z
# OK X37A 2012-02-24T00:00:00.000000Z  to  2051-01-01T00:00:00.000000Z
# These sta codes had entries in arrival but were not found in site
# CHGQ
# ACTO
# DRWO
# DELO
# ORIO
# BMRO
# TCOL
# TORO
# BRCO
# BELQ
# MATQ
# ALFO
# ALGO
# PLIO
# ELFO
# Y22E
# EPYK
# PLVO
# BANO
# BASO
# TOBO
# PEMO
# HDA
# BUKO
# CLWO
# WLVO
# PKRO
# LSQQ
# KLBO
# MEDO
# STCO
# DRCO
# BWLO
# TYNO
# TOLK
# POKR
# LATQ
# ORHO

# %% [markdown]
# So, we clearly need to do some detective work to sort this out.   There are multiple issues we need to fix, and that, unfortunately, is part of the tedious work of assembling any data set.  We will attack these in pieces with two helpful functions we can use to query the site and channel collections.
#
# Let's first look at the entries for the US network code.   You might guess that they share a common problem and indeed they do as shown by the output of this small block of code:

# %%
from mspasspy.preprocessing.seed.util import (site_report, channel_report)
usnetlist=['AAM', 'ACSO','CBKS','ERPA','GLMI','JFWS','MCWV','NHSC']
for sta in usnetlist:
    print('site entries for station=',sta)
    site_report(db,sta=sta,net='US')
    print('channel entries for station=',sta)
    channel_report(db,sta=sta,net='US')
# Out:
# site entries for station= AAM
#  net      sta =loc== latitude longitude starttime endtime
#   US      AAM ==00== 42.3012 -83.6567 0.172 1994-06-20T00:00:00.000000Z 2051-01-01T00:00:00.000000Z
#   
00.000000Z 2051-01-01T00:00:00.000000Z
#   US     JFWS    BHE ====== 42.9142 -90.2481 0.335 2006-07-22T17:00:00.000000Z 2011-05-02T21:49:00.000000Z
#   US     JFWS    BHN ====== 42.9142 -90.2481 0.335 2006-07-22T17:00:00.000000Z 2011-05-02T21:49:00.000000Z
#   US     JFWS    BHZ ====== 42.9142 -90.2481 0.335 2006-07-22T17:00:00.000000Z 2011-05-02T21:49:00.000000Z
# site entries for station= MCWV
#  net      sta =loc== latitude longitude starttime endtime
#   US     MCWV ==00== 39.6581 -79.8456 0.28 1991-03-28T00:00:00.000000Z 2051-01-01T00:00:00.000000Z
#   US     MCWV ====== 39.6581 -79.8456 0.28 1991-03-28T00:00:00.000000Z 2051-01-01T00:00:00.000000Z
# channel entries for station= MCWV
#  net      sta   chan =loc== latitude longitude starttime endtime
#   US     MCWV    BH1 ==00== 39.6581 -79.8456 0.28 2011-11-30T17:00:00.000000Z 2051-01-01T00:00:00.000000Z
#   US     MCWV    BH2 ==00== 39.6581 -79.8456 0.28 2011-11-30T17:00:00.000000Z 2051-01-01T00:00:00.000000Z
#   US     MCWV    BHZ ==00== 39.6581 -79.8456 0.28 2011-11-30T17:00:00.000000Z 2051-01-01T00:00:00.000000Z
#   US     MCWV    BHE ====== 39.6581 -79.8456 0.28 2010-07-20T21:30:00.000000Z 2011-05-02T22:15:00.000000Z
#   US     MCWV    BHN ====== 39.6581 -79.8456 0.28 2010-07-20T21:30:00.000000Z 2011-05-02T22:15:00.000000Z
#   US     MCWV    BHZ ====== 39.6581 -79.8456 0.28 2010-07-20T21:30:00.000000Z 2011-05-02T22:15:00.000000Z
# site entries for station= NHSC
#  net      sta =loc== latitude longitude starttime endtime
#   US     NHSC ==00== 33.1067 -80.1778 0.011 2001-05-01T00:00:00.000000Z 2051-01-01T00:00:00.000000Z
#   US     NHSC ====== 33.1067 -80.1778 0.011 2001-05-01T00:00:00.000000Z 2051-01-01T00:00:00.000000Z
# channel entries for station= NHSC
#  net      sta   chan =loc== latitude longitude starttime endtime
#   US     NHSC    BH1 ==00== 33.1067 -80.1778 0.011 2011-05-02T22:35:10.000000Z 2018-10-28T15:30:00.000000Z
#   US     NHSC    BH2 ==00== 33.1067 -80.1778 0.011 2011-05-02T22:35:10.000000Z 2018-10-28T15:30:00.000000Z
#   US     NHSC    BHZ ==00== 33.1067 -80.1778 0.011 2011-05-02T22:35:10.000000Z 2018-10-28T15:30:00.000000Z
#   US     NHSC    BHE ====== 33.1067 -80.1778 0.011 2010-04-29T19:00:00.000000Z 2011-05-02T22:35:10.000000Z
#   US     NHSC    BHN ====== 33.1067 -80.1778 0.011 2010-04-29T19:00:00.000000Z 2011-05-02T22:35:10.000000Z
#   US     NHSC    BHZ ====== 33.1067 -80.1778 0.011 2010-04-29T19:00:00.000000Z 2011-05-02T22:35:10.000000Z

# %% [markdown]
# This shows all of these are ambiguous only in the sense that there are two loc codes for the same site.  However, the report shows that, as they should, both documents for the same site but different loc codes have a exactly the same location.
#
# Let's now look at IU CCM (Cathedral caves for the Iris University network code)

# %%
print('site data for IU CCM')
site_report(db,net='IU',sta='CCM')
print('channel data for IU CCM')
channel_report(db,net='IU',sta='CCM')
# Out:
# site data for IU CCM
#  net      sta =loc== latitude longitude starttime endtime
#   IU      CCM ==00== 38.0557 -91.2446 0.1715 2011-07-14T00:00:00.000000Z 2051-01-01T00:00:00.000000Z
#   IU      CCM ==00== 38.0557 -91.2446 0.1715 1996-06-07T21:00:00.000000Z 2011-07-14T00:00:00.000000Z
# channel data for IU CCM
#  net      sta   chan =loc== latitude longitude starttime endtime
#   IU      CCM    BH1 ==00== 38.0557 -91.2446 0.1715 2011-07-14T00:00:00.000000Z 2012-06-14T23:27:00.000000Z
#   IU      CCM    BH2 ==00== 38.0557 -91.2446 0.1715 2011-07-14T00:00:00.000000Z 2012-06-14T23:27:00.000000Z
#   IU      CCM    BHZ ==00== 38.0557 -91.2446 0.1715 2011-07-14T00:00:00.000000Z 2012-06-14T23:27:00.000000Z
#   IU      CCM    BHE ==00== 38.0557 -91.2446 0.1715 1999-06-03T19:50:00.000000Z 2011-07-14T00:00:00.000000Z
#   IU      CCM    BHN ==00== 38.0557 -91.2446 0.1715 1999-06-03T19:50:00.000000Z 2011-07-14T00:00:00.000000Z
#   IU      CCM    BHZ ==00== 38.0557 -91.2446 0.1715 1999-06-03T19:50:00.000000Z 2011-07-14T00:00:00.000000Z

# %% [markdown]
# This shows CCM had an instrumentation change July 14, 2011.   The location was unchanged but the channels were renamed.  For this tutorial this particular change is irrelevant as the data being handled here are only from 2012.
#
# The next issue is the long list of stations with a common sta name but two different net codes:  TA and TD.   We need only look closely at one of these to understand what the problem is here.

# %%
print('site data for J31A')
site_report(db,sta='J31A')
print('channel data for J31A')
channel_report(db,sta='J31A')
# Out:
# site data for J31A
#  net      sta =loc== latitude longitude starttime endtime
#   7D     J31A ====== 45.553101 -129.672699 -2.657 2011-11-21T00:00:00.000000Z 2012-05-16T23:59:59.000000Z
#   TA     J31A ====== 43.2915 -98.739601 0.491 2010-07-31T00:00:00.000000Z 2012-05-18T23:59:59.000000Z
# channel data for J31A
#  net      sta   chan =loc== latitude longitude starttime endtime
#   7D     J31A    BH1 ====== 45.553101 -129.672699 -2.657 2011-11-21T00:00:00.000000Z 2012-05-16T23:59:59.000000Z
#   7D     J31A    BH2 ====== 45.553101 -129.672699 -2.657 2011-11-21T00:00:00.000000Z 2012-05-16T23:59:59.000000Z
#   7D     J31A    BHZ ====== 45.553101 -129.672699 -2.657 2011-11-21T00:00:00.000000Z 2012-05-16T23:59:59.000000Z
#   TA     J31A    BHE ====== 43.2915 -98.739601 0.491 2010-07-31T00:00:00.000000Z 2012-02-06T17:15:00.000000Z
#   TA     J31A    BHN ====== 43.2915 -98.739601 0.491 2010-07-31T00:00:00.000000Z 2012-02-06T17:15:00.000000Z
#   TA     J31A    BHZ ====== 43.2915 -98.739601 0.491 2010-07-31T00:00:00.000000Z 2012-02-06T17:15:00.000000Z

# %% [markdown]
# If you go to IRIS's Metadata aggregator page for query by network, <http://ds.iris.edu/SeismiQuery/by_network.html>, you will learn that 7D is a set of OBS instruments deployed in Cascadia in 2012.  The TA code is for the USArray Transportable Array.  The ANF received TA data in real time and the focus of their efforts was the data received in real time.  To the best of my knowledge they did not go back and pick the OBS data that was not accessible until well after 2012 - the year of all arrival picks we are trying to sort out here.  Hence, the assumption we make is that all of those picks can safely assign TA as the net code.   The only exception is X37A, but the timestamps suggest this is an example of a TA station adopted by the OK network.  Let's check the coordinates to verify that is true before proceeding:

# %%
print('site data for X37A')
site_report(db,sta='X37A')
print('channel data for X37A')
channel_report(db,sta='X37A')
# Out:
# site data for X37A
#  net      sta =loc== latitude longitude starttime endtime
#   OK     X37A ====== 34.5892 -95.3713 0.207 2012-02-24T00:00:00.000000Z 2051-01-01T00:00:00.000000Z
#   TA     X37A ====== 34.589199 -95.3713 0.207 2010-04-21T00:00:00.000000Z 2012-02-27T23:59:59.000000Z
# channel data for X37A
#  net      sta   chan =loc== latitude longitude starttime endtime
#   OK     X37A    BHE ====== 34.5892 -95.3713 0.207 2012-02-24T00:00:00.000000Z 2051-01-01T00:00:00.000000Z
#   OK     X37A    BHN ====== 34.5892 -95.3713 0.207 2012-02-24T00:00:00.000000Z 2051-01-01T00:00:00.000000Z
#   OK     X37A    BHZ ====== 34.5892 -95.3713 0.207 2012-02-24T00:00:00.000000Z 2051-01-01T00:00:00.000000Z
#   TA     X37A    BHE ====== 34.589199 -95.3713 0.207 2010-04-21T00:00:00.000000Z 2012-02-27T20:10:00.000000Z
#   TA     X37A    BHN ====== 34.589199 -95.3713 0.207 2010-04-21T00:00:00.000000Z 2012-02-27T20:10:00.000000Z
#   TA     X37A    BHZ ====== 34.589199 -95.3713 0.207 2010-04-21T00:00:00.000000Z 2012-02-27T20:10:00.000000Z

# %% [markdown]
# Which confirms or hypothesis that X37A was adopted by OK on Feb 2, 2012.
#
# The last issue is a set of stations with the net code CI.  The network aggregator will show you that CI is the southern California seismic network and the CI is a mnemonic for Caltech who have been the operator of that network since it was defined with that code.  Let's run as script similar to that we used for the US net code:

# %%
cinetlist=['IKP','SNCC']
for sta in cinetlist:
    print('site entries for station=',sta)
    site_report(db,sta=sta,net='CI')
    print('channel entries for station=',sta)
    channel_report(db,sta=sta,net='CI')
# Out:
# site entries for station= IKP
#  net      sta =loc== latitude longitude starttime endtime
#   CI      IKP ====== 32.65012 -116.10948 0.906 1972-03-29T00:00:00.000000Z 3000-01-01T00:00:00.000000Z
#   CI      IKP ====== 32.65012 -116.109482 0.906 1972-03-29T00:00:00.000000Z 2051-01-01T00:00:00.000000Z
# channel entries for station= IKP
#  net      sta   chan =loc== latitude longitude starttime endtime
#   CI      IKP    BHE ====== 32.65012 -116.10948 0.906 2011-04-05T20:00:00.000000Z 3000-01-01T00:00:00.000000Z
#   CI      IKP    BHN ====== 32.65012 -116.10948 0.906 2011-04-05T20:00:00.000000Z 3000-01-01T00:00:00.000000Z
#   CI      IKP    BHZ ====== 32.65012 -116.10948 0.906 2011-04-05T20:00:00.000000Z 3000-01-01T00:00:00.000000Z
#   CI      IKP    BHE ====== 32.65012 -116.109482 0.906 2011-04-05T20:00:00.000000Z 2051-01-01T00:00:00.000000Z
#   CI      IKP    BHN ====== 32.65012 -116.109482 0.906 2011-04-05T20:00:00.000000Z 2051-01-01T00:00:00.000000Z
#   CI      IKP    BHZ ====== 32.65012 -116.109482 0.906 2011-04-05T20:00:00.000000Z 2051-01-01T00:00:00.000000Z
# site entries for station= SNCC
#  net      sta =loc== latitude longitude starttime endtime
#   CI     SNCC ====== 33.24787 -119.52437 0.275 1994-05-03T00:00:00.000000Z 3000-01-01T00:00:00.000000Z
#   CI     SNCC ====== 33.247871 -119.524368 0.275 1994-05-03T00:00:00.000000Z 2051-01-01T00:00:00.000000Z
# channel entries for station= SNCC
#  net      sta   chan =loc== latitude longitude starttime endtime
#   CI     SNCC    BHE ====== 33.24787 -119.52437 0.275 2010-04-26T00:00:00.000000Z 2012-07-31T18:00:00.000000Z
#   CI     SNCC    BHN ====== 33.24787 -119.52437 0.275 2010-04-26T00:00:00.000000Z 2012-07-31T18:00:00.000000Z
#   CI     SNCC    BHZ ====== 33.24787 -119.52437 0.275 2010-04-26T00:00:00.000000Z 2012-07-31T18:00:00.000000Z

# %% [markdown]
# This is the messiest problem we need to fix.  It appears we have near but not exact duplicate records in both site and channel for both of the stations IKP and SNCC.   Not at all clear why this has happened, but if you go back and run the unix diff command on the xml files from 2011 you will see they are indeed different.  Why they are returned that way from web services is not at all clear, but a reasonable hypothesis is they came from different data centers that had slightly different entries for these stations.
#
# What makes this even more challenging is the two stations have different problem:  IKP needs edits to both site and channel while SNCC requires only edits to site.  In all cases a (nonunique) solution appears to be to use the endtime key to distinguish the keeper.   We judge the entries with endtime in 2051 to be better than the alternative because the coordinates appear to have been measured to higher precision.  First, let's fix IKP.
#
# You may want to run this twice.  The first time it will produce a lot of output because the channel documents are large due to storage of the response data.  Repeating the box will show 0 deletes which is what we want to confirm.

# %%
from obspy import UTCDateTime
dbsite=db.site
query=dict()
query['sta']='IKP'
query['net']='CI'
t_test=UTCDateTime('2060-01-01:00:00:00.0')
query['endtime']={'$gt':t_test.timestamp}
n=dbsite.count_documents(query)
print('IKP with this query yields ',n,' documents')
if n==1:
    doc=dbsite.find_one(query)
    print('Deleting this entry in site:')
    print(doc)
    dbsite.delete_one(query)
# same for channel use delete_many
dbchan=db.channel
n=dbchan.count_documents(query)
print('IKP number of channel documents to be deleted=',n)
print('channel documents that will be deleted')
curs=dbchan.find(query)
for doc in curs:
    print(doc)
dbchan.delete_many(query)
# Out:
# IKP with this query yields  0  documents
# IKP number of channel documents to be deleted= 0
# channel documents that will be deleted

# %% [markdown]
# Now the same for SNCC but we only need to handle site.

# %%
query=dict()
query['sta']='SNCC'
query['net']='CI'
t_test=UTCDateTime('2060-01-01:00:00:00.0')
query['endtime']={'$gt':t_test.timestamp}
n=dbsite.count_documents(query)
print('SNCC with this query yields ',n,' documents')
if n==1:
    doc=dbsite.find_one(query)
    print('Deleting this entry in site:')
    print(doc)
    dbsite.delete_one(query)
# Out:
# SNCC with this query yields  1  documents
# Deleting this entry in site:
# {'_id': ObjectId('600c122eaeca3fad23077ecc'), 'loc': '', 'net': 'CI', 'sta': 'SNCC', 'latitude': 33.24787, 'longitude': -119.52437, 'coords': [33.24787, -119.52437], 'elevation': 0.275, 'edepth': 0.0, 'starttime': 767923200.0, 'endtime': 32503680000.0, 'site_id': ObjectId('600c122eaeca3fad23077ecc')}

# %% [markdown]
# Now we are left with the problem of setting net and loc codes for the stations marked ambiguous earlier.  Since we fixed the duplicate problem with IKP and SNCC the residual problems we need to fix are:
# 1.  The list of stations with net code US need to have the net code set to US and loc set to 00
# 2.  CCM arrival picks need the net code set to IU and the loc code set to 00
# 3.  All remaining arrivals with net null should have it set to TA
#
# First let's handle US data station.  There all we do is find all entries matching our US net station list and force the loc code to 00.   We do that because I think 00 are borehole instruments that should be quieter, but that is not necessarily the right choice.  If it really mattered one might want to dig.

# %%
dbarr=db.arrival
for sta in usnetlist:
    query=dict()
    query['sta']=sta
    newval={"$set" : {'loc':'00', 'net':'US'}}
    x = dbarr.update_many(query,newval)
    print(x.modified_count, "arrival documents updated for station=",sta)
# Out:
# 501 arrival documents updated for station= AAM
# 583 arrival documents updated for station= ACSO
# 670 arrival documents updated for station= CBKS
# 553 arrival documents updated for station= ERPA
# 395 arrival documents updated for station= GLMI
# 666 arrival documents updated for station= JFWS
# 518 arrival documents updated for station= MCWV
# 372 arrival documents updated for station= NHSC

# %% [markdown]
# Now a simpler step for CCM because we don't need a loop.

# %%
query['sta']='CCM'
newval={"$set" : {'loc':'00', 'net':'IU'}}
x = dbarr.update_many(query,newval)
print(x.modified_count, "arrival documents updated for station=CCM")
# Out:
# 670 arrival documents updated for station=CCM

# %% [markdown]
# Now we can run this script that sets all remaining null net codes to TA. This works only because we fixed the earlier ones.

# %%
from mspasspy.preprocessing.css30.dbarrival import set_netcode_time_interval
# First we have to run this function again to refresh the list of ambiguous stations
rt_setsite=set_netcode_from_site(db)
# Now we only need this one
ambiguous=rt_setsite[2]
# and in a later box this one
sta_not_found=rt_setsite[3]
# first use a set container to find all unique names
sta_to_force=set()
for t in ambiguous:
    sta_to_force.add(t[1])
for sta in sta_to_force:
    n=set_netcode_time_interval(db,sta,net='TA')
    print('set net code to TA for ',n,' arrival documents with picks for station=',sta)
# Out:
# set net code to TA for  518  arrival documents with picks for station= J36A
# set net code to TA for  87  arrival documents with picks for station= X37A
# set net code to TA for  133  arrival documents with picks for station= J46A
# set net code to TA for  161  arrival documents with picks for station= J35A
# set net code to TA for  1069  arrival documents with picks for station= TPNV
# set net code to TA for  190  arrival documents with picks for station= J31A
# set net code to TA for  45  arrival documents with picks for station= J52A
# set net code to TA for  4  arrival documents with picks for station= J55A
# set net code to TA for  560  arrival documents with picks for station= SCIA
# set net code to TA for  149  arrival documents with picks for station= J48A
# set net code to TA for  178  arrival documents with picks for station= J47A
# set net code to TA for  761  arrival documents with picks for station= J39A
# set net code to TA for  512  arrival documents with picks for station= J37A
# set net code to TA for  7  arrival documents with picks for station= J54A
# set net code to TA for  87  arrival documents with picks for station= J45A
# set net code to TA for  481  arrival documents with picks for station= J38A
# set net code to TA for  645  arrival documents with picks for station= J43A
# set net code to TA for  209  arrival documents with picks for station= J33A

# %% [markdown]
# Finally, we have to deal with the orphans, which are the stations held in the set container with the name sta_not_found.  We will do that with this little

# %%
from obspy.clients.fdsn import Client
webclient=Client('IRIS')
starttime=UTCDateTime("2004-01-01T00:00:00.000")
endtime=UTCDateTime("2016-12-31T00:00:00.000")
write_dir="data/raw_data_tutorial/orphanxml"
for sta in sta_not_found:
    print('Attempting to download xml data for station=',sta)
    try:
        inv=webclient.get_stations(network="*",station=sta,location="*",
                            channel="BH*",
                            starttime=starttime,endtime=endtime,
                            level="response")
    except:
        print("No B channel data for station=",sta," for any net code")
        print("Ignoring this station")
        continue
    print('downloaded as this inventory object by obspy:')
    print(inv)
    fname=write_dir+'/'+sta+'.xml'
    print('writing as xml data to file=',fname)
    inv.write(fname,format='STATIONXML')
    print('saving to MongoDB site and channel collections')
    db.save_inventory(inv,verbose=True)
# Out:
# Attempting to download xml data for station= CHGQ
# No B channel data for station= CHGQ  for any net code
# Ignoring this station
# Attempting to download xml data for station= ACTO
# No B channel data for station= ACTO  for any net code
# Ignoring this station
# Attempting to download xml data for station= DRWO
# No B channel data for station= DRWO  for any net code
# Ignoring this station
# Attempting to download xml data for station= DELO
# No B channel data for station= DELO  for any net code
# Ignoring this station
# Attempting to download xml data for station= ORIO
# No B channel data for station= ORIO  for any net code
# Ignoring this station
# Attempting to download xml data for station= BMRO
# No B channel data for station= BMRO  for any net code
# Ignoring this station
# Attempting to download xml data for station= TCOL
# downloaded as this inventory object by obspy:
# Inventory created at 2021-01-23T21:35:06.000000Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.47
# 		    http://service.iris.edu/fdsnws/station/1/query?starttime=2004-01-01...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (1):
# 			TA
# 		Stations (1):
# 			TA.TCOL (CIGO, UAF Yankovich Road, Fairbanks, AK, USA)
# 		Channels (21):
# 			TA.TCOL..BHZ (4x), TA.TCOL..BHN (4x), TA.TCOL..BHE (4x),
# 			TA.TCOL.01.BHZ (3x), TA.TCOL.01.BHN (3x), TA.TCOL.01.BHE (3x)
# writing as xml data to file= data/raw_data_tutorial/orphanxml/TCOL.xml
# saving to MongoDB site and channel collections
# net:sta:loc= TA : TCOL :  for time span  2012-10-08T00:00:00.000000Z  to  2019-10-01T23:59:59.000000Z  added to site collection
# net:sta:loc:chan= TA : TCOL :  : BHE for time span  2012-10-08T00:00:00.000000Z  to  2012-10-28T02:48:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : TCOL :  : BHE for time span  2012-10-28T02:49:00.000000Z  to  2012-11-01T22:14:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : TCOL :  : BHE for time span  2012-11-01T22:15:00.000000Z  to  2013-06-14T00:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : TCOL :  : BHE for time span  2013-06-14T01:00:00.000000Z  to  2017-09-14T01:29:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : TCOL :  : BHN for time span  2012-10-08T00:00:00.000000Z  to  2012-10-28T02:48:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : TCOL :  : BHN for time span  2012-10-28T02:49:00.000000Z  to  2012-11-01T22:14:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : TCOL :  : BHN for time span  2012-11-01T22:15:00.000000Z  to  2013-06-14T00:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : TCOL :  : BHN for time span  2013-06-14T01:00:00.000000Z  to  2017-09-14T01:29:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : TCOL :  : BHZ for time span  2012-10-08T00:00:00.000000Z  to  2012-10-28T02:48:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : TCOL :  : BHZ for time span  2012-10-28T02:49:00.000000Z  to  2012-11-01T22:14:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : TCOL :  : BHZ for time span  2012-11-01T22:15:00.000000Z  to  2013-06-14T00:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : TCOL :  : BHZ for time span  2013-06-14T01:00:00.000000Z  to  2017-09-14T01:29:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : TCOL :  : BHE for time span  2012-10-08T00:00:00.000000Z  to  2012-10-28T02:48:59.000000Z  already in channel collection - ignored
# net:sta:loc:chan= TA : TCOL :  : BHE for time span  2012-10-28T02:49:00.000000Z  to  2012-11-01T22:14:59.000000Z  already in channel collection - ignored
# net:sta:loc:chan= TA : TCOL :  : BHE for time span  2012-11-01T22:15:00.000000Z  to  2013-06-14T00:59:59.000000Z  already in channel collection - ignored
# net:sta:loc:chan= TA : TCOL :  : BHN for time span  2012-10-08T00:00:00.000000Z  to  2012-10-28T02:48:59.000000Z  already in channel collection - ignored
# net:sta:loc:chan= TA : TCOL :  : BHN for time span  2012-10-28T02:49:00.000000Z  to  2012-11-01T22:14:59.000000Z  already in channel collection - ignored
# net:sta:loc:chan= TA : TCO
# 			NJ.TORO..BHZ, NJ.TORO..BHN, NJ.TORO..BHE
# writing as xml data to file= data/raw_data_tutorial/orphanxml/TORO.xml
# saving to MongoDB site and channel collections
# NJ : TORO :   (Warning):  station section position is not consistent with loc code position
# Data in loc code section overrides station section
# Station section coordinates:   10.055 9.12 0.882
# loc code section coordinates:   10.986 8.118 0.882
# net:sta:loc= NJ : TORO :  for time span  2009-01-01T00:00:00.000000Z  to  2051-01-01T00:00:00.000000Z  added to site collection
# net:sta:loc:chan= NJ : TORO :  : BHE for time span  2009-01-01T00:00:00.000000Z  to  2014-12-31T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= NJ : TORO :  : BHN for time span  2009-01-01T00:00:00.000000Z  to  2014-12-31T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= NJ : TORO :  : BHZ for time span  2009-01-01T00:00:00.000000Z  to  2014-12-31T23:59:59.000000Z  added to channel collection
# Database.save_inventory processing summary:
# Number of site records processed= 1
# number of site records saved= 1
# number of channel records processed= 3
# number of channel records saved= 3
# Attempting to download xml data for station= BRCO
# No B channel data for station= BRCO  for any net code
# Ignoring this station
# Attempting to download xml data for station= BELQ
# No B channel data for station= BELQ  for any net code
# Ignoring this station
# Attempting to download xml data for station= MATQ
# No B channel data for station= MATQ  for any net code
# Ignoring this station
# Attempting to download xml data for station= ALFO
# No B channel data for station= ALFO  for any net code
# Ignoring this station
# Attempting to download xml data for station= ALGO
# No B channel data for station= ALGO  for any net code
# Ignoring this station
# Attempting to download xml data for station= PLIO
# No B channel data for station= PLIO  for any net code
# Ignoring this station
# Attempting to download xml data for station= ELFO
# No B channel data for station= ELFO  for any net code
# Ignoring this station
# Attempting to download xml data for station= Y22E
# downloaded as this inventory object by obspy:
# Inventory created at 2021-01-23T21:35:14.000000Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.47
# 		    http://service.iris.edu/fdsnws/station/1/query?starttime=2004-01-01...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (1):
# 			TA
# 		Stations (1):
# 			TA.Y22E (IRIS PASSCAL Instrument Center, Socorro, NM, USA)
# 		Channels (12):
# 			TA.Y22E..BHZ (2x), TA.Y22E..BHN (2x), TA.Y22E..BHE (2x),
# 			TA.Y22E.01.BHZ (2x), TA.Y22E.01.BHN (2x), TA.Y22E.01.BHE (2x)
# writing as xml data to file= data/raw_data_tutorial/orphanxml/Y22E.xml
# saving to MongoDB site and channel collections
# net:sta:loc= TA : Y22E :  for time span  2011-03-28T00:00:00.000000Z  to  2012-08-06T23:59:59.000000Z  added to site collection
# net:sta:loc:chan= TA : Y22E :  : BHE for time span  2011-03-28T00:00:00.000000Z  to  2011-08-01T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : Y22E :  : BHE for time span  2011-11-03T00:00:00.000000Z  to  2012-08-06T21:15:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : Y22E :  : BHN for time span  2011-03-28T00:00:00.000000Z  to  2011-08-01T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : Y22E :  : BHN for time span  2011-11-03T00:00:00.000000Z  to  2012-08-06T21:15:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : Y22E :  : BHZ for time span  2011-03-28T00:00:00.000000Z  to  2011-08-01T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : Y22E :  : BHZ for time span  2011-11-03T00:00:00.000000Z  to  2012-08-06T21:15:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : Y22E :  : BHE for time span  2011-03-28T00:00:00.000000Z  to  2011-08-01T23:59:59.000000Z  already in channel collection - ignored
# net:sta:loc:chan= TA : Y22E :  : BHE for time span  2011-11-08T17:00:00.000000Z  to  2012-08-06T21:15:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : Y22E :  : BHN for time span  2011-03-28T00:00:00.000000Z  to  2011-08-01T23:59:59.000000Z  already in channel collection - ignored
# net:sta:loc:chan= TA : Y22E :  : BHN for time span  2011-11-08T17:00:00.000000Z  to  2012-08-06T21:15:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : Y22E :  : BHZ for time span  2011-03-28T00:00:00.000000Z  to  2011-08-01T23:59:59.000000Z  already in channel collection - ignored
# net:sta:loc:chan= TA : Y22E :  : BHZ for time span  2011-11-08T17:00:00.000000Z  to  2012-08-06T21:15:00.000000Z  added to channel collection
# net:sta:loc= TA : Y22E : 01 for time span  2011-03-28T00:00:00.000000Z  to  2012-08-06T23:59:59.000000Z  added to site collection
# net:sta:loc:chan= TA : Y22E : 01 : BHE for time span  2011-03-28T00:00:00.000000Z  to  2011-08-01T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : Y22E : 01 : BHE for time span  2011-11-03T00:00:00.000000Z  to  2012-08-06T21:15:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : Y22E : 01 : BHN for time span  2011-03-28T00:00:00.000000Z  to  2011-08-01T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : Y22E : 01 : BHN for time span  2011-11-03T00:00:00.000000Z  to  2012-08-06T21:15:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : Y22E : 01 : BHZ for time span  2011-03-28T00:00:00.000000Z  to  2011-08-01T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : Y22E : 01 : BHZ for time span  2011-11-03T00:00:00.000000Z  to  2012-08-06T21:15:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : Y22E : 01 : BHE for time span  2011-03-28T00:00:00.000000Z  to  2011-08-01T23:59:59.000000Z  already in channel collection - ignored
# net:sta:loc:chan= TA : Y22E : 01 : BHE for time span  2011-11-08T17:00:00.000000Z  to  2012-08-06T21:15:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : Y22E : 01 : BHN for time span  2011-03-28T00:00:00.000000Z  to  2011-08-01T23:59:59.000000Z  already in channel collection - ignored
# net:sta:loc:chan= TA : Y22E : 01 : BHN for time span  2011-11-08T17:00:00.000000Z  to  2012-08-06T21:15:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : Y22E : 01 : BHZ for time span  2011-03-28T00:00:00.000000Z  to  2011-08-01T23:59:59.000000Z  already in channel collection - ignored
# net:sta:loc:chan= TA : Y22E : 01 : BHZ for time span  2011-11-08T17:00:00.000000Z  to  2012-08-06T21:15:00.000000Z  added to channel collection
# Database.save_inventory processing summary:
# Number of site records processed= 2
# number of site records saved= 2
# number of channel records processed= 24
# number of channel records saved= 18
# Attempting to download xml data for station= EPYK
# downloaded as this inventory object by obspy:
# Inventory created at 2021-01-23T21:35:14.000000Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.47
# 		    http://service.iris.edu/fdsnws/station/1/query?starttime=2004-01-01...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (1):
# 			TA
# 		Stations (1):
# 			TA.EPYK (Eagle Plains, Yukon Territory, CAN)
# 		Channels (6):
# 			TA.EPYK..BHZ, TA.EPYK..BHN, TA.EPYK..BHE, TA.EPYK.01.BHZ,
# 			TA.EPYK.01.BHN, TA.EPYK.01.BHE
# writing as xml data to file= data/raw_data_tutorial/orphanxml/EPYK.xml
# saving to MongoDB site and channel collections
# net:sta:loc= TA : EPYK :  for time span  2012-10-10T00:00:00.000000Z  to  2051-01-01T00:00:00.000000Z  added to site collection
# net:sta:loc:chan= TA : EPYK :  : BHE for time span  2012-10-10T00:00:00.000000Z  to  2051-01-01T00:00:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : EPYK :  : BHN for time span  2012-10-10T00:00:00.000000Z  to  2051-01-01T00:00:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : EPYK :  : BHZ for time span  2012-10-10T00:00:00.000000Z  to  2051-01-01T00:00:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : EPYK :  : BHE for time span  2016-08-23T00:00:00.000000Z  to  2051-01-01T00:00:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : EPYK :  : BHN for time span  2016-08-23T00:00:00.000000Z  to  2051-01-01T00:00:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : EPYK :  : BHZ for time span  2016-08-23T00:00:00.000000Z  to  2051-01-01T00:00:00.000000Z  added to channel collection
# net:sta:loc= TA : EPYK : 01 for time span  2012-10-10T00:00:00.000000Z  to  2051-01-01T00:00:00.000000Z  added to site collection
# net:sta:loc:chan= TA : EPYK : 01 : BHE for time span  2012-10-10T00:00:00.000000Z  to  2051-01-01T00:00:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : EPYK : 01 : BHN for time span  2012-10-10T00:00:00.000000Z  to  2051-01-01T00:00:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : EPYK : 01 : BHZ for time span  2012-10-10T00:00:00.000000Z  to  2051-01-01T00:00:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : EPYK : 01 : BHE for time span  2016-08-23T00:00:00.000000Z  to  2051-01-01T00:00:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : EPYK : 01 : BHN for time span  2016-08-23T00:00:00.000000Z  to  2051-01-01T00:00:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : EPYK : 01 : BHZ for time span  2016-08-23T00:00:00.000000Z  to  2051-01-01T00:00:00.000000Z  added to channel collection
# Database.save_inventory processing summary:
# Number of site records processed= 2
# number of site records saved= 2
# number of channel records processed= 12
# number of channel records saved= 12
# Attempting to download xml data for station= PLVO
# No B channel data for station= PLVO  for any net code
# Ignoring this station
# Attempting to download xml data for station= BANO
# downloaded as this inventory object by obspy:
# Inventory created at 2021-01-23T21:35:14.000000Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.47
# 		    http://service.iris.edu/fdsnws/station/1/query?starttime=2004-01-01...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (1):
# 			YR
# 		Stations (1):
# 			YR.BANO (WADI DARABAN)
# 		Channels (6):
# 			YR.BANO..BHZ (2x), YR.BANO..BHN (2x), YR.BANO..BHE (2x)
# writing as xml data to file= data/raw_data_tutorial/orphanxml/BANO.xml
# saving to MongoDB site and channel collections
# net:sta:loc= YR : BANO :  for time span  2005-09-26T12:00:00.000000Z  to  2006-08-28T12:00:00.000000Z  added to site collection
# net:sta:loc:chan= YR : BANO :  : BHE for time span  2005-09-26T12:00:00.000000Z  to  2006-02-23T10:02:40.000000Z  added to channel collection
# net:sta:loc:chan= YR : BANO :  : BHE for time span  2006-02-23T10:02:40.000000Z  to  2006-08-28T12:00:00.000000Z  added to channel collection
# net:sta:loc:chan= YR : BANO :  : BHN for time span  2005-09-26T12:00:00.000000Z  to  2006-02-23T10:02:40.000000Z  added to channel collection
# net:sta:loc:chan= YR : BANO :  : BHN for time span  2006-02-23T10:02:40.000000Z  to  2006-08-28T12:00:00.000000Z  added to channel collection
# net:sta:loc:chan= YR : BANO :  : BHZ for time span  2005-09-26T12:00:00.000000Z  to  2006-02-23T10:02:40.000000Z  added to channel collection
# net:sta:loc:chan= YR : BANO :  : BHZ for time span  2006-02-23T10:02:40.000000Z  to  2006-08-28T12:00:00.000000Z  added to channel collection
# Database.save_inventory processing summary:
# Number of site records processed= 1
# number of site records saved= 1
# number of channel records processed= 6
# number of channel records saved= 6
# Attempting to download xml data for station= BASO
# No B channel data for station= BASO  for any net code
# Ignoring this station
# Attempting to download xml data for station= TOBO
# No B channel data for station= TOBO  for any net code
# Ignoring this station
# Attempting to download xml data for station= PEMO
# No B channel data for station= PEMO  for any net code
# Ignoring this station
# Attempting to download xml data for station= HDA
# downloaded as this inventory object by obspy:
# Inventory created at 2021-01-23T21:35:15.000000Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.47
# 		    http://service.iris.edu/fdsnws/station/1/query?starttime=2004-01-01...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (2):
# 			AK, TA
# 		Stations (3):
# 			AK.HDA (Harding Lake, AK, USA) (2x)
# 			TA.HDA (Harding Lake, AK, USA)
# 		Channels (12):
# 			AK.HDA..BHZ (2x), AK.HDA..BHN (2x), AK.HDA..BHE (2x),
# 			TA.HDA..BHZ (2x), TA.HDA..BHN (2x), TA.HDA..BHE (2x)
# writing as xml data to file= data/raw_data_tutorial/orphanxml/HDA.xml
# saving to MongoDB site and channel collections
# net:sta:loc= AK : HDA :  for time span  2008-09-03T00:00:00.000000Z  to  2012-09-30T23:59:59.000000Z  added to site collection
# net:sta:loc:chan= AK : HDA :  : BHE for time span  2009-07-20T00:00:00.000000Z  to  2012-09-30T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= AK : HDA :  : BHN for time span  2009-07-20T00:00:00.000000Z  to  2012-09-30T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= AK : HDA :  : BHZ for time span  2009-07-20T00:00:00.000000Z  to  2012-09-30T23:59:59.000000Z  added to channel collection
# net:sta:loc= TA : HDA :  for time span  2012-10-01T00:00:00.000000Z  to  2014-10-23T23:59:59.000000Z  added to site collection
# net:sta:loc:chan= TA : HDA :  : BHE for time span  2012-10-01T00:00:00.000000Z  to  2013-09-17T20:44:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : HDA :  : BHE for time span  2013-09-17T20:45:00.000000Z  to  2014-10-23T22:20:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : HDA :  : BHN for time span  2012-10-01T00:00:00.000000Z  to  2013-09-17T20:44:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : HDA :  : BHN for time span  2013-09-17T20:45:00.000000Z  to  2014-10-23T22:20:00.000000Z  added to channel collection
# net:sta:loc:chan= TA : HDA :  : BHZ for time span  2012-10-01T00:00:00.000000Z  to  2013-09-17T20:44:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : HDA :  : BHZ for time span  2013-09-17T20:45:00.000000Z  to  2014-10-23T22:20:00.000000Z  added to channel collection
# Database.save_inventory processing summary:
# Number of site records processed= 2
# number of site records saved= 2
# number of channel records processed= 9
# number of channel records saved= 9
# Attempting to download xml data for station= BUKO
# No B channel data for station= BUKO  for any net code
# Ignoring this station
# Attempting to download xml data for station= CLWO
# No B channel data for station= CLWO  for any net code
# Ignoring this station
# Attempting to download xml data for station= WLVO
# No B channel data for station= WLVO  for any net code
# Ignoring this station
# Attempting to download xml data for station= PKRO
# No B channel data for station= PKRO  for any net code
# Ignoring this station
# Attempting to download xml data for station= LSQQ
# No B channel data for station= LSQQ  for any net code
# Ignoring this station
# Attempting to download xml data for station= KLBO
# No B channel data for station= KLBO  for any net code
# Ignoring this station
# Attempting to download xml data for station= MEDO
# No B channel data for station= MEDO  for any net code
# Ignoring this station
# Attempting to download xml data for station= STCO
# No B channel data for station= STCO  for any net code
# Ignoring this station
# Attempting to download xml data for station= DRCO
# No B channel data for station= DRCO  for any net code
# Ignoring this station
# Attempting to download xml data for station= BWLO
# No B channel data for station= BWLO  for any net code
# Ignoring this station
# Attempting to download xml data for station= TYNO
# No B channel data for station= TYNO  for any net code
# Ignoring this station
# Attempting to download xml data for station= TOLK
# downloaded as this inventory object by obspy:
# Inventory created at 2021-01-23T21:35:24.000000Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.47
# 		    http://service.iris.edu/fdsnws/station/1/query?starttime=2004-01-01...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (1):
# 			TA
# 		Stations (1):
# 			TA.TOLK (Toolik Lake Research Station, AK, USA)
# 		Channels (6):
# 			TA.TOLK..BHZ, TA.TOLK..BHN, TA.TOLK..BHE, TA.TOLK.01.BHZ,
# 			TA.TOLK.01.BHN, TA.TOLK.01.BHE
# writing as xml data to file= data/raw_data_tutorial/orphanxml/TOLK.xml
# saving to MongoDB site and channel collections
# net:sta:loc= TA : TOLK :  for time span  2011-08-13T00:00:00.000000Z  to  2020-02-14T23:59:59.000000Z  added to site collection
# net:sta:loc:chan= TA : TOLK :  : BHE for time span  2011-08-13T00:00:00.000000Z  to  2020-02-14T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : TOLK :  : BHN for time span  2011-08-13T00:00:00.000000Z  to  2020-02-14T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : TOLK :  : BHZ for time span  2011-08-13T00:00:00.000000Z  to  2020-02-14T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : TOLK :  : BHE for time span  2011-08-13T00:00:00.000000Z  to  2020-02-14T23:59:59.000000Z  already in channel collection - ignored
# net:sta:loc:chan= TA : TOLK :  : BHN for time span  2011-08-13T00:00:00.000000Z  to  2020-02-14T23:59:59.000000Z  already in channel collection - ignored
# net:sta:loc:chan= TA : TOLK :  : BHZ for time span  2011-08-13T00:00:00.000000Z  to  2020-02-14T23:59:59.000000Z  already in channel collection - ignored
# net:sta:loc= TA : TOLK : 01 for time span  2011-08-13T00:00:00.000000Z  to  2020-02-14T23:59:59.000000Z  added to site collection
# net:sta:loc:chan= TA : TOLK : 01 : BHE for time span  2011-08-13T00:00:00.000000Z  to  2020-02-14T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : TOLK : 01 : BHN for time span  2011-08-13T00:00:00.000000Z  to  2020-02-14T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : TOLK : 01 : BHZ for time span  2011-08-13T00:00:00.000000Z  to  2020-02-14T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : TOLK : 01 : BHE for time span  2011-08-13T00:00:00.000000Z  to  2020-02-14T23:59:59.000000Z  already in channel collection - ignored
# net:sta:loc:chan= TA : TOLK : 01 : BHN for time span  2011-08-13T00:00:00.000000Z  to  2020-02-14T23:59:59.000000Z  already in channel collection - ignored
# net:sta:loc:chan= TA : TOLK : 01 : BHZ for time span  2011-08-13T00:00:00.000000Z  to  2020-02-14T23:59:59.000000Z  already in channel collection - ignored
# Database.save_inventory processing summary:
# Number of site records processed= 2
# number of site records saved= 2
# number of channel records processed= 12
# number of channel records saved= 6
# Attempting to download xml data for station= POKR
# downloaded as this inventory object by obspy:
# Inventory created at 2021-01-23T21:35:24.000000Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.47
# 		    http://service.iris.edu/fdsnws/station/1/query?starttime=2004-01-01...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (1):
# 			TA
# 		Stations (1):
# 			TA.POKR (Poker Flat Research Range, AK, USA)
# 		Channels (9):
# 			TA.POKR..BHZ, TA.POKR..BHN, TA.POKR..BHE, TA.POKR.01.BHZ (2x),
# 			TA.POKR.01.BHN (2x), TA.POKR.01.BHE (2x)
# writing as xml data to file= data/raw_data_tutorial/orphanxml/POKR.xml
# saving to MongoDB site and channel collections
# net:sta:loc= TA : POKR :  for time span  2012-10-02T00:00:00.000000Z  to  2020-02-11T23:59:59.000000Z  added to site collection
# net:sta:loc:chan= TA : POKR :  : BHE for time span  2012-10-02T00:00:00.000000Z  to  2020-02-11T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : POKR :  : BHN for time span  2012-10-02T00:00:00.000000Z  to  2020-02-11T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : POKR :  : BHZ for time span  2012-10-02T00:00:00.000000Z  to  2020-02-11T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : POKR :  : BHE for time span  2012-10-02T00:00:00.000000Z  to  2013-06-14T18:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : POKR :  : BHE for time span  2013-06-14T19:00:00.000000Z  to  2020-02-11T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : POKR :  : BHN for time span  2012-10-02T00:00:00.000000Z  to  2013-06-14T18:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : POKR :  : BHN for time span  2013-06-14T19:00:00.000000Z  to  2020-02-11T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : POKR :  : BHZ for time span  2012-10-02T00:00:00.000000Z  to  2013-06-14T18:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : POKR :  : BHZ for time span  2013-06-14T19:00:00.000000Z  to  2020-02-11T23:59:59.000000Z  added to channel collection
# net:sta:loc= TA : POKR : 01 for time span  2012-10-02T00:00:00.000000Z  to  2020-02-11T23:59:59.000000Z  added to site collection
# net:sta:loc:chan= TA : POKR : 01 : BHE for time span  2012-10-02T00:00:00.000000Z  to  2020-02-11T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : POKR : 01 : BHN for time span  2012-10-02T00:00:00.000000Z  to  2020-02-11T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : POKR : 01 : BHZ for time span  2012-10-02T00:00:00.000000Z  to  2020-02-11T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : POKR : 01 : BHE for time span  2012-10-02T00:00:00.000000Z  to  2013-06-14T18:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : POKR : 01 : BHE for time span  2013-06-14T19:00:00.000000Z  to  2020-02-11T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : POKR : 01 : BHN for time span  2012-10-02T00:00:00.000000Z  to  2013-06-14T18:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : POKR : 01 : BHN for time span  2013-06-14T19:00:00.000000Z  to  2020-02-11T23:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : POKR : 01 : BHZ for time span  2012-10-02T00:00:00.000000Z  to  2013-06-14T18:59:59.000000Z  added to channel collection
# net:sta:loc:chan= TA : POKR : 01 : BHZ for time span  2013-06-14T19:00:00.000000Z  to  2020-02-11T23:59:59.000000Z  added to channel collection
# Database.save_inventory processing summary:
# Number of site records processed= 2
# number of site records saved= 2
# number of channel records processed= 18
# number of channel records saved= 18
# Attempting to download xml data for station= LATQ
# No B channel data for station= LATQ  for any net code
# Ignoring this station
# Attempting to download xml data for station= ORHO
# No B channel data for station= ORHO  for any net code
# Ignoring this station

# %% [markdown]
# The verbose output of that script above shows the problem sites are all created by new sites coming into the TA data stream from testing in Alaska.  Other seem extraneous stations that do not have broadband channels.
#
# Note that should eventually be removed before release:  There is a bug in the save_inventory script somewhere from some initialization related to the obnoxious behavior of insert_one. insert_one adds the object_id of the inserted document to the dict it is passed as an argument.  That creates a duplicate key condition if that id is not cleared.   Couldn't find it without a more careful debugging but found I could get through the whole processing by just hitting run again and again until it finished.  Apparently the initialization is on a second pass after a file is processed.

# %% [markdown]
# Let's verify what stations still have null net codes

# %%
from mspasspy.preprocessing.css30.dbarrival import find_null_net_stations
ret=find_null_net_stations(db)
print(ret)
# Out:
# {'CHGQ', 'ACTO', 'DRWO', 'DELO', 'ORIO', 'BMRO', 'TCOL', 'TORO', 'BRCO', 'BELQ', 'MATQ', 'ALFO', 'ALGO', 'PLIO', 'ELFO', 'Y22E', 'EPYK', 'PLVO', 'BANO', 'BASO', 'TOBO', 'PEMO', 'HDA', 'BUKO', 'CLWO', 'WLVO', 'PKRO', 'LSQQ', 'KLBO', 'MEDO', 'STCO', 'DRCO', 'BWLO', 'TYNO', 'TOLK', 'POKR', 'LATQ', 'ORHO'}

# %% [markdown]
# The output from above suggests all these data are not of interest for what we are assembling (Alaska test sites and sites that don't have broadband sensors) but we should do what we can.   The next block test the set returned above and reruns the function to try to set the net code from the site table:

# %%
for sta in ret:
    n=set_netcode_time_interval(db,sta,net='TA')
    print('set net code to TA for ',n,' arrival documents with picks for station=',sta)
# Out:
# set net code to TA for  234  arrival documents with picks for station= CHGQ
# set net code to TA for  288  arrival documents with picks for station= ACTO
# set net code to TA for  223  arrival documents with picks for station= DRWO
# set net code to TA for  380  arrival documents with picks for station= DELO
# set net code to TA for  250  arrival documents with picks for station= ORIO
# set net code to TA for  305  arrival documents with picks for station= BMRO
# set net code to TA for  248  arrival documents with picks for station= TCOL
# set net code to TA for  73  arrival documents with picks for station= TORO
# set net code to TA for  216  arrival documents with picks for station= BRCO
# set net code to TA for  149  arrival documents with picks for station= BELQ
# set net code to TA for  287  arrival documents with picks for station= MATQ
# set net code to TA for  438  arrival documents with picks for station= ALFO
# set net code to TA for  117  arrival documents with picks for station= ALGO
# set net code to TA for  49  arrival documents with picks for station= PLIO
# set net code to TA for  270  arrival documents with picks for station= ELFO
# set net code to TA for  270  arrival documents with picks for station= Y22E
# set net code to TA for  287  arrival documents with picks for station= EPYK
# set net code to TA for  368  arrival documents with picks for station= PLVO
# set net code to TA for  373  arrival documents with picks for station= BANO
# set net code to TA for  302  arrival documents with picks for station= BASO
# set net code to TA for  272  arrival documents with picks for station= TOBO
# set net code to TA for  358  arrival documents with picks for station= PEMO
# set net code to TA for  266  arrival documents with picks for station= HDA
# set net code to TA for  331  arrival documents with picks for station= BUKO
# set net code to TA for  260  arrival documents with picks for station= CLWO
# set net code to TA for  282  arrival documents with picks for station= WLVO
# set net code to TA for  283  arrival documents with picks for station= PKRO
# set net code to TA for  256  arrival documents with picks for station= LSQQ
# set net code to TA for  349  arrival documents with picks for station= KLBO
# set net code to TA for  275  arrival documents with picks for station= MEDO
# set net code to TA for  221  arrival documents with picks for station= STCO
# set net code to TA for  127  arrival documents with picks for station= DRCO
# set net code to TA for  260  arrival documents with picks for station= BWLO
# set net code to TA for  276  arrival documents with picks for station= TYNO
# set net code to TA for  1062  arrival documents with picks for station= TOLK
# set net code to TA for  270  arrival documents with picks for station= POKR
# set net code to TA for  184  arrival documents with picks for station= LATQ
# set net code to TA for  8  arrival documents with picks for station= ORHO

# %% [markdown]
# Let's finish this by verifying we no longer have any null net entries in the arrival collection:

# %%
from mspasspy.preprocessing.css30.dbarrival import find_null_net_stations
ret=find_null_net_stations(db)
print(ret)
# Out:
# set()

# %% [markdown]
# ## 5. Indexing Waveform Data
# For this tutorial we will be reading a set of miniseed files derived from the files downloaded by web services with obspy as described in section 3 above.   As noted earlier I elected to concatenate the large number of miniseed files obspy's downloader wrote to create files that would work more efficiently on HPC systems.  For readers familiar with seismic reflection processing the files we will be working with in this and the next section can be thought of as a bundle that defines a common source (shot) gather.   In MsPASS we abstract any group of seismic data objects that have some relationship into a container we call and Ensemble object.   For obspy users an ensemble is similar in concept to the obspy Stream object but more generic.
#
# For the preprocessing phase the next step we need to accomplish is building an index that defines the contents of the data we are aiming to assemble.   We will again be using MongoDB to accomplish this task.  We will create a set of documents that describe our data in it's raw form.   In the following sections we will edit these documents to add additional metadata needed to complete the data set.  Then we will run an example MsPASS run with spark that will be used to preprocessind and time window these data before writing them into the processing collection with call *wf*.
#
# The next code block runs a small function we can use to build our index.   Run the next code block and we will discuss what it does in afterwards by mixing in some words with database queries to explain the concepts.

# %%
from mspasspy.preprocessing.seed.ensembles import (dbsave_seed_ensemble_file)
for i in range(29):
    fname="wf/2012/event{0}.mseed".format(i+1)
    print('Building index for miniseed file=',fname)
    try:
        dbsave_seed_ensemble_file(db,fname)
    except Exception as err:
        print(err)
# Out:
# Building index for miniseed file= wf/2012/event1.mseed
# Building index for miniseed file= wf/2012/event2.mseed
# Building index for miniseed file= wf/2012/event3.mseed
# Building index for miniseed file= wf/2012/event4.mseed
# Building index for miniseed file= wf/2012/event5.mseed
# /home/pavlis/.local/lib/python3.8/site-packages/obspy/io/mseed/headers.py:828: InternalMSEEDWarning: readMSEEDBuffer(): Not a SEED record. Will skip bytes 273015296 to 273015423.
#   warnings.warn(_w, InternalMSEEDWarning)
# /home/pavlis/.local/lib/python3.8/site-packages/obspy/io/mseed/headers.py:828: InternalMSEEDWarning: readMSEEDBuffer(): Not a SEED record. Will skip bytes 273015424 to 273015551.
#   warnings.warn(_w, InternalMSEEDWarning)
# /home/pavlis/.local/lib/python3.8/site-packages/obspy/io/mseed/headers.py:828: InternalMSEEDWarning: readMSEEDBuffer(): Not a SEED record. Will skip bytes 273015552 to 273015679.
#   warnings.warn(_w, InternalMSEEDWarning)
# /home/pavlis/.local/lib/python3.8/site-packages/obspy/io/mseed/headers.py:828: InternalMSEEDWarning: readMSEEDBuffer(): Not a SEED record. Will skip bytes 273015680 to 273015807.
#   warnings.warn(_w, InternalMSEEDWarning)
# /home/pavlis/.local/lib/python3.8/site-packages/obspy/io/mseed/headers.py:828: InternalMSEEDWarning: readMSEEDBuffer(): Not a SEED record. Will skip bytes 273024000 to 273024127.
#   warnings.warn(_w, InternalMSEEDWarning)
# /home/pavlis/.local/lib/python3.8/site-packages/obspy/io/mseed/headers.py:828: InternalMSEEDWarning: readMSEEDBuffer(): Not a SEED record. Will skip bytes 

#   warnings.warn(_w, InternalMSEEDWarning)
# /home/pavlis/.local/lib/python3.8/site-packages/obspy/io/mseed/headers.py:828: InternalMSEEDWarning: readMSEEDBuffer(): Not a SEED record. Will skip bytes 617762944 to 617763071.
#   warnings.warn(_w, InternalMSEEDWarning)
# /home/pavlis/.local/lib/python3.8/site-packages/obspy/io/mseed/headers.py:828: InternalMSEEDWarning: readMSEEDBuffer(): Not a SEED record. Will skip bytes 617763072 to 617763199.
#   warnings.warn(_w, InternalMSEEDWarning)
# /home/pavlis/.local/lib/python3.8/site-packages/obspy/io/mseed/headers.py:828: InternalMSEEDWarning: readMSEEDBuffer(): Not a SEED record. Will skip bytes 617763200 to 617763327.
#   warnings.warn(_w, InternalMSEEDWarning)
# something threw an exception - this needs detailed handlers
# Building index for miniseed file= wf/2012/event6.mseed
# Building index for miniseed file= wf/2012/event7.mseed
# Building index for miniseed file= wf/2012/event8.mseed
# Building index for miniseed file= wf/2012/event9.mseed
# Building index for miniseed file= wf/2012/event10.mseed
# Building index for miniseed file= wf/2012/event11.mseed
# Building index for miniseed file= wf/2012/event12.mseed
# Building index for miniseed file= wf/2012/event13.mseed
# Building index for miniseed file= wf/2012/event14.mseed
# Building index for miniseed file= wf/2012/event15.mseed
# Building index for miniseed file= wf/2012/event16.mseed
# Building index for miniseed file= wf/2012/event17.mseed
# Building index for miniseed file= wf/2012/event18.mseed
# Building index for miniseed file= wf/2012/event19.mseed
# Building index for miniseed file= wf/2012/event20.mseed
# Building index for miniseed file= wf/2012/event21.mseed
# Building index for miniseed file= wf/2012/event22.mseed
# Building index for miniseed file= wf/2012/event23.mseed
# Building index for miniseed file= wf/2012/event24.mseed
# Building index for miniseed file= wf/2012/event25.mseed
# Building index for miniseed file= wf/2012/event26.mseed
# Building index for miniseed file= wf/2012/event27.mseed
# Building index for miniseed file= wf/2012/event28.mseed
# Building index for miniseed file= wf/2012/event29.mseed

# %% [markdown]
# Notice that event5 had read errors.  That problem, unfortunately, is too common with waveform data downloaded by web services.  This function makes no attempt to salvage that data so it is lost until we attempt further detective work.   We will ignore that problem for now, but emphasize to the reader that is part of the tedious work that is required today to assemble the most complete dataset.  What complete means is dependent on the project so we treat solving that particular problem as an exercise for the student.  We intentionally leave the data slightly dirty to emphasize this point.
#
# The following script shows only 28 of the 29 files were successfully processed and prints the contents of the first document in a prettier for (the full collection has 27 similar documents)

# %%
dbwf=db.wf_miniseed
n=dbwf.count_documents({})
print('seedwf collection has ',n,' documents - should have been 29')
doc=dbwf.find_one()
print('Ensemble Metadata')
for k in doc:
    if k!='members':
        print(k,doc[k])
print('Ensemble Member Metadata')
n=0
for d in doc['members']:
    print('Metadata dict for member number ',n)
    print(d)
    n+=1
# Out:
# seedwf collection has  28  documents - should have been 29
# Ensemble Metadata
# _id 600c9b15df5fa30c0c62c771
# dir /home/pavlis/mspass_tutorial/notebooks/wf/2012
# dfile event1.mseed
# format mseed
# member_type TimeSeries
# mover obspy_seed_ensemble_reader
# starttime 1356943580.750001
# endtime 1356947180.744538
# Ensemble Member Metadata
# Metadata dict for member number  0
# {'net': '2G', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.799998, 'endtime': 1356947180.749998, 'sampling_rate': 20.0, 'delta': 0.05, 'npts': 72000, 'calib': 1.0, 'seed_file_id': '37894c69-443f-4595-99ae-43a4f7ab4965'}
# Metadata dict for member number  1
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7527978, 'endtime': 1356947180.7327979, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'fcdebd65-1fe7-4aa1-bda3-696169247a4e'}
# Metadata dict for member number  2
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.7556999, 'endtime': 1356947180.7357, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'f9943401-e303-4a76-9579-2f67b56f7dca'}
# Metadata dict for member number  3
# {'net': '2G', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.799998, 'endtime': 1356947180.749998, 'sampling_rate': 20.0, 'delta': 0.05, 'npts': 72000, 'calib': 1.0, 'seed_file_id': '9986b312-b177-4047-bc05-4a867dd4aa5b'}
# Metadata dict for member number  4
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.766, 'endtime': 1356947180.7459998, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '81750672-5664-4a72-be1a-01926d5aef27'}
# Metadata dict for member number  5
# {'net': '2G', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.799998, 'endtime': 1356947180.749998, 'sampling_rate': 20.0, 'delta': 0.05, 'npts': 72000, 'calib': 1.0, 'seed_file_id': '826dafc9-86b2-4813-9e83-aeccd8bc4605'}
# Metadata dict for member number  6
# {'net': 'AE', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7500002, 'endtime': 1356947180.7500002, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'b16f7e54-d3ab-4909-9715-95c9e25a9a7d'}
# Metadata dict for member number  7
# {'net': 'AZ', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7505002, 'endtime': 1356947180.7254999, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '0ad2432c-965d-41e6-a689-7e786677ca37'}
# Metadata dict for member number  8
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.760833, 'endtime': 1356947180.740833, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '26fe2e37-a74d-4870-a52a-94c1f10ba81f'}
# Metadata dict for member number  9
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'b389d35f-7494-4bfe-910e-13e613e0b634'}
# Metadata dict for member number  10
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.769536, 'endtime': 1356947180.7445362, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '0d4aec91-aa08-4c15-8370-bac2c3721082'}
# Metadata dict for member number  11
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.7555, 'endtime': 1356947180.7355, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '79406bfb-871d-4a9a-9d66-d347292b4551'}
# Metadata dict for member number  12
# {'net': 'AZ', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '5d0d76b7-b3cb-414a-98d7-5a2f9787359c'}
# Metadata dict for member number  13
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.755698, 'endtime': 1356947180.735698, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '5d9c48b6-e182-4505-9f74-1d362a700d6b'}
# Metadata dict for member number  14
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '5072f7c1-35eb-46b8-8312-dd1dd2d59fdb'}
# Metadata dict for member number  15
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.766, 'endtime': 1356947180.7459998, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'f01b8032-ecc4-4026-9d39-7f52cd2953ac'}
# Metadata dict for member number  16
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '8989c580-8eba-4045-b0f9-d6bb608e5cf0'}
# Metadata dict for member number  17
# {'net': 'AZ', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7505002, 'endtime': 1356947180.7254999, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'c83714a9-8c77-449f-a647-c6dd639cfd0b'}
# Metadata dict for member number  18
# {'net': 'AZ', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'ca76c0cd-9f50-42db-8c30-44e5169e5886'}
# Metadata dict for member number  19
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.755476, 'endtime': 1356947180.735476, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '94cdacaf-ac7c-42b1-a464-b185f0ca0096'}
# Metadata dict for member number  20
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.755498, 'endtime': 1356947180.735498, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'd9c5a7b9-a733-4cc7-a4c3-69fa50376df3'}
# Metadata dict for member number  21
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'd166c363-afe3-44cb-9267-23653ea67956'}
# Metadata dict for member number  22
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '92ec416b-0e2d-4811-80d9-c01eeceb336b'}
# Metadata dict for member number  23
# {'net': 'AZ', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '05070f41-78a8-472f-a2e9-9840517c44fa'}
# Metadata dict for member number  24
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.766, 'endtime': 1356947180.7459998, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '799b33cd-feb1-4532-9221-8e1c871a2394'}
# Metadata dict for member number  25
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'd6ec5c7b-818a-4289-a4d6-51b2aa15b7f9'}
# Metadata dict for member number  26
# {'net': 'AZ', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '6768ffc9-0cfc-4e0d-897a-ad9740b463ed'}
# Metadata dict for member number  27
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7555, 'endtime': 1356947180.7355, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '418c0353-b456-4cfb-a1b6-eca56c990a40'}
# Metadata dict for member number  28
# {'net': 'AZ', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7443998, 'endtime': 1356947180.7443998, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'ab94be85-d621-41c4-a4b6-80c1304ef152'}
# Metadata dict for member number  29
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'b0239f53-ce3d-450b-b8e7-8dcc0b8fe050'}
# Metadata dict for member number  30
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.7577999, 'endtime': 1356947180.7378, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '16b1795d-4a37-4c53-b111-6de11a333202'}
# Metadata dict for member number  31
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '73be0c1d-6da7-4998-9ddf-92eae14e75b3'}
# Metadata dict for member number  32
# {'net': 'AZ', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '9873a4d8-5e5c-4204-852c-83f8a3b7cc5f'}
# Metadata dict for member number  33
# {'net': 'AZ', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '1230c6a8-7b04-4405-8e49-8e15bf927a01'}
# Metadata dict for member number  34
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.760833, 'endtime': 1356947180.740833, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'dd284217-abb8-48ac-bd48-15481c3e0414'}
# Metadata dict for member number  35
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.7631, 'endtime': 1356947180.7431, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '3aee8ba2-2515-48c2-83d8-88f488d6ca8c'}
# Metadata dict for member number  36
# {'net': 'AZ', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'ff7ccb50-c9db-48e3-8981-8a4dbdb96786'}
# Metadata dict for member number  37
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.769536, 'endtime': 1356947180.7445362, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '3b9356f9-cab0-46f1-b62c-5b34cb911919'}
# Metadata dict for member number  38
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.7577999, 'endtime': 1356947180.7378, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '0bffc264-0aae-454e-a02b-31f530a61652'}
# Metadata dict for member number  39
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '0a5b120d-abf5-4def-a6d0-4ee56bc7b7d9'}
# Metadata dict for member number  40
# {'net': 'AZ', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7443998, 'endtime': 1356947180.7443998, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'b78fe9f5-6cd7-4c11-9fdd-2fe06adc3ad1'}
# Metadata dict for member number  41
# {'net': 'AZ', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '4fe2fe76-a5bf-4766-88e1-8684c34bfb66'}
# Metadata dict for member number  42
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.755476, 'endtime': 1356947180.735476, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '76ae8ef2-f38a-4dc3-996d-8fc95100dd13'}
# Metadata dict for member number  43
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.7631, 'endtime': 1356947180.7431, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '294691eb-61d6-4f3b-8c21-fe2f34504d3a'}
# Metadata dict for member number  44
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7577999, 'endtime': 1356947180.7378, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '4ef7358f-7652-4d55-8263-93cd7dcaa4b6'}
# Metadata dict for member number  45
# {'net': 'AZ', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7443998, 'endtime': 1356947180.7443998, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'fc245586-a96c-4d2b-b5db-5103a0954c01'}
# Metadata dict for member number  46
# {'net': 'AZ', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'e9983589-8b97-4787-82e0-3d7269bb3873'}
# Metadata dict for member number  47
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '57ba8a51-8ff3-4e32-b3dc-0aa1536c9ca8'}
# Metadata dict for member number  48
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'fdd5a38c-0337-4a38-b5d8-7dd2734c538b'}
# Metadata dict for member number  49
# {'net': 'AZ', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7443998, 'endtime': 1356947180.7443998, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '45a8ea90-9309-43b5-8a4a-26502ae93ab1'}
# Metadata dict for member number  50
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7631, 'endtime': 1356947180.7431, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '0da0d872-833f-49ec-86f4-ea48aeb9672b'}
# Metadata dict for member number  51
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.7532, 'endtime': 1356947180.7331998, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '4c71b450-830a-43bb-a722-c2f5fb9763d5'}
# Metadata dict for member number  52
# {'net': 'AZ', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '6c97b730-ba20-4c5c-b564-ee6f021aea0b'}
# Metadata dict for member number  53
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.769536, 'endtime': 1356947180.7445362, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '9e5b206d-4dc8-42ce-a784-10433a34ba44'}
# Metadata dict for member number  54
# {'net': 'AZ', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7443998, 'endtime': 1356947180.7443998, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '6db48d22-3cbe-4046-b2d4-dcb722ac1a95'}
# Metadata dict for member number  55
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.7505002, 'endtime': 1356947180.7305, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '6883f811-f274-4ced-ad24-5261d586fea7'}
# Metadata dict for member number  56
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.760833, 'endtime': 1356947180.740833, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '14693ae2-ad3a-43ca-b081-b5bdf886bb56'}
# Metadata dict for member number  57
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'e88bc397-aaab-4fe2-9977-ff2cdd38cc69'}
# Metadata dict for member number  58
# {'net': 'AZ', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '15f47e91-14fa-4c3b-a30e-1ad990b77e6b'}
# Metadata dict for member number  59
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.769536, 'endtime': 1356947180.7445362, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '3ca045fb-505a-4167-a11a-7f12aed707fa'}
# Metadata dict for member number  60
# {'net': 'AZ', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '04951ee6-0847-4ebb-8bdf-2097e0328967'}
# Metadata dict for member number  61
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.769539, 'endtime': 1356947180.7445388, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '8b69c1d7-a2e8-4582-a76c-20c1e7cd5870'}
# Metadata dict for member number  62
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.7532, 'endtime': 1356947180.7331998, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '9ff0121f-3509-4617-8a41-fb3a03e9babb'}
# Metadata dict for member number  63
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.755476, 'endtime': 1356947180.735476, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'c1d48a50-43c8-4a47-b2c5-2f5280705b84'}
# Metadata dict for member number  64
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.750498, 'endtime': 1356947180.730498, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '6205871d-9577-4d3d-97b5-225dadbcb717'}
# Metadata dict for member number  65
# {'net': 'AZ', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '48b9ae45-88c0-4739-83b2-8515bcdf99b1'}
# Metadata dict for member number  66
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.769539, 'endtime': 1356947180.7445388, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '55d7508f-d048-4573-946a-e1c86834118c'}
# Metadata dict for member number  67
# {'net': 'AZ', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '8dbf4c86-46b2-46da-a007-bf0c02bc4eb3'}
# Metadata dict for member number  68
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.750498, 'endtime': 1356947180.730498, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '149b9900-da9c-4079-955f-f39810c93d98'}
# Metadata dict for member number  69
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7532, 'endtime': 1356947180.7331998, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '8c950f3f-da44-4354-815f-f40a5575c35e'}
# Metadata dict for member number  70
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.769539, 'endtime': 1356947180.7445388, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'd3d22a16-9726-4077-9bcb-38ee4e504ba7'}
# Metadata dict for member number  71
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'e0150e60-ac80-406a-a4fa-0bf06d521f77'}
# Metadata dict for member number  72
# {'net': 'AZ', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'efdaba46-e576-4d0b-8dd1-eaaef5adb541'}
# Metadata dict for member number  73
# {'net': 'AZ', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '0551b500-b3d5-4a48-8c0d-8f0773ac569e'}
# Metadata dict for member number  74
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.762698, 'endtime': 1356947180.742698, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '41974ad4-9fc6-4ac4-93ad-9132be582e4b'}
# Metadata dict for member number  75
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.769536, 'endtime': 1356947180.7445362, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'c22cfe01-7a9a-4394-a04e-2f16264fa0b8'}
# Metadata dict for member number  76
# {'net': 'AZ', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7422998, 'endtime': 1356947180.7422998, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'f3413c71-ed42-4a2d-b1cb-b4255536d715'}
# Metadata dict for member number  77
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.759003, 'endtime': 1356947180.739003, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'c93f6cbe-3c1d-4f0e-9f3e-fcfdacc7eeaa'}
# Metadata dict for member number  78
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.768949, 'endtime': 1356947180.748949, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '5f0bcfe7-6f83-4cff-aa34-fb9cc080cd96'}
# Metadata dict for member number  79
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'b94d4ba0-75f1-4bf7-b015-b3a04c647abb'}
# Metadata dict for member number  80
# {'net': 'AZ', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7443998, 'endtime': 1356947180.7443998, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'd9d98898-1df1-4817-a167-7068f5f261a3'}
# Metadata dict for member number  81
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'fbc93511-3759-4e53-b47f-4996677e23f1'}
# Metadata dict for member number  82
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.762698, 'endtime': 1356947180.742698, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '5118d1a3-09f4-482b-8d80-71610ea18a8b'}
# Metadata dict for member number  83
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.769536, 'endtime': 1356947180.7445362, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '7d44633b-597b-422e-b4c1-19d02d737b56'}
# Metadata dict for member number  84
# {'net': 'AZ', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7422998, 'endtime': 1356947180.7422998, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '002e830e-f7b0-4590-ba14-9e4deb7aa164'}
# Metadata dict for member number  85
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.759003, 'endtime': 1356947180.739003, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '31e293e9-1a71-471a-ac19-fdc5172aabfa'}
# Metadata dict for member number  86
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.754, 'endtime': 1356947180.7340002, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '04145aa4-e318-41a5-a3ab-569d04220722'}
# Metadata dict for member number  87
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.7500002, 'endtime': 1356947180.7, 'sampling_rate': 20.0, 'delta': 0.05, 'npts': 72000, 'calib': 1.0, 'seed_file_id': 'cc257200-d013-4053-9c1e-6422c9f5db36'}
# Metadata dict for member number  88
# {'net': 'AZ', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7422998, 'endtime': 1356947180.7422998, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'aebd1156-213d-41fd-9347-b8ab2d4b79cb'}
# Metadata dict for member number  89
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.769536, 'endtime': 1356947180.7445362, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '9ee5ca28-26aa-4895-bedd-b2e4daf7fa3b'}
# Metadata dict for member number  90
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.762698, 'endtime': 1356947180.742698, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '691319f5-5ca2-45ba-984d-19dc95391ce4'}
# Metadata dict for member number  91
# {'net': 'AZ', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '492e4eed-a93f-4666-b99a-126174a5a055'}
# Metadata dict for member number  92
# {'net': 'AZ', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'bb2e42da-72fa-458d-b13f-2eee6adc73f4'}
# Metadata dict for member number  93
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.759, 'endtime': 1356947180.739, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'cd287758-51e8-4e65-b435-deffdc01fdbf'}
# Metadata dict for member number  94
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.760598, 'endtime': 1356947180.740598, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '11123598-72d8-468d-9c2b-32f1365504f1'}
# Metadata dict for member number  95
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.7500002, 'endtime': 1356947180.7, 'sampling_rate': 20.0, 'delta': 0.05, 'npts': 72000, 'calib': 1.0, 'seed_file_id': '9142cbb8-a158-443d-a761-c43ec46e9491'}
# Metadata dict for member number  96
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.754, 'endtime': 1356947180.7340002, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '2b600acb-6ea0-4cd4-9811-a7578f06606e'}
# Metadata dict for member number  97
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '26fb4e99-b763-4754-a499-6dafabb33198'}
# Metadata dict for member number  98
# {'net': 'AZ', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7443998, 'endtime': 1356947180.7443998, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '9a555446-a387-4b62-8ea6-5c93133502fc'}
# Metadata dict for member number  99
# {'net': 'AZ', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'fa9d6c50-068a-4b46-a734-024b55d0df1d'}
# Metadata dict for member number  100
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.769539, 'endtime': 1356947180.7445388, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '964ded7d-7c1a-43cd-b736-a7b29fd2f75c'}
# Metadata dict for member number  101
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.7686, 'endtime': 1356947180.7486, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'bc7f9600-fbf0-41fb-9589-95ff29e8a11c'}
# Metadata dict for member number  102
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.768949, 'endtime': 1356947180.748949, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'f104afe8-7b9c-489a-bb17-7e24074a228c'}
# Metadata dict for member number  103
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.7500002, 'endtime': 1356947180.7, 'sampling_rate': 20.0, 'delta': 0.05, 'npts': 72000, 'calib': 1.0, 'seed_file_id': 'e8e5cce5-f730-41be-8434-6e77c9f45371'}
# Metadata dict for member number  104
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.760598, 'endtime': 1356947180.740598, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'b8ba3e94-92e0-4417-8c24-e9b91b56aa47'}
# Metadata dict for member number  105
# {'net': 'AZ', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'ecac3b9b-d2fa-4c69-8cf9-9d2ad84448f5'}
# Metadata dict for member number  106
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'a05aaf35-9331-49c4-9f31-cb4942bbb767'}
# Metadata dict for member number  107
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.754, 'endtime': 1356947180.7340002, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '6265e67a-51c9-4ab2-a3a9-c90d7ae1db6f'}
# Metadata dict for member number  108
# {'net': 'AZ', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'c8eb5efb-a934-4b6f-bb38-a9ca7daaccb6'}
# Metadata dict for member number  109
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.769536, 'endtime': 1356947180.7445362, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'dc99731a-6536-4707-8191-c3dd6cb4c447'}
# Metadata dict for member number  110
# {'net': 'AZ', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '407692bf-3e02-43cb-826f-fc31dedb55f5'}
# Metadata dict for member number  111
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'f1a09ac4-0f6c-43d9-b171-1147973c5754'}
# Metadata dict for member number  112
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.760598, 'endtime': 1356947180.740598, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '9cca5e6b-1dff-4fba-827e-0181aebc6ca8'}
# Metadata dict for member number  113
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.7686, 'endtime': 1356947180.7486, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'c0f6b6fe-8e74-49ed-8064-dfa0d4096151'}
# Metadata dict for member number  114
# {'net': 'AZ', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7443998, 'endtime': 1356947180.7443998, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '53e6dc0b-7f61-4f57-af44-dee32cc79c39'}
# Metadata dict for member number  115
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.7685041, 'endtime': 1356947180.7485042, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '399a29a5-79ab-4394-85b2-598e78d7b473'}
# Metadata dict for member number  116
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'c858f4be-973c-4693-b861-8c7f37b45175'}
# Metadata dict for member number  117
# {'net': 'AZ', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7443998, 'endtime': 1356947180.7443998, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'dc33f715-5c30-4fd1-947b-58a88a509c5a'}
# Metadata dict for member number  118
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.769536, 'endtime': 1356947180.7445362, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'cc65ad52-fb42-4bc0-85cf-f2824e2c6df5'}
# Metadata dict for member number  119
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.752255, 'endtime': 1356947180.732255, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'e73065e8-40c1-44c6-beb9-684e128e8fa1'}
# Metadata dict for member number  120
# {'net': 'AZ', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '7e33cc74-1c83-4df3-9e3c-6050482b0715'}
# Metadata dict for member number  121
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '778a094f-5b9a-4042-bab7-f7c2d1dc2e52'}
# Metadata dict for member number  122
# {'net': 'AZ', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '132f6682-0444-4b1e-b898-da36a5c83c18'}
# Metadata dict for member number  123
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7686, 'endtime': 1356947180.7486, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '62d91642-1515-4af7-a064-2e7da24c8d24'}
# Metadata dict for member number  124
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.769536, 'endtime': 1356947180.7445362, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '447ac258-3f0c-4cde-9f65-b8addeced6e9'}
# Metadata dict for member number  125
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.768949, 'endtime': 1356947180.748949, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '121f03da-6442-48af-baa9-77b211131449'}
# Metadata dict for member number  126
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.769536, 'endtime': 1356947180.7445362, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '251bea87-c007-403e-8d24-3846631abf1b'}
# Metadata dict for member number  127
# {'net': 'AZ', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'b4c1e916-15bd-4485-abca-8167a767def5'}
# Metadata dict for member number  128
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.769536, 'endtime': 1356947180.7445362, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '615d2715-52bd-4963-84e3-0121c790575e'}
# Metadata dict for member number  129
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.7525, 'endtime': 1356947180.7325, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'b2515eba-5099-4c08-ae91-5577eb6fcfcb'}
# Metadata dict for member number  130
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.769536, 'endtime': 1356947180.7445362, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '1a0485c0-2e55-4844-817f-bdfdd8ce7299'}
# Metadata dict for member number  131
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'a96b36a5-17fd-48c2-877a-623709d1714a'}
# Metadata dict for member number  132
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.769536, 'endtime': 1356947180.7445362, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '3df3126d-99c0-45e6-9c5e-12f68add1b44'}
# Metadata dict for member number  133
# {'net': 'AZ', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '20c47036-3c48-46ec-8935-86a422de5281'}
# Metadata dict for member number  134
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '2398fbc5-add4-44b1-aca8-c42645b7b309'}
# Metadata dict for member number  135
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.7525, 'endtime': 1356947180.7325, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '32c9b4fd-0fc6-48eb-9baf-5ec5eb8c9633'}
# Metadata dict for member number  136
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '7a080923-c617-4631-918b-ed0790da223f'}
# Metadata dict for member number  137
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.769536, 'endtime': 1356947180.7445362, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '13f8675a-f4b1-408f-85b8-992bb2e39d53'}
# Metadata dict for member number  138
# {'net': 'AZ', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'f8aa6256-6834-477b-8711-248027365533'}
# Metadata dict for member number  139
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'cb110b0d-1daf-471f-ac95-d49c88a259c5'}
# Metadata dict for member number  140
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.7685041, 'endtime': 1356947180.7485042, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'fd85b8e7-a5fe-4a6f-af46-a2dcc23f6b1b'}
# Metadata dict for member number  141
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '45f72b2e-e7ad-430e-bdef-4c494adf5ca3'}
# Metadata dict for member number  142
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.752255, 'endtime': 1356947180.732255, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'e8402658-4815-43dc-b6d4-ec6bfe5b95a1'}
# Metadata dict for member number  143
# {'net': 'AZ', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7443998, 'endtime': 1356947180.7443998, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'ebc75803-428b-4286-b6dc-03b269bcbf7d'}
# Metadata dict for member number  144
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '3275137b-bf0d-4916-a175-3b32eef1765d'}
# Metadata dict for member number  145
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7525, 'endtime': 1356947180.7325, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'dda43f02-f707-4f4a-8e03-a42fd513ddc8'}
# Metadata dict for member number  146
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '59c382de-3c5d-40e4-b051-bd2a6dbbd6aa'}
# Metadata dict for member number  147
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'cfe39412-3031-4513-9809-fe4cd4ecc5a6'}
# Metadata dict for member number  148
# {'net': 'AZ', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7443998, 'endtime': 1356947180.7443998, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'd596edcd-3ab9-435e-a178-8cf0c3b1a1fa'}
# Metadata dict for member number  149
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.769539, 'endtime': 1356947180.7445388, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '3fd578cf-af2d-4b06-bf0f-4772b51ceb12'}
# Metadata dict for member number  150
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.7503092, 'endtime': 1356947180.7503092, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180001, 'calib': 1.0, 'seed_file_id': '95cb859c-dbdb-40aa-a84d-63b57e4d1723'}
# Metadata dict for member number  151
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '7570cbbb-aacb-4cd9-bc90-bd8e0a82caa5'}
# Metadata dict for member number  152
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.766142, 'endtime': 1356947180.746142, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '6045af8c-898a-4f56-a9da-49c7532f4386'}
# Metadata dict for member number  153
# {'net': 'AZ', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '0e209acd-0e6b-4124-9abd-7856719705e4'}
# Metadata dict for member number  154
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '9edf7433-e540-4b89-a5f2-0462b41928ec'}
# Metadata dict for member number  155
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.769539, 'endtime': 1356947180.7445388, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'cc569fd7-8883-4b4a-b027-79bc10e2c39a'}
# Metadata dict for member number  156
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'bee1ef5a-47f9-4531-bdfb-971ef86959a6'}
# Metadata dict for member number  157
# {'net': 'AZ', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '371b5ad5-3b05-406d-b193-6477a0ebc8c3'}
# Metadata dict for member number  158
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'c08100f4-9a72-43c4-9ad7-3fe8e9f2b48d'}
# Metadata dict for member number  159
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '26533fcb-b2b6-43cb-a78c-1a44afd7e7ad'}
# Metadata dict for member number  160
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'e7b975c2-c4ce-4c59-b0b3-ee4a6ae46e9e'}
# Metadata dict for member number  161
# {'net': 'AZ', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': '75c9c978-e073-442a-90e5-daacbe9f6596'}
# Metadata dict for member number  162
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7685041, 'endtime': 1356947180.7485042, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '810747c2-ffde-4e0b-9894-34f9a64669c3'}
# Metadata dict for member number  163
# {'net': '7D', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.752255, 'endtime': 1356947180.732255, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '05b01d51-1937-41c2-a91e-66d31d37969e'}
# Metadata dict for member number  164
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '2ca09be1-ae30-4879-97c0-b0a6c6fe20d5'}
# Metadata dict for member number  165
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '043c9c9a-fa10-437b-92a4-5f076ca6f07c'}
# Metadata dict for member number  166
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '2983a956-1765-4698-bbe2-02b010ae4e2c'}
# Metadata dict for member number  167
# {'net': 'AZ', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7445, 'endtime': 1356947180.7445, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144001, 'calib': 1.0, 'seed_file_id': 'b0c5c571-5e50-4190-9bb4-70defaee5014'}
# Metadata dict for member number  168
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.7503092, 'endtime': 1356947180.7503092, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180001, 'calib': 1.0, 'seed_file_id': '93e0103d-8ff0-4484-9aaf-bc4b44d588d3'}
# Metadata dict for member number  169
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.769536, 'endtime': 1356947180.7445362, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'e47b8272-26bc-4d1d-96ae-342c2d043346'}
# Metadata dict for member number  170
# {'net': 'AZ', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7505002, 'endtime': 1356947180.7254999, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'e8e103cc-68e4-437b-b2a1-980e68e24b68'}
# Metadata dict for member number  171
# {'net': '7D', 'sta': 'BH2', 'chan': '', 'starttime': 1356943580.766142, 'endtime': 1356947180.746142, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'e3466f6b-3248-4c03-935e-fc2d1b4b1292'}
# Metadata dict for member number  172
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '37713d64-3cbe-4cbd-af07-e0038ad58d7a'}
# Metadata dict for member number  173
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.769536, 'endtime': 1356947180.7445362, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'e06a35b2-8824-45ad-9da5-eaccd062071f'}
# Metadata dict for member number  174
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'e3a831da-ef94-4a44-ba80-a097d30df812'}
# Metadata dict for member number  175
# {'net': 'BK', 'sta': 'BHE', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '50b94cae-9cf8-4bfe-9f38-531bf5a49ec6'}
# Metadata dict for member number  176
# {'net': 'BK', 'sta': 'BHN', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '92d85239-7e1a-4271-8901-8b4eb0cb2681'}
# Metadata dict for member number  177
# {'net': 'CC', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '879e39fb-3d78-4b4f-a486-6c071cb5930e'}
# Metadata dict for member number  178
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.769665, 'endtime': 1356947180.729665, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 179999, 'calib': 1.0, 'seed_file_id': 'a64f99a9-1675-43a1-9f47-57b6a459b0ad'}
# Metadata dict for member number  179
# {'net': '7D', 'sta': 'BH1', 'chan': '', 'starttime': 1356943580.754994, 'endtime': 1356947180.734994, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '731ae6c0-26ad-4926-8869-454cc8a1cf81'}
# Metadata dict for member number  180
# {'net': 'BK', 'sta': 'BHZ', 'chan': '00', 'starttime': 1356943580.7695382, 'endtime': 1356947180.744538, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'dad7f88f-a471-4878-bf49-a3adc8ffcdce'}
# Metadata dict for member number  181
# ...
# Metadata dict for member number  3748
# {'net': 'ZL', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7649999, 'endtime': 1356947180.74, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'bdaf1da1-98e0-4011-8dd5-99842e3b6ca8'}
# Metadata dict for member number  3749
# {'net': 'Z9', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '6f2e733e-082f-4e39-93c0-e6afd2035cf5'}
# Metadata dict for member number  3750
# {'net': 'Z9', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '6a506f29-d785-4823-be56-27b5002c6aa5'}
# Metadata dict for member number  3751
# {'net': 'Z9', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '2cf45056-b6b4-4977-acb6-a716a6ff18a4'}
# Metadata dict for member number  3752
# {'net': 'Z9', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '8e94c040-fc59-4839-8930-d2e2f590735b'}
# Metadata dict for member number  3753
# {'net': 'Z9', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '6640de6f-7eca-4841-a930-6dd8fbaa761f'}
# Metadata dict for member number  3754
# {'net': 'Z9', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'a59e5826-420a-4007-9936-6d36e5aa6a7b'}
# Metadata dict for member number  3755
# {'net': 'Z9', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '4681929b-1fa8-45cf-9af0-1a5f68a40d0d'}
# Metadata dict for member number  3756
# {'net': 'Z9', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'b3db9e90-3fa5-4539-b7aa-5671670864fa'}
# Metadata dict for member number  3757
# {'net': 'Z9', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'c75582c0-71c1-474a-8923-6b249a2f39eb'}
# Metadata dict for member number  3758
# {'net': 'Z9', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'd307b855-34c7-4f20-b0fe-3d37fe6de2a0'}
# Metadata dict for member number  3759
# {'net': 'Z9', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'a4dc83cc-fc08-4b27-8e88-0d5bf54bd85b'}
# Metadata dict for member number  3760
# {'net': 'Z9', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'afef182a-eed6-4744-92d7-09bf31002fe7'}
# Metadata dict for member number  3761
# {'net': 'Z9', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '89b850d6-617c-4a55-9419-f47f9eee0c5a'}
# Metadata dict for member number  3762
# {'net': 'Z9', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '79dcc93b-8fa3-4981-8d10-c9e13e780002'}
# Metadata dict for member number  3763
# {'net': 'Z9', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '7b94dd1f-804b-4610-aea1-4f642d924f16'}
# Metadata dict for member number  3764
# {'net': 'Z9', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '4e46a64e-704c-49f5-a9c4-e8a7802d576e'}
# Metadata dict for member number  3765
# {'net': 'Z9', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '38cae02a-bcd7-4a8f-9a60-cb92a24a9b96'}
# Metadata dict for member number  3766
# {'net': 'Z9', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '0d56e9e8-d294-4872-99f6-72b11779806d'}
# Metadata dict for member number  3767
# {'net': 'Z9', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '50b22150-0bce-4af6-b2da-2df741b425b7'}
# Metadata dict for member number  3768
# {'net': 'Z9', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '8c9e6a8e-e86f-4f81-bf9e-1e0d77b381bc'}
# Metadata dict for member number  3769
# {'net': 'Z9', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '7d96290d-3a5e-48bd-8f13-0f856d1005e6'}
# Metadata dict for member number  3770
# {'net': 'Z9', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'c0850038-8455-464f-8b91-892181a9096d'}
# Metadata dict for member number  3771
# {'net': 'Z9', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '246e130c-fa4f-4c5d-84c5-ee23bd0e603c'}
# Metadata dict for member number  3772
# {'net': 'Z9', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '18ee3634-d547-4a31-b2f0-33e60a51c29e'}
# Metadata dict for member number  3773
# {'net': 'Z9', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'b68667bd-1300-45fd-8de1-9d68e2f07efd'}
# Metadata dict for member number  3774
# {'net': 'Z9', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '6ce70010-f3d3-4147-9eb2-c70557c85b90'}
# Metadata dict for member number  3775
# {'net': 'Z9', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '71b971e4-e259-488c-a783-58cae19bfd23'}
# Metadata dict for member number  3776
# {'net': 'Z9', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '4565f0d8-a26b-41a5-ab75-b20b8d85ecab'}
# Metadata dict for member number  3777
# {'net': 'Z9', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '1aa2d933-9802-4412-8a35-c3266c1f9721'}
# Metadata dict for member number  3778
# {'net': 'Z9', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '8487b151-627c-4453-8f81-f8cec59b87a8'}
# Metadata dict for member number  3779
# {'net': 'Z9', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '838d8af5-c384-4a48-837e-fe0b143b921c'}
# Metadata dict for member number  3780
# {'net': 'Z9', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'ef5058ac-f5ad-4f6c-8079-5b4da37053c2'}
# Metadata dict for member number  3781
# {'net': 'Z9', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '5593c356-2e81-44b9-8eb1-4bed8ca05eaf'}
# Metadata dict for member number  3782
# {'net': 'ZL', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.7350001, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '0d48c45f-caa2-46e7-b5e3-1ee05de6a5b3'}
# Metadata dict for member number  3783
# {'net': 'Z9', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '074682c2-1792-4711-9735-ebcb82c7521e'}
# Metadata dict for member number  3784
# {'net': 'ZL', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.7350001, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '2b71eb27-4d01-4860-9a47-f7683babcf42'}
# Metadata dict for member number  3785
# {'net': 'Z9', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '29f744e8-b817-477a-aa7b-26d0d65d4555'}
# Metadata dict for member number  3786
# {'net': 'Z9', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '48502f49-572a-4642-9dd5-348070672525'}
# Metadata dict for member number  3787
# {'net': 'ZL', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.7350001, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '94bf0b7e-ef4d-4ea4-9e7f-dce3ae4fb7bb'}
# Metadata dict for member number  3788
# {'net': 'Z9', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'e4d84e26-b533-435e-9882-e7d1036d2a71'}
# Metadata dict for member number  3789
# {'net': 'Z9', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '46fb1fe1-9941-4b8e-ac52-c48b870d549d'}
# Metadata dict for member number  3790
# {'net': 'ZL', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7649999, 'endtime': 1356947180.74, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '8159debd-ac34-4e96-82b2-ef6cccb50f70'}
# Metadata dict for member number  3791
# {'net': 'Z9', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '8280e162-447c-4d56-8781-c96ba427c8d6'}
# Metadata dict for member number  3792
# {'net': 'Z9', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '04ad908c-fe05-4120-9a22-b3da21852fe8'}
# Metadata dict for member number  3793
# {'net': 'ZL', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7649999, 'endtime': 1356947180.74, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '344899ac-08d0-4215-83d2-48f8bbbbc0e0'}
# Metadata dict for member number  3794
# {'net': 'Z9', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '1fb66210-6aa1-4a2e-b336-36d58f66aa66'}
# Metadata dict for member number  3795
# {'net': 'ZL', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7649999, 'endtime': 1356947180.74, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'dc572622-2f73-498e-8097-259424823849'}
# Metadata dict for member number  3796
# {'net': 'ZL', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7649999, 'endtime': 1356947180.74, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'b677770e-6bce-4257-9bb8-e49bec243fe1'}
# Metadata dict for member number  3797
# {'net': 'ZL', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7649999, 'endtime': 1356947180.74, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '20d674c7-c516-4c5d-ae63-0cbeea9db04d'}
# Metadata dict for member number  3798
# {'net': 'Z9', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '1b71bc26-6f64-4d73-bca2-6bfddab77df5'}
# Metadata dict for member number  3799
# {'net': 'ZL', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7649999, 'endtime': 1356947180.74, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '02d5e5f1-e91f-4fef-9648-22272f62ab35'}
# Metadata dict for member number  3800
# {'net': 'ZL', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7649999, 'endtime': 1356947180.74, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': 'b15afeb9-b9d5-4def-8ff7-7c574f384abe'}
# Metadata dict for member number  3801
# {'net': 'Z9', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': '33a5597e-ca18-4c33-8de3-29ecb9b74beb'}
# Metadata dict for member number  3802
# {'net': 'ZL', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7649999, 'endtime': 1356947180.74, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '0697f37f-f979-48fc-b66f-455297a89cbc'}
# Metadata dict for member number  3803
# {'net': 'Z9', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'a3480390-1ca5-4be7-a81f-899601e85f82'}
# Metadata dict for member number  3804
# {'net': 'Z9', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.76, 'endtime': 1356947180.74, 'sampling_rate': 50.0, 'delta': 0.02, 'npts': 180000, 'calib': 1.0, 'seed_file_id': 'e55e6c4a-6015-4b1b-ab14-5957306bcaf2'}
# Metadata dict for member number  3805
# {'net': 'ZL', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7649999, 'endtime': 1356947180.74, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '95e8f99e-cefe-49df-b104-fb0fbbc60886'}
# Metadata dict for member number  3806
# {'net': 'ZL', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7649999, 'endtime': 1356947180.74, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '219fa93e-d2a5-49d4-8097-2c8cbe69d8ab'}
# Metadata dict for member number  3807
# {'net': 'ZL', 'sta': 'BHN', 'chan': '', 'starttime': 1356943580.7649999, 'endtime': 1356947180.74, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '8756e256-c1ca-4d0e-bc9f-bf0e9fa98a58'}
# Metadata dict for member number  3808
# {'net': 'ZL', 'sta': 'BHZ', 'chan': '', 'starttime': 1356943580.7649999, 'endtime': 1356947180.74, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '696c3088-e23c-4e08-b336-cd0128da7c55'}
# Metadata dict for member number  3809
# {'net': 'ZL', 'sta': 'BHE', 'chan': '', 'starttime': 1356943580.7649999, 'endtime': 1356947180.74, 'sampling_rate': 40.0, 'delta': 0.025, 'npts': 144000, 'calib': 1.0, 'seed_file_id': '1f665954-59ac-477c-a655-5ec79b57130c'}

# %% [markdown]
# Here are some key points about this rather large output:
# - We write the documents that define this index in a collection called "seed_data.ensemble".   Note the "." character is treated as part of the name and is not significant.  i.e. the collection name is literally "seed_data.ensemble".  It is, however, common practice to use names like this in MongoDB to group collections having some kind of conceptual relationship.  In this case, it is one of several possible collections that could be created from seed data.  Other raw data types are expected to appear as collections with similar names (e.g. segy_data, ph5_data, etc.)
# - Readers familiar with CSS3.0 and/or Antelope may find it useful think of seed_data.ensemble as comparable to the css3.0 table called wfdisc.   The data are not loaded into MongoDB's work area.  seed_data.ensemble documents are only an index defining data holdings in files.  The approach here is strictly file based, but could be completely different.  e.g. instead of a file with properties defined by dir, dfile, and format we could define a web services URL.
# - Under the hood here we use obspy's miniseed reader.
# - This collection uses what MongoDB calls subdocuments.  There is one subdocument for each channel of data in this event gather.  The subdocuments are a list of dict containers derived from the obspy stats array for each Trace object obspy reader creates in cracking the miniseed file.  The list is indexed by the key "members".
# - Each file also generates a set of metadata we tag in the print script above as "Ensemble Metadata".  We do that because the will literally be used for that purpose in the MsPASS Ensemble container later, but more importantly because it fits a generic concept.  That is, an "Ensemble" in MsPASS means a group of atomic objects that have some generic relationship.  In this case, the relationship is there are all connected to a single earthquake. The next thing we will need to do is link the ensemble to the source with with it is associated.  We will do that with pure database manipulations of small tables for efficiency.
# - The member Metadata contain an attribute with the key seed_file_id.   That is an internally generated unique key that was created by this function to provide a unique tag for each original seed file TimeSeries.   For processing using the object-level history functions of MsPASS that tag is important to define what we call an ORIGIN for a processing history chain.

# %% [markdown]
# ## 6. Source Association
# The general problem of associating a set of waveforms to a metadata describing the source of the transient signals to be analyzed can be a thorny one.  For this tutorial we can use a very simple algorithm, however, due to the specific way I downloaded these data with obspy.   That is, all the event files were referenced to a be similar to seismic reflection shot gathers such that the first data sample for all channels is approximately the estimated origin time of the earthquake.  You can see that in the dump above because all the channels have a start time within a few 10s of ms of epoch time 1356943580.7.  Hence, the algorithm we will run below just looks for events in the source collection for which the origin time is within a tolerance of the average start time of the ensemble members (stored in the ensemble metadata with the key starttime).

# %%
from mspasspy.preprocessing.seed.ensembles import link_source_collection
link_source_collection(db)

# %% [markdown]
# Now that little function associated source data downloaded with web services by obspy.   Those events are not from the same source as the events ANF used to when they picked P waves from the TA data stream.   Further, a large fraction of the station in our download did not come on the real time data stream to ANF so they would not have picks in the css3.0 arrival data.  Recall our objective in this tutorial is to extract only waveforms that have a pick made by ANF.
#
# Our first step to do that is we need to also load the source locations in the ascii file we used to generate the arrival collection into our source collection.  We first run this small function to get the unique sources found in the (large) ascii table we created earlier.   Run the next cell and we will view the output below:

# %%
from mspasspy.preprocessing.css30.dbarrival import extract_unique_css30_sources
events=extract_unique_css30_sources('data/raw_data_tutorial/catalog_data/usarray_tele2012.txt')
print('Found ',len(events),' unique sources from 2012 css3.0 data file')
# print just the first 10 events
n=0
for k in events:
    print('evid=',k,' contents:  ',events[k])
    n+=1
    if(n>=10):
        break
# Out:
# Found  906  unique sources from 2012 css3.0 data file
# evid= 206397  contents:   {'evid': 206397, 'latitude': 12.011, 'longitude': 143.505, 'depth': 10.0, 'time': 1325377805.03}
# evid= 206398  contents:   {'evid': 206398, 'latitude': -11.372, 'longitude': 166.224, 'depth': 66.7, 'time': 1325379008.01}
# evid= 206401  contents:   {'evid': 206401, 'latitude': 31.416, 'longitude': 138.155, 'depth': 348.5, 'time': 1325395674.5}
# evid= 206408  contents:   {'evid': 206408, 'latitude': 12.018, 'longitude': 143.607, 'depth': 6.5, 'time': 1325432652.07}
# evid= 206439  contents:   {'evid': 206439, 'latitude': -14.748, 'longitude': 167.44, 'depth': 221.6, 'time': 1325652454.05}
# evid= 206454  contents:   {'evid': 206454, 'latitude': -10.67, 'longitude': 166.375, 'depth': 75.9, 'time': 1325703417.29}
# evid= 206458  contents:   {'evid': 206458, 'latitude': -45.97, 'longitude': -76.014, 'depth': 10.0, 'time': 1325724873.21}
# evid= 206459  contents:   {'evid': 206459, 'latitude': -17.691, 'longitude': -173.543, 'depth': 35.0, 'time': 1325726020.43}
# evid= 206464  contents:   {'evid': 206464, 'latitude': 18.325, 'longitude': -70.361, 'depth': 39.8, 'time': 1325756132.1}
# evid= 206500  contents:   {'evid': 206500, 'latitude': -6.341, 'longitude': -107.312, 'depth': 10.0, 'time': 1325876079.31}

# %% [markdown]
# As the name of that function implies what it did was scan that large text file keeping all locations associated with unique evid values.  That is a potentially dangerous test if used on a poorly constructed css3.0 database, but the ANF databases are clean so we don't have an issue.  I state that because if anyone tries to extend this tutorial don't do so without making sure the evid values are unique with and between any file(s) you try to process this way.
#
# We now use the function below to load this set of locations with the evid attributes into the source collection.  Note, however, that the number of attributes we store with these sources is much smaller than those loaded form the quakeml files.

# %%
from mspasspy.preprocessing.css30.dbarrival import load_css30_sources
n=load_css30_sources(db,events)
print('loaded ',n,' new documents into source collection')
# Out:
# loaded  906  new documents into source collection

# %% [markdown]
# The set of events we just loaded can be distinguished from those created from the quakeml file by the existence of the attribute "evid" in the documents we just saved;  the quakeml generated documents do not contain an evid attribute.  This short script demonstrates that using some low level MongoDB queries:

# %%
dbsource=db.source
n=dbsource.count_documents({})
print('Source collection currently has ',n,' total source documents')
query={'evid': {'$exists' : True}}
n=dbsource.count_documents(query)
print(n,' of the documents have evid set')
# Out:
# Source collection currently has  1867  total source documents
# 906  of the documents have evid set

# %% [markdown]
# Because evid values appear in arrival documents too, we will exploit that relation to associate arrivals with waveforms.  First, because evids are potentially dangerous we will run the following small function to post the unique id source_id to all arrival documents.

# %%
from mspasspy.preprocessing.css30.dbarrival import set_source_id_from_evid
result=set_source_id_from_evid(db)
print('Number of arrival documents processed=',result[0])
print('Number of arrival documents updated=',result[1])
print('Number arrivals in set that did not match keyed by evid =',result[3])
# Out:
# Number of arrival documents processed= 353482
# Number of arrival documents updated= 353482
# Number arrivals in set that did not match keyed by evid = {}

# %% [markdown]
# # 7. Defining Indexes
# A MongoDB database is heavily dependent upon a well defined index to improve preformance on large collections.  In this tutorial the only collection that will create problems for us is the arrival collection.   We saw that earlier when we updated every document in the collection. Indices are best built on static collections as they slow writes.  We didn't do this step earlier because we were building the arrival collection and doing as many writes as reads. For the next step we will only be reading form arrival (a lot) so we need to build an index.  Experience shows this will speed processing by 1 to 3 orders of magnitude.
#
# We are going to build the index with these three keys to support the queries we will be running on arrival below:   source_id, net, and sta.  The MongoDB syntax to build an index is a bit weird but this serves as a good example:

# %%
db.arrival.create_index(
[
    ('source_id',1),
    ('net', 1),
    ('sta',1)
])
# Out:
# 'source_id_1_net_1_sta_1'

# %% [markdown]
# Noting two things about this:
# 1.  The pymongo api uses a different data structure from the mongo shell.  This warning is important if you do an internet search for building an index in MongoDB - build on pymongo examples as mongo shell commands require a translation.
# 2.  The magic 1 is a cryptic shorthand for the more verbose "ASCENDING" tag you will find in some sources.  You can also use "DESCENDING" or -1 to reverse the search order for the index.   Reversing the order of the index search has no merit here, but you can imagine examples where it would matter.

# %% [markdown]
# # 8.  Ensemble Processing
# ## 8.1. Cross-referencing source data
# We previously wrote an index for common source gather files we downloaded in a collection we called seed_data.ensembles.  The following function takes the time range of that data and associates a document in the source collection with the file writing the source_id to the ensemble's index document.  We will need that in the reduction workflow that concludes this tutorial to link arrivals to the waveform data.
#
# This function also has to deal with another not so small detail.  We have duplicate source locations for most of the events in the source collection.  The reason is we loaded the catalog obspy downloaded and the one ANF used in measuring the picks in the arrival collection.  We want to prefer the ones form ANF as they are the ones we can easily link to arrival.

# %%
from mspasspy.preprocessing.seed.ensembles import link_source_collection
# this function is like subroutine and returns nothing
link_source_collection(db,prefer_evid=True)
# Out:
# link_source_collection(WARNING): unique match for source at time= 2012-12-31T08:46:20.750001Z  does not have evid set but function was called with prefer_evid true
# link_source_collection(WARNING): unique match for source at time= 2012-12-31T01:45:01.500000Z  does not have evid set but function was called with prefer_evid true
# link_source_collection(WARNING): unique match for source at time= 2012-12-29T21:47:28.174900Z  does not have evid set but function was called with prefer_evid true
# link_source_collection(WARNING): unique match for source at time= 2012-12-29T21:37:02.000000Z  does not have evid set but function was called with prefer_evid true
# link_source_collection(WARNING): unique match for source at time= 2012-12-29T07:19:32.750001Z  does not have evid set but function was called with prefer_evid true
# link_source_collection(WARNING): unique match for source at time= 2012-12-28T22:17:11.245000Z  does not have evid set but function was called with prefer_evid true
# link_source_collection(WARNING): unique match for source at time= 2012-12-28T14:27:07.145000Z  does not have evid set but function was called with prefer_evid true
# link_source_collection(WARNING): unique match for source at time= 2012-12-27T06:57:08.550000Z  does not have evid set but function was called with prefer_evid true
# link_source_collection(WARNING): unique match for source at time= 2012-12-26T23:49:28.745000Z  does not have evid set but function was called with prefer_evid true
# link_source_collection(WARNING): unique match for source at time= 2012-12-26T22:47:14.945000Z  does not have evid set but function was called with prefer_evid true
# link_source_collection(WARNING): unique match for source at time= 2012-12-23T13:33:43.274900Z  does not have evid set but function was called with prefer_evid true
# link_source_collection(WARNING): unique match for source at time= 2012-12-22T16:02:43.724996Z  does not have evid set but function was called with prefer_evid true
# link_source_collection(WARNING): unique match for source at time= 2012-12-21T08:07:19.050000Z  does not have evid set but function was called with prefer_evid true

# %% [markdown]
# ## 8.2 Final Data Assembly Workflow
# First, we need to load a number of new modules that will be used in the workflow below:

# %%
from mspasspy.util.Undertaker import Undertaker
from mspasspy.algorithms import signals
from mspasspy.ccore.seismic import (TimeWindow,TimeSeries,TimeSeriesEnsemble)
from mspasspy.algorithms.window import WindowData
from mspasspy.algorithms.bundle import bundle_seed_data
from mspasspy.preprocessing.seed.ensembles import (load_one_ensemble,
                                                   load_channel_data,
                                                   load_site_data,
                                                   load_arrivals_by_id,
                                                   erase_seed_metadata)
import time

# %% [markdown]
# We now run our load preprocessor.  It has these steps it applies to each ensemble in our test data set:
#
# 1. Loads the seed data into memory using the wf_miniseed collection as an index.
# 2. Associates arrivals with the waveforms now loaded
# 3. Kills data that do not have an arrival association and destroys them (the cremate method of Undertaker).
# 4. Uses obspy's detrend operator on each signal
# 5. Time shifts each seismogram to put time 0 at the arrival time
# 6. Window each signal from 300 s before to 400 s after the arrival time.
# 7. Loads data from the channel collection (notably hang and vang needed to define orientation)
# 8. Runs bundle_seed_data to create Seismogram objects from groups of 3 TimeSeries with common net,sta,loc values.
# 9. Saves the results to MongoDB in gridfs storage.

# %%
stedronsky=Undertaker(db)
dbwf=db.wf_miniseed
cursor=dbwf.find({},no_cursor_timeout = True)
n=0
for doc in cursor:
    print('working on enemble number ',n)
    if not 'evid' in doc:
        print('Ensemble number ',n,' does not have an evid set - skipped')
        n+=1
        continue
    ens=load_one_ensemble(doc,apply_calib=True,
                  ensemble_mdkeys=['source_id','evid','starttime','endtime'])
    load_site_data(db,ens)
    nlive=load_arrivals_by_id(db,ens)
    n+=1
    t0=time.time()
    d_cleaned=stedronsky.cremate(ens)
    t1=time.time()
    print('Time to handle dead data=',t1-t0)
    t0=time.time()
    signals.detrend(d_cleaned,'demean')
    t1=time.time()
    print('Time to apply detrend operator=',t1-t0)
    t0=time.time()
    twin=TimeWindow(-300.0,400.0)
    for i in range(len(d_cleaned.member)):
        d=TimeSeries(d_cleaned.member[i])
        t=d['arrival_time']
        d.ator(t)
        d=WindowData(d,twin)
        d_cleaned.member[i]=d
    t1=time.time()
    print('Time to window cleaned ensemble=',t1-t0)
    t0=time.time()
    signals.filter(d_cleaned,"bandpass",corners=2,freqmin=0.01,freqmax=2.0)
    t1=time.time()
    print('Time to filter cleaned ensemble=',t1-t0)
    t0=time.time()
    load_channel_data(db,d_cleaned)
    t1=time.time()
    print('Time to build cross reference to channel=',t1-t0)
    t0=time.time()
    ens3c=bundle_seed_data(d_cleaned)
    t1=time.time()
    print('Time to run bundle algorithm=',t1-t0)
    print("Number of Seismograms after bundle_seed_data=",len(ens3c.member))
    #print_dead_logs(ens3c)
    erase_seed_metadata(d_cleaned)
    # This is a workaround for a bug that currently exists in
    # save_ensemble_data in handling history database
    # Should be able to eventually delete this
    for d in ens3c.member:
        d.clear_history()
    t0=time.time()
    db.save_ensemble_data(ens3c,'gridfs')
    t1=time.time()
    print("Time to save data to MongoDB=",t1-t0)
    del ens
    n+=1
# Out:
# working on enemble number  0
# Ensemble number  0  does not have an evid set - skipped
# working on enemble number  1
# Ensemble number  1  does not have an evid set - skipped
# working on enemble number  2
# Time to handle dead data= 0.10956454277038574
# Time to apply detrend operator= 40.367491245269775
# Time to window cleaned ensemble= 0.16676712036132812
# Time to filter cleaned ensemble= 8.166987895965576
# Time to build cross reference to channel= 2.6701512336730957
# Time to run bundle algorithm= 0.3094930648803711
# Number of Seismograms after bundle_seed_data= 190
# Time to save data to MongoDB= 0.20568346977233887
# working on enemble number  4
# Time to handle dead data= 0.037932395935058594
# Time to apply detrend operator= 9.896740913391113
# Time to window cleaned ensemble= 0.03679490089416504
# Time to filter cleaned ensemble= 2.0053420066833496
# Time to build cross reference to channel= 0.6282927989959717
# Time to run bundle algorithm= 0.06404304504394531
# Number of Seismograms after bundle_seed_data= 46
# Time to save data to MongoDB= 0.047939300537109375
# working on enemble number  6
# Ensemble number  6  does not have an evid set - skipped
# working on enemble number  7
# Ensemble number  7  does not have an evid set - skipped
# working on enemble number  8
# Time to handle dead data= 0.18467378616333008
# Time to apply detrend operator= 70.36259722709656
# Time to window cleaned ensemble= 0.26117730140686035
# Time to filter cleaned ensemble= 14.576944351196289
# Time to build cross reference to channel= 4.838292360305786
# Time to run bundle algorithm= 0.6778957843780518
# Number of Seismograms after bundle_seed_data= 329
# Time to save data to MongoDB= 0.6625761985778809
# working on enemble number  10
# Ensemble number  10  does not have an evid set - skipped
# working on enemble number  11
# Ensemble number  11  does not have an evid set - skipped
# working on enemble number  12
# Ensemble number  12  does not have an evid set - skipped
# working on enemble number  13
# Time to handle dead data= 0.2831699848175049
# Time to apply detrend operator= 107.97234439849854
# Time to window cleaned ensemble= 0.399014949798584
# Time to filter cleaned ensemble= 21.95903778076172
# Time to build cross reference to channel= 7.119220018386841
# Time to run bundle algorithm= 0.9646563529968262
# Number of Seismograms after bundle_seed_data= 500
# Time to save data to MongoDB= 0.3404080867767334
# working on enemble number  15
# Time to handle dead data= 0.03399157524108887
# Time to apply detrend operator= 6.130080938339233
# Time to window cleaned ensemble= 0.023614883422851562
# Time to filter cleaned ensemble= 1.23893404006958
# Time to build cross reference to channel= 0.4453427791595459
# Time to run bundle algorithm= 0.03890419006347656
# Number of Seismograms after bundle_seed_data= 29
# Time to save data to MongoDB= 0.023342370986938477
# working on enemble number  17
# Ensemble number  17  does not have an evid set - skipped
# working on enemble number  18
# Time to handle dead data= 0.22115063667297363
# Time to apply detrend operator= 86.24960827827454
# Time to window cleaned ensemble= 0.3169846534729004
# Time to filter cleaned ensemble= 17.680928945541382
# Time to build cross reference to channel= 5.625434875488281
# Time to run bundle algorithm= 0.7062826156616211
# Number of Seismograms after bundle_seed_data= 400
# Time to save data to MongoDB= 0.2687702178955078
# working on enemble number  20
# Time to handle dead data= 0.17645549774169922
# Time to apply detrend operator= 65.70081114768982
# Time to window cleaned ensemble= 0.24080348014831543
# Time to filter cleaned ensemble= 13.303651571273804
# Time to build cross reference to channel= 4.267780065536499
# Time to run bundle algorithm= 0.5510716438293457
# Number of Seismograms after bundle_seed_data= 304
# Time to save data to MongoDB= 0.20673203468322754
# working on enemble number  22
# Ensemble number  22  does not have an evid set - skipped
# working on enemble number  23
# Ensemble number  23  does not have an evid set - skipped
# working on enemble number  24
# Time to handle dead data= 0.0470278263092041
# Time to apply detrend operator= 13.183772802352905
# Time to window cleaned ensemble= 0.04903984069824219
# Time to filter cleaned ensemble= 2.6477746963500977
# Time to build cross reference to channel= 0.8799021244049072
# Time to run bundle algorithm= 0.09473609924316406
# Number of Seismograms after bundle_seed_data= 62
# Time to save data to MongoDB= 0.05203580856323242
# working on enemble number  26
# Time to handle dead data= 0.22217583656311035
# Time to apply detrend operator= 83.91864442825317
# Time to window cleaned ensemble= 0.3149559497833252
# Time to filter cleaned ensemble= 17.054719924926758
# Time to build cross reference to channel= 5.42427921295166
# Time to run bundle algorithm= 0.7248449325561523
# Number of Seismograms after bundle_seed_data= 389
# Time to save data to MongoDB= 0.273817777633667
# working on enemble number  28
# Time to handle dead data= 0.13989019393920898
# Time to apply detrend operator= 50.45906329154968
# Time to window cleaned ensemble= 0.189422607421875
# Time to filter cleaned ensemble= 10.363325357437134
# Time to build cross reference to channel= 3.389432430267334
# Time to run bundle algorithm= 0.4339611530303955
# Number of Seismograms after bundle_seed_data= 235
# Time to save data to MongoDB= 0.15652990341186523
# working on enemble number  30
# Time to handle dead data= 0.20803618431091309
# Time to apply detrend operator= 78.4597692489624
# Time to window cleaned ensemble= 0.28624868392944336
# Time to filter cleaned ensemble= 16.148847818374634
# Time to build cross reference to channel= 5.114699840545654
# Time to run bundle algorithm= 0.74690842628479
# Number of Seismograms after bundle_seed_data= 363
# Time to save data to MongoDB= 0.2558295726776123
# working on enemble number  32
# Time to handle dead data= 0.1895608901977539
# Time to apply detrend operator= 69.78387379646301
# Time to window cleaned ensemble= 0.25932836532592773
# Time to filter cleaned ensemble= 14.210691690444946
# Time to build cross reference to channel= 4.5730321407318115
# Time to run bundle algorithm= 0.6219203472137451
# Number of Seismograms after bundle_seed_data= 326
# Time to save data to MongoDB= 0.27637314796447754
# working on enemble number  34
# Ensemble number  34  does not have an evid set - skipped
# working on enemble number  35
# Time to handle dead data= 0.17670488357543945
# Time to apply detrend operator= 66.66598510742188
# Time to window cleaned ensemble= 0.2481074333190918
# Time to filter cleaned ensemble= 13.583601713180542
# Time to build cross reference to channel= 4.2740819454193115
# Time to run bundle algorithm= 0.5764093399047852
# Number of Seismograms after bundle_seed_data= 305
# Time to save data to MongoDB= 0.20552325248718262
# working on enemble number  37
# Time to handle dead data= 0.046616315841674805
# Time to apply detrend operator= 12.770059585571289
# Time to window cleaned ensemble= 0.04847216606140137
# Time to filter cleaned ensemble= 2.580209255218506
# Time to build cross reference to channel= 0.8231894969940186
# Time to run bundle algorithm= 0.09206175804138184
# Number of Seismograms after bundle_seed_data= 59
# Time to save data to MongoDB= 0.04470539093017578
# working on enemble number  39
# Ensemble number  39  does not have an evid set - skipped
# working on enemble number  40
# Time to handle dead data= 0.2326045036315918
# Time to apply detrend operator= 90.16708588600159
# Time to window cleaned ensemble= 0.32558655738830566
# Time to filter cleaned ensemble= 18.421093940734863
# Time to build cross reference to channel= 5.840509414672852
# Time to run bundle algorithm= 0.7694094181060791
# Number of Seismograms after bundle_seed_data= 416
# Time to save data to MongoDB= 0.25582051277160645
# working on enemble number  42
# Ensemble number  42  does not have an evid set - skipped
