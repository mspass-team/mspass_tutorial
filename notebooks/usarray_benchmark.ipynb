# %% [markdown]
# # Benchmark Data Assembly
# ## *Gary Pavlis - started March 30, 2021*
# This notebook documents how the benchmark data was assembled from the downloaded usarray data set.  It build on the raw_data_tutorial combined with a more complete database assembled previously, exported as json, and sent to TACC.   This notebook will be run on a mac pro called quakes.geology.indiana.edu testing the docker container image.

# %% [markdown]
# ## Importing metadata collections
# As noted I previously the first step is to import the json files created with the export process.  To do that I had to first start the docker all-in-one container.   An oddity I think we need to fix is the name of the running container seems to be assigned automatically somehow.  My instance on quakes was called "infallible_thompson.   To get a shell in the container I did this:
# ```
# docker exec -it infallible_thompson bash
# cd /home
# ```
# noting I had launched docker from /Volumes/data/usarray/db.  postscript:  After a call to Ian it seems the random naming was intentional for this use.  The all in one procedure is intended for running tutorials where knowing the container name would be baggage.
#
# Importing such data is well documented in the mongodb documentation.   I followed this source https://docs.mongodb.com/guides/server/import/ to generate the following command lines to import the four exported collections.

# %% [markdown]
# ```
# # top level directory on quakes is - run this in a shell from this directory /scratch/06058/iwang/mspass/workdir
# mongoimport --host $HOSTNAME --port "27017" --db usarraytest --collection arrival --file json_import/arrival.json
# mongoimport --host $HOSTNAME --port "27017" --db usarraytest --collection channel --file json_import/channel.json
# mongoimport --host $HOSTNAME --port "27017" --db usarraytest --collection site --file json_import/site.json
# mongoimport --host $HOSTNAME --port "27017" --db usarraytest --collection source --file json_import/source.json
# ```

# %% [markdown]
# # Indexing waveform data
# We now run a variant of section 5 of the raw data tutorial with the same title as above.  The variant is that here we define a year at the top and assume a specific file structure that is valid for the way I assembled these data.  Some tweeking may be needed when this notebook is transferred to TACC.
#
# In running this I uncovered an important issue to beware of.  That is, it really matters what directory is mapped into the container.   I (incorrectly) created a seperate db directory and had docker mount that as /home.  Problem I created was the mount point is inside the file system tree.  I had the waveform data in (to use unix shell syntax) the directory ../wf.  The problem is ".." is not visible as I mounted it.  Symbolic links wouldn't work either for the same reason.  I solved it for this test by creating a wf/2012 directory and creating hard links form ../wf/2012/*.mseed to create aliases in the local wf/2012.  Works as a patch, but not the right solution.

# %%
import fnmatch
import os
topdirectory= os.environ.get('SCRATCH') + '/mspass/workdir/wf'   # appropriate for container if wf contains the waveform data
year='2012'   # Change this for a different year
dir=topdirectory+'/'+year
filelist=fnmatch.filter(os.listdir(dir),'*.mseed')
print(filelist)
# Out:
# ['event756.mseed', 'event548.mseed', 'event394.mseed', 'event714.mseed', 'event305.mseed', 'event936.mseed', 'event89.mseed', 'event960.mseed', 'event656.mseed', 'event916.mseed', 'event327.mseed', 'event580.mseed', 'event716.mseed', 'event506.mseed', 'event407.mseed', 'event674.mseed', 'event867.mseed', 'event892.mseed', 'event443.mseed', 'event310.mseed', 'event83.mseed', 'event39.mseed', 'event421.mseed', 'event161.mseed', 'event645.mseed', 'event32.mseed', 'event820.mseed', 'event171.mseed', 'event110.mseed', 'event634.mseed', 'event308.mseed', 'event953.mseed', 'event851.mseed', 'event267.mseed', 'event781.mseed', 'event434.mseed', 'event795.mseed', 'event195.mseed', 'event668.mseed', 'event526.mseed', 'event463.mseed', 'event870.mseed', 'event56.mseed', 'event497.mseed', 'event44.mseed', 'event393.mseed', 'event830.mseed', 'event928.mseed', 'event292.mseed', 'event194.mseed', 'event119.mseed', 'event279.mseed', 'event502.mseed', 'event212.mseed', 'event204.mseed', 'event670.mseed', 'event929.mseed', 'event557.mseed', 'event122.mseed', 'event258.mseed', 'event150.mseed', 'event457.mseed', 'event93.mseed', 'event725.mseed', 'event941.mseed', 'event226.mseed', 'event57.mseed', 'event35.mseed', 'event429.mseed', 'event897.mseed', 'event461.mseed', 'event753.mseed', 'event225.mseed', 'event739.mseed', 'event59.mseed', 'event382.mseed', 'event647.mseed', 'event840.mseed', 'event733.mseed', 'event316.mseed', 'event749.mseed', 'event775.mseed', 'event789.mseed', 'event655.mseed', 'event732.mseed', 'event664.mseed', 'event492.mseed', 'event930.mseed', 'event702.mseed', 'event636.mseed', 'event218.mseed', 'event94.mseed', 'event55.mseed', 'event524.mseed', 'event837.mseed', 'event777.mseed', 'event708.mseed', 'event950.mseed', 'event69.mseed', 'event364.mseed', 'event365.mseed', 'event629.mseed', 'event834.mseed', 'event625.mseed', 'event481.mseed', 'event336.mseed', 'event521.mseed', 'event72.mseed', 'event841.mseed', 'event675.mseed', 'event578.mseed', 'event346.mseed', 'event329.mseed', 'event695.mseed', 'event263.mseed', 'event594.mseed', 'event389.mseed', 'event691.mseed', 'event423.mseed', 'event386.mseed', 'event342.mseed', 'event932.mseed', 'event81.mseed', 'event156.mseed', 'event848.mseed', 'event593.mseed', 'event399.mseed', 'event542.mseed', 'event620.mseed', 'event862.mseed', 'event793.mseed', 'event448.mseed', 'event562.mseed', 'event896.mseed', 'event832.mseed', 'event553.mseed', 'event248.mseed', 'event885.mseed', 'event417.mseed', 'event209.mseed', 'event203.mseed', 'event6.mseed', 'event50.mseed', 'event608.mseed', 'event38.mseed', 'event903.mseed', 'event91.mseed', 'event819.mseed', 'event249.mseed', 'event63.mseed', 'event913.mseed', 'event805.mseed', 'event650.mseed', 'event769.mseed', 'event699.mseed', 'event576.mseed', 'event525.mseed', 'event358.mseed', 'event138.mseed', 'event860.mseed', 'event721.mseed', 'event383.mseed', 'event899.mseed', 'event169.mseed', 'event282.mseed', 'event49.mseed', 'event283.mseed', 'event818.mseed', 'event231.mseed', 'event199.mseed', 'event296.mseed', 'event158.mseed', 'event523.mseed', 'event303.mseed', 'event875.mseed', 'event924.mseed', 'event610.mseed', 'event938.mseed', 'event18.mseed', 'event352.mseed', 'event441.mseed', 'event375.mseed', 'event367.mseed', 'event151.mseed', 'event141.mseed', 'event658.mseed', 'event755.mseed', 'event251.mseed', 'event238.mseed', 'event865.mseed', 'event114.mseed', 'event746.mseed', 'event596.mseed', 'event887.mseed', 'event854.mseed', 'event438.mseed', 'event937.mseed', 'event210.mseed', 'event901.mseed', 'event850.mseed', 'event206.mseed', 'event772.mseed', 'event243.mseed', 'event744.mseed', 'event290.mseed', 'event237.mseed', 'event317.mseed', 'event639.mseed', 'event85.mseed', 'event864.mseed', 'event126.mseed', 'event512.mseed', 'event736.mseed', 'event162.mseed', 'event541.mseed', 'event286.mseed', 'event412.mseed', 'event165.mseed', 'event709.mseed', 'event559.mseed', 'event272.mseed', 'event701.mseed', 'event213.mseed', 'event215 ...

# %%
import dask.bag
from dask.distributed import Client as DaskClient
from mspasspy.db.database import Database
from mspasspy.db.client import DBClient
from mspasspy.preprocessing.seed.ensembles import (dbsave_seed_ensemble_file)

hostname = os.environ.get('HOSTNAME')
daskclient = DaskClient(hostname + ':8786')
dbclient = DBClient(hostname + ':27017')
db = Database(dbclient,'usarraytest')

def save_ens(fn):
    fname=dir+'/'+fn
    try:
        db.index_mseed_file(fn, dir=dir, collection='import_miniseed_ensemble')
    except Exception as err:
        return err
    return 'Building index for miniseed file='+fname

filelist_dbg = dask.bag.from_sequence(filelist)
filelist_map = filelist_dbg.map(save_ens)
save_log = filelist_map.compute()


# from mspasspy.db.database import Database
# from mspasspy.db.client import Client
# from mspasspy.preprocessing.seed.ensembles import (dbsave_seed_ensemble_file)

# dbclient=Client('mongodb://c402-003:27017')
# db=Database(dbclient,'usarraytest')
# print(db.list_collection_names())
# for file in filelist:
#     fname=dir+'/'+file
#     print('Building index for miniseed file=',fname)
#     try:
#         dbsave_seed_ensemble_file(db,fname)
#     except Exception as err:
#         print(err)

# %%
print(save_log)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## Source association
# Next the same steps as 6 in raw data tutorial.  Well shortened and without the explanations:

# %%
# Added to run remotely test status.  Could be removed.

dbclient=DBClient(hostname + ':27017')
db=Database(dbclient,'usarraytest')
cols=db.list_collections()
for doc in cols:
    print(doc)
# Out:
# {'name': 'source', 'type': 'collection', 'options': {}, 'info': {'readOnly': False, 'uuid': UUID('2a422223-5cb7-41de-8dc6-ae3dd19a953e')}, 'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_', 'ns': 'usarraytest.source'}}
# {'name': 'channel', 'type': 'collection', 'options': {}, 'info': {'readOnly': False, 'uuid': UUID('600479e9-de65-49ff-8f70-ee2eeabce12c')}, 'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_', 'ns': 'usarraytest.channel'}}
# {'name': 'site', 'type': 'collection', 'options': {}, 'info': {'readOnly': False, 'uuid': UUID('7515415e-bdef-41e0-86fb-4a0ae30a8e60')}, 'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_', 'ns': 'usarraytest.site'}}
# {'name': 'import_miniseed_ensemble', 'type': 'collection', 'options': {}, 'info': {'readOnly': False, 'uuid': UUID('96be719e-9b12-4439-9e5d-046036cbf4b1')}, 'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_', 'ns': 'usarraytest.import_miniseed_ensemble'}}
# {'name': 'arrival', 'type': 'collection', 'options': {}, 'info': {'readOnly': False, 'uuid': UUID('df1541b0-d6ab-467b-bd3c-61a753f19fb9')}, 'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_', 'ns': 'usarraytest.arrival'}}

# %% [markdown]
# Started this up much later than above (April 7) so wanted to verify how many ensembles were actually processed with the following:

# %%
n=db.import_miniseed_ensemble.count_documents({})
print("number of ensembles successfully indexed=",n)
# Out:
# number of ensembles successfully indexed= 3833785

# %%
from mspasspy.preprocessing.seed.ensembles import link_source_collection
link_source_collection(db)

# %% [markdown]
# The next step requires some changes because it needs to access the converted antelope database tables used to build the arrival collection.

# %%
from mspasspy.preprocessing.css30.dbarrival import extract_unique_css30_sources
arrfiledir= os.environ.get('SCRATCH') + 'mspass'  # for docker container
arrfile=arrfiledir+'/'+'usarray_tele'+year+'.txt'
events=extract_unique_css30_sources(arrfile)
# print just the first 10 events
n=0
for k in events:
    print('evid=',k,' contents:  ',events[k])
    n+=1
    if(n>=10):
        break
# Out:
# evid= 206397  contents:   {'evid': 206397, 'lat': 12.011, 'lon': 143.505, 'depth': 10.0, 'time': 1325377805.03}
# evid= 206398  contents:   {'evid': 206398, 'lat': -11.372, 'lon': 166.224, 'depth': 66.7, 'time': 1325379008.01}
# evid= 206401  contents:   {'evid': 206401, 'lat': 31.416, 'lon': 138.155, 'depth': 348.5, 'time': 1325395674.5}
# evid= 206408  contents:   {'evid': 206408, 'lat': 12.018, 'lon': 143.607, 'depth': 6.5, 'time': 1325432652.07}
# evid= 206439  contents:   {'evid': 206439, 'lat': -14.748, 'lon': 167.44, 'depth': 221.6, 'time': 1325652454.05}
# evid= 206454  contents:   {'evid': 206454, 'lat': -10.67, 'lon': 166.375, 'depth': 75.9, 'time': 1325703417.29}
# evid= 206458  contents:   {'evid': 206458, 'lat': -45.97, 'lon': -76.014, 'depth': 10.0, 'time': 1325724873.21}
# evid= 206459  contents:   {'evid': 206459, 'lat': -17.691, 'lon': -173.543, 'depth': 35.0, 'time': 1325726020.43}
# evid= 206464  contents:   {'evid': 206464, 'lat': 18.325, 'lon': -70.361, 'depth': 39.8, 'time': 1325756132.1}
# evid= 206500  contents:   {'evid': 206500, 'lat': -6.341, 'lon': -107.312, 'depth': 10.0, 'time': 1325876079.31}

# %% [markdown]
# Then this that uses the output of the above:

# %%
from mspasspy.preprocessing.css30.dbarrival import load_css30_sources
n=load_css30_sources(db,events)
print('loaded ',n,' new documents into source collection')
# Out:
# The following records in collection  source  have matching data for one or more evids
# You must fix the mismatch problem before you can load these data
# 206397 {'_id': ObjectId('6012d95c961f396071be8657'), 'evid': 206397, 'latitude': 12.011, 'longitude': 143.505, 'depth': 10.0, 'time': 1325377805.03, 'source_id': '6012d95c961f396071be8657'}
# 206398 {'_id': ObjectId('6012d95c961f396071be8658'), 'evid': 206398, 'latitude': -11.372, 'longitude': 166.224, 'depth': 66.7, 'time': 1325379008.01, 'source_id': '6012d95c961f396071be8658'}
# 206401 {'_id': ObjectId('6012d95c961f396071be8659'), 'evid': 206401, 'latitude': 31.416, 'longitude': 138.155, 'depth': 348.5, 'time': 1325395674.5, 'source_id': '6012d95c961f396071be8659'}
# 206408 {'_id': ObjectId('6012d95c961f396071be865a'), 'evid': 206408, 'latitude': 12.018, 'longitude': 143.607, 'depth': 6.5, 'time': 1325432652.07, 'source_id': '6012d95c961f396071be865a'}
# 206439 {'_id': ObjectId('6012d95c961f396071be865b'), 'evid': 206439, 'latitude': -14.748, 'longitude': 167.44, 'depth': 221.6, 'time': 1325652454.05, 'source_id': '6012d95c961f396071be865b'}
# 206454 {'_id': ObjectId('6012d95c961f396071be865c'), 'evid': 206454, 'latitude': -10.67, 'longitude': 166.375, 'depth': 75.9, 'time': 1325703417.29, 'source_id': '6012d95c961f396071be865c'}
# 206458 {'_id': ObjectId('6012d95c961f396071be865d'), 'evid': 206458, 'latitude': -45.97, 'longitude': -76.014, 'depth': 10.0, 'time': 1325724873.21, 'source_id': '6012d95c961f396071be865d'}
# 206459 {'_id': ObjectId('6012d95c961f396071be865e'), 'evid': 206459, 'latitude': -17.691, 'longitude': -173.543, 'depth': 35.0, 'time': 1325726020.43, 'source_id': '6012d95c961f396071be865e'}
# 206464 {'_id': ObjectId('6012d95c961f396071be865f'), 'evid': 206464, 'latitude': 18.325, 'longitude': -70.361, 'depth': 39.8, 'time': 1325756132.1, 'source_id': '6012d95c961f396071be865f'}
# 206500 {'_id': ObjectId('6012d95c961f396071be8660'), 'evid': 206500, 'latitude': -6.341, 'longitude': -107.312, 'depth': 10.0, 'time': 1325876079.31, 'source_id': '6012d95c961f396071be8660'}
# 206510 {'_id': ObjectId('6012d95c961f396071be8661'), 'evid': 206510, 'latitude': -28.613, 'longitude': -176.935, 'depth': 10.0, 'time': 1325961488.09, 'source_id': '6012d95c961f396071be8661'}
# 206514 {'_id': ObjectId('6012d95c961f396071be8662'), 'evid': 206514, 'latitude': -17.897, 'longitude': -178.541, 'depth': 554.5, 'time': 1325982952.5, 'source_id': '6012d95c961f396071be8662'}
# 206527 {'_id': ObjectId('6012d95c961f396071be8663'), 'evid': 206527, 'latitude': 39.363, 'longitude': 141.785, 'depth': 62.3, 'time': 1326060789.58, 'source_id': '6012d95c961f396071be8663'}
# 206529 {'_id': ObjectId('6012d95c961f396071be8664'), 'evid': 206529, 'latitude': -15.063, 'longitude': -174.142, 'depth': 10.0, 'time': 1326067614.8, 'source_id': '6012d95c961f396071be8664'}
# 206533 {'_id': ObjectId('6012d95c961f396071be8665'), 'evid': 206533, 'latitude': -10.617, 'longitude': 165.16, 'depth': 28.0, 'time': 1326082034.67, 'source_id': '6012d95c961f396071be8665'}
# 206539 {'_id': ObjectId('6012d95c961f396071be8666'), 'evid': 206539, 'latitude': -32.573, 'longitude': -71.594, 'depth': 21.4, 'time': 1326144651.0, 'source_id': '6012d95c961f396071be8666'}
# 206542 {'_id': ObjectId('6012d95c961f396071be8667'), 'evid': 206542, 'latitude': -16.991, 'longitude': 171.406, 'depth': 10.0, 'time': 1326159939.06, 'source_id': '6012d95c961f396071be8667'}
# 206547 {'_id': ObjectId('6012d95c961f396071be8668'), 'evid': 206547, 'latitude': -17.414, 'longitude': -172.779, 'depth': 10.0, 'time': 1326200918.95, 'source_id': '6012d95c961f396071be8668'}
# 206578 {'_id': ObjectId('6012d95c961f396071be8669'), 'evid': 206578, 'latitude': 36.994, 'longitude': 141.071, 'depth': 16.0, 'time': 1326338449.99, 'source_id': '6012d95c961f396071be8669'}
# 206579 {'_id': ObjectId('6012d95c961f396071be866a'), 'evid': 206579, 'latitude': 38.336, 'longitude': 142.461, 'depth': 35.0, 'time': 1326346648.76, 'source_id': '6012d95c961f396071be866a'}
# 206591 {'_id': ObjectId('6012d95c961f396071be866b'), 'evid': 206591, 'latitude': -16.508, 'longitude': -173.37, 'depth': 78.1, 'time': 1326407461.09, 'source_id': '6012d95c961f396071be866b'}
# 206605 {'_id': ObjectId('6012d95c961f396071be866c'), 'evid': 206605, 'latitude': -32.809, 'longitude': -178.566, 'depth': 10.0, 'time': 1326476950.12, 'source_id': '6012d95c961f396071be866c'}
# 206606 {'_id': ObjectId('6012d95c961f396071be866d'), 'evid': 206606, 'latitude': 51.08, 'longitude': -130.72, 'depth': 10.0, 'time': 1326483964.0, 'source_id': '6012d95c961f396071be866d'}
# 206608 {'_id': ObjectId('6012d95c961f396071be866e'), 'evid': 206608, 'latitude': -32.882, 'longitude': -178.476, 'depth': 10.0, 'time': 1326486324.54, 'source_id': '6012d95c961f396071be866e'}
# 206617 {'_id': ObjectId('6012d95c961f396071be866f'), 'evid': 206617, 'latitude': 19.202, 'longitude': 121.156, 'depth': 17.0, 'time': 1326558981.04, 'source_id': '6012d95c961f396071be866f'}
# 206652 {'_id': ObjectId('6012d95c961f396071be8670'), 'evid': 206652, 'latitude': -4.045, 'longitude': -104.146, 'depth': 10.0, 'time': 1326814068.53, 'source_id': '6012d95c961f396071be8670'}
# 206660 {'_id': ObjectId('6012d95c961f396071be8671'), 'evid': 206660, 'latitude': -31.655, 'longitude': -71.499, 'depth': 32.9, 'time': 1326842495.04, 'source_id': '6012d95c961f396071be8671'}
# 206668 {'_id': ObjectId('6012d95c961f396071be8672'), 'evid': 206668, 'latitude': -31.761, 'longitude': -68.084, 'depth': 10.0, 'time': 1326886550.51, 'source_id': '6012d95c961f396071be8672'}
# 206674 {'_id': ObjectId('6012d95c961f396071be8673'), 'evid': 206674, 'latitude': -11.018, 'longitude': 165.536, 'depth': 17.1, 'time': 1326906082.37, 'source_id': '6012d95c961f396071be8673'}
# 206675 {'_id': ObjectId('6012d95c961f396071be8674'), 'evid': 206675, 'latitude': -10.999, 'longitude': 165.464, 'depth': 38.2, 'time': 1326906177.42, 'source_id': '6012d95c961f396071be8674'}
# 206677 {'_id': ObjectId('6012d95c961f396071be8675'), 'evid': 206677, 'latitude': -11.023, 'longitude': 165.478, 'depth': 39.9, 'time': 1326907563.55, 'source_id': '6012d95c961f396071be8675'}
# 206687 {'_id': ObjectId('6012d95c961f396071be8676'), 'evid': 206687, 'latitude': -10.979, 'longitude': 165.477, 'depth': 46.8, 'time': 1326946002.0, 'source_id': '6012d95c961f396071be8676'}
# 206690 {'_id': ObjectId('6012d95c961f396071be8677'), 'evid': 206690, 'latitude': -10.966, 'longitude': 165.57, 'depth': 12.0, 'time': 1326952718.79, 'source_id': '6012d95c961f396071be8677'}
# 206694 {'_id': ObjectId('6012d95c961f396071be8678'), 'evid': 206694, 'latitude': -31.62, 'longitude': -71.618, 'depth': 49.8, 'time': 1326957022.07, 'source_id': '6012d95c961f396071be8678'}
# 206698 {'_id': ObjectId('6012d95c961f396071be8679'), 'evid': 206698, 'latitude': 36.29, 'longitude': 58.84, 'depth': 8.0, 'time': 1326976551.0, 'source_id': '6012d95c961f396071be8679'}
# 206710 {'_id': ObjectId('6012d95c961f396071be867a'), 'evid': 206710, 'latitude': 37.75, 'longitude': 143.311, 'depth': 22.4, 'time': 1327066250.59, 'source_id': '6012d95c961f396071be867a'}
# 206716 {'_id': ObjectId('6012d95c961f396071be867b'), 'evid': 206716, 'latitude': 14.873, 'longitude': -93.005, 'depth': 45.0, 'time': 1327171631.56, 'source_id': '6012d95c961f396071be867b'}
# 206736 {'_id': ObjectId('6012d95c961f396071be867c'), 'evid': 206736, 'latitude': 37.108, 'longitude': 140.965, 'depth': 62.4, 'time': 1327319143.7, 'source_id': '6012d95c961f396071be867c'}
# 206737 {'_id': ObjectId('6012d95c961f396071be867d'), 'evid': 206737, 'latitude': -36.409, 'longitude': -73.03, 'depth': 20.0, 'time': 1327334692.98, 'source_id': '6012d95c961f396071be867d'}
# 206741 {'_id': ObjectId('6012d95c961f396071be867e'), 'evid': 206741, 'latitude': 19.542, 'longitude': -70.077, 'depth': 8.8, 'time': 1327351814.5, 'source_id': '6012d95c961f396071be867e'}
# 206743 {'_id': ObjectId('6012d95c961f396071be867f'), 'evid': 206743, 'latitude': -24.977, 'longitude': 178.52, 'depth': 580.3, 'time': 1327366325.23, 'source_id': '6012d95c961f396071be867f'}
# 206757 {'_id': ObjectId('6012d95c961f396071be8680'), 'evid': 206757, 'latitude': 52.654, 'longitude': -167.049, 'depth': 41.4, 'time': 1327452357.71, 'source_id': '6012d95c961f396071be8680'}
# 206759 {'_id': ObjectId('6012d95c961f396071be8681'), 'evid': 206759, 'latitude': -5.209, 'longitude': 152.136, 'depth': 65.4, 'time': 1327475824.22, 'source_id': '6012d95c961f396071be8681'}
# 206767 {'_id': ObjectId('6012d95c961f396071be8682'), 'evid': 206767, 'latitude': -6.672, 'longitude': -122.202, 'depth': 10.0, 'time': 1327507449.3, 'source_id': '6012d95c961f396071be8682'}
# 206774 {'_id': ObjectId('6012d95c961f396071be8683'), 'evid': 206774, 'latitude': 38.19, 'longitude': 141.573, 'depth': 52.3, 'time': 1327524175.91, 'source_id': '6012d95c961f396071be8683'}
# 206779 {'_id': ObjectId('6012d95c961f396071be8684'), 'evid': 206779, 'latitude': 36.06, 'longitude': 25.07, 'depth': 29.0, 'time': 1327551898.3, 'source_id': '6012d95c961f396071be8684'}
# 206780 {'_id': ObjectId('6012d95c961f396071be8685'), 'evid': 206780, 'latitude': 14.338, 'longitude': 145.189, 'depth': 113.3, 'time': 1327552925.57, 'source_id': '6012d95c961f396071be8685'}
# 206808 {'_id': ObjectId('6012d95c961f396071be8686'), 'evid': 206808, 'latitude': 21.645, 'longitude': 142.852, 'depth': 314.4, 'time': 1327615446.91, 'source_id': '6012d95c961f396071be8686'}
# 206817 {'_id': ObjectId('6012d95c961f396071be8687'), 'evid': 206817, 'latitude': 36.044, 'longitude': 25.064, 'depth': 5.2, 'time': 1327628004.0, 'source_id': '6012d95c961f396071be8687'}
# 206830 {'_id': ObjectId('6012d95c961f396071be8688'), 'evid': 206830, 'latitude': 44.48, 'longitude': 10.03, 'depth': 60.0, 'time': 1327675993.0, 'source_id': '6012d95c961f396071be8688'}
# 206838 {'_id': ObjectId('6012d95c961f396071be8689'), 'evid': 206838, 'latitude': 35.474, 'longitude': 138.888, 'depth': 36.3, 'time': 1327704196.14, 'source_id': '6012d95c961f396071be8689'}
# 206839 {'_id': ObjectId('6012d95c961f396071be868a'), 'evid': 206839, 'latitude': 40.177, 'longitude': 142.211, 'depth': 55.3, 'time': 1327710138.94, 'source_id': '6012d95c961f396071be868a'}
# 206844 {'_id': ObjectId('6012d95c961f396071be868b'), 'evid': 206844, 'latitude': -36.793, 'longitude': -110.509, 'depth': 10.0, 'time': 1327725821.03, 'source_id': '6012d95c961f396071be868b'}
# 206848 {'_id': ObjectId('6012d95c961f396071be868c'), 'evid': 206848, 'latitude': -21.466, 'longitude': -66.43, 'depth': 198.9, 'time': 1327740696.43, 'source_id': '6012d95c961f396071be868c'}
# 206852 {'_id': ObjectId('6012d95c961f396071be868d'), 'evid': 206852, 'latitude': -29.43, 'longitude': -177.386, 'depth': 21.0, 'time': 1327772571.72, 'source_id': '6012d95c961f396071be868d'}
# 206853 {'_id': ObjectId('6012d95c961f396071be868e'), 'evid': 206853, 'latitude': -29.41, 'longitude': -177.261, 'depth': 27.3, 'time': 1327772749.45, 'source_id': '6012d95c961f396071be868e'}
# 206854 {'_id': ObjectId('6012d95c961f396071be868f'), 'evid': 206854, 'latitude': -29.59, 'longitude': -177.139, 'depth': 10.0, 'time': 1327772855.79, 'source_id': '6012d95c961f396071be868f'}
# 206855 {'_id': ObjectId('6012d95c961f396071be8690'), 'evid': 206855, 'latitude': -29.69, 'longitude': -177.175, 'depth': 18.4, 'time': 1327774670.68, 'source_id': '6012d95c961f396071be8690'}
# 206856 {'_id': ObjectId('6012d95c961f396071be8691'), 'evid': 206856, 'latitude': -29.519, 'longitude': -177.172, 'depth': 10.0, 'time': 1327776541.41, 'source_id': '6012d95c961f396071be8691'}
# 206857 {'_id': ObjectId('6012d95c961f396071be8692'), 'evid': 206857, 'latitude': -29.574, 'longitude': -177.259, 'depth': 25.3, 'time': 1327777539.73, 'source_id': '6012d95c961f396071be8692'}
# 206872 {'_id': ObjectId('6012d95c961f396071be8693'), 'evid': 206872, 'latitude': 16.488, 'longitude': -46.529, 'depth': 10.0, 'time': 1327873405.09, 'source_id': '6012d95c961f396071be8693'}
# 206875 {'_id': ObjectId('6012d95c961f396071be8694'), 'evid': 206875, 'latitude': -14.169, 'longitude': -75.63, 'depth': 43.0, 'time': 1327900260.93, 'source_id': '6012d95c961f396071be8694'}
# 206922 {'_id': ObjectId('6012d95c961f396071be8695'), 'evid': 206922, 'latitude': -31.585, 'longitude': -111.525, 'depth': 10.0, 'time': 1328132626.48, 'source_id': '6012d95c961f396071be8695'}
# 206930 {'_id': ObjectId('6012d95c961f396071be8696'), 'evid': 206930, 'latitude': -6.586, 'longitude': 149.718, 'depth': 38.6, 'time': 1328175136.88, 'source_id': '6012d95c961f396071be8696'}
# 206932 {'_id': ObjectId('6012d95c961f396071be8697'), 'evid': 206932, 'latitude': -17.827, 'longitude': 167.133, 'depth': 23.0, 'time': 1328189680.65, 'source_id': '6012d95c961f396071be8697'}
# 206933 {'_id': ObjectId('6012d95c961f396071be8698'), 'evid': 206933, 'latitude': -17.754, 'longitude': 167.53, 'depth': 10.0, 'time': 1328189963.13, 'source_id': '6012d95c961f396071be8698'}
# 206936 {'_id': ObjectId('6012d95c961f396071be8699'), 'evid': 206936, 'latitude': -17.455, 'longitude': 167.176, 'depth': 10.0, 'time': 1328191027.05, 'source_id': '6012d95c961f396071be8699'}
# 206939 {'_id': ObjectId('6012d95c961f396071be869a'), 'evid': 206939, 'latitude': -17.954, 'longitude': 167.179, 'depth': 20.6, 'time': 1328203626.98, 'source_id': '6012d95c961f396071be869a'}
# 206940 {'_id': ObjectId('6012d95c961f396071be869b'), 'evid': 206940, 'latitude': -17.597, 'longitude': 167.304, 'depth': 10.0, 'time': 1328203726.42, 'source_id': '6012d95c961f396071be869b'}
# 206946 {'_id': ObjectId('6012d95c961f396071be869c'), 'evid': 206946, 'latitude': -17.43, 'longitude': 167.209, 'depth': 23.9, 'time': 1328211874.17, 'source_id': '6012d95c961f396071be869c'}
# 206948 {'_id': ObjectId('6012d95c961f396071be869d'), 'evid': 206948, 'latitude': -17.534, 'longitude': 167.327, 'depth': 22.5, 'time': 1328214391.91, 'source_id': '6012d95c961f396071be869d'}
# 206954 {'_id': ObjectId('6012d95c961f396071be869e'), 'evid': 206954, 'latitude': -17.378, 'longitude': 167.277, 'depth': 8.0, 'time': 1328240781.15, 'source_id': '6012d95c961f396071be869e'}
# 206956 {'_id': ObjectId('6012d95c961f396071be869f'), 'evid': 206956, 'latitude': -17.463, 'longitude': 167.187, 'depth': 25.2, 'time': 1328243589.0, 'source_id': '6012d95c961f396071be869f'}
# 206958 {'_id': ObjectId('6012d95c961f396071be86a0'), 'evid': 206958, 'latitude': -17.386, 'longitude': 167.232, 'depth': 10.0, 'time': 1328248898.88, 'source_id': '6012d95c961f396071be86a0'}
# 206965 {'_id': ObjectId('6012d95c961f396071be86a1'), 'evid': 206965, 'latitude': 24.698, 'longitude': 122.601, 'depth': 121.5, 'time': 1328324062.49, 'source_id': '6012d95c961f396071be86a1'}
# 206966 {'_id': ObjectId('6012d95c961f396071be86a2'), 'evid': 206966, 'latitude': 42.291, 'longitude': 105.61, 'depth': 2.2, 'time': 1328328573.99, 'source_id': '6012d95c961f396071be86a2'}
# 206968 {'_id': ObjectId('6012d95c961f396071be86a3'), 'evid': 206968, 'latitude': -20.536, 'longitude': -174.035, 'depth': 8.0, 'time': 1328341212.8, 'source_id': '6012d95c961f396071be86a3'}
# 206975 {'_id': ObjectId('6012d95c961f396071be86a4'), 'evid': 206975, 'latitude': -17.086, 'longitude': 167.81, 'depth': 10.0, 'time': 1328377528.54, 'source_id': '6012d95c961f396071be86a4'}
# 206976 {'_id': ObjectId('6012d95c961f396071be86a5'), 'evid': 206976, 'latitude': 0.922, 'longitude': -26.746, 'depth': 10.0, 'time': 1328378506.7, 'source_id': '6012d95c961f396071be86a5'}
# 206980 {'_id': ObjectId('6012d95c961f396071be86a6'), 'evid': 206980, 'latitude': 48.6, 'longitude': -128.21, 'depth': 10.0, 'time': 1328385927.0, 'source_id': '6012d95c961f396071be86a6'}
# 206981 {'_id': ObjectId('6012d95c961f396071be86a7'), 'evid': 206981, 'latitude': -18.894, 'longitude': 168.917, 'depth': 145.0, 'time': 1328400938.9, 'source_id': '6012d95c961f396071be86a7'}
# 206983 {'_id': ObjectId('6012d95c961f396071be86a8'), 'evid': 206983, 'latitude': 41.437, 'longitude': 74.784, 'depth': 10.0, 'time': 1328425816.58, 'source_id': '6012d95c961f396071be86a8'}
# 206986 {'_id': ObjectId('6012d95c961f396071be86a9'), 'evid': 206986, 'latitude': 13.314, 'longitude': -89.015, 'depth': 90.2, 'time': 1328451579.32, 'source_id': '6012d95c961f396071be86a9'}
# 206989 {'_id': ObjectId('6012d95c961f396071be86aa'), 'evid': 206989, 'latitude': -17.948, 'longitude': 167.226, 'depth': 8.0, 'time': 1328460039.16, 'source_id': '6012d95c961f396071be86aa'}
# 206993 {'_id': ObjectId('6012d95c961f396071be86ab'), 'evid': 206993, 'latitude': -20.423, 'longitude': -177.987, 'depth': 525.3, 'time': 1328485841.19, 'source_id': '6012d95c961f396071be86ab'}
# 207023 {'_id': ObjectId('6012d95c961f396071be86ac'), 'evid': 207023, 'latitude': 76.848, 'longitude': 7.323, 'depth': 10.0, 'time': 1328657825.34, 'source_id': '6012d95c961f396071be86ac'}
# 207025 {'_id': ObjectId('6012d95c961f396071be86ad'), 'evid': 207025, 'latitude': -29.455, 'longitude': -177.409, 'depth': 36.5, 'time': 1328666321.47, 'source_id': '6012d95c961f396071be86ad'}
# 207029 {'_id': ObjectId('6012d95c961f396071be86ae'), 'evid': 207029, 'latitude': 0.658, 'longitude': -79.258, 'depth': 64.5, 'time': 1328698482.29, 'source_id': '6012d95c961f396071be86ae'}
# 207030 {'_id': ObjectId('6012d95c961f396071be86af'), 'evid': 207030, 'latitude': 37.858, 'longitude': 137.999, 'depth': 10.0, 'time': 1328702497.48, 'source_id': '6012d95c961f396071be86af'}
# 207031 {'_id': ObjectId('6012d95c961f396071be86b0'), 'evid': 207031, 'latitude': 14.682, 'longitude': -94.427, 'depth': 16.1, 'time': 1328706401.2, 'source_id': '6012d95c961f396071be86b0'}
# 207046 {'_id': ObjectId('6012d95c961f396071be86b1'), 'evid': 207046, 'latitude': 16.069, 'longitude': -97.191, 'depth': 11.3, 'time': 1328779315.2, 'source_id': '6012d95c961f396071be86b1'}
# 207056 {'_id': ObjectId('6012d95c961f396071be86b2'), 'evid': 207056, 'latitude': -17.968, 'longitude': -178.549, 'depth': 582.3, 'time': 1328838454.19, 'source_id': '6012d95c961f396071be86b2'}
# 207057 {'_id': ObjectId('6012d95c961f396071be86b3'), 'evid': 207057, 'latitude': -0.324, 'longitude': 132.691, 'depth': 15.0, 'time': 1328852045.03, 'source_id': '6012d95c961f396071be86b3'}
# 207068 {'_id': ObjectId('6012d95c961f396071be86b4'), 'evid': 207068, 'latitude': -37.456, 'longitude': -73.884, 'depth': 20.2, 'time': 1328929097.0, 'source_id': '6012d95c961f396071be86b4'}
# 207071 {'_id': ObjectId('6012d95c961f396071be86b5'), 'evid': 207071, 'latitude': -9.954, 'longitude': 160.274, 'depth': 47.0, 'time': 1328973787.9, 'source_id': '6012d95c961f396071be86b5'}
# 207077 {'_id': ObjectId('6012d95c961f396071be86b6'), 'evid': 207077, 'latitude': 38.529, 'longitude': 144.252, 'depth': 20.2, 'time': 1329021661.15, 'source_id': '6012d95c961f396071be86b6'}
# 207089 {'_id': ObjectId('6012d95c961f396071be86b7'), 'evid': 207089, 'latitude': -18.175, 'longitude': -172.415, 'depth': 36.0, 'time': 1329124154.38, 'source_id': '6012d95c961f396071be86b7'}
# 207090 {'_id': ObjectId('6012d95c961f396071be86b8'), 'evid': 207090, 'latitude': -32.554, 'longitude': -178.851, 'depth': 35.9, 'time': 1329127927.24, 'source_id': '6012d95c961f396071be86b8'}
# 207091 {'_id': ObjectId('6012d95c961f396071be86b9'), 'evid': 207091, 'latitude': 9.183, 'longitude': -84.121, 'depth': 16.0, 'time': 1329130509.44, 'source_id': '6012d95c961f396071be86b9'}
# 207094 {'_id': ObjectId('6012d95c961f396071be86ba'), 'evid': 207094, 'latitude': 41.1527, 'longitude': -123.8175, 'depth': 32.85, 'time': 1329167222.25, 'source_id': '6012d95c961f396071be86ba'}
# 207097 {'_id': ObjectId('6012d95c961f396071be86bb'), 'evid': 207097, 'latitude': 40.13, 'longitude': 24.09, 'depth': 24.0, 'time': 1329183278.7, 'source_id': '6012d95c961f396071be86bb'}
# 207098 {'_id': ObjectId('6012d95c961f396071be86bc'), 'evid': 207098, 'latitude': 36.193, 'longitude': 141.402, 'depth': 30.2, 'time': 1329190070.5, 'source_id': '6012d95c961f396071be86bc'}
# 207099 {'_id': ObjectId('6012d95c961f396071be86bd'), 'evid': 207099, 'latitude': 36.214, 'longitude': 141.386, 'depth': 28.0, 'time': 1329200521.17, 'source_id': '6012d95c961f396071be86bd'}
# 207102 {'_id': ObjectId('6012d95c961f396071be86be'), 'evid': 207102, 'latitude': -10.39, 'longitude': 161.102, 'depth': 51.0, 'time': 1329207595.47, 'source_id': '6012d95c961f396071be86be'}
# 207103 {'_id': ObjectId('6012d95c961f396071be86bf'), 'evid': 207103, 'latitude': 32.106, 'longitude': -115.201, 'depth': 4.7, 'time': 1329214168.6, 'source_id': '6012d95c961f396071be86bf'}
# 207114 {'_id': ObjectId('6012d95c961f396071be86c0'), 'evid': 207114, 'latitude': 36.16, 'longitude': 141.642, 'depth': 13.8, 'time': 1329258878.2, 'source_id': '6012d95c961f396071be86c0'}
# 207116 {'_id': ObjectId('6012d95c961f396071be86c1'), 'evid': 207116, 'latitude': 0.859, 'longitude': -29.228, 'depth': 10.0, 'time': 1329262756.42, 'source_id': '6012d95c961f396071be86c1'}
# 207117 {'_id': ObjectId('6012d95c961f396071be86c2'), 'evid': 207117, 'latitude': -19.321, 'longitude': -177.378, 'depth': 353.6, 'time': 1329270580.01, 'source_id': '6012d95c961f396071be86c2'}
# 207119 {'_id': ObjectId('6012d95c961f396071be86c3'), 'evid': 207119, 'latitude': 43.625, 'longitude': -127.518, 'depth': 11.0, 'time': 1329276680.61, 'source_id': '6012d95c961f396071be86c3'}
# 207127 {'_id': ObjectId('6012d95c961f396071be86c4'), 'evid': 207127, 'latitude': -7.501, 'longitude': 146.958, 'depth': 8.0, 'time': 1329314871.22, 'source_id': '6012d95c961f396071be86c4'}
# 207135 {'_id': ObjectId('6012d95c961f396071be86c5'), 'evid': 207135, 'latitude': 51.763, 'longitude': -177.97, 'depth': 80.5, 'time': 1329347028.83, 'source_id': '6012d95c961f396071be86c5'}
# 207155 {'_id': ObjectId('6012d95c961f396071be86c6'), 'evid': 207155, 'latitude': -19.367, 'longitude': 168.847, 'depth': 35.0, 'time': 1329443849.47, 'source_id': '6012d95c961f396071be86c6'}
# 207167 {'_id': ObjectId('6012d95c961f396071be86c7'), 'evid': 207167, 'latitude': 15.264, 'longitude': -95.67, 'depth': 16.1, 'time': 1329528859.8, 'source_id': '6012d95c961f396071be86c7'}
# 207168 {'_id': ObjectId('6012d95c961f396071be86c8'), 'evid': 207168, 'latitude': 15.227, 'longitude': -95.651, 'depth': 15.9, 'time': 1329529078.4, 'source_id': '6012d95c961f396071be86c8'}
# 207170 {'_id': ObjectId('6012d95c961f396071be86c9'), 'evid': 207170, 'latitude': -5.285, 'longitude': 151.415, 'depth': 73.8, 'time': 1329540622.43, 'source_id': '6012d95c961f396071be86c9'}
# 207173 {'_id': ObjectId('6012d95c961f396071be86ca'), 'evid': 207173, 'latitude': -20.957, 'longitude': -173.521, 'depth': 62.9, 'time': 1329592525.52, 'source_id': '6012d95c961f396071be86ca'}
# 207175 {'_id': ObjectId('6012d95c961f396071be86cb'), 'evid': 207175, 'latitude': 36.761, 'longitude': 140.313, 'depth': 10.0, 'time': 1329630889.68, 'source_id': '6012d95c961f396071be86cb'}
# 207189 {'_id': ObjectId('6012d95c961f396071be86cc'), 'evid': 207189, 'latitude': 14.276, 'longitude': -92.779, 'depth': 10.0, 'time': 1329764976.29, 'source_id': '6012d95c961f396071be86cc'}
# 207197 {'_id': ObjectId('6012d95c961f396071be86cd'), 'evid': 207197, 'latitude': -17.678, 'longitude': -172.96, 'depth': 36.3, 'time': 1329782060.4, 'source_id': '6012d95c961f396071be86cd'}
# 207201 {'_id': ObjectId('6012d95c961f396071be86ce'), 'evid': 207201, 'latitude': 67.744, 'longitude': -167.057, 'depth': 20.0, 'time': 1329832242.62, 'source_id': '6012d95c961f396071be86ce'}
# 207212 {'_id': ObjectId('6012d95c961f396071be86cf'), 'evid': 207212, 'latitude': -17.868, 'longitude': 167.051, 'depth': 57.3, 'time': 1329871843.76, 'source_id': '6012d95c961f396071be86cf'}
# 207214 {'_id': ObjectId('6012d95c961f396071be86d0'), 'evid': 207214, 'latitude': -5.173, 'longitude': 133.565, 'depth': 19.0, 'time': 1329907522.87, 'source_id': '6012d95c961f396071be86d0'}
# 207215 {'_id': ObjectId('6012d95c961f396071be86d1'), 'evid': 207215, 'latitude': 4.99, 'longitude': 94.4, 'depth': 33.3, 'time': 1329912165.51, 'source_id': '6012d95c961f396071be86d1'}
# 207222 {'_id': ObjectId('6012d95c961f396071be86d2'), 'evid': 207222, 'latitude': -17.699, 'longitude': -13.193, 'depth': 10.0, 'time': 1329973692.79, 'source_id': '6012d95c961f396071be86d2'}
# 207226 {'_id': ObjectId('6012d95c961f396071be86d3'), 'evid': 207226, 'latitude': -5.197, 'longitude': 151.926, 'depth': 68.6, 'time': 1330003530.19, 'source_id': '6012d95c961f396071be86d3'}
# 207227 {'_id': ObjectId('6012d95c961f396071be86d4'), 'evid': 207227, 'latitude': 14.16, 'longitude': -93.37, 'depth': 16.1, 'time': 1330006149.5, 'source_id': '6012d95c961f396071be86d4'}
# 207230 {'_id': ObjectId('6012d95c961f396071be86d5'), 'evid': 207230, 'latitude': -29.231, 'longitude': -176.185, 'depth': 33.5, 'time': 1330021583.46, 'source_id': '6012d95c961f396071be86d5'}
# 207236 {'_id': ObjectId('6012d95c961f396071be86d6'), 'evid': 207236, 'latitude': 6.702, 'longitude': -72.952, 'depth': 161.5, 'time': 1330090996.66, 'source_id': '6012d95c961f396071be86d6'}
# 207245 {'_id': ObjectId('6012d95c961f396071be86d7'), 'evid': 207245, 'latitude': 19.122, 'longitude': 145.747, 'depth': 123.7, 'time': 1330132320.09, 'source_id': '6012d95c961f396071be86d7'}
# 207246 {'_id': ObjectId('6012d95c961f396071be86d8'), 'evid': 207246, 'latitude': -25.686, 'longitude': 179.534, 'depth': 506.6, 'time': 1330146381.54, 'source_id': '6012d95c961f396071be86d8'}
# 207249 {'_id': ObjectId('6012d95c961f396071be86d9'), 'evid': 207249, 'latitude': 49.186, 'longitude': 155.941, 'depth': 28.2, 'time': 1330150513.6, 'source_id': '6012d95c961f396071be86d9'}
# 207250 {'_id': ObjectId('6012d95c961f396071be86da'), 'evid': 207250, 'latitude': 49.23, 'longitude': 155.982, 'depth': 27.7, 'time': 1330150684.29, 'source_id': '6012d95c961f396071be86da'}
# 207256 {'_id': ObjectId('6012d95c961f396071be86db'), 'evid': 207256, 'latitude': 22.661, 'longitude': 120.891, 'depth': 28.0, 'time': 1330223700.53, 'source_id': '6012d95c961f396071be86db'}
# 207257 {'_id': ObjectId('6012d95c961f396071be86dc'), 'evid': 207257, 'latitude': -24.477, 'longitude': -177.5, 'depth': 10.0, 'time': 1330224381.28, 'source_id': '6012d95c961f396071be86dc'}
# 207259 {'_id': ObjectId('6012d95c961f396071be86dd'), 'evid': 207259, 'latitude': -24.495, 'longitude': -177.238, 'depth': 10.0, 'time': 1330233684.63, 'source_id': '6012d95c961f396071be86dd'}
# 207260 {'_id': ObjectId('6012d95c961f396071be86de'), 'evid': 207260, 'latitude': -32.495, 'longitude': -177.73, 'depth': 39.0, 'time': 1330233899.26, 'source_id': '6012d95c961f396071be86de'}
# 207261 {'_id': ObjectId('6012d95c961f396071be86df'), 'evid': 207261, 'latitude': 51.708, 'longitude': 95.991, 'depth': 12.0, 'time': 1330237039.76, 'source_id': '6012d95c961f396071be86df'}
# 207262 {'_id': ObjectId('6012d95c961f396071be86e0'), 'evid': 207262, 'latitude': -18.811, 'longitude': -69.29, 'depth': 108.5, 'time': 1330243732.95, 'source_id': '6012d95c961f396071be86e0'}
# 207266 {'_id': ObjectId('6012d95c961f396071be86e1'), 'evid': 207266, 'latitude': 51.693, 'longitude': 96.084, 'depth': 10.0, 'time': 1330254461.2, 'source_id': '6012d95c961f396071be86e1'}
# 207267 {'_id': ObjectId('6012d95c961f396071be86e2'), 'evid': 207267, 'latitude': -24.869, 'longitude': -177.222, 'depth': 10.0, 'time': 1330255022.95, 'source_id': '6012d95c961f396071be86e2'}
# 207269 {'_id': ObjectId('6012d95c961f396071be86e3'), 'evid': 207269, 'latitude': 51.687, 'longitude': 95.981, 'depth': 15.8, 'time': 1330257546.8, 'source_id': '6012d95c961f396071be86e3'}
# 207275 {'_id': ObjectId('6012d95c961f396071be86e4'), 'evid': 207275, 'latitude': -24.672, 'longitude': -177.205, 'depth': 15.1, 'time': 1330264199.05, 'source_id': '6012d95c961f396071be86e4'}
# 207283 {'_id': ObjectId('6012d95c961f396071be86e5'), 'evid': 207283, 'latitude': -24.849, 'longitude': -177.305, 'depth': 14.7, 'time': 1330285029.24, 'source_id': '6012d95c961f396071be86e5'}
# 207286 {'_id': ObjectId('6012d95c961f396071be86e6'), 'evid': 207286, 'latitude': 23.873, 'longitude': 123.355, 'depth': 40.1, 'time': 1330305108.39, 'source_id': '6012d95c961f396071be86e6'}
# 207289 {'_id': ObjectId('6012d95c961f396071be86e7'), 'evid': 207289, 'latitude': 46.922, 'longitude': 152.74, 'depth': 67.5, 'time': 1330319268.35, 'source_id': '6012d95c961f396071be86e7'}
# 207294 {'_id': ObjectId('6012d95c961f396071be86e8'), 'evid': 207294, 'latitude': -24.688, 'longitude': -177.229, 'depth': 10.0, 'time': 1330354483.99, 'source_id': '6012d95c961f396071be86e8'}
# 207297 {'_id': ObjectId('6012d95c961f396071be86e9'), 'evid': 207297, 'latitude': 25.557, 'longitude': 127.096, 'depth': 42.2, 'time': 1330371111.72, 'source_id': '6012d95c961f396071be86e9'}
# 207302 {'_id': ObjectId('6012d95c961f396071be86ea'), 'evid': 207302, 'latitude': 49.262, 'longitude': 156.1, 'depth': 47.9, 'time': 1330407212.54, 'source_id': '6012d95c961f396071be86ea'}
# 207303 {'_id': ObjectId('6012d95c961f396071be86eb'), 'evid': 207303, 'latitude': 28.2, 'longitude': 139.391, 'depth': 504.2, 'time': 1330441655.04, 'source_id': '6012d95c961f396071be86eb'}
# 207316 {'_id': ObjectId('6012d95c961f396071be86ec'), 'evid': 207316, 'latitude': 37.203, 'longitude': 144.137, 'depth': 10.0, 'time': 1330469557.85, 'source_id': '6012d95c961f396071be86ec'}
# 207320 {'_id': ObjectId('6012d95c961f396071be86ed'), 'evid': 207320, 'latitude': -12.543, 'longitude': 166.487, 'depth': 80.7, 'time': 1330499112.11, 'source_id': '6012d95c961f396071be86ed'}
# 207321 {'_id': ObjectId('6012d95c961f396071be86ee'), 'evid': 207321, 'latitude': 37.305, 'longitude': 141.513, 'depth': 45.0, 'time': 1330506005.37, 'source_id': '6012d95c961f396071be86ee'}
# 207323 {'_id': ObjectId('6012d95c961f396071be86ef'), 'evid': 207323, 'latitude': 49.259, 'longitude': 156.103, 'depth': 42.5, 'time': 1330515395.59, 'source_id': '6012d95c961f396071be86ef'}
# 207324 {'_id': ObjectId('6012d95c961f396071be86f0'), 'evid': 207324, 'latitude': 35.2, 'longitude': 141.001, 'depth': 26.2, 'time': 1330525967.83, 'source_id': '6012d95c961f396071be86f0'}
# 207330 {'_id': ObjectId('6012d95c961f396071be86f1'), 'evid': 207330, 'latitude': -17.647, 'longitude': 168.038, 'depth': 46.3, 'time': 1330531437.29, 'source_id': '6012d95c961f396071be86f1'}
# 207336 {'_id': ObjectId('6012d95c961f396071be86f2'), 'evid': 207336, 'latitude': 36.427, 'longitude': 140.448, 'depth': 74.9, 'time': 1330554755.61, 'source_id': '6012d95c961f396071be86f2'}
# 207356 {'_id': ObjectId('6012d95c961f396071be86f3'), 'evid': 207356, 'latitude': 52.228, 'longitude': 178.588, 'depth': 163.5, 'time': 1330706910.66, 'source_id': '6012d95c961f396071be86f3'}
# 207362 {'_id': ObjectId('6012d95c961f396071be86f4'), 'evid': 207362, 'latitude': 64.26, 'longitude': -128.67, 'depth': 20.0, 'time': 1330730961.0, 'source_id': '6012d95c961f396071be86f4'}
# 207368 {'_id': ObjectId('6012d95c961f396071be86f5'), 'evid': 207368, 'latitude': -30.348, 'longitude': -71.129, 'depth': 49.0, 'time': 1330772507.25, 'source_id': '6012d95c961f396071be86f5'}
# 207369 {'_id': ObjectId('6012d95c961f396071be86f6'), 'evid': 207369, 'latitude': -22.141, 'longitude': 170.34, 'depth': 14.0, 'time': 1330777195.09, 'source_id': '6012d95c961f396071be86f6'}
# 207375 {'_id': ObjectId('6012d95c961f396071be86f7'), 'evid': 207375, 'latitude': 40.134, 'longitude': 24.059, 'depth': 2.5, 'time': 1330831868.4, 'source_id': '6012d95c961f396071be86f7'}
# 207379 {'_id': ObjectId('6012d95c961f396071be86f8'), 'evid': 207379, 'latitude': 2.687, 'longitude': -84.34, 'depth': 9.0, 'time': 1330854254.6, 'source_id': '6012d95c961f396071be86f8'}
# 207381 {'_id': ObjectId('6012d95c961f396071be86f9'), 'evid': 207381, 'latitude': -21.529, 'longitude': 169.769, 'depth': 14.0, 'time': 1330865342.44, 'source_id': '6012d95c961f396071be86f9'}
# 207383 {'_id': ObjectId('6012d95c961f396071be86fa'), 'evid': 207383, 'latitude': -21.554, 'longitude': -69.848, 'depth': 46.2, 'time': 1330878441.04, 'source_id': '6012d95c961f396071be86fa'}
# 207390 {'_id': ObjectId('6012d95c961f396071be86fb'), 'evid': 207390, 'latitude': -28.246, 'longitude': -63.294, 'depth': 553.9, 'time': 1330933570.04, 'source_id': '6012d95c961f396071be86fb'}
# 207407 {'_id': ObjectId('6012d95c961f396071be86fc'), 'evid': 207407, 'latitude': 10.527, 'longitude': 140.306, 'depth': 45.2, 'time': 1331013950.09, 'source_id': '6012d95c961f396071be86fc'}
# 207414 {'_id': ObjectId('6012d95c961f396071be86fd'), 'evid': 207414, 'latitude': 25.609, 'longitude': 127.13, 'depth': 48.0, 'time': 1331101091.03, 'source_id': '6012d95c961f396071be86fd'}
# 207415 {'_id': ObjectId('6012d95c961f396071be86fe'), 'evid': 207415, 'latitude': -2.814, 'longitude': 138.888, 'depth': 53.8, 'time': 1331121646.01, 'source_id': '6012d95c961f396071be86fe'}
# 207417 {'_id': ObjectId('6012d95c961f396071be86ff'), 'evid': 207417, 'latitude': -19.571, 'longitude': 168.194, 'depth': 14.7, 'time': 1331128562.09, 'source_id': '6012d95c961f396071be86ff'}
# 207425 {'_id': ObjectId('6012d95c961f396071be8700'), 'evid': 207425, 'latitude': -17.895, 'longitude': 167.152, 'depth': 28.9, 'time': 1331178695.04, 'source_id': '6012d95c961f396071be8700'}
# 207430 {'_id': ObjectId('6012d95c961f396071be8701'), 'evid': 207430, 'latitude': 32.874, 'longitude': 46.957, 'depth': 18.0, 'time': 1331230898.5, 'source_id': '6012d95c961f396071be8701'}
# 207434 {'_id': ObjectId('6012d95c961f396071be8702'), 'evid': 207434, 'latitude': 39.383, 'longitude': 81.307, 'depth': 38.0, 'time': 1331247008.41, 'source_id': '6012d95c961f396071be8702'}
# 207439 {'_id': ObjectId('6012d95c961f396071be8703'), 'evid': 207439, 'latitude': -19.125, 'longitude': 169.613, 'depth': 16.0, 'time': 1331276990.95, 'source_id': '6012d95c961f396071be8703'}
# 207442 {'_id': ObjectId('6012d95c961f396071be8704'), 'evid': 207442, 'latitude': 36.719, 'longitude': 140.392, 'depth': 27.1, 'time': 1331313933.19, 'source_id': '6012d95c961f396071be8704'}
# 207450 {'_id': ObjectId('6012d95c961f396071be8705'), 'evid': 207450, 'latitude': -19.738, 'longitude': -69.25, 'depth': 101.0, 'time': 1331346417.0, 'source_id': '6012d95c961f396071be8705'}
# 207453 {'_id': ObjectId('6012d95c961f396071be8706'), 'evid': 207453, 'latitude': 55.146, 'longitude': -157.567, 'depth': 10.0, 'time': 1331388639.85, 'source_id': '6012d95c961f396071be8706'}
# 207477 {'_id': ObjectId('6012d95c961f396071be8707'), 'evid': 207477, 'latitude': 36.741, 'longitude': 73.152, 'depth': 11.0, 'time': 1331532400.64, 'source_id': '6012d95c961f396071be8707'}
# 207478 {'_id': ObjectId('6012d95c961f396071be8708'), 'evid': 207478, 'latitude': -14.313, 'longitude': -75.567, 'depth': 61.4, 'time': 1331534098.51, 'source_id': '6012d95c961f396071be8708'}
# 207480 {'_id': ObjectId('6012d95c961f396071be8709'), 'evid': 207480, 'latitude': 45.239, 'longitude': 147.609, 'depth': 110.4, 'time': 1331555566.36, 'source_id': '6012d95c961f396071be8709'}
# 207495 {'_id': ObjectId('6012d95c961f396071be870a'), 'evid': 207495, 'latitude': 14.959, 'longitude': -93.026, 'depth': 49.0, 'time': 1331680003.56, 'source_id': '6012d95c961f396071be870a'}
# 207500 {'_id': ObjectId('6012d95c961f396071be870b'), 'evid': 207500, 'latitude': 40.887, 'longitude': 144.944, 'depth': 12.0, 'time': 1331716115.14, 'source_id': '6012d95c961f396071be870b'}
# 207501 {'_id': ObjectId('6012d95c961f396071be870c'), 'evid': 207501, 'latitude': -24.412, 'longitude': -176.331, 'depth': 10.0, 'time': 1331716722.8, 'source_id': '6012d95c961f396071be870c'}
# 207502 {'_id': ObjectId('6012d95c961f396071be870d'), 'evid': 207502, 'latitude': 40.781, 'longitude': 144.761, 'depth': 10.0, 'time': 1331722164.58, 'source_id': '6012d95c961f396071be870d'}
# 207503 {'_id': ObjectId('6012d95c961f396071be870e'), 'evid': 207503, 'latitude': 40.755, 'longitude': 144.806, 'depth': 12.0, 'time': 1331722660.1, 'source_id': '6012d95c961f396071be870e'}
# 207504 {'_id': ObjectId('6012d95c961f396071be870f'), 'evid': 207504, 'latitude': 40.905, 'longitude': 144.848, 'depth': 10.0, 'time': 1331725217.1, 'source_id': '6012d95c961f396071be870f'}
# 207505 {'_id': ObjectId('6012d95c961f396071be8710'), 'evid': 207505, 'latitude': 35.687, 'longitude': 140.695, 'depth': 10.0, 'time': 1331726704.52, 'source_id': '6012d95c961f396071be8710'}
# 207512 {'_id': ObjectId('6012d95c961f396071be8711'), 'evid': 207512, 'latitude': -5.595, 'longitude': 151.042, 'depth': 28.0, 'time': 1331759588.04, 'source_id': '6012d95c961f396071be8711'}
# 207513 {'_id': ObjectId('6012d95c961f396071be8712'), 'evid': 207513, 'latitude': 35.502, 'longitude': 141.612, 'depth': 30.0, 'time': 1331761135.35, 'source_id': '6012d95c961f396071be8712'}
# 207522 {'_id': ObjectId('6012d95c961f396071be8713'), 'evid': 207522, 'latitude': 35.802, 'longitude': 139.279, 'depth': 103.8, 'time': 1331839218.26, 'source_id': '6012d95c961f396071be8713'}
# 207524 {'_id': ObjectId('6012d95c961f396071be8714'), 'evid': 207524, 'latitude': 49.274, 'longitude': 156.074, 'depth': 10.0, 'time': 1331858283.91, 'source_id': '6012d95c961f396071be8714'}
# 207525 {'_id': ObjectId('6012d95c961f396071be8715'), 'evid': 207525, 'latitude': 10.037, 'longitude': 125.633, 'depth': 18.0, 'time': 1331884682.5, 'source_id': '6012d95c961f396071be8715'}
# 207539 {'_id': ObjectId('6012d95c961f396071be8716'), 'evid': 207539, 'latitude': -34.905, 'longitude': -107.644, 'depth': 11.8, 'time': 1332013820.56, 'source_id': '6012d95c961f396071be8716'}
# 207547 {'_id': ObjectId('6012d95c961f396071be8717'), 'evid': 207547, 'latitude': -4.36, 'longitude': 143.888, 'depth': 113.4, 'time': 1332164554.67, 'source_id': '6012d95c961f396071be8717'}
# 207555 {'_id': ObjectId('6012d95c961f396071be8718'), 'evid': 207555, 'latitude': -14.621, 'longitude': -175.702, 'depth': 27.9, 'time': 1332200795.4, 'source_id': '6012d95c961f396071be8718'}
# 207568 {'_id': ObjectId('6012d95c961f396071be8719'), 'evid': 207568, 'latitude': -3.812, 'longitude': 140.266, 'depth': 66.0, 'time': 1332266178.8, 'source_id': '6012d95c961f396071be8719'}
# 207569 {'_id': ObjectId('6012d95c961f396071be871a'), 'evid': 207569, 'latitude': 16.493, 'longitude': -98.231, 'depth': 20.0, 'time': 1332266567.44, 'source_id': '6012d95c961f396071be871a'}
# 207570 {'_id': ObjectId('6012d95c961f396071be871b'), 'evid': 207570, 'latitude': 16.289, 'longitude': -98.172, 'depth': 10.0, 'time': 1332267753.1, 'source_id': '6012d95c961f396071be871b'}
# 207571 {'_id': ObjectId('6012d95c961f396071be871c'), 'evid': 207571, 'latitude': 16.228, 'longitude': -98.22, 'depth': 10.0, 'time': 1332268536.95, 'source_id': '6012d95c961f396071be871c'}
# 207572 {'_id': ObjectId('6012d95c961f396071be871d'), 'evid': 207572, 'latitude': 15.899, 'longitude': -98.715, 'depth': 3.9, 'time': 1332270158.9, 'source_id': '6012d95c961f396071be871d'}
# 207574 {'_id': ObjectId('6012d95c961f396071be871e'), 'evid': 207574, 'latitude': 16.132, 'longitude': -98.338, 'depth': 10.0, 'time': 1332271190.98, 'source_id': '6012d95c961f396071be871e'}
# 207575 {'_id': ObjectId('6012d95c961f396071be871f'), 'evid': 207575, 'latitude': 16.323, 'longitude': -98.128, 'depth': 11.7, 'time': 1332272048.44, 'source_id': '6012d95c961f396071be871f'}
# 207576 {'_id': ObjectId('6012d95c961f396071be8720'), 'evid': 207576, 'latitude': 16.478, 'longitude': -97.987, 'depth': 24.6, 'time': 1332274479.99, 'source_id': '6012d95c961f396071be8720'}
# 207599 {'_id': ObjectId('6012d95c961f396071be8721'), 'evid': 207599, 'latitude': -6.242, 'longitude': 145.955, 'depth': 118.0, 'time': 1332368106.13, 'source_id': '6012d95c961f396071be8721'}
# 207600 {'_id': ObjectId('6012d95c961f396071be8722'), 'evid': 207600, 'latitude': 3.513, 'longitude': 125.859, 'depth': 116.9, 'time': 1332375696.95, 'source_id': '6012d95c961f396071be8722'}
# 207611 {'_id': ObjectId('6012d95c961f396071be8723'), 'evid': 207611, 'latitude': 16.334, 'longitude': -98.343, 'depth': 27.7, 'time': 1332434807.79, 'source_id': '6012d95c961f396071be8723'}
# 207639 {'_id': ObjectId('6012d95c961f396071be8724'), 'evid': 207639, 'latitude': -33.052, 'longitude': -71.063, 'depth': 68.8, 'time': 1332574113.0, 'source_id': '6012d95c961f396071be8724'}
# 207654 {'_id': ObjectId('6012d95c961f396071be8725'), 'evid': 207654, 'latitude': 37.692, 'longitude': 141.603, 'depth': 62.2, 'time': 1332681761.65, 'source_id': '6012d95c961f396071be8725'}
# 207656 {'_id': ObjectId('6012d95c961f396071be8726'), 'evid': 207656, 'latitude': -18.638, 'longitude': -178.774, 'depth': 507.5, 'time': 1332683962.57, 'source_id': '6012d95c961f396071be8726'}
# 207659 {'_id': ObjectId('6012d95c961f396071be8727'), 'evid': 207659, 'latitude': -35.2, 'longitude': -72.217, 'depth': 40.7, 'time': 1332715026.0, 'source_id': '6012d95c961f396071be8727'}
# 207664 {'_id': ObjectId('6012d95c961f396071be8728'), 'evid': 207664, 'latitude': 66.363, 'longitude': -174.648, 'depth': 10.0, 'time': 1332754218.74, 'source_id': '6012d95c961f396071be8728'}
# 207665 {'_id': ObjectId('6012d95c961f396071be8729'), 'evid': 207665, 'latitude': 39.171, 'longitude': 42.33, 'depth': 5.0, 'time': 1332758132.64, 'source_id': '6012d95c961f396071be8729'}
# 207674 {'_id': ObjectId('6012d95c961f396071be872a'), 'evid': 207674, 'latitude': 9.995, 'longitude': -104.228, 'depth': 10.0, 'time': 1332784122.42, 'source_id': '6012d95c961f396071be872a'}
# 207678 {'_id': ObjectId('6012d95c961f396071be872b'), 'evid': 207678, 'latitude': 10.071, 'longitude': -104.16, 'depth': 10.0, 'time': 1332785572.85, 'source_id': '6012d95c961f396071be872b'}
# 207687 {'_id': ObjectId('6012d95c961f396071be872c'), 'evid': 207687, 'latitude': 39.859, 'longitude': 142.017, 'depth': 15.0, 'time': 1332846044.5, 'source_id': '6012d95c961f396071be872c'}
# 207724 {'_id': ObjectId('6012d95c961f396071be872d'), 'evid': 207724, 'latitude': 37.539, 'longitude': 141.244, 'depth': 57.2, 'time': 1333082313.66, 'source_id': '6012d95c961f396071be872d'}
# 207730 {'_id': ObjectId('6012d95c961f396071be872e'), 'evid': 207730, 'latitude': 40.764, 'longitude': 144.807, 'depth': 10.0, 'time': 1333104924.4, 'source_id': '6012d95c961f396071be872e'}
# 207740 {'_id': ObjectId('6012d95c961f396071be872f'), 'evid': 207740, 'latitude': 14.383, 'longitude': -93.062, 'depth': 10.0, 'time': 1333131368.31, 'source_id': '6012d95c961f396071be872f'}
# 207741 {'_id': ObjectId('6012d95c961f396071be8730'), 'evid': 207741, 'latitude': -6.583, 'longitude': 154.659, 'depth': 62.4, 'time': 1333137065.98, 'source_id': '6012d95c961f396071be8730'}
# 207745 {'_id': ObjectId('6012d95c961f396071be8731'), 'evid': 207745, 'latitude': 4.616, 'longitude': 95.115, 'depth': 59.3, 'time': 1333144931.96, 'source_id': '6012d95c961f396071be8731'}
# 207749 {'_id': ObjectId('6012d95c961f396071be8732'), 'evid': 207749, 'latitude': -23.63, 'longitude': 179.299, 'depth': 534.5, 'time': 1333184679.27, 'source_id': '6012d95c961f396071be8732'}
# 207756 {'_id': ObjectId('6012d95c961f396071be8733'), 'evid': 207756, 'latitude': -20.326, 'longitude': -175.234, 'depth': 142.6, 'time': 1333213608.94, 'source_id': '6012d95c961f396071be8733'}
# 207765 {'_id': ObjectId('6012d95c961f396071be8734'), 'evid': 207765, 'latitude': -23.045, 'longitude': -69.025, 'depth': 94.5, 'time': 1333265496.98, 'source_id': '6012d95c961f396071be8734'}
# 207768 {'_id': ObjectId('6012d95c961f396071be8735'), 'evid': 207768, 'latitude': -35.191, 'longitude': -14.877, 'depth': 10.0, 'time': 1333286072.67, 'source_id': '6012d95c961f396071be8735'}
# 207769 {'_id': ObjectId('6012d95c961f396071be8736'), 'evid': 207769, 'latitude': 37.116, 'longitude': 140.957, 'depth': 48.0, 'time': 1333289064.91, 'source_id': '6012d95c961f396071be8736'}
# 207773 {'_id': ObjectId('6012d95c961f396071be8737'), 'evid': 207773, 'latitude': -4.516, 'longitude': 153.427, 'depth': 117.9, 'time': 1333316644.13, 'source_id': '6012d95c961f396071be8737'}
# 207774 {'_id': ObjectId('6012d95c961f396071be8738'), 'evid': 207774, 'latitude': 16.46, 'longitude': -98.54, 'depth': 20.0, 'time': 1333319028.0, 'source_id': '6012d95c961f396071be8738'}
# 207776 {'_id': ObjectId('6012d95c961f396071be8739'), 'evid': 207776, 'latitude': -16.935, 'longitude': -173.514, 'depth': 42.7, 'time': 1333354626.95, 'source_id': '6012d95c961f396071be8739'}
# 207781 {'_id': ObjectId('6012d95c961f396071be873a'), 'evid': 207781, 'latitude': 16.395, 'longitude': -98.316, 'depth': 9.0, 'time': 1333388202.06, 'source_id': '6012d95c961f396071be873a'}
# 207792 {'_id': ObjectId('6012d95c961f396071be873b'), 'evid': 207792, 'latitude': -33.847, 'longitude': -72.757, 'depth': 31.6, 'time': 1333419063.0, 'source_id': '6012d95c961f396071be873b'}
# 207794 {'_id': ObjectId('6012d95c961f396071be873c'), 'evid': 207794, 'latitude': -5.18, 'longitude': -80.583, 'depth': 63.9, 'time': 1333422488.02, 'source_id': '6012d95c961f396071be873c'}
# 207796 {'_id': ObjectId('6012d95c961f396071be873d'), 'evid': 207796, 'latitude': -19.638, 'longitude': -69.093, 'depth': 117.0, 'time': 1333437908.0, 'source_id': '6012d95c961f396071be873d'}
# 207815 {'_id': ObjectId('6012d95c961f396071be873e'), 'evid': 207815, 'latitude': -5.654, 'longitude': 133.876, 'depth': 10.0, 'time': 1333496539.37, 'source_id': '6012d95c961f396071be873e'}
# 207857 {'_id': ObjectId('6012d95c961f396071be873f'), 'evid': 207857, 'latitude': -4.551, 'longitude': 153.457, 'depth': 108.5, 'time': 1333728958.01, 'source_id': '6012d95c961f396071be873f'}
# 207878 {'_id': ObjectId('6012d95c961f396071be8740'), 'evid': 207878, 'latitude': -6.746, 'longitude': 149.555, 'depth': 20.0, 'time': 1333799884.8, 'source_id': '6012d95c961f396071be8740'}
# 207887 {'_id': ObjectId('6012d95c961f396071be8741'), 'evid': 207887, 'latitude': -6.057, 'longitude': 130.684, 'depth': 79.7, 'time': 1333829380.55, 'source_id': '6012d95c961f396071be8741'}
# 207907 {'_id': ObjectId('6012d95c961f396071be8742'), 'evid': 207907, 'latitude': 24.0, 'longitude': 122.35, 'depth': 10.0, 'time': 1333921410.9, 'source_id': '6012d95c961f396071be8742'}
# 207919 {'_id': ObjectId('6012d95c961f396071be8743'), 'evid': 207919, 'latitude': -1.261, 'longitude': -13.972, 'depth': 10.0, 'time': 1334034548.41, 'source_id': '6012d95c961f396071be8743'}
# 207935 {'_id': ObjectId('6012d95c961f396071be8744'), 'evid': 207935, 'latitude': -16.856, 'longitude': -14.397, 'depth': 9.2, 'time': 1334120006.38, 'source_id': '6012d95c961f396071be8744'}
# 207941 {'_id': ObjectId('6012d95c961f396071be8745'), 'evid': 207941, 'latitude': 51.364, 'longitude': -176.097, 'depth': 20.8, 'time': 1334134809.71, 'source_id': '6012d95c961f396071be8745'}
# 207985 {'_id': ObjectId('6012d95c961f396071be8746'), 'evid': 207985, 'latitude': 43.584, 'longitude': -127.638, 'depth': 8.0, 'time': 1334184106.04, 'source_id': '6012d95c961f396071be8746'}
# 207986 {'_id': ObjectId('6012d95c961f396071be8747'), 'evid': 207986, 'latitude': 18.229, 'longitude': -102.689, 'depth': 20.0, 'time': 1334184910.25, 'source_id': '6012d95c961f396071be8747'}
# 207999 {'_id': ObjectId('6012d95c961f396071be8748'), 'evid': 207999, 'latitude': 28.837, 'longitude': -113.027, 'depth': 9.0, 'time': 1334214360.57, 'source_id': '6012d95c961f396071be8748'}
# 208000 {'_id': ObjectId('6012d95c961f396071be8749'), 'evid': 208000, 'latitude': 28.696, 'longitude': -113.104, 'depth': 13.0, 'time': 1334214948.5, 'source_id': '6012d95c961f396071be8749'}
# 208004 {'_id': ObjectId('6012d95c961f396071be874a'), 'evid': 208004, 'latitude': 36.865, 'longitude': 141.032, 'depth': 27.3, 'time': 1334229600.98, 'source_id': '6012d95c961f396071be874a'}
# 208011 {'_id': ObjectId('6012d95c961f396071be874b'), 'evid': 208011, 'latitude': 37.513, 'longitude': 141.468, 'depth': 25.1, 'time': 1334242252.85, 'source_id': '6012d95c961f396071be874b'}
# 208024 {'_id': ObjectId('6012d95c961f396071be874c'), 'evid': 208024, 'latitude': 36.988, 'longitude': 141.152, 'depth': 11.0, 'time': 1334311801.2, 'source_id': '6012d95c961f396071be874c'}
# 208025 {'_id': ObjectId('6012d95c961f396071be874d'), 'evid': 208025, 'latitude': 16.236, 'longitude': -98.138, 'depth': 15.1, 'time': 1334311804.62, 'source_id': '6012d95c961f396071be874d'}
# 208026 {'_id': ObjectId('6012d95c961f396071be874e'), 'evid': 208026, 'latitude': 37.022, 'longitude': 141.151, 'depth': 28.1, 'time': 1334319125.66, 'source_id': '6012d95c961f396071be874e'}
# 208046 {'_id': ObjectId('6012d95c961f396071be874f'), 'evid': 208046, 'latitude': -57.679, 'longitude': -65.308, 'depth': 15.0, 'time': 1334400979.38, 'source_id': '6012d95c961f396071be874f'}
# 208049 {'_id': ObjectId('6012d95c961f396071be8750'), 'evid': 208049, 'latitude': 49.38, 'longitude': 155.651, 'depth': 90.3, 'time': 1334416394.14, 'source_id': '6012d95c961f396071be8750'}
# 208058 {'_id': ObjectId('6012d95c961f396071be8751'), 'evid': 208058, 'latitude': -18.972, 'longitude': 168.741, 'depth': 11.0, 'time': 1334441126.43, 'source_id': '6012d95c961f396071be8751'}
# ...
# 303089 {'_id': ObjectId('6012d95c961f396071be898e'), 'evid': 303089, 'latitude': 13.757, 'longitude': -92.113, 'depth': 10.0, 'time': 1354217551.75, 'source_id': '6012d95c961f396071be898e'}
# 303099 {'_id': ObjectId('6012d95c961f396071be898f'), 'evid': 303099, 'latitude': -18.824, 'longitude': -175.595, 'depth': 200.2, 'time': 1354274438.43, 'source_id': '6012d95c961f396071be898f'}
# 303802 {'_id': ObjectId('6012d95c961f396071be8990'), 'evid': 303802, 'latitude': 58.422, 'longitude': -154.121, 'depth': 91.5, 'time': 1354348857.94, 'source_id': '6012d95c961f396071be8990'}
# 303809 {'_id': ObjectId('6012d95c961f396071be8991'), 'evid': 303809, 'latitude': -16.975, 'longitude': 167.645, 'depth': 32.0, 'time': 1354409662.69, 'source_id': '6012d95c961f396071be8991'}
# 303813 {'_id': ObjectId('6012d95c961f396071be8992'), 'evid': 303813, 'latitude': 11.852, 'longitude': -88.988, 'depth': 47.5, 'time': 1354423477.27, 'source_id': '6012d95c961f396071be8992'}
# 303816 {'_id': ObjectId('6012d95c961f396071be8993'), 'evid': 303816, 'latitude': -20.69, 'longitude': -174.214, 'depth': 10.0, 'time': 1354455164.66, 'source_id': '6012d95c961f396071be8993'}
# 303818 {'_id': ObjectId('6012d95c961f396071be8994'), 'evid': 303818, 'latitude': 23.91, 'longitude': 121.631, 'depth': 10.0, 'time': 1354470337.18, 'source_id': '6012d95c961f396071be8994'}
# 303829 {'_id': ObjectId('6012d95c961f396071be8995'), 'evid': 303829, 'latitude': -54.637, 'longitude': -136.157, 'depth': 16.8, 'time': 1354526858.27, 'source_id': '6012d95c961f396071be8995'}
# 303830 {'_id': ObjectId('6012d95c961f396071be8996'), 'evid': 303830, 'latitude': -28.745, 'longitude': -70.302, 'depth': 95.4, 'time': 1354527113.0, 'source_id': '6012d95c961f396071be8996'}
# 303842 {'_id': ObjectId('6012d95c961f396071be8997'), 'evid': 303842, 'latitude': 14.16, 'longitude': -92.372, 'depth': 35.0, 'time': 1354579115.43, 'source_id': '6012d95c961f396071be8997'}
# 303843 {'_id': ObjectId('6012d95c961f396071be8998'), 'evid': 303843, 'latitude': 61.237, 'longitude': -150.76, 'depth': 62.2, 'time': 1354585368.46, 'source_id': '6012d95c961f396071be8998'}
# 303871 {'_id': ObjectId('6012d95c961f396071be8999'), 'evid': 303871, 'latitude': 64.886, 'longitude': -133.99, 'depth': 5.0, 'time': 1354718100.0, 'source_id': '6012d95c961f396071be8999'}
# 303874 {'_id': ObjectId('6012d95c961f396071be899a'), 'evid': 303874, 'latitude': 33.506, 'longitude': 59.571, 'depth': 14.4, 'time': 1354727293.56, 'source_id': '6012d95c961f396071be899a'}
# 303885 {'_id': ObjectId('6012d95c961f396071be899b'), 'evid': 303885, 'latitude': -20.781, 'longitude': -178.95, 'depth': 625.8, 'time': 1354748916.86, 'source_id': '6012d95c961f396071be899b'}
# 303887 {'_id': ObjectId('6012d95c961f396071be899c'), 'evid': 303887, 'latitude': 10.974, 'longitude': 126.638, 'depth': 30.6, 'time': 1354754604.1, 'source_id': '6012d95c961f396071be899c'}
# 303904 {'_id': ObjectId('6012d95c961f396071be899d'), 'evid': 303904, 'latitude': 37.89, 'longitude': 143.949, 'depth': 31.0, 'time': 1354868303.13, 'source_id': '6012d95c961f396071be899d'}
# 303905 {'_id': ObjectId('6012d95c961f396071be899e'), 'evid': 303905, 'latitude': 37.914, 'longitude': 143.764, 'depth': 32.0, 'time': 1354869074.81, 'source_id': '6012d95c961f396071be899e'}
# 303906 {'_id': ObjectId('6012d95c961f396071be899f'), 'evid': 303906, 'latitude': 37.828, 'longitude': 143.607, 'depth': 20.2, 'time': 1354870093.04, 'source_id': '6012d95c961f396071be899f'}
# 303909 {'_id': ObjectId('6012d95c961f396071be89a0'), 'evid': 303909, 'latitude': 38.745, 'longitude': 88.098, 'depth': 10.0, 'time': 1354889322.86, 'source_id': '6012d95c961f396071be89a0'}
# 303910 {'_id': ObjectId('6012d95c961f396071be89a1'), 'evid': 303910, 'latitude': 37.813, 'longitude': 143.633, 'depth': 35.0, 'time': 1354890737.2, 'source_id': '6012d95c961f396071be89a1'}
# 303912 {'_id': ObjectId('6012d95c961f396071be89a2'), 'evid': 303912, 'latitude': 37.654, 'longitude': 143.771, 'depth': 35.0, 'time': 1354896114.64, 'source_id': '6012d95c961f396071be89a2'}
# 303914 {'_id': ObjectId('6012d95c961f396071be89a3'), 'evid': 303914, 'latitude': -38.278, 'longitude': 176.099, 'depth': 167.5, 'time': 1354904347.05, 'source_id': '6012d95c961f396071be89a3'}
# 303919 {'_id': ObjectId('6012d95c961f396071be89a4'), 'evid': 303919, 'latitude': -7.661, 'longitude': 146.954, 'depth': 139.8, 'time': 1354909823.43, 'source_id': '6012d95c961f396071be89a4'}
# 303928 {'_id': ObjectId('6012d95c961f396071be89a5'), 'evid': 303928, 'latitude': 37.739, 'longitude': 143.762, 'depth': 24.4, 'time': 1354921200.5, 'source_id': '6012d95c961f396071be89a5'}
# 303936 {'_id': ObjectId('6012d95c961f396071be89a6'), 'evid': 303936, 'latitude': 25.748, 'longitude': 122.35, 'depth': 291.3, 'time': 1354976815.85, 'source_id': '6012d95c961f396071be89a6'}
# 303939 {'_id': ObjectId('6012d95c961f396071be89a7'), 'evid': 303939, 'latitude': -7.211, 'longitude': 143.973, 'depth': 10.0, 'time': 1354984516.82, 'source_id': '6012d95c961f396071be89a7'}
# 303946 {'_id': ObjectId('6012d95c961f396071be89a8'), 'evid': 303946, 'latitude': 37.744, 'longitude': 143.617, 'depth': 19.1, 'time': 1355020457.09, 'source_id': '6012d95c961f396071be89a8'}
# 303956 {'_id': ObjectId('6012d95c961f396071be89a9'), 'evid': 303956, 'latitude': -16.236, 'longitude': -174.22, 'depth': 137.7, 'time': 1355086359.24, 'source_id': '6012d95c961f396071be89a9'}
# 303959 {'_id': ObjectId('6012d95c961f396071be89aa'), 'evid': 303959, 'latitude': 6.703, 'longitude': 126.166, 'depth': 63.2, 'time': 1355089535.21, 'source_id': '6012d95c961f396071be89aa'}
# 303965 {'_id': ObjectId('6012d95c961f396071be89ab'), 'evid': 303965, 'latitude': -6.533, 'longitude': 129.825, 'depth': 155.0, 'time': 1355158388.77, 'source_id': '6012d95c961f396071be89ab'}
# 303974 {'_id': ObjectId('6012d95c961f396071be89ac'), 'evid': 303974, 'latitude': 68.093, 'longitude': -136.372, 'depth': 10.0, 'time': 1355202740.0, 'source_id': '6012d95c961f396071be89ac'}
# 303976 {'_id': ObjectId('6012d95c961f396071be89ad'), 'evid': 303976, 'latitude': 0.533, 'longitude': 126.231, 'depth': 30.0, 'time': 1355206707.33, 'source_id': '6012d95c961f396071be89ad'}
# 303980 {'_id': ObjectId('6012d95c961f396071be89ae'), 'evid': 303980, 'latitude': -18.974, 'longitude': 167.669, 'depth': 35.0, 'time': 1355228301.49, 'source_id': '6012d95c961f396071be89ae'}
# 303991 {'_id': ObjectId('6012d95c961f396071be89af'), 'evid': 303991, 'latitude': -19.556, 'longitude': -176.278, 'depth': 10.0, 'time': 1355276660.69, 'source_id': '6012d95c961f396071be89af'}
# 304012 {'_id': ObjectId('6012d95c961f396071be89b0'), 'evid': 304012, 'latitude': -30.911, 'longitude': -178.39, 'depth': 38.7, 'time': 1355360008.77, 'source_id': '6012d95c961f396071be89b0'}
# 304015 {'_id': ObjectId('6012d95c961f396071be89b1'), 'evid': 304015, 'latitude': 9.062, 'longitude': -84.015, 'depth': 48.9, 'time': 1355418982.19, 'source_id': '6012d95c961f396071be89b1'}
# 304016 {'_id': ObjectId('6012d95c961f396071be89b2'), 'evid': 304016, 'latitude': 9.225, 'longitude': -83.947, 'depth': 47.4, 'time': 1355419229.21, 'source_id': '6012d95c961f396071be89b2'}
# 304023 {'_id': ObjectId('6012d95c961f396071be89b3'), 'evid': 304023, 'latitude': 13.071, 'longitude': -89.967, 'depth': 10.0, 'time': 1355433999.18, 'source_id': '6012d95c961f396071be89b3'}
# 304024 {'_id': ObjectId('6012d95c961f396071be89b4'), 'evid': 304024, 'latitude': 80.804, 'longitude': 121.383, 'depth': 10.0, 'time': 1355439818.53, 'source_id': '6012d95c961f396071be89b4'}
# 304025 {'_id': ObjectId('6012d95c961f396071be89b5'), 'evid': 304025, 'latitude': 13.926, 'longitude': -91.679, 'depth': 37.3, 'time': 1355457846.86, 'source_id': '6012d95c961f396071be89b5'}
# 304028 {'_id': ObjectId('6012d95c961f396071be89b6'), 'evid': 304028, 'latitude': 31.095, 'longitude': -119.66, 'depth': 13.0, 'time': 1355481361.59, 'source_id': '6012d95c961f396071be89b6'}
# 304033 {'_id': ObjectId('6012d95c961f396071be89b7'), 'evid': 304033, 'latitude': -15.307, 'longitude': -178.186, 'depth': 10.0, 'time': 1355503958.24, 'source_id': '6012d95c961f396071be89b7'}
# 304044 {'_id': ObjectId('6012d95c961f396071be89b8'), 'evid': 304044, 'latitude': 37.311, 'longitude': 141.205, 'depth': 62.6, 'time': 1355545622.33, 'source_id': '6012d95c961f396071be89b8'}
# 304045 {'_id': ObjectId('6012d95c961f396071be89b9'), 'evid': 304045, 'latitude': 52.291, 'longitude': 174.011, 'depth': 26.0, 'time': 1355546969.65, 'source_id': '6012d95c961f396071be89b9'}
# 304058 {'_id': ObjectId('6012d95c961f396071be89ba'), 'evid': 304058, 'latitude': -4.632, 'longitude': 153.016, 'depth': 52.0, 'time': 1355599802.17, 'source_id': '6012d95c961f396071be89ba'}
# 304068 {'_id': ObjectId('6012d95c961f396071be89bb'), 'evid': 304068, 'latitude': 14.675, 'longitude': -91.457, 'depth': 115.1, 'time': 1355652432.04, 'source_id': '6012d95c961f396071be89bb'}
# 304070 {'_id': ObjectId('6012d95c961f396071be89bc'), 'evid': 304070, 'latitude': 14.185, 'longitude': 146.733, 'depth': 21.0, 'time': 1355673120.92, 'source_id': '6012d95c961f396071be89bc'}
# 304078 {'_id': ObjectId('6012d95c961f396071be89bd'), 'evid': 304078, 'latitude': 49.785, 'longitude': 155.837, 'depth': 68.0, 'time': 1355704138.8, 'source_id': '6012d95c961f396071be89bd'}
# 304081 {'_id': ObjectId('6012d95c961f396071be89be'), 'evid': 304081, 'latitude': -0.649, 'longitude': 123.807, 'depth': 44.2, 'time': 1355735790.9, 'source_id': '6012d95c961f396071be89be'}
# 304085 {'_id': ObjectId('6012d95c961f396071be89bf'), 'evid': 304085, 'latitude': -4.182, 'longitude': -104.488, 'depth': 10.0, 'time': 1355766092.26, 'source_id': '6012d95c961f396071be89bf'}
# 304086 {'_id': ObjectId('6012d95c961f396071be89c0'), 'evid': 304086, 'latitude': -4.028, 'longitude': -104.177, 'depth': 10.0, 'time': 1355766406.63, 'source_id': '6012d95c961f396071be89c0'}
# 304097 {'_id': ObjectId('6012d95c961f396071be89c1'), 'evid': 304097, 'latitude': 16.028, 'longitude': -95.72, 'depth': 42.5, 'time': 1355794703.0, 'source_id': '6012d95c961f396071be89c1'}
# 304099 {'_id': ObjectId('6012d95c961f396071be89c2'), 'evid': 304099, 'latitude': 13.054, 'longitude': -89.978, 'depth': 35.0, 'time': 1355818342.03, 'source_id': '6012d95c961f396071be89c2'}
# 304107 {'_id': ObjectId('6012d95c961f396071be89c3'), 'evid': 304107, 'latitude': 36.664, 'longitude': 141.917, 'depth': 32.1, 'time': 1355855784.3, 'source_id': '6012d95c961f396071be89c3'}
# 304156 {'_id': ObjectId('6012d95c961f396071be89c4'), 'evid': 304156, 'latitude': 0.562, 'longitude': 126.217, 'depth': 27.5, 'time': 1356040049.76, 'source_id': '6012d95c961f396071be89c4'}
# 304178 {'_id': ObjectId('6012d95c961f396071be89c5'), 'evid': 304178, 'latitude': -14.344, 'longitude': 167.286, 'depth': 200.7, 'time': 1356128888.57, 'source_id': '6012d95c961f396071be89c5'}
# 304179 {'_id': ObjectId('6012d95c961f396071be89c6'), 'evid': 304179, 'latitude': 49.818, 'longitude': 155.103, 'depth': 125.2, 'time': 1356151357.57, 'source_id': '6012d95c961f396071be89c6'}
# 304184 {'_id': ObjectId('6012d95c961f396071be89c7'), 'evid': 304184, 'latitude': 22.443, 'longitude': 94.782, 'depth': 134.4, 'time': 1356194505.74, 'source_id': '6012d95c961f396071be89c7'}
# 304185 {'_id': ObjectId('6012d95c961f396071be89c8'), 'evid': 304185, 'latitude': 19.061, 'longitude': 121.194, 'depth': 38.9, 'time': 1356199637.45, 'source_id': '6012d95c961f396071be89c8'}
# 304190 {'_id': ObjectId('6012d95c961f396071be89c9'), 'evid': 304190, 'latitude': -13.086, 'longitude': 167.11, 'depth': 224.0, 'time': 1356222596.57, 'source_id': '6012d95c961f396071be89c9'}
# 304194 {'_id': ObjectId('6012d95c961f396071be89ca'), 'evid': 304194, 'latitude': 38.466, 'longitude': 44.863, 'depth': 10.0, 'time': 1356244737.14, 'source_id': '6012d95c961f396071be89ca'}
# 304197 {'_id': ObjectId('6012d95c961f396071be89cb'), 'evid': 304197, 'latitude': 4.19, 'longitude': 126.584, 'depth': 41.3, 'time': 1356267144.45, 'source_id': '6012d95c961f396071be89cb'}
# 304198 {'_id': ObjectId('6012d95c961f396071be89cc'), 'evid': 304198, 'latitude': 42.428, 'longitude': 41.073, 'depth': 16.1, 'time': 1356269500.94, 'source_id': '6012d95c961f396071be89cc'}
# 304207 {'_id': ObjectId('6012d95c961f396071be89cd'), 'evid': 304207, 'latitude': 54.907, 'longitude': 162.034, 'depth': 26.0, 'time': 1356335649.86, 'source_id': '6012d95c961f396071be89cd'}
# 304209 {'_id': ObjectId('6012d95c961f396071be89ce'), 'evid': 304209, 'latitude': -29.037, 'longitude': -71.494, 'depth': 19.7, 'time': 1356351155.34, 'source_id': '6012d95c961f396071be89ce'}
# 304211 {'_id': ObjectId('6012d95c961f396071be89cf'), 'evid': 304211, 'latitude': 4.149, 'longitude': 126.679, 'depth': 25.0, 'time': 1356353900.18, 'source_id': '6012d95c961f396071be89cf'}
# 304219 {'_id': ObjectId('6012d95c961f396071be89d0'), 'evid': 304219, 'latitude': 1.109, 'longitude': 125.464, 'depth': 52.5, 'time': 1356420881.22, 'source_id': '6012d95c961f396071be89d0'}
# 304223 {'_id': ObjectId('6012d95c961f396071be89d1'), 'evid': 304223, 'latitude': 42.436, 'longitude': 40.974, 'depth': 10.0, 'time': 1356475473.51, 'source_id': '6012d95c961f396071be89d1'}
# 304228 {'_id': ObjectId('6012d95c961f396071be89d2'), 'evid': 304228, 'latitude': -37.274, 'longitude': -73.267, 'depth': 29.0, 'time': 1356527877.26, 'source_id': '6012d95c961f396071be89d2'}
# 304232 {'_id': ObjectId('6012d95c961f396071be89d3'), 'evid': 304232, 'latitude': -10.411, 'longitude': -13.132, 'depth': 10.0, 'time': 1356553466.65, 'source_id': '6012d95c961f396071be89d3'}
# 304242 {'_id': ObjectId('6012d95c961f396071be89d4'), 'evid': 304242, 'latitude': -35.783, 'longitude': -73.255, 'depth': 14.2, 'time': 1356568628.83, 'source_id': '6012d95c961f396071be89d4'}
# 304245 {'_id': ObjectId('6012d95c961f396071be89d5'), 'evid': 304245, 'latitude': 13.007, 'longitude': -58.003, 'depth': 10.0, 'time': 1356586572.08, 'source_id': '6012d95c961f396071be89d5'}
# 304247 {'_id': ObjectId('6012d95c961f396071be89d6'), 'evid': 304247, 'latitude': -18.302, 'longitude': -173.562, 'depth': 22.9, 'time': 1356601319.69, 'source_id': '6012d95c961f396071be89d6'}
# 304253 {'_id': ObjectId('6012d95c961f396071be89d7'), 'evid': 304253, 'latitude': -12.396, 'longitude': -14.876, 'depth': 10.0, 'time': 1356626039.87, 'source_id': '6012d95c961f396071be89d7'}
# 304268 {'_id': ObjectId('6012d95c961f396071be89d8'), 'evid': 304268, 'latitude': -29.596, 'longitude': -176.245, 'depth': 10.0, 'time': 1356690945.05, 'source_id': '6012d95c961f396071be89d8'}
# 304271 {'_id': ObjectId('6012d95c961f396071be89d9'), 'evid': 304271, 'latitude': 55.707, 'longitude': 164.724, 'depth': 35.0, 'time': 1356702154.81, 'source_id': '6012d95c961f396071be89d9'}
# 304277 {'_id': ObjectId('6012d95c961f396071be89da'), 'evid': 304277, 'latitude': -0.145, 'longitude': 122.918, 'depth': 112.1, 'time': 1356715938.07, 'source_id': '6012d95c961f396071be89da'}
# 304290 {'_id': ObjectId('6012d95c961f396071be89db'), 'evid': 304290, 'latitude': 38.738, 'longitude': 142.024, 'depth': 55.6, 'time': 1356793178.91, 'source_id': '6012d95c961f396071be89db'}
# 304292 {'_id': ObjectId('6012d95c961f396071be89dc'), 'evid': 304292, 'latitude': 35.711, 'longitude': 70.599, 'depth': 117.4, 'time': 1356803452.84, 'source_id': '6012d95c961f396071be89dc'}
# 304300 {'_id': ObjectId('6012d95c961f396071be89dd'), 'evid': 304300, 'latitude': 37.018, 'longitude': 141.168, 'depth': 39.8, 'time': 1356822324.2, 'source_id': '6012d95c961f396071be89dd'}
# 304308 {'_id': ObjectId('6012d95c961f396071be89de'), 'evid': 304308, 'latitude': 14.446, 'longitude': -92.991, 'depth': 26.0, 'time': 1356870081.87, 'source_id': '6012d95c961f396071be89de'}
# 304315 {'_id': ObjectId('6012d95c961f396071be89df'), 'evid': 304315, 'latitude': -12.871, 'longitude': -70.932, 'depth': 35.0, 'time': 1356900568.72, 'source_id': '6012d95c961f396071be89df'}
# 304316 {'_id': ObjectId('6012d95c961f396071be89e0'), 'evid': 304316, 'latitude': 15.031, 'longitude': -92.037, 'depth': 122.6, 'time': 1356916518.77, 'source_id': '6012d95c961f396071be89e0'}
# loaded  None  new documents into source collection

# %% [markdown]
# That output suggests strongly that evids were set earlier when I created the original usarray data set.  Will blunder on assuming that is so.

# %% [markdown]
# Anf finally this for this step:

# %%
from mspasspy.preprocessing.css30.dbarrival import set_source_id_from_evid
result=set_source_id_from_evid(db)
print('Number of arrival documents processed=',result[0])
print('Number of arrival documents updated=',result[1])
print('Number arrivals in set that did not match keyed by evid =',result[3])
# Out:
# Number of arrival documents processed= 0
# Number of arrival documents updated= 0
# Number arrivals in set that did not match keyed by evid = {}

# %% [markdown]
# That failed for an unknown reason.  The next books seeks to know why.

# %%
cursor=db.arrival.find({}).limit(20)
for doc in cursor:
    print(doc)
# Out:
# {'_id': ObjectId('601012354b4f9e654b4e0e97'), 'index': 6, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': '115A', 'phase': 'P', 'iphase': 'P', 'delta': 62.786, 'seaz': 136.82, 'esaz': 322.89, 'residual': -0.054000000000000006, 'time': 1174877841.55093, 'deltim': 2.275, 'net': 'TA', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0e91'), 'index': 0, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': '319A', 'phase': 'P', 'iphase': 'P', 'delta': 60.128, 'seaz': 138.91, 'esaz': 323.99, 'residual': -0.445, 'time': 1174877823.17531, 'deltim': 1.3, 'css30_sta': '319ATA', 'net': 'TA', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0e94'), 'index': 3, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': '217A', 'phase': 'P', 'iphase': 'P', 'delta': 61.29600000000001, 'seaz': 137.7, 'esaz': 323.17, 'residual': -0.079, 'time': 1174877831.50638, 'deltim': 1.625, 'net': 'TA', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0e96'), 'index': 5, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': '116A', 'phase': 'P', 'iphase': 'P', 'delta': 62.38399999999999, 'seaz': 137.22, 'esaz': 323.14, 'residual': -0.7170000000000001, 'time': 1174877838.19964, 'deltim': 2.925, 'net': 'TA', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0e9a'), 'index': 9, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': 'X15A', 'phase': 'P', 'iphase': 'P', 'delta': 64.1, 'seaz': 137.42, 'esaz': 324.24, 'residual': -0.085, 'time': 1174877850.21896, 'deltim': 1.625, 'net': 'TA', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0e93'), 'index': 2, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': '218A', 'phase': 'P', 'iphase': 'P', 'delta': 61.007, 'seaz': 138.45, 'esaz': 323.88, 'residual': -0.107, 'time': 1174877829.5188901, 'deltim': 1.625, 'css30_sta': '218ATA', 'net': 'TA', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0e99'), 'index': 8, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': 'MVCO', 'phase': 'P', 'iphase': 'P', 'delta': 64.203, 'seaz': 141.58, 'esaz': 328.77, 'residual': -0.88, 'time': 1174877850.09711, 'deltim': 2.6, 'css30_sta': 'MVCOUS', 'net': 'US', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0e92'), 'index': 1, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': '318A', 'phase': 'P', 'iphase': 'P', 'delta': 60.576, 'seaz': 138.3, 'esaz': 323.51, 'residual': -0.099, 'time': 1174877826.5889, 'deltim': 1.625, 'css30_sta': '318ATA', 'net': 'TA', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0e95'), 'index': 4, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': '216A', 'phase': 'P', 'iphase': 'P', 'delta': 61.832, 'seaz': 137.23, 'esaz': 322.89, 'residual': -0.389, 'time': 1174877834.81605, 'deltim': 1.95, 'net': 'TA', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0e98'), 'index': 7, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': 'Z14A', 'phase': 'P', 'iphase': 'P', 'delta': 63.681000000000004, 'seaz': 136.44, 'esaz': 322.91, 'residual': 0.93, 'time': 1174877848.4718099, 'deltim': 1.95, 'css30_sta': 'Z14ATA', 'net': 'TA', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0e9c'), 'index': 11, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': 'WUAZ', 'phase': 'P', 'iphase': 'P', 'delta': 64.392, 'seaz': 138.5, 'esaz': 325.59, 'residual': -1.101, 'time': 1174877851.11815, 'deltim': 1.625, 'css30_sta': 'WUAZUS', 'net': 'US', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0e9b'), 'index': 10, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': 'Y14A', 'phase': 'P', 'iphase': 'P', 'delta': 64.132, 'seaz': 136.58, 'esaz': 323.31, 'residual': -0.053, 'time': 1174877850.46158, 'deltim': 1.95, 'css30_sta': 'Y14ATA', 'net': 'TA', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0ea0'), 'index': 15, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': 'W15A', 'phase': 'P', 'iphase': 'P', 'delta': 64.627, 'seaz': 137.62, 'esaz': 324.74, 'residual': 1.205, 'time': 1174877854.96231, 'deltim': 2.275, 'net': 'TA', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0e9d'), 'index': 12, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': 'X14A', 'phase': 'P', 'iphase': 'P', 'delta': 64.454, 'seaz': 136.85, 'esaz': 323.79, 'residual': -0.716, 'time': 1174877851.90942, 'deltim': 3.575, 'net': 'TA', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0e9e'), 'index': 13, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': 'Y13A', 'phase': 'P', 'iphase': 'P', 'delta': 64.516, 'seaz': 135.84, 'esaz': 322.67, 'residual': 0.297, 'time': 1174877853.3286, 'deltim': 1.95, 'net': 'TA', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0eac'), 'index': 27, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': 'T15A', 'phase': 'P', 'iphase': 'P', 'delta': 66.054, 'seaz': 138.08, 'esaz': 326.02, 'residual': -0.445, 'time': 1174877862.5619, 'deltim': 1.95, 'net': 'TA', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0e9f'), 'index': 14, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': 'GLA', 'phase': 'P', 'iphase': 'P', 'delta': 64.56, 'seaz': 134.76, 'esaz': 321.42, 'residual': 0.34, 'time': 1174877853.6588, 'deltim': 1.625, 'css30_sta': 'GLA_CI', 'net': 'CI', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0ead'), 'index': 28, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': 'BEL', 'phase': 'P', 'iphase': 'P', 'delta': 65.922, 'seaz': 134.11, 'esaz': 321.41, 'residual': 0.679, 'time': 1174877862.83465, 'deltim': 1.95, 'css30_sta': 'BEL_CI', 'net': 'CI', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0ebb'), 'index': 42, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': 'GSC', 'phase': 'P', 'iphase': 'P', 'delta': 67.303, 'seaz': 133.85, 'esaz': 321.93, 'residual': 1.3259999999999998, 'time': 1174877872.31057, 'deltim': 1.3, 'css30_sta': 'GSC_CI', 'net': 'CI', 'source_id': '6012d929961f396071be7569'}
# {'_id': ObjectId('601012354b4f9e654b4e0eaf'), 'index': 30, 'evid': 243020, 'source_lat': -17.376, 'source_lon': -72.611, 'source_depth': 26.9, 'source_time': 1174877218.64, 'mb': -999.0, 'ms': -999.0, 'sta': 'GMR', 'phase': 'P', 'iphase': 'P', 'delta': 66.27, 'seaz': 134.63, 'esaz': 322.24, 'residual': 0.33, 'time': 1174877864.7270901, 'deltim': 1.3, 'css30_sta': 'GMR_CI', 'net': 'CI', 'source_id': '6012d929961f396071be7569'}

# %% [markdown]
# From this output and looking at the code for set_source_id_from_evid I think it means this is all good to go.   Hence I'm going to see if I can release the kraken and got on.

# %% [markdown]
# Warning - the above takes a long time.  It might be smart to run the next box before running the above.
#
# ## Build index
# As noted in raw data tutorial building these indices will speed things up a lot:

# %%
db.arrival.create_index(
[
    ('source_id',1),
    ('net', 1),
    ('sta',1)
])
# Out:
# 'source_id_1_net_1_sta_1'

# %% [markdown]
# ## Source data final preprocessing
# One last step 8.1 of raw data tutorial.  No change form that prototype

# %%
from mspasspy.preprocessing.seed.ensembles import link_source_collection
# this function is like subroutine and returns nothing
#link_source_collection(db,prefer_evid=True)
# Above failed trying this variant
link_source_collection(db)

# %% [markdown]
# ## Ensemble preprocessing data loading
# This is a variant of the last box in the raw data tutorial. This should run a bit faster with no significant degradation of the result.   Omit the bandpass filtering and doesn't do demean until after cutting the data down to size with a shorter time window.

# %%
from mspasspy.util.Undertaker import Undertaker
from mspasspy.algorithms import signals
from mspasspy.ccore.seismic import (TimeWindow,TimeSeries,TimeSeriesEnsemble)
from mspasspy.algorithms.window import WindowData
from mspasspy.algorithms.bundle import bundle_seed_data
from mspasspy.preprocessing.seed.ensembles import (load_one_ensemble,
                                                   load_channel_data,
                                                   load_site_data,
                                                   load_arrivals_by_id,
                                                   erase_seed_metadata)
import time
stedronsky=Undertaker(db)
dbwf=db.import_miniseed_ensemble
cursor=dbwf.find({},no_cursor_timeout = True)
n=0
for doc in cursor:
    print('working on enemble number ',n)
    if not 'evid' in doc:
        print('Ensemble number ',n,' does not have an evid set - skipped')
        n+=1
        continue
    print('calling load_one_ensmble for event number=',n)
    ens=load_one_ensemble(doc,apply_calib=True,
                  ensemble_mdkeys=['source_id','evid','starttime','endtime'])
    print('calling load_site_data')
    load_site_data(db,ens)
    print('calling_load_arrivals_by_id')
    nlive=load_arrivals_by_id(db,ens)
    print('Done - calling editor to cremate the dead')
    n+=1
    t0=time.time()
    d_cleaned=stedronsky.cremate(ens)
    t1=time.time()
    print('Time to handle dead data=',t1-t0)
    t0=time.time()
    twin=TimeWindow(-300.0,400.0)
    for i in range(len(d_cleaned.member)):
        d=TimeSeries(d_cleaned.member[i])
        t=d['arrival_time']
        d.ator(t)
        d=WindowData(d,twin)
        d_cleaned.member[i]=d
    t1=time.time()
    print('Time to window cleaned ensemble=',t1-t0)
    t0=time.time()
    signals.detrend(d_cleaned,'demean')
    t1=time.time()
    print('Time to apply detrend operator=',t1-t0)
    t0=time.time()
    load_channel_data(db,d_cleaned)
    t1=time.time()
    print('Time to build cross reference to channel=',t1-t0)
    t0=time.time()
    ens3c=bundle_seed_data(d_cleaned)
    t1=time.time()
    print('Time to run bundle algorithm=',t1-t0)
    print("Number of Seismograms after bundle_seed_data=",len(ens3c.member))
    #print_dead_logs(ens3c)
    erase_seed_metadata(d_cleaned)
    # This is a workaround for a bug that currently exists in
    # save_ensemble_data in handling history database
    # Should be able to eventually delete this
    for d in ens3c.member:
        d.clear_history()
    t0=time.time()
    db.save_ensemble_data(ens3c,'gridfs')
    t1=time.time()
    print("Time to save data to MongoDB=",t1-t0)
    del ens
    n+=1
